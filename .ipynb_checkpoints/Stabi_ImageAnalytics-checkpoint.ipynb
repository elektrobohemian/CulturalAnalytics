# %% [markdown]
# # Analysis of a Library Metadata Corpus and Data Enrichment
# ## Why to Read this Tutorial?
#
# * In this tutorial, you will learn to read metadata from an OAI-PMH data provider and how to convert the retrieved data from Dublin Core to a pandas data frame.
# * Furthermore, you will carry out some basic data analysis on your data in order to find out if the data is corrupt or unclean. Based on an example, you will clean some aspects of your data using techniques borrowed from machine learning.
# * Finally, you will visualize data with the help of a network graph.
#
# ![title](img/architecture.png)
#
# ### Preparations
# The following code snippet initializes your Python run-time enviroment in order to run all of the subsequent actions.
#
# If you installed everything correctly with the help of [Anaconda](https://www.continuum.io/downloads) as explained in [dst4l0.ipynb](dst4l0.ipynb), the following packages should be installed correctly and be importable without problems.
#
# The notebook assumes the presence of [ImageMagick](https://www.imagemagick.org) at the executing computer.

# %%
# !pip install geopy
# !pip install geojson
# !pip install sickle
# !pip install googlemaps
# Out:
# Requirement already satisfied: geopy in /anaconda3/lib/python3.6/site-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /anaconda3/lib/python3.6/site-packages (from geopy) (1.49)
# luigi 2.7.8 has requirement tornado<5,>=4.0, but you'll have tornado 5.1 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: geojson in /anaconda3/lib/python3.6/site-packages (2.4.0)
# luigi 2.7.8 has requirement tornado<5,>=4.0, but you'll have tornado 5.1 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: sickle in /anaconda3/lib/python3.6/site-packages (0.6.3)
# Requirement already satisfied: requests>=1.1.0 in /anaconda3/lib/python3.6/site-packages (from sickle) (2.19.1)
# Requirement already satisfied: lxml>=3.2.3 in /anaconda3/lib/python3.6/site-packages (from sickle) (4.2.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests>=1.1.0->sickle) (2018.8.24)
# Requirement already satisfied: idna<2.8,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests>=1.1.0->sickle) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests>=1.1.0->sickle) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests>=1.1.0->sickle) (1.23)
# luigi 2.7.8 has requirement tornado<5,>=4.0, but you'll have tornado 5.1 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: googlemaps in /anaconda3/lib/python3.6/site-packages (3.0.2)
# Requirement already satisfied: requests<3.0,>=2.11.1 in /anaconda3/lib/python3.6/site-packages (from googlemaps) (2.19.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps) (2018.8.24)
# Requirement already satisfied: idna<2.8,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps) (2.7)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests<3.0,>=2.11.1->googlemaps) (1.23)
# luigi 2.7.8 has requirement tornado<5,>=4.0, but you'll have tornado 5.1 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline

# See all the "as ..." contructs? They're just aliasing the package names.
# That way we can call methods like plt.plot() instead of matplotlib.pyplot.plot().
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

from bs4 import BeautifulSoup
from collections import OrderedDict # provides the ordered dictionary
import re # for regular expressions used below
import urllib # to read from URLs
import json
import networkx as nx # network analysis
from networkx.readwrite import json_graph
import itertools
import os.path
from datetime import datetime # for time measurement
import sys
import os
import pickle
import subprocess as subp
import gzip
import math
import codecs

from jellyfish import jaro_distance, jaro_winkler, hamming_distance, levenshtein_distance
import scipy.cluster.hierarchy as scipycluster
from sklearn.feature_extraction.text import TfidfVectorizer

from skimage import io, exposure
from scipy.spatial import distance
# import the k-means algorithm
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics import pairwise_distances_argmin,pairwise_distances_argmin_min, pairwise_distances
from sklearn.metrics.pairwise import euclidean_distances

# OAI
from sickle import Sickle

import googlemaps
from geopy.distance import vincenty
import geojson as gj

def printLog(text):
    now=str(datetime.now())
    print("["+now+"]\t"+text)
    # forces to output the result of the print command immediately, see: http://stackoverflow.com/questions/230751/how-to-flush-output-of-python-print
    sys.stdout.flush()
    
def pickleCompress(fileName,pickledObject):
    printLog("Pickling to '%s'" %fileName)
    f = gzip.open(fileName,'wb')
    pickle.dump(pickledObject,f)
    f.close()
    printLog("Pickling done.")
    
def pickleDecompress(fileName):
    #restore the object
    printLog("Depickling from '%s'" %fileName)
    f = gzip.open(fileName,'rb')
    pickledObject = pickle.load(f)
    f.close()
    printLog("Depickling done.")
    return pickledObject

if not os.path.exists("./graphs/"):
        os.makedirs("./graphs/")
if not os.path.exists("./graphs/generics/"):
        os.makedirs("./graphs/generics/")        
if not os.path.exists("./html/"):
        os.makedirs("./html/")
if not os.path.exists("./web/"):
        os.makedirs("./web/")
if not os.path.exists("./web/qa/"):
        os.makedirs("./web/qa/")
if not os.path.exists("./web/qa/data/"):
        os.makedirs("./web/qa/data/")
if not os.path.exists("./web/qa/data/ppn/"):
        os.makedirs("./web/qa/data/ppn/")
if not os.path.exists("./web/qa/data/layers/"):
        os.makedirs("./web/qa/data/layers/")

# %% [markdown]
# The only missing package is most likely Jellyfish, which provides support for string matching and offers such phonetic distance functions that we will need below. For further details, see the [Jellyfish homepage](https://pypi.python.org/pypi/jellyfish). The package can be installed by running the following command.

# %%
# !pip install jellyfish
# Out:
# Requirement already satisfied: jellyfish in /anaconda3/lib/python3.6/site-packages (0.6.1)
# luigi 2.7.8 has requirement tornado<5,>=4.0, but you'll have tornado 5.1 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ### Additional Configuration of This Notebook

# %%
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If you set 'allowDownloads' to True, all images will be downloaded and processed again
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
allowDownloads=False # should be True if you run this for the first time

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If you set 'demoClustering' to False, the clustering steps will take about 2 hours
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
demoClustering=False # should be False if you run this for the first time

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If you set 'allowComputationallyExtensiveCalculations' to True, various time consuming tasks (some of them running 
# several hours) will be carried out and not only loaded from pre-computed data files
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
allowComputationallyExtensiveCalculations=False # should be True if you run this for the first time

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# Enabling this action activates exact string matching againt name lists
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
allowExactStringMatching=True

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If you set to True, some plots will be saved as PDF documents in ./figures/
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
saveFiguresAsPDF=True

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If you set to True, Google Map API will be used to resolve location names, if False OpenStreetMap will be used
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *i
useGoogleMapsAPI=False

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If set to True, OpenStreetMap API will be used to fetch spatial names and alternative localized names, should be True at first run
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
getSpatialNamesFromOSM=False

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If set to True, details per PPN will be saved as separate JSON files in "jsonWebDir"
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
serializePPNLookup2JSON=False
jsonWebDir="/Users/david/Documents/src/python/CulturalAnalytics/web/qa/data/ppn/"

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If set to True, the raw features created by the Java application will be read from disk and converted for further usage, must be True at first run
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
reinterpretVisualWordRawFeatures=False

# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
#
# If set to True, a HTTP webserver will be started after all cells have been processed to show the results
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
launchHTTPServer=False

# %% [markdown]
# ## Retrieving Data
# ### Connecting to the OAI-conform Repository

# %%
# connect to a metadata repository
sickle = Sickle('http://digital.staatsbibliothek-berlin.de/oai')

# for debugging purposes you might want to uncomment the following commands
# get the sets from the data provider connected to
#sets = sickle.ListSets()
# print the returned sets including their identifiers
#print("Sets provided by data provider\n* * * * * * * * * * * * * * * * * * * * * ") # \n creates a new line
#for s in sets:
#    print("'"+s.setName+"' accessible via: '"+s.setSpec+"'")

# %%
# get the records from this repository's specific document set 'DC_krieg.1914.1918' (documents related to World War I) 
# using Dublin Core format 
records = sickle.ListRecords(metadataPrefix='oai_dc', set='DC_all')

# %% [markdown]
# ### Downloading Metadata Records
#
# * download records and save them locally to work with them later, saving is using the pickling mechanism of Python - its built-in object serialization
# * if you want to skip this step: decompress save_120k_dc_all.pickle.zip.

# %%
savedRecords=[]
if allowDownloads:
    printLog("Starting OAI record download...")
    # initialize some variables for counting and saving the metadata records
    savedDocs=0
    # 2:15 h for 100k
    maxDocs=120000 # 100 is just for testing, for more interesting results increase this value to 1000. ATTENTION! this will also take more time for reading data.

    # save the records locally as we don't want to have to rely on a connection to the OAI-PMH server all the time
    # iterate over all records until maxDocs is reached
    # ATTENTION! if you re-run this cell, the contents of the savedRecords array will be altered!
    for record in records:
        # check if we reach the maximum document value
        if savedDocs<maxDocs:
            savedDocs=savedDocs+1
            # save the current record to the "savedRecords" array
            savedRecords.append(record.metadata)
            if savedDocs%10000==0:
                printLog("Downloaded %d of %d records."%(savedDocs,maxDocs))
        # if so, end the processing of the for-loop
        else:
            break # break ends the processing of the loop

    printLog("Finished OAI download of "+str(len(savedRecords))+" records.")
    pickle.dump( savedRecords, open( "save_120k_dc_all.pickle", "wb" ) )

# %%
# uncomment this cell if you want to split the image download to two different computers
# in this case, one computer will use "even_dc_all.pickle" while the other will use "odd_dc_all.pickle" in the next cell

#availableKeys=dict()
#evenRecords=[]
#oddRecords=[]

#for i,r in enumerate(savedRecords):
#    for k in r.keys():
#        if not k in availableKeys:
#            availableKeys[k]=1
#        else:
#            availableKeys[k]=availableKeys[k]+1
#    if i%2==0:
#        evenRecords.append(r)
#    else:
#        oddRecords.append(r)

#pickle.dump( evenRecords, open( "even_dc_all.pickle", "wb" ) )
#pickle.dump( oddRecords, open( "odd_dc_all.pickle", "wb" ) )

# %% [markdown]
# * downloading images, downscaling, and conversion to JPEG

# %%
# uncomment this line if you are continuing the execution of this notebook at a later point in time
#savedRecords=pickle.load( open( "save_120k_dc_all.pickle", "rb" ) )
countSavedRecords=len(savedRecords)
printLog("Started image download and processing. This will take a while...")
#logFile = open("/Volumes/2TB_WD/sbb_images/downloadIssues.txt", "w")
logFile = open("./downloadIssues.txt", "w")

for i,record in enumerate(savedRecords):
    if i%1000==0:
        if allowDownloads:
            printLog("Downloading image %d of %d images."%(i,countSavedRecords))
    downloadDir="/Volumes/2TB_WD/sbb_images/tmp/"
    #downloadDir="./tmp/"
    ppn=""
    if len(record["identifier"])>1:
        ppn=str(record["identifier"][1])
    else:
        ppn=str(record["identifier"][0])
    ppnTIFF=ppn+".tif"
    ppnJPEGPAth=downloadDir+ppn+".jpg"
    if "object" in record.keys() and allowDownloads:
        # prevent downloading of already present files
        if not os.path.isfile(ppnJPEGPAth) :
            # check for the HTTP error code, maybe the file does not exist
            httpCode=urllib.urlopen(record["object"][0],downloadDir+ppnTIFF).getcode()
            if httpCode==200:
                #if allowDownloads:
                urlinfo=urllib.urlretrieve(record["object"][0],downloadDir+ppnTIFF)
                ret=subp.call(["mogrify", "-resize","512x512","-format", "jpg",downloadDir+ppnTIFF])
                if ret!=0:
                    print("Problem with mogrifying "+ppnTIFF)
                    logFile.write("[MOGRIFY]: %s \n%s\n\n" % (str("Problem with mogrifying "+ppnTIFF),str("Downloaded from: "+record["object"][0])))
                ret=subp.call(["rm",downloadDir+ppnTIFF])
                if ret!=0:
                    print("Problem with removing "+ppnTIFF)
                    logFile.write("[REMOVAL]: %s\n\n" % "Problem with removing "+ppnTIFF)
            else:
                print("Problem with accessing "+ppnTIFF+ " due to HTTP code: "+str(httpCode))
                logFile.write("[HTTP]: %s\n\n" % "Problem with accessing "+ppnTIFF)
                logFile.write("HTTP Code: "+str(httpCode)+"\n")
                logFile.write(str(urlinfo[1])+"\n\n")
    else:
        logFile.write("[OBJECT key missing]: %s\n\n" % str(record))
logFile.close()
print("\n")
if allowDownloads:
    printLog("Finished image download and processing.")
else:
    printLog("Skipped image download and processing.")
# Out:
# [2018-09-21 16:22:27.345790]	Started image download and processing. This will take a while...
#
#
# [2018-09-21 16:22:27.347648]	Skipped image download and processing.

# %% [markdown]
# In most cases, you will be able to download an image of the title page. However, the download will sometimes fail in case of periodical or multivolume works.

# %% [markdown]
# ### Creating a Dataframe from the Metadata Records
#
# For later processing, it is handy to save all data in a dataframe.
#
# The notebook will try to load the data from harddisk. For a working example just decompress save_120k_dc_all.pickle.zip.

# %%
# checks if a string is valid PPN
def isValidPPN(ppn):
    rePattern = "^PPN\d+[0-9X]?"
    p = re.compile(rePattern, re.IGNORECASE)
    if p.match(ppn):
        return True
    else:
        return False

# load the records
printLog("Loading pickled records...")
# uncomment this line if you are continuing the execution of this notebook at a later point in time
savedRecords=pickle.load( open( "save_120k_dc_all.pickle", "rb" ) )
printLog("Finished loading pickled records.")

availableKeys=dict()

# check for all keys present in the previously downloaded dataset
for i,r in enumerate(savedRecords):
    for k in r.keys():
        if not k in availableKeys:
            availableKeys[k]=1
        else:
            availableKeys[k]=availableKeys[k]+1
    
print(availableKeys)

# create a dictionary for the records
values=dict()
# take the keys as they have found within the downloaded OAI records
keys=availableKeys.keys()
# for every metadata field, create an empty array as the content of the dictionary filed under the key 'k'
for k in keys:
    values[k]=[]
# in addition, store the PPN (the SBB's unique identifier for digitized content)    
values["PPN"]=[]

# iterate over all saved records
for record in savedRecords:
    # we cannot iterate over the keys of record.metadata directly because not all records cotain the same fields,...
    for k in keys:
        # thus we check if the metadata field 'k' has been created above
        if k in values:
            # append the metadata fields to the dictionary created above
            # if the metadata field 'k' is not available input "None" instead
            #values[k].append(record.get(k,["None"])[0].encode('ISO-8859-1'))
            if k in record:
                value=record.get(k)[0]
                if value:
                    if value.isdigit():
                        value=int(value)
                    else:
                        #p27 value=value.encode('ISO-8859-1')
                        value=value.encode('ISO-8859-1').decode("utf-8", "backslashreplace")
                        pass
                
                values[k].append(value)
                # get the PPN
                if k=="identifier":
                    if len(record["identifier"])>1:
                        ppn=str(record.get(k)[1])
                        if not isValidPPN(ppn):
                            ppn=str(record.get(k)[0])
                    else:
                        ppn=str(record.get(k)[0])
                    values["PPN"].append(ppn)
            else:
                values[k].append(np.nan)
# create a data frame from the 
#p27 df=pd.DataFrame(pd.to_numeric(values,errors='coerce'))
df=pd.DataFrame(values)
df['date']=pd.to_numeric(df['date'],errors='ignore',downcast='integer')
#df=pd.DataFrame(values)
#df=df.convert_objects(convert_dates=False, convert_numeric=True, convert_timedeltas=False, copy=True)
df.shape
# Out:
# [2018-09-21 16:22:27.355682]	Loading pickled records...
# [2018-09-21 16:22:31.991215]	Finished loading pickled records.
# {'object': 102054, 'type': 120000, 'identifier': 120000, 'rights': 120000, 'title': 120000, 'format': 120000, 'source': 120000, 'provider': 120000, 'isShownAt': 119994, 'dataProvider': 120000, 'creator': 92532, 'subject': 120000, 'spatial': 98511, 'issued': 64751, 'date': 64751, 'alternative': 32089, 'publisher': 60862, 'relation': 27570, 'description': 9794}
# (120000, 20)

# %%
#df.to_csv("rawData.csv",sep=';',header=True, index=False, encoding='utf-8')
#df['PPN'].to_csv("ppnList.csv",sep=';',header=True, index=False, encoding='utf-8')
#printLog("Done.")

# %% [markdown]
# ### Inspecting Data

# %%
df.head()
# Out:
#                                               object        type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                             creator                   subject   spatial issued  date  \
# 0  http://digital.staatsbibliothek-berlin.de/euro...        Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Großer Kommentar über die Metaphysik des Arist...  image/jpeg  Averroes,: Großer Kommentar über die Metaphysi...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                           Averroes,  Hebräische Handschriften       NaN    NaN   NaN
# 1                                                NaN  Periodical  http://www.bibliothek.uni-regensburg.de/ezeit/...  Open Access            Allgemeines Polizei-Archiv für Preussen  image/jpeg  Allgemeines Polizei-Archiv für Preussen. Berli...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://www.bibliothek.uni-regensburg.de/ezeit/...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                 NaN        Rechtswissenschaft    Berlin    NaN   NaN
# 2  http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                             Der XLII. Psalm Davids  image/jpeg  Jordano, Alberto  Läger, Joachimus: Der XLII. ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  Jordano, Alberto  Läger, Joachimus            Einblattdrucke    [S.l.]   1650  1650
# 3  http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Der erlauchte Bauer oder Lebensgeschichte und ...  image/jpeg  Maubert de Gouvest, Jean Henri: Der erlauchte ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...      Maubert de Gouvest, Jean Henri        Historische Drucke    Berlin   1755  1755
# 4                                                NaN  Periodical  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                                        Der Wächter  image/jpeg  Der Wächter  Polizeiblatt für Mecklenburg. Sch...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                 NaN        Rechtswissenschaft  Schwerin    NaN   NaN
#
#                                          alternative         publisher relation description           PPN
# 0                                                NaN               NaN      NaN         NaN  PPN818409886
# 1                                                NaN               NaN      NaN         NaN  PPN743983386
# 2  Auff eine anmutige bekandte Melodey appliciret...               NaN      NaN         NaN  PPN839758545
# 3  Enthaltend verschiedene geheime Nachrichten vo...  Haude und Spener      NaN         NaN  PPN828810257
# 4                       Polizeiblatt für Mecklenburg               NaN      NaN         NaN  PPN743984099

# %%
df[df.PPN.isnull()].count()
# Out:
# object          0
# type            0
# identifier      0
# rights          0
# title           0
# format          0
# source          0
# provider        0
# isShownAt       0
# dataProvider    0
# creator         0
# subject         0
# spatial         0
# issued          0
# date            0
# alternative     0
# publisher       0
# relation        0
# description     0
# PPN             0
# dtype: int64

# %% [markdown]
# Typically, we know what columns should only contain unique values.. The next function checks our hypothesis on each column of the dataframe.

# %%
# checks for unique values in each column
def uniqueValues(currentDataFrame):
    colNames=currentDataFrame.columns.values.tolist()
    for colName in colNames:
        print(colName+";\t\t unique values:\t"+str(len(currentDataFrame[colName].unique()))+ "\t total count: "+str(currentDataFrame[colName].count()))

uniqueValues(df)
# Out:
# object;		 unique values:	102053	 total count: 102054
# type;		 unique values:	6	 total count: 120000
# identifier;		 unique values:	119938	 total count: 120000
# rights;		 unique values:	1	 total count: 120000
# title;		 unique values:	85471	 total count: 120000
# format;		 unique values:	1	 total count: 120000
# source;		 unique values:	101804	 total count: 120000
# provider;		 unique values:	1	 total count: 120000
# isShownAt;		 unique values:	119933	 total count: 119994
# dataProvider;		 unique values:	1	 total count: 120000
# creator;		 unique values:	44469	 total count: 92532
# subject;		 unique values:	44	 total count: 120000
# spatial;		 unique values:	8054	 total count: 98511
# issued;		 unique values:	571	 total count: 64751
# date;		 unique values:	571	 total count: 64751
# alternative;		 unique values:	29238	 total count: 32089
# publisher;		 unique values:	14755	 total count: 60862
# relation;		 unique values:	16791	 total count: 27570
# description;		 unique values:	9500	 total count: 9794
# PPN;		 unique values:	119956	 total count: 120000

# %% [markdown]
# ## Classification of Data with the Help of Regular Expressions
#
# From inspecting the dataframe, we have learned that, e.g., the date column does not contain number in the way we would expect them. Regular expression are a practical means to deal with pattern present in our data.

# %%
# zum matchen: p.match
# regular expressions taken from: http://stackoverflow.com/questions/1449817/what-are-some-of-the-most-useful-regular-expressions-for-programmers
# extended by David Zellhöfer

patterns=dict()
#^ beginning of string, $ end of string, \d digits +: once or more times
patterns["positiveInteger"]="^\d+$"
patterns["negativeInteger"]="^-\d+$"
patterns["generalInteger"]="^-?\d+$"
patterns["positiveFloat"]="^\d*\.\d+$"
patterns["negativeFloat"]="^-\d*\.\d+$"
patterns["generalFloat"]="^-?\d*\.\d+$"
patterns["positiveGermanFloat"]="^\d*,\d+$"
patterns["negativeGermanFloat"]="^-\d*,\d+$"
patterns["generalGermanFloat"]="^-?\d*,\d+$"
# Date (dd mm yyyy, d/m/yyyy, etc.), in range 1000-2099 without proper February handling
patterns["dateVariant"]="^([1-9]|0[1-9]|[12][0-9]|3[01])\D([1-9]|0[1-9]|1[012])\D(1[0-9][0-9][0-9]|20[0-9][0-9])$"
patterns["year"]="^(1[0-9][0-9][0-9]|20[0-9][0-9])$"
patterns["ancientYear"]="^([0-1]?[0-9][0-9][0-9]|20[0-9][0-9])$"
patterns["century"]="^(1[0-9][Xx][Xx]|20[Xx][Xx])$"
patterns["ancientCentury"]="^([0-1]?[0-9][Xx][Xx]|20[Xx][Xx])$"
patterns["decade"]="^(1[0-9][0-9][Xx]|20[0-9][Xx])$"
patterns["ancientDecade"]="^([0-1]?[0-9][0-9][Xx]|20[0-9][Xx])$"
# year range with splitter "- / :", the splitter can be surrounded by an arbitrary amount of whitespaces (\s)
patterns["rangeYear"]="^\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*$"
patterns["rangeCentury"]="^\s*(1[0-9][Xx][Xx]|20[Xx][Xx])\s*(\-|\/|:)\s*(1[0-9][Xx][Xx]|20[Xx][Xx])\s*$"
patterns["rangeAncientYear"]="^\s*([0-1]?[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*$"
patterns["rangeAncientCentury"]="^\s*([0-1]?[0-9][Xx][Xx]|20[Xx][Xx])\s*(\-|\/|:)\s*(1[0-9][Xx][Xx]|20[Xx][Xx])\s*$"
patterns["rangeYear2Digit"]="^\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*([0-9][0-9])\s*$"
patterns["rangeDateVariant"]="^\s*([1-9]|0[1-9]|[12][0-9]|3[01])\D([1-9]|0[1-9]|1[012])\D(1[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*([1-9]|0[1-9]|[12][0-9]|3[01])\D([1-9]|0[1-9]|1[012])\D(1[0-9][0-9][0-9]|20[0-9][0-9])\s*$"

patterns["email"]="^[_]*([a-z0-9]+(\.|_*)?)+@([a-z][a-z0-9-]+(\.|-*\.))+[a-z]{2,6}$"
patterns["domain"]="^([a-z][a-z0-9-]+(\.|-*\.))+[a-z]{2,6}$"
patterns["url"]="^https?\:\/\/[a-zA-Z0-9.-]+\.[a-zA-Z]{2,3}\/?$"
patterns["ipv4"]="^(?:\d{1,3}\.){3}\d{1,3}$"
patterns["rgbHex"]="^#([a-fA-F0-9]{6}|[a-fA-F0-9]{3})$"
patterns["generalHex"]="^#[a-fA-F0-9]*$"
 
patterns["isbnPrefix"]="^ISBN(-1(?:(0)|3))?:?\x20(\s)*[0-9]+[- ][0-9]+[- ][0-9]+[- ][0-9]*[- ]*[xX0-9]$"
patterns["isbn"]="^[0-9]+[- ][0-9]+[- ][0-9]+[- ][0-9]*[- ]*[xX0-9]$"
patterns["NaN"]="^[Nn][Aa][Nn]$"

# %% [markdown]
# * match patterns and output statistics regarding the matched patterns

# %%
rowCount=0
histogram=dict()
for row in df.iterrows():
    rowCount=rowCount+1
    readDate=str(row[1]["date"])
    matchedOnce=False
    if not readDate=="None":
        for key in patterns:
            p=re.compile(patterns[key])
            m = p.search(readDate)
            if m:
                if not key in histogram:
                    histogram[key]=0
                histogram[key]=histogram[key]+1
                matchedOnce=True
            else:
                pass
        if not matchedOnce:
            print("No matches at all: "+row[1]["PPN"]+"\t for: "+str(readDate))
print("Row count: "+str(rowCount))
print(histogram)
# Out:
# No matches at all: PPN3303600473	 for: 16XX-1867
# No matches at all: PPN670389129	 for: 1756 $ [ca. 1756]
# No matches at all: PPN670201561	 for: 1739 $ [ca. 1739]
# No matches at all: PPN666097402	 for: um 1100
# Row count: 120000
# {'NaN': 55249, 'positiveInteger': 64126, 'generalInteger': 64126, 'year': 64125, 'ancientYear': 64126, 'rangeYear': 4, 'rangeAncientYear': 4, 'century': 577, 'ancientCentury': 582, 'decade': 30, 'ancientDecade': 30, 'rangeYear2Digit': 2, 'rangeCentury': 3, 'rangeAncientCentury': 3}

# %% [markdown]
# ### Cleaning Complex Data - Spatial Information
# In the next step, we will take a closer look on the locations associated with each metadata record.

# %%
df.spatial.head(30)
# Out:
# 0                                  NaN
# 1                               Berlin
# 2                               [S.l.]
# 3                               Berlin
# 4                             Schwerin
# 5                              Hamburg
# 6                              Hamburg
# 7                              Leipzig
# 8                              Hamburg
# 9                              Hamburg
# 10                                 NaN
# 11                             Hamburg
# 12                                 NaN
# 13                                 NaN
# 14                            Bayreuth
# 15                                 NaN
# 16                                 NaN
# 17                             Breslau
# 18                                 NaN
# 19                              Berlin
# 20                                 NaN
# 21                             Hamburg
# 22    Leipzig  Franckfurth  [Nürnberg]
# 23                             Hamburg
# 24                                 NaN
# 25                             Hamburg
# 26                           Straßburg
# 27                                Prag
# 28                 Leipzig  Franckfurt
# 29                                 NaN
# Name: spatial, dtype: object

# %% [markdown]
# Obviously, the spatial column does not only contain city names. Sometimes, there is more than one city present or brackets are used.  There are even abbreviation such as s.l. (sine loco) indicating an unknown place or u.a. (amongst others). Question marks indicate that the cataloguing librarian could not determine the location with an accuracy of 100%.
#
# In the next step, we will try to handle these irregularities in combination with the date column.

# %%
class DataCleaner:
    # matches alphanumeric character and the underscore at the beginning of the string
    #Unicode flag is needed because of Asian character sets otherwise such signs would be considered as non-alphanumeric
    regEx_AlphaNum=re.compile("^\w",re.UNICODE)
    # checks for surrounding []; will match almost everything but Asian characters
    regEx_BracketText=re.compile("^\[[\w\?\.,\sßÄäÖöÜü]*\]",re.UNICODE)
    # checks for typical spellings of the "sine loco" abbreviation "s. l."
    regEx_SineLoco=re.compile("[sSoO]\s?\.\s?[lLoO]\s?\.?\s?",re.UNICODE)
    
    def __init__(self):
        pass
    
    def cleanAncientYearStrict(self,readData):
        if type(readData)==float:
            return readDate
        else:
            p=re.compile(patterns["ancientYear"])
            m = p.search(str(readData))
            if m:
                firstAppearance=m.group()
                return firstAppearance
            else:
                return np.nan
            
    def cleanSpatialText(self,readData):
        returnedString=""
        # just in case we did not get a string, we use brute force and return NaN
        if type(readData)==float:
            return ""
        else:
            #readData=str(readData)
            m = self.regEx_AlphaNum.search(readData)
            # if the string does start with a bracket...
            if not m:
                #print "No matches at all: "+row[1]["PPN"]+"\t for: "+str(readData)
                m2 = self.regEx_BracketText.search(readData)
                if m2:
                    matchedGroup=m2.group()
                    #print "\tMatch: "+matchedGroup
                    m3=self.regEx_SineLoco.search(matchedGroup)
                    if m3:
                        #print "\tMatched Sine Loco: "+str(m3.group())
                        return ""
                    else:
                        matchedGroup=matchedGroup.replace("[","").replace("]","")
                        #print "\tFinal string: "+matchedGroup
                        returnedString=matchedGroup
            # otherwise, it may still be a "sine loco"
            else:
                m3=self.regEx_SineLoco.search(readData)
                if m3:
                    #print "\tMatched Sine Loco: "+str(m3.group())
                    return ""
                else:
                    # in any case, there might be brackets left
                    returnedString=readData.replace("[","").replace("]","")
        
        # remove variants of "u.a."            
        regex = re.compile("[uU]\.\s?[aA]\.\s?",re.UNICODE)
        returnedString=regex.sub("",returnedString)
        return returnedString

# %%
dc=DataCleaner()

# clean the columns and save the results to a newly created column
    
df['spatialClean'] = df.spatial.apply(dc.cleanSpatialText)
df['dateClean'] = df.date.apply(dc.cleanAncientYearStrict)

uniqueValues(df)
# Out:
# object;		 unique values:	102053	 total count: 102054
# type;		 unique values:	6	 total count: 120000
# identifier;		 unique values:	119938	 total count: 120000
# rights;		 unique values:	1	 total count: 120000
# title;		 unique values:	85471	 total count: 120000
# format;		 unique values:	1	 total count: 120000
# source;		 unique values:	101804	 total count: 120000
# provider;		 unique values:	1	 total count: 120000
# isShownAt;		 unique values:	119933	 total count: 119994
# dataProvider;		 unique values:	1	 total count: 120000
# creator;		 unique values:	44469	 total count: 92532
# subject;		 unique values:	44	 total count: 120000
# spatial;		 unique values:	8054	 total count: 98511
# issued;		 unique values:	571	 total count: 64751
# date;		 unique values:	571	 total count: 64751
# alternative;		 unique values:	29238	 total count: 32089
# publisher;		 unique values:	14755	 total count: 60862
# relation;		 unique values:	16791	 total count: 27570
# description;		 unique values:	9500	 total count: 9794
# PPN;		 unique values:	119956	 total count: 120000
# spatialClean;		 unique values:	7283	 total count: 120000
# dateClean;		 unique values:	535	 total count: 119375

# %%
df.head(30)
# Out:
#                                                object        type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                                            creator                   subject  \
# 0   http://digital.staatsbibliothek-berlin.de/euro...        Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Großer Kommentar über die Metaphysik des Arist...  image/jpeg  Averroes,: Großer Kommentar über die Metaphysi...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                          Averroes,  Hebräische Handschriften
# 1                                                 NaN  Periodical  http://www.bibliothek.uni-regensburg.de/ezeit/...  Open Access            Allgemeines Polizei-Archiv für Preussen  image/jpeg  Allgemeines Polizei-Archiv für Preussen. Berli...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://www.bibliothek.uni-regensburg.de/ezeit/...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                                NaN        Rechtswissenschaft
# 2   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                             Der XLII. Psalm Davids  image/jpeg  Jordano, Alberto  Läger, Joachimus: Der XLII. ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                 Jordano, Alberto  Läger, Joachimus            Einblattdrucke
# 3   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Der erlauchte Bauer oder Lebensgeschichte und ...  image/jpeg  Maubert de Gouvest, Jean Henri: Der erlauchte ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                     Maubert de Gouvest, Jean Henri        Historische Drucke
# 4                                                 NaN  Periodical  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                                        Der Wächter  image/jpeg  Der Wächter  Polizeiblatt für Mecklenburg. Sch...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                                NaN        Rechtswissenschaft
# 5   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Scheid-Gedicht/ über Den Bitter-Süssen Abzuge ...  image/jpeg  Wolcken, Johann  Meier, Johannes: Scheid-Gedic...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                   Wolcken, Johann  Meier, Johannes        Historische Drucke
# 6   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Hochzeitliches Ehren-Gedicht Auff das Ehliche ...  image/jpeg  Lithoecaeus, Georgius  Röver, Johann  Overbeck...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  
               NaN    NaN   NaN                                                NaN                NaN                                                NaN         NaN  PPN841192952                                      1738
# 16                               NaN    NaN   NaN                                                NaN                NaN                                                NaN         NaN  PPN841209405                                      1738
# 17                           Breslau    NaN   NaN                                                NaN           Aderholz                                                NaN         NaN  PPN743985346                         Breslau      1738
# 18                               NaN    NaN   NaN                                                NaN                NaN                                                NaN         NaN  PPN843925329                                      1738
# 19                            Berlin    NaN   NaN                                                NaN                NaN                                                NaN         NaN  PPN743982053                          Berlin      1738
# 20                               NaN    NaN   NaN                                                NaN                NaN                                                NaN         NaN  PPN841196281                                      1738
# 21                           Hamburg   1768  1768                                                NaN           Piscator                                                NaN         NaN  PPN841240264                         Hamburg      1768
# 22  Leipzig  Franckfurth  [Nürnberg]   1732  1732                                                NaN             Monath  Faramond, Ludwig Ernst: Ludwig Ernst von Faram...         NaN  PPN836134109  Leipzig  Franckfurth  Nürnberg      1732
# 23                           Hamburg   1640  1640                                                NaN   Rebenlein, Jacob                                                NaN         NaN  PPN839759274                         Hamburg      1640
# 24                               NaN    NaN   NaN                                                NaN                NaN                                                NaN         NaN  PPN845005537                                      1738
# 25                           Hamburg   1640  1640  Welche ihren Ehren-Tag halten den 14. Septemb....   Rebenlein, Jacob                                                NaN         NaN  PPN83980041X                         Hamburg      1640
# 26                         Straßburg   1582  1582                                                NaN    Jobin, Bernhard                                                NaN         NaN  PPN820575046                       Straßburg      1582
# 27                              Prag   1885  1885                                                NaN            Urbánek                                                NaN         NaN  PPN842138994                            Prag      1885
# 28               Leipzig  Franckfurt   1733  1733                                      Eigenschaften                NaN                                                NaN         NaN  PPN836042700             Leipzig  Franckfurt      1733
# 29                               NaN    NaN   NaN                                                NaN                NaN                                                NaN         NaN  PPN841194823                                      1738

# %% [markdown]
# ## Using Clustering for Further Data Cleansing
#
# If we further inspect the spatial column, we discover that there are many spelling variants of cities as well as Latin forms etc.
# To deal with this issue, we could simply try to match our findings against known places that are provided as lists at various places, e.g.:
#
# * https://www.maxmind.com/en/free-world-cities-database
# * http://www.geonames.org/export/
# * http://www.opengeocode.org/download.php#cities
# * https://en.wikipedia.org/wiki/Lists_of_cities_by_country
#
# However, for learning purposes, we will try to deal with this challenge by using [clustering](https://en.wikipedia.org/wiki/Cluster_analysis).
#
# Consider the example below. Given four city names, respectively spelling variants, we want to find out which ones are the most similar.

# %%
words = u'Berlin Balin Cölln Köln'.split()
print(words)

print("Number of words: %i" % len(words))
for i,val in enumerate(words):
    print(str(i)+":\t "+str(val.encode('utf-8')))
# Out:
# ['Berlin', 'Balin', 'Cölln', 'Köln']
# Number of words: 4
# 0:	 b'Berlin'
# 1:	 b'Balin'
# 2:	 b'C\xc3\xb6lln'
# 3:	 b'K\xc3\xb6ln'

# %% [markdown]
# One way to do this is to use the __jaro\_distance()__ provided by the Jellyfish pacakge (see above).
# Unfortunately, the name of the function is quite misleading as it technically computes a similarity as illustrated below. A distance between two equal strings would be 0...

# %%
jaro_distance(u'Berlin',u'Berlin')
# Out:
# 1.0

# %% [markdown]
# In order to determine the dissimilarity between each city name, we compute a so-called distance matrix. A square matrix whose diagonal is 0 as the distance between the same city name is 0 for obvious reasons. Each column and row of the matrix corresponds to a name pair. For instance, the first column stands for Berlin, the third row for Cölln.

# %%
# http://docs.scipy.org/doc/numpy-1.10.1/reference/generated/numpy.triu_indices.html
# 2nd parameter:
# Diagonal above which to zero elements. k = 0 (the default) is the main diagonal, k < 0 is below it and k > 0 is above."""
# r= Return the indices for the upper-triangle of an (n, m) array. da m nicht angegeben ist, wird n=m angenommen
# m is not passed, hence m=n

# create a square matrix
r=np.triu_indices(n=len(words), k=1)
r
# Out:
# (array([0, 0, 0, 1, 1, 2]), array([1, 2, 3, 2, 3, 3]))

# %% [markdown]
# Our distance matrix is structured as follows:
# $$
# A=
# \begin{pmatrix}
# a_{0,0} & \underline{a_{0,1}} & \underline{a_{0,2}} & \underline{a_{0,3}} \\
# \cdot & a_{1,1} & \underline{a_{1,2}} & \underline{a_{1,3}} \\
# \cdot & \cdot & a_{2,2} & \underline{a_{2,3}} \\
# \cdot & \cdot & \cdot & a_{3,3}
# \end{pmatrix}
# $$
#
# To give an example, $a_{0,1}$ yields the difference between "Berlin" and "Balin".

# %%
def d_demo(coord):
    print(coord)
    i, j = coord
    # 1-distance is needed as the function yields a similarity (see above)
    return 1-jaro_distance(words[i], words[j])

# %%
# http://docs.scipy.org/doc/numpy-1.10.1/reference/generated/numpy.set_printoptions.html
np.set_printoptions(precision=4)

# axis (3rd parameter): 0= along y axis, 1= along x axis
r2=np.apply_along_axis(d_demo, 0, r)
r2
# Out:
# [0 1]
# [0 2]
# [0 3]
# [1 2]
# [1 3]
# [2 3]
# array([0.1778, 0.4222, 0.3889, 0.4   , 0.3667, 0.2167])

# %% [markdown]
# If we map the resulting array back to a matrix, we obtain:
# $$
# A=
# \begin{pmatrix}
# a_{0,0} & \underline{0.1778} & \underline{0.4222} & \underline{0.3889} \\
# \cdot & a_{1,1} & \underline{0.4} & \underline{0.3667} \\
# \cdot & \cdot & a_{2,2} & \underline{0.2167} \\
# \cdot & \cdot & \cdot & a_{3,3}
# \end{pmatrix}
# $$
#
# That is, $a_{0,1}$, the difference between "Berlin" and "Balin", is 0.17777778. In other words, the strings are fairly similar (there is a low distance between them).

# %% [markdown]
# ### Working with Real Data
#
# First, we have to define the distance function to build our distance matrix.

# %%
def d(coord):
    #print(coord)
    i, j = coord
    #py27 return 1-jaro_distance(unicode(str(words[i]), 'utf-8'), unicode(str(words[j]), 'utf-8'))
    return 1-jaro_distance(words[i],words[j])

# %%
df3=df#pd27 .sort_values(by="date")#.head(100)

uniqueSpatials=df3["spatialClean"].unique()
words=None
if demoClustering:
    words=uniqueSpatials[:100] # only consider the first 100 elements for performance reasons
    printLog("Running demo clustering.")
else: # during normal operation, we want to consider all unique spatial names...
    words=uniqueSpatials
r=np.triu_indices(len(words), 1)

# %% [markdown]
# the next step will take some time as the distance matrix gets fairly large.

# %%
printLog("Started calculation of distance matrix for %i words..."%len(words))
# _ is the last evaluated value in an interactive shell
# axis (3rd parameter): 0= along y axis, 1= along x axis
r2=np.apply_along_axis(d, 0, r)
printLog("Finished calculations.")
# Out:
# [2018-09-21 16:22:46.159006]	Started calculation of distance matrix for 7283 words...
# [2018-09-21 16:24:36.542434]	Finished calculations.

# %% [markdown]
# First, we give agglomerative/hierarchical clustering a try. For details, see https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.cluster.hierarchy.linkage.html .

# %%
Z=scipycluster.linkage(r2)
if not demoClustering:
    pickle.dump( Z, open( "cluster_hierarchy_linkage_result_without_name_clustering.pickle", "wb" ) )

# %% [markdown]
# A 4 by (n-1) matrix Z is returned. At the i-th iteration, clusters with indices Z[i, 0] and Z[i, 1] are combined to form cluster n + i. A cluster with an index less than n corresponds to one of the n original observations. The distance between clusters Z[i, 0] and Z[i, 1] is given by Z[i, 2]. The fourth value Z[i, 3] represents the number of original observations in the newly formed cluster.
#
# The result of the clustering algorithm can serve as input for a dendrogram plot, e.g., as described by
# https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/.

# %%
#Z=pickle.load( open( "cluster_hierarchy_linkage_result.pickle", "rb" ) )
# for performance reasons, we will only plot a dendrogram for demo clusterings
if demoClustering:
    plt.figure(figsize=(25, 10))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('sample index')
    plt.ylabel('distance')
    scipycluster.dendrogram(
        Z,
        leaf_rotation=90.,  # rotates the x axis labels
        leaf_font_size=16.,  # font size for the x axis labels
    )
    plt.show()

# %% [markdown]
# To use the clusters in our dataframe, we have to flatten the hierarchical clusters first.

# %%
clusters=scipycluster.fcluster(Z, t=0.1,criterion="distance")
# 2. parameter ist abhängig von der clustering strategie, -> cophenetic distance
# see: http://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.fcluster.html
# An array of length n. T[i] is the flat cluster number to which original observation i belongs.


# https://stat.ethz.ch/R-manual/R-devel/library/stats/html/cophenetic.html
# https://en.wikipedia.org/wiki/Cophenetic
# wir erhalten für jedes unser elemente eine cluster ID
clusters
# Out:
# array([5356, 3314, 2474, ..., 3969, 2258, 2127], dtype=int32)

# %% [markdown]
# The next service functions help to establish a linkage between the cluster IDs and human readable names.

# %%
def getWordIndex(word):
    return np.where(words==word)[0]

def getClusterID(data):
#for row in df3.iterrows():
    #data=row[1]["spatialClean"]
    #wordIndex=np.where(words==data)[0]
    #if data == u"奈良".encode('utf-8'):
    #    print "China!"
    #    wordIndex=getWordIndex(data)
    #    print wordIndex
    #    print clusters[wordIndex][0]
    wordIndex=getWordIndex(data)
    if wordIndex:
        return clusters[wordIndex][0]
    else:
        return ""

# %% [markdown]
# ### Inspecting the Clustered Results Deeper

# %%
#
Z_huge=pickle.load( open( "cluster_hierarchy_linkage_result_without_name_clustering.pickle", "rb" ) )
uniqueSpatials=df3["spatialClean"].unique()
words=uniqueSpatials
len(words)
# Out:
# 7283

# %%
clusters=scipycluster.fcluster(Z_huge, t=0.07,criterion="distance")
clusters
# Out:
# array([5974, 3929, 2778, ..., 4587, 2521, 2347], dtype=int32)

# %% [markdown]
# Next, we take the cluster IDs and link them to the spatial clean columns in order to reveal similar spatial names.

# %%
df3['spatialCluster'] = df3["spatialClean"].apply(getClusterID)
grp=df3.groupby("spatialCluster")
#print grp.groups.keys()
print("Number of clusters: %i" % len(grp.groups.keys()))
# Out:
# Number of clusters: 5984

# %% [markdown]
# By using our service function from above as a selector we can inspect all results that are in the same cluster as "Berlin". For instance, you will find "Berlin?" or "Berolini" there as well as these terms are more similar to "Berlin" than to other terms in the corpus.

# %%
grp.get_group(clusters[getWordIndex("Berlin")][0])
# Out:
#                                                    object              type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                                            creator               subject   spatial issued  \
# 1                                                     NaN        Periodical  http://www.bibliothek.uni-regensburg.de/ezeit/...  Open
#        'Frankfurt a. Oder', 'Frankfurt, M', 'Frankfurt a. d. Oder',
#        'Frankfurt a.  M.', 'Frankfurt ', 'Frankfurt a./O.',
#        'Frankfurt, M.', 'Frankfurt a/Oder', 'Frankfurt a/m',
#        'Frankfurt/ M.', 'Frankfurt /M.', 'Frankfurt /Main',
#        'Frankfurt a/M', 'Frankfurt a/O ', 'Frankfurt / M',
#        'Frankfurt a. M. ', 'Frankfurt A/M', 'Frankfurt <Main>;',
#        'Frankfurt a./Oder', 'Frankfurth', 'Frankfurt Main',
#        'Frankfurt a/M.', 'Franckfurt, Oder', 'Frankfurt (Main)',
#        'Frankfurt (Oder)', 'Frankfurt a.O.', 'Frankfurth a. d. O.',
#        'Franckfurt a.O.', 'Frankfurt a/O.', 'Franckfurt, Main',
#        'Frankfurt a./M.', 'Frankfurt a. d. O.', 'Franckfurt a.M.',
#        'Frankfurta a.M.'], dtype=object)

# %% [markdown]
# This cluster perfectly illustrates a limitation of the clustering algorithm: it only works on the strings and neglects further semantics. The cities "Frankfurt am Main" and "Frankfurt am Oder" are very similar string-wise but different locations.

# %%
# inspect all clusters
for key in grp.groups.keys():
    if key:
        print(key)
        print(grp.get_group(key)["spatialClean"].unique())
# Out:
# 1
# ['高崎']
# 2
# ['長崎']
# 3
# ['長岡']
# 4
# ['高田山専修寺']
# 5
# ['成田']
# 6
# ['羊城']
# 7
# ['羊城 (=廣東)']
# 8
# ['紹義堂 藏版']
# 9
# ['玉勾草堂 藏版']
# 10
# ['振賢堂梓行' '振賢堂 梓行']
# 11
# ['本堂藏板']
# 12
# ['本衙藏板']
# 13
# ['文畲堂 藏板']
# 14
# ['貴文堂 藏板']
# 15
# ['文畬堂藏板']
# 16
# ['廣慶堂 藏板']
# 17
# ['春暉堂 藏板']
# 18
# ['來鹿堂 藏板']
# 19
# ['振賢堂 藏板']
# 20
# ['培德堂 梓行']
# 21
# ['敬書堂 梓行']
# 22
# ['本衙藏板  實擭齋 藏板 (第二套)']
# 23
# ['近譬堂 梓']
# 24
# ['元新堂藏板  萃文堂梓行']
# 25
# ['吳門種書堂梓']
# 26
# ['積秀堂 藏板  德壽堂 梓']
# 27
# ['灌文書社 印行']
# 28
# ['玉堂  日章堂']
# 29
# ['石渠閣藏板']
# 30
# ['廣東']
# 31
# ['廣東嘉應州']
# 32
# ['廣州']
# 33
# ['廣州  廣東佛鎮']
# 34
# ['??']
# 35
# ['B???']
# 36
# ['S?']
# 37
# ['BeVI, 261 S.']
# 38
# ['VIII, 35 S.']
# 39
# ['HXIV, 303 S., 1 Bl.']
# 40
# ['VI, 107 S, 1 Taf.  Berlin']
# 41
# ['武昌']
# 42
# ['武昌  wu chang']
# 43
# ['o.0.']
# 44
# ['o.D.']
# 45
# ['o.D. Via Calessano 21']
# 46
# ['oO.']
# 47
# ['S.I.']
# 48
# ['s.n.']
# 49
# ['Snowdonia-Nationalpark Pen-y-Pass']
# 50
# ['Snowdonia-Nationalpark Cyfyng Falls']
# 51
# ['南海伍氏粵雅堂  nan hai wu shi yue ya tang']
# 52
# ['南海']
# 53
# ['2']
# 54
# ['S. 201 -351']
# 55
# ['Būlāg']
# 56
# ['Būlāq']
# 57
# ['San Domenico near Florenz, Villa Fontanella']
# 58
# ['San Domenico ermittelt near Florenz, Villa Fontanella']
# 59
# ['Br117 S.']
# 60
# ['Elb175 S.']
# 61
# ['Nevers <Nièvre, Kriegsgefangenenlager>  Druckort- Paris']
# 62
# ['Villenave <Gironde, Kriegsgefangenenlager>  Druckort- Paris']
# 63
# ['Montargis <Kriegsgefangenenlager>  Druckort- Paris']
# 64
# ['St-Aubin-Epinay <Kriegsgefangenenlager>  Druckort- Paris']
# 65
# ['Castelluccio <Korsika, Kriegsgefangenenlager>  Druckort- Paris']
# 66
# ['和歌山  紀藩 和歌山']
# 67
# ['和歌山']
# 68
# ['Šīrāz']
# 69
# ['Širāz']
# 70
# ['Djakarta']
# 71
# ['Jogjakarta']
# 72
# ['Quito']
# 73
# ['Juist']
# 74
# ['Villars s/Ollon Hotel Palace']
# 75
# ['Villars s/Ollon Villars Palace']
# 76
# ['Villars sur Ollon Hotel Bellvue']
# 77
# ['Villars-sur-Ollon Grand Hotel']
# 78
# ['Pont de Roide']
# 79
# ['In Monte Regio']
# 80
# ['Ithaca']
# 81
# ['Ithaca N.Y.']
# 82
# ['Alḳôsh']
# 83
# ['Alkosh']
# 84
# ['Knockaloe']
# 85
# ['Knockaloe Camp']
# 86
# ['Knockaloe, Isle of Man']
# 87
# ['Shanklin Isle of Wight']
# 88
# ['Isle of Wight']
# 89
# ['Gröwohld/Trittau' 'Grönwohld/Trittau']
# 90
# ['Le Mesnil-le-Roi ermittelt']
# 91
# ['Le Mesnil-le-Roi']
# 92
# ['Moosach bei Grafing Jagdhaus Nieder-Seeon']
# 93
# ['Moosbach Jagdhaus Nieder-Seeon']
# 94
# ['Moosach b. Grafing']
# 95
# ['Guelpherbyti' 'Gvelpherbyti']
# 96
# ['Guelferbyti']
# 97
# ['St. Austell ermittelt Carlyon Bay Hotel']
# 98
# ['St. Austell Carlyon Bay Hotel']
# 99
# ['Ruurlo']
# 100
# ['Ruhrort']
# 101
# ['Kaibitz Schloss Kaibitz bei Kemnath']
# 102
# ['Kaibitz bei Kemnath']
# 103
# ['Neon-Phaliron' 'Neon-Phalirou']
# 104
# ['Tarnowitz Oberschlesien - Schloss Neudeck Kreis Tarnowitz'
#  'Tarnowitz Oberschlesien - Schloss Neudeck, Kreis Tarnowitz']
# 105
# ['Temesvár']
# 106
# ['Temeswar']
# 107
# ['北京']
# 108
# ['北京  北京']
# 109
# ['Kolozsvártt' 'Kolozsvár']
# 110
# ['Sanremo Pension Aurora']
# 111
# ['San Remo Pension Aurora']
# 112
# ['Saint-Marcellin <Isère>']
# 113
# ['Saint-Martin (Eure)']
# 114
# ['伊勢']
# 115
# ['伊勢国津']
# 116
# ['伊州 伊勢  京都']
# 117
# ['伊勢  京都']
# 118
# ['京都  尾州 名古屋']
# 119
# ['京都  薩州']
# 120
# ['名古屋  京都' '名古屋 ; 京都']
# 121
# ['名古屋  江戸' '名古屋 ; 江戸']
# 122
# ['名古屋, 江戸']
# 123
# ['名古屋  江戸  尾陽 名古屋']
# 124
# ['名古屋  大阪']
# 125
# ['名古屋']
# 126
# ['江戸  大阪' '江戸 ; 大阪']
# 127
# ['江戸  大坂']
# 128
# ['江戸  浪花 大坂']
# 129
# ['浪華 大阪  江戸']
# 130
# ['浪華 大阪  東都 江戸']
# 131
# ['浪華 大阪']
# 132
# ['大阪  江戸  和歌山']
# 133
# ['大阪  和歌山']
# 134
# ['江戸  蔵板']
# 135
# ['江戸  蔵版']
# 136
# ['江戸  京都' '江戸 ; 京都']
# 137
# ['江戸  東京' '江戸 東京']
# 138
# ['京都  江戸  蔵版' '江戸  京都  蔵版']
# 139
# ['京都  江戸' '京都 ; 江戸']
# 140
# ['大阪  京都' '大阪 ; 京都']
# 141
# ['大阪  東京']
# 142
# ['京都  大坂  江戸' '大坂  京都  江戸']
# 143
# ['大阪  江戸' '大阪 ; 江戸']
# 144
# ['大坂  江戸']
# 145
# ['大阪  江戸  京都']
# 146
# ['大阪  江戸  蔵版']
# 147
# ['江戸  江戸  京都']
# 148
# ['大阪  京都  江戸  名古屋']
# 149
# ['浪華 大阪  皇都 京都']
# 150
# ['東都 江戸']
# 151
# ['江戸  和歌山']
# 152
# ['江戸']
# 153
# ['大坂  京師 京都']
# 154
# ['京都  大阪']
# 155
# ['東京  蔵版']
# 156
# ['京都']
# 157
# ['京都  伊勢']
# 158
# ['大阪']
# 159
# ['東京']
# 160
# ['大坂']
# 161
# ['大阪  仙臺']
# 162
# ['水戸  江戸']
# 163
# ['松本  京都']
# 164
# ['大坂  名古屋  江戸  尾張 名古屋']
# 165
# ['京都  英華堂']
# 166
# ['東京  Tôkyô']
# 167
# ['B.']
# 168
# ['B. Leipa ']
# 169
# ['Cap-d\x92Ail Eden-Hotel' 'Cap-d\x92Ail Eden - Hotel']
# 170
# ['Kurume']
# 171
# ['Kurume (Japan)']
# 172
# ['Landeck i. Schl. Villa Thalheim']
# 173
# ['Bad Landeck i. Schl. Villa Thalheim']
# 174
# ['Landeck i/Schl.']
# 175
# ['Randeck Schlesien (?)']
# 176
# ['Regio-Borussorum-Monti' 'In Regio-Borussorum-Monte']
# 177
# ['Karalauczuje' 'Karalauczuie']
# 178
# ['Karaliaucziuie Prusuu']
# 179
# ['Pössneck i. Th.']
# 180
# ['Pößneck']
# 181
# ['Noordwijk-Batavia']
# 182
# ['Noordwijk']
# 183
# ['Noordwijk Kurhaus']
# 184
# ['Seidorf Villa Fontuna']
# 185
# ['Seidorf  Hain']
# 186
# ['Birmingham King´s Norton']
# 187
# ['Birmingham King´s Norton - Poststempel']
# 188
# ['Birmingham Edgbaston']
# 189
# ['Silvaplana Engadin']
# 190
# ['Silvaplana']
# 191
# ['Cadiz']
# 192
# ['Cádiz']
# 193
# ['Aix la Chapelle' 'Air la Chapelle']
# 194
# ['Kiøbenhavn  Kiøbenhavn' 'Kjøbenhavn  Kjøbenhavn']
# 195
# ['Kjöbenhavn' 'Kjøbenhavn' 'Kiøbenhavn' 'København ']
# 196
# ['Ge8 S.']
# 197
# ['Ha68 S.']
# 198
# ['M. Gladbach' 'M.Gladbach' 'M. Gladbach ' 'B. Gladbach']
# 199
# ['Gladbach-Rheydt']
# 200
# ['Ballenstedt  Hamburg  Berlin  Hannover  Wedderstedt']
# 201
# ['Ballenstedt  Hamburg  Kronberg  Berlin  Hannover  Wedderstedt']
# 202
# ['Allendorff an der Werre']
# 203
# ['Allendorf an der Werra  Franckfurt  Leipzig']
# 204
# ['Polnisch Lissa']
# 205
# ['Poln. Lissa']
# 206
# ['Görbersdorf']
# 207
# ['Görbersdorf / Schlesien Sanatorium Marienhaus']
# 208
# ['Rudolphipoli']
# 209
# ['Claudiopoli']
# 210
# ['Turici  Londini  Parisiis  Petropoli  Stuttgardiae']
# 211
# ['Turici  Londini  Parisiis  Petropoli']
# 212
# ['杭州  hang zhou']
# 213
# ['荊州  jing zhou']
# 214
# ['杭州  筠淥山房  hang zhou']
# 215
# ['京都  jing du']
# 216
# ['Saint Quentin' 'Saint-Quentin']
# 217
# ['St. Quentin']
# 218
# ['Haidarabad']
# 219
# ['Hadamar']
# 220
# ['Châlons']
# 221
# ['Châlons-en-Champagne']
# 222
# ['Saarlouis']
# 223
# ['Salonik']
# 224
# ['Lvgduni Bat.  Lvgduni Bat.']
# 225
# ['Lvgduni Bat.']
# 226
# ['Lugduni Batavorum']
# 227
# ['Lugduni']
# 228
# ['Wroclaw']
# 229
# ['Wloclawek']
# 230
# ['Upsaliæ']
# 231
# ['Upsala']
# 232
# ['Colombo']
# 233
# ['Colombo u.a']
# 234
# ['Colfosco']
# 235
# ['Wolgast' 'Wolgast ']
# 236
# ['Bogotá']
# 237
# ['Bogotà']
# 238
# ['Kyllith']
# 239
# ['Ḳyllith']
# 240
# ['Meadville, Pa.']
# 241
# ['Reading, Pa.']
# 242
# ['Saint-Germain-en-Laye']
# 243
# ['Saint-Germain-en-Laye vermutlich']
# 244
# ['Saint-Germain-en-Laye Poststempel']
# 245
# ['Cöthen/ Im Fürstenthumb Anhalt' 'Cöthen Im Fürstenthumb Anhalt'
#  'Cöthen im Fürstenthume Anhalt']
# 246
# ['Front']
# 247
# ['Pyrmont']
# 248
# ['Soerabaia']
# 249
# ['Soerabaya']
# 250
# ['Soerabaja']
# 251
# ['Białymstoku']
# 252
# ['Bialystok']
# 253
# ['Lwów']
# 254
# ['Lwow']
# 255
# ['Lucknow']
# 256
# ['Lukow']
# 257
# ['Pulkowa']
# 258
# ['Chur  Lindau']
# 259
# ['Chur']
# 260
# ['Sassnitz Schloss Dwasieden auf Rügen']
# 261
# ['Sassnitz Schloss Dwasieden']
# 262
# ['Sassnitz']
# 263
# ['Siusi presso Bolzano Seiser Alm' 'Siusi presso Belzano Seiser Alm']
# 264
# ['Siusi presso Balzano']
# 265
# ['Radebeul-Oberlößnitz']
# 266
# ['Radebeul']
# 267
# ['Sauen b. Pfaffendorf']
# 268
# ['Pfaffendorf']
# 269
# ['Bombay' 'Bombay ']
# 270
# ['N. Ruppin']
# 271
# ['Ruppin']
# 272
# ['Neu Ruppin' 'Neu-Ruppin']
# 273
# ['Neuruppin']
# 274
# ['Neo-Ruppini']
# 275
# ['Neo-Rupp.']
# 276
# ['Neuen-Ruppin']
# 277
# ['w Warszawie']
# 278
# ['W Warszawie']
# 279
# ['Warszawa']
# 280
# ['Clausthal']
# 281
# ['Caputh']
# 282
# ['Telkef']
# 283
# ['Telkêf']
# 284
# ['Diez Haus Oranien']
# 285
# ['Diez Oranien']
# 286
# ['Diez']
# 287
# ['Graefelfing']
# 288
# ['Lochham Gräfelfing']
# 289
# ['Greifenhagen']
# 290
# ['Guayana']
# 291
# ['Guacana']
# 292
# ['Guayra']
# 293
# ['Guayaquil']
# 294
# ['Kraków']
# 295
# ['W Krakowie']
# 296
# ['Krakau']
# 297
# ['Braunschweig  London  Paris  Milano  Boston, Mass.'
#  'Braunschweig  Paris  London  Milano  Boston, Mass.']
# 298
# ['Nienburg (Weser)' 'Nienburg, Weser']
# 299
# ['Leipzig  Varsovie  Varsovie  St. Petersbourg  St. Petersbourg  Wilna  Amsterdam  Hamburg'
#  'Leipzig  Varsovie  Varsovie  St. Petersbourg  St. Petersbourg  Wilna  Amsterdam']
# 300
# ['Leipzig  Varsovie  Varsovie  St. Petersbourg  St. Petersbourg  Hambourg']
# 301
# ['Treisa Mühltal']
# 302
# ['Tierra Alta']
# 303
# ['Geislingen-St.' 'Geislingen-Stg.']
# 304
# ['Pallanza Lago Maggiore']
# 305
# ['Meina Lago Maggiore']
# 306
# ['Dortmund' 'Dormundt' 'Dortmundt']
# 307
# ['Sils Maria']
# 308
# ['Sils Sils Maria']
# 309
# ['Straßengel bei Graz, Künstlererholungsheim']
# 310
# ['Sraßengel bei Graz, Künstlerheim']
# 311
# ['Sraßengel']
# 312
# ['Straßengel Graz']
# 313
# ['Pörtschach']
# 314
# ['Pörtschach am See']
# 315
# ['Christian-Erlang' 'Christian-Erlangæ']
# 316
# ['Christ-Erlang']
# 317
# ['Kristiania Oslo' 'Christiania Oslo']
# 318
# ['Kristiania']
# 319
# ['Christianstat']
# 320
# ['Christiansstadt  Carlsruhe']
# 321
# ['Kūstanǧa']
# 322
# ['Sestri Levante' 'Sestri-Levante']
# 323
# ['Sestri Levante Gran Hotel Jensch']
# 324
# ['Servestae']
# 325
# ['Flims Waldhaus']
# 326
# ['Flims Hotel Waldhaus']
# 327
# ['Fulpmes']
# 328
# ['Flims']
# 329
# ['Eger']
# 330
# ['Eggerssen']
# 331
# ['Römhild']
# 332
# ['roemhild']
# 333
# ['Amerika']
# 334
# ['Emmerik']
# 335
# ['Gollub']
# 336
# ['Follebu']
# 337
# ['Cambridge']
# 338
# ['Camberley']
# 339
# ['Cambridge, Massachusetts;Altona']
# 340
# ['Hongkong' 'Hongkong ']
# 341
# ['Utrecht']
# 342
# ['Utrecht: Honig']
# 343
# ['Ultrajecti']
# 344
# ['Utrecht  Utrecht']
# 345
# ['Zwickau']
# 346
# ['Zwickaw']
# 347
# ['Zwickau(?)']
# 348
# ['Zwickau i. Sa.']
# 349
# ['Zwickau-Sachsen']
# 350
# ['Zwickau  Marburg']
# 351
# ['Zwickau  Nikolsburg']
# 352
# ['Ospedaletti Postkarte von']
# 353
# ['Ospedaletti']
# 354
# ['Rom Hotel de Russie']
# 355
# ['Rom Hotel des Princes']
# 356
# ['Rome Grand Hotel de Russie']
# 357
# ['Fulpmes Grand Hotel Stubai']
# 358
# ['sʹGravenhage' "s' Gravenhage" "s'-Gravenhage " "s'Gravenhage"]
# 359
# ["s' Gravenhage: van Doorn"]
# 360
# ['Neumünster']
# 361
# ['Neu-Oster']
# 362
# ['Lauderstedt']
# 363
# ['Lauchstedt']
# 364
# ['Collingwood']
# 365
# ['Collingwood Hawkhurst']
# 366
# ['Schoonhoven']
# 367
# ['Schoonhoviae']
# 368
# ['Espergæde']
# 369
# ['Espergaede']
# 370
# ['Epe']
# 371
# ['Hohenzollern  Wien']
# 372
# ['Hohenzollern i.e. Wien']
# 373
# ['Hohenzollern']
# 374
# ['Hohenlychen']
# 375
# ['Wien  Hohenzollern']
# 376
# ['Mexico']
# 377
# ['Mexici']
# 378
# ['México']
# 379
# ['Mexico  Mexico']
# 380
# ['Acoma New Mexico']
# 381
# ['Caslano Tessin']
# 382
# ['Caslano Lugano']
# 383
# ['Bad Nassau (Lahn)']
# 384
# ['Bad-Nassau (Lahn)']
# 385
# ['Bad Nassau']
# 386
# ['Bad Nauheim']
# 387
# ['Bad Nauheim Hotel Hohenzollern']
# 388
# ['Bad Langenau']
# 389
# ['Bad Schandau']
# 390
# ['Salamanticae']
# 391
# ['Salamanca']
# 392
# ['Saamaaranch']
# 393
# ['Munic  Leipsic  Paris  Petersbourg'
#  'Munic  Leipsic  Paris  St. Petersbourg']
# 394
# ['Meriden/Connecticut']
# 395
# ['Meriden, Conn.']
# 396
# ['Rottach-Egern am Tegernsee']
# 397
# ['Rottach-Egern']
# 398
# ['Egern a. Tegernsee']
# 399
# ['Görlitz im Marggraffthumb OberLausitz'
#  'Görlitz im Marggraffenthumb OberLausitz']
# 400
# ['Neuendorf Ostseebad']
# 401
# ['Neuhaus Ostseebad']
# 402
# ['Rovio' 'Rovigo']
# 403
# ['Rovio Ticino']
# 404
# ['Conimbricæ']
# 405
# ['Conimbricae']
# 406
# ['Obersasbach bei Achern']
# 407
# ['Obersasbach']
# 408
# ['Dorf Kreuth']
# 409
# ['Dorf Kreuth Tegernsee']
# 410
# ['Rottweil' 'Rotweil']
# 411
# ['Germantown bei Philadelphia']
# 412
# ['Germantown bei Philadelphia  Berlin']
# 413
# ['Kiefersfelden Poststempel']
# 414
# ['Kiefersfelden']
# 415
# ['Kaiserswerth am Rhein' 'Kaiserwerth am Rhein']
# 416
# ['Kaiserswerth am Rhein Düsseldorf']
# 417
# ['Kaiserswerth am Rhein vermutlich']
# 418
# ['Kaiserswerth am Rhein Poststempel']
# 419
# ['Kaiserswerth Düsseldorf']
# 420
# ['Bangalore']
# 421
# ['Mangalore']
# 422
# ['Baltimore']
# 423
# ['Innsbruck' 'Innsbruck .']
# 424
# ['Inspruck']
# 425
# ['Karersee Haus Laurin']
# 426
# ['Karersee']
# 427
# ['Menton Winter Palace']
# 428
# ['Gstaad Winter Palace']
# 429
# ['Zollikon']
# 430
# ['Zollikon bei Zürich']
# 431
# ['Lugano Villa Eugenia']
# 432
# ['Lugano Villa Castagnola']
# 433
# ['Lugano Castagnola - Villa Favorita']
# 434
# ['Alexandersbad']
# 435
# ['Alexandersbad bei Wunsiedel']
# 436
# ['Alexandrie']
# 437
# ['Hof']
# 438
# ['Hoff']
# 439
# ['Hof  Hof']
# 440
# ['Igls bei Innsbruck']
# 441
# ['Igls bei Innsbruck Hohenburg']
# 442
# ['Wien in Oesterreich' 'Wienn in Oesterreich']
# 443
# ['Breslau  Lissa in Südpr.  Hirschberg']
# 444
# ['Breslau  Hirschberg  Lissa in Südpreußen']
# 445
# ['Lissa in Südpreussen  Breslau  Hirschberg  Breslau']
# 446
# ['Ienae  Vratislav.  Ienae']
# 447
# ['Bregae  Vratislav.  Bregae']
# 448
# ['Wedderstedt Stempel']
# 449
# ['Wedderstedt']
# 450
# ['Witebergae  Lipsiae  Francofurti  Helmestadii']
# 451
# ['Witebergae  Lipsiae  Helmestadii  Leipzig  Wittenberg']
# 452
# ['Vratislaviae  Francofurtana cis Viadrum']
# 453
# ['Vratislaviae  Francofurti ad Moenum  Lipsiae  Bregae']
# 454
# ['Lipsiae  Vratislaviae  Francofurti ad Moenum  Bregae']
# 455
# ["Plancy-L'Abbaye ermittelt"]
# 456
# ["Plancy-L'Abbaye"]
# 457
# ['Travemünde Seebadeanstalt Travemünde']
# 458
# ['Travemünde Sanatorium Travemünde']
# 459
# ['Chicago' 'Chicago ']
# 460
# ['Chicago, Ill.']
# 461
# ['Chicago Illinois']
# 462
# ['China']
# 463
# ['Bayern (Straubing?)']
# 464
# ['Bayern (Oettingen?)']
# 465
# ['Wateringbury']
# 466
# ['Wateringbury near Maidstone']
# 467
# ['Zaltbommel']
# 468
# ['Zalt-Bommel']
# 469
# ['Zel-Bommel']
# 470
# ['Zalt-Bommel  Paris']
# 471
# ['Brüssel  Antwerpen  Mainz  London  Leipzig  Wien']
# 472
# ['Brüssel  Antwerpen  Mainz']
# 473
# ['Antwerpen  Mainz  Brüssel  Leipzig  Wien']
# 474
# ['Nordfrankreich']
# 475
# ['Nordfrankreich  Flandern']
# 476
# ['Langenberg bei Gera  Leipzig  Gera'
#  'Langenberg ohnweit Gera  Leipzig  Gera'
#  'Langenberg ohnweit Gera  Leipzig']
# 477
# ['Langenberg  Leipzig  Gera']
# 478
# ['Mitteldeutschland']
# 479
# ['Mitteldeutschland (Lauchhammer?)']
# 480
# ['Uri']
# 481
# ['Uri?']
# 482
# ['Urmia']
# 483
# ['Umbria']
# 484
# ['Urbino']
# 485
# ['Urmia, Iran']
# 486
# ['Costantz am Bodensee']
# 487
# ['Lindau am Bodensee']
# 488
# ['Desoy' 'Desoye']
# 489
# ['Göhren Rügen']
# 490
# ['Göhren']
# 491
# ['Worms' 'Wormbs']
# 492
# ['Worbis']
# 493
# ['Am Rhein']
# 494
# ['Worms a. Rhein']
# 495
# ['Kreuth Herzogl. Wildbad Kreuth']
# 496
# ['Kreuth Wildbad Kreuth']
# 497
# ['Zürich Hotel Gotthard']
# 498
# ['Zürich Hotel Baur au Lac']
# 499
# ['Tegernsee']
# 500
# ['Tegernsee Pension Seeheim']
# 501
# ['Herrenalb, Württemberg']
# 502
# ['Herrenalb']
# 503
# ['Mohrungen']
# 504
# ['Mohrungen u. Königsberg']
# 505
# ['Fürth i/B.']
# 506
# ['Fürth']
# 507
# ['Boston']
# 508
# ['Boyton']
# 509
# ['Noyon']
# 510
# ['Boston, Mass.']
# 511
# ['Havanna']
# 512
# ['Habana']
# 513
# ['Ravenna']
# 514
# ['Madras']
# 515
# ['Madras  Madras']
# 516
# ['Bochum' 'Bochum ']
# 517
# ['Friedewald-Dresden']
# 518
# ['Friedewalde-Dresden']
# 519
# ['Lemgo' 'Lemgou']
# 520
# ['Lemgoviae']
# 521
# ['Lemgo  Detmold']
# 522
# ['Stadt am Hof' 'Stadt am Hoff']
# 523
# ['Stadtamhof']
# 524
# ['Beograd']
# 525
# ['U Beogradu']
# 526
# ['Petrograd']
# 527
# ['Neudeck']
# 528
# ['Neurode ']
# 529
# ['Plauen im Voigtlandt' 'Plauen im Voigtlandte']
# 530
# ['Plauen in Voigtlandt']
# 531
# ['Alt-Gaarz']
# 532
# ['Alte Gaarz']
# 533
# ['Ystad']
# 534
# ['Gstaad']
# 535
# ['Rawicz']
# 536
# ['Rawitsch']
# 537
# ['Baranowitschi']
# 538
# ['Photopolis']
# 539
# ['Moropolis']
# 540
# ['Cosmopolis']
# 541
# ['Elsaß' 'Elsaß?']
# 542
# ['Elsass']
# 543
# ['Nowogrodek']
# 544
# ['Novgorod']
# 545
# ['bei Novgorod Severskiy']
# 546
# ['Köln-Mülheim' 'Cöln-Mülheim']
# 547
# ['Kaufbeuren']
# 548
# ['Kaufbeuren  Ulm']
# 549
# ['Ems']
# 550
# ['Elmshorn']
# 551
# ['Emmishofen']
# 552
# ['Militsch']
# 553
# ['Quirlequitsch']
# 554
# ['Soltquellæ' 'Solquellæ']
# 555
# ['Schlettstadt' 'Schlettstatt']
# 556
# ['Schlettstadt  Wien']
# 557
# ['Schlettstadt  Schlettstadt']
# 558
# ['Hettstedt']
# 559
# ['Dinglingen (Baden)']
# 560
# ['Dinglingen']
# 561
# ['Sigmaringen']
# 562
# ['Moguntiae']
# 563
# ['Montjoie']
# 564
# ['La Roche-sur-Yon Poststempel']
# 565
# ['La Roche-sur-Yon ermittelt']
# 566
# ['La Roche-sur-Yon']
# 567
# ['Venise Grand Hotel des Bains']
# 568
# ['Venise Grand Hotel - Venise']
# 569
# ['Venise Grand Hotel Britannia']
# 570
# ['Castelraimondo']
# 571
# ['Castelraimondo vermutlich']
# 572
# ['Castelfranco di Sotto']
# 573
# ['Kattowitz ' 'Kattowitz']
# 574
# ['Kattowitz O./S.' 'Kattowitz O.-S.']
# 575
# ['Schafhausen' 'Schaffhausen']
# 576
# ['Schönhausen']
# 577
# ['Schaffhausen  Wädenswil']
# 578
# ['Schaffhausen  Schaffhausen']
# 579
# ['Oberzwehren']
# 580
# ['Obernzenn']
# 581
# ['Ratisbonae' 'Ratisponae' 'Ratisbonne' 'Ratisbonnæ' 'Ratisbonae ']
# 582
# ['Ratisbonae  Wetzlar']
# 583
# ['Ratibor O.-S.']
# 584
# ['Ratibor']
# 585
# ['Westdeutschland' 'Westdeutschland?']
# 586
# ['Westdeutschland, Trier?']
# 587
# ['Westdeutschland (Marienberg?)']
# 588
# ['S. Margherita Ligure erschlossen']
# 589
# ['Santa Margherita Ligure erschlossen']
# 590
# ['Santa Margherita']
# 591
# ['Santa Margherita Ligure']
# 592
# ['Santa Margherita Ligure mutmaßlich']
# 593
# ['Santa Margherita Ligure Poststempel']
# 594
# ['Santa Margherita Ligure Villa Porticiuolo erschlossen']
# 595
# ['Santa Margherita Ligure Grand Hotel "Lido"']
# 596
# ['Santa Margherita Hotel Continental']
# 597
# ['Santa Margherita Ligure Grand Hotel Continental Santa Margherita Ligure']
# 598
# ['Santa Margharia Ligure Villa Degli Ulivi']
# 599
# ['Sachsenhausen']
# 600
# ['Schlappershausen']
# 601
# ['Delft']
# 602
# ['Delitii']
# 603
# ['Augustae Trevirorum']
# 604
# ['Augustæ Treviorum']
# 605
# ['Augustae Taurinorum']
# 606
# ['Augustae Vindelicorum' 'Augusta Vindelicorum']
# 607
# ['Avgvstae Vindelicorvm']
# 608
# ['Aug. Vind.']
# 609
# ['August. Vind.']
# 610
# ['Augustae Vindel.']
# 611
# ['Augustae Vind.  Graecii']
# 612
# ['Augustae' 'Augusta']
# 613
# ['Augustae Tiberii']
# 614
# ['Augustae et Coloniae']
# 615
# ['Louvain']
# 616
# ['Lovanii']
# 617
# ['Grossen Glogaw' 'Grossen-Glogaw']
# 618
# ['Groß-Glogau' 'Gros-Glogau']
# 619
# ['GroßGlogaw']
# 620
# ['Ober-Glogau']
# 621
# ['Grossegg']
# 622
# ['Bruchsal' 'Bruchsall']
# 623
# ['Buchschlag']
# 624
# ['Wolfenbüttel' 'Wolffenbüttel' 'Wolffenbuttel' 'Wolfenbutteli'
#  'Wulffenbüttel' 'Wolffenbuttelae' 'Wolfenbuttelae' 'Wolfenbuttel']
# 625
# ['Wolffenbüttel  Hannover']
# 626
# ['Wolfurt']
# 627
# ['Loschwitz']
# 628
# ['Leobschütz']
# 629
# ['Loschwitz bei Dresden']
# 630
# ['Wachwitz']
# 631
# ['Macerata']
# 632
# ['Maracay']
# 633
# ['Malacca']
# 634
# ['Caracas']
# 635
# ['Dordrecht']
# 636
# ['Dordrecht  Dordrecht']
# 637
# ['Dordraci']
# 638
# ['Lille' 'Lille ']
# 639
# ['Lille Hammer']
# 640
# ['Lille Elvedal']
# 641
# ['den Haag']
# 642
# ['Den Haag']
# 643
# ['De Hage']
# 644
# ['The Hague']
# 645
# ['La Havane']
# 646
# ['La Havana']
# 647
# ['La Habana']
# 648
# ['La Haye']
# 649
# ['Le Haye']
# 650
# ['la Haye']
# 651
# ['A La Haye']
# 652
# ['Le Havre']
# 653
# ['La Haye  Utrecht']
# 654
# ['New Haven']
# 655
# ['Calcutta' 'Calcutta ']
# 656
# ['Kalkutta']
# 657
# ['Herrnhut']
# 658
# ['Herrnhut i.Sa.']
# 659
# ['Durlaci']
# 660
# ['Durlach']
# 661
# ['Dahlbruch']
# 662
# ['Dantisci']
# 663
# ['Dantisci  Rigae']
# 664
# ['Magontiaci']
# 665
# ['Chamonix']
# 666
# ['Chaumont']
# 667
# ['Hautmont']
# 668
# ['Chauny']
# 669
# ['Chaumont vermutlich']
# 670
# ['Klobenstein']
# 671
# ['Lobenstein']
# 672
# ['Allenstein']
# 673
# ['Palaeo-Sedini']
# 674
# ['Palaeo Stetini']
# 675
# ['Rostochii  Wismariae  Gottingae']
# 676
# ['Rostochii  Wismariae  Gottingae  Gottingae']
# 677
# ['Moscou  St.-Petersbourg  Kieff']
# 678
# ['Moscou  St.-Petersbourg  Kieff  Varsavie']
# 679
# ['Moscou  Petersbourg  Varsovie']
# 680
# ['Petersbourg  Moscou  Varsovie']
# 681
# ['Werningerodae' 'Wernigerode' 'Wernigeroda' 'Wernigerodae']
# 682
# ['Wernigerode  Grossglienicke']
# 683
# ['Höchst  Frankfurt']
# 684
# ['Höchst  Hanau']
# 685
# ['Werder a.H.']
# 686
# ['Werder']
# 687
# ['Lauban' 'Laubani']
# 688
# ['Laubae']
# 689
# ['Lubawa']
# 690
# ['Lausanne']
# 691
# ['Lausanne  Neuchâtel']
# 692
# ['Pesaro']
# 693
# ['Parow']
# 694
# ['Mainz & Anvers  Paris  Londres']
# 695
# ['Mainz et Anvers  Paris']
# 696
# ['Brüssel  Leipzig  London  New York, NY']
# 697
# ['Brüssel  New York, NY  London  Leipzig']
# 698
# ['Breslau  New York, NY  Riga']
# 699
# ['Gablonz']
# 700
# ['Babylon']
# 701
# ['Barby']
# 702
# ['Brühl-Köln']
# 703
# ['Bühl']
# 704
# ['Bocholt i. W.']
# 705
# ['Bocholt']
# 706
# ['Bocholt/Westfalen']
# 707
# ['Bichl']
# 708
# ['Strehlen (Schlesien)']
# 709
# ['Strehlen']
# 710
# ['Leodii']
# 711
# ['Lodi']
# 712
# ['Lodz']
# 713
# ['Laodicea']
# 714
# ['Hoorn' 'Horn']
# 715
# ['Osterwieck/Harz' 'Osterwieck/Harz ' 'Osterwieck-Harz ']
# 716
# ['Osterwieck']
# 717
# ['Helsingfors']
# 718
# ['Helsingør']
# 719
# ['Helsinki']
# 720
# ['Mossul' 'Mosul']
# 721
# ['Moscou' 'Moscou ']
# 722
# ['Moskva' 'Moskva ']
# 723
# ['Moskau']
# 724
# ['Moskou']
# 725
# ['Muskau']
# 726
# ['Moskau  Riga']
# 727
# ['V Moskvě']
# 728
# ['Aarau']
# 729
# ['Aarau  Biel']
# 730
# ['Hemipoli']
# 731
# ['Herbipoli']
# 732
# ['Tirol']
# 733
# ['Airolo']
# 734
# ['Tiflis']
# 735
# ['Tilsit']
# 736
# ['Tripolis']
# 737
# ['Tbilissi']
# 738
# ['Italien/Deutschland?']
# 739
# ['Italien  Westdeutschland?']
# 740
# ['Calw ' 'Calw']
# 741
# ['Crembs']
# 742
# ['Krems']
# 743
# ['Kolding']
# 744
# ['Konin']
# 745
# ['Kornelimünster']
# 746
# ['Sevilla']
# 747
# ['Simla']
# 748
# ['Eschwege']
# 749
# ['Eschweiler']
# 750
# ['Enschede']
# 751
# ['Agra']
# 752
# ['Autograph']
# 753
# ['Aquisgrani']
# 754
# ['Corrientes']
# 755
# ['Sorrent']
# 756
# ['Soest']
# 757
# ['Pest ' 'Pest' 'Pesth']
# 758
# ['Palestrina']
# 759
# ['Lörrach']
# 760
# ['Lorch']
# 761
# ['Corbach']
# 762
# ['Freising']
# 763
# ['Freysing']
# 764
# ['Glückstadt']
# 765
# ['Glückstadii']
# 766
# ['Steinoviae Ad Oderam']
# 767
# ['Steinoviae ad Oderam']
# 768
# ['Cologne Sur La Spree']
# 769
# ['Cologne sur la Spree']
# 770
# ['Cöln an der Spree  Franckfurt' 'Cölln an der Spree  Franckfurt']
# 771
# ['Cölln an der Spree' 'Cöln an der Spree' 'Kölln an der Spree']
# 772
# ['Cölln an det Spree']
# 773
# ['Cölln an der\n\t\t\t\t\t\t\t\tSpree']
# 774
# ['Cölln an der Spree  Cölln an der Spree']
# 775
# ['Berlin  Posen  Stettin  Dresden  Wien  Hamburg  Leipzig']
# 776
# ['Berlin  Posen  Wien  Leipzig  Dresden  Hamburg  Stettin']
# 777
# ['Weimar Oberweimar' 'Weimar Ober-Weimar']
# 778
# ['Curiae Nariscorum' 'Curiae Variscorum' 'Curiae-Variscorum']
# 779
# ['Antverpiae']
# 780
# ['Antverpiæ']
# 781
# ['Antwerpen?' 'Antwerpen']
# 782
# ['Thantwerpẽ']
# 783
# ['Thantwerpen']
# 784
# ['Antwerpen  Paris  Mainz']
# 785
# ['Anvers']
# 786
# ['Moers']
# 787
# ['Meurs']
# 788
# ['Monrepos']
# 789
# ['Morgiis']
# 790
# ['Arel']
# 791
# ['Argelan']
# 792
# ['Abel']
# 793
# ['Aigen']
# 794
# ['bei jing  北京']
# 795
# ['bei jing  Bagazivg  北京']
# 796
# ['Querfurti' 'Querfurth' 'Querfurt']
# 797
# ['Querfurth  Sangerhausen']
# 798
# ['Wallmow']
# 799
# ['Wallmerod']
# 800
# ['Nagpur']
# 801
# ['Nagpore']
# 802
# ["Nágpu'r"]
# 803
# ['Kirchheim']
# 804
# ['Forchheim']
# 805
# ['Forchheim (Bayern)']
# 806
# ['Kirchheim und Biebrig']
# 807
# ['Kirchheim an dehr Theck']
# 808
# ['Arnhem' 'Arnheim']
# 809
# ['Gorinchem']
# 810
# ['Kochem']
# 811
# ['Bapaume  München']
# 812
# ['Dachau bei München']
# 813
# ['Bapaume']
# 814
# ['Gütersloh']
# 815
# ['Günterstal']
# 816
# ['Gütersloh  Iserlohn']
# 817
# ['Ulm']
# 818
# ['Ulmae']
# 819
# ['Vlmae']
# 820
# ['Onoltzbach' 'Onolzbach']
# 821
# ['Onoldsbachii']
# 822
# ['Onoldi']
# 823
# ['Culmbaci']
# 824
# ['Culmbach']
# 825
# ['Sulzbach' 'Sultzbach']
# 826
# ['Butzbach']
# 827
# ['Sulzbach i. Opf.']
# 828
# ['Culm']
# 829
# ['Ulm a.Donau' 'Ulm a. Donau']
# 830
# ['Ulm a. D.' 'Ulm a.D.']
# 831
# ['Culm a. W.']
# 832
# ['Ulm (Donau)']
# 833
# ['Ulm  Ulm']
# 834
# ['New York  Druckort- Paris']
# 835
# ['New York getarnt  Druckort- Paris']
# 836
# ['Montreux Hotel Continental']
# 837
# ['München Hotel Continental']
# 838
# ['Argentorati' 'Argentoratii']
# 839
# ['Argentinae  Argentinae']
# 840
# ['Argentinae']
# 841
# ['Aschersleb.']
# 842
# ['Aschersleben']
# 843
# ['Oschersleben  Gotha']
# 844
# ['Aschersleben  Quedlinburg']
# 845
# ['Paris Hotel Moderne']
# 846
# ['Paris Hotel Cayré']
# 847
# ['Paris Hotel Palais d´Orsay']
# 848
# ['Paris Hotel Ambrassador']
# 849
# ['Primislaviae']
# 850
# ['Primislaviæ']
# 851
# ['Varsovie']
# 852
# ['Varsaviae']
# 853
# ['Wratislaviae  Wratislaviae' 'Vratislaviae  Vratislaviae']
# 854
# ['Vratislaviae  Vratislaviae  Vratislaviae']
# 855
# ['Vratislaviae  Breslau']
# 856
# ['Vratislaviae  Bregae']
# 857
# ['Vratislaviae  Ienae']
# 858
# ['Vrastislaviae' 'Vratislaviae' 'Wratislaviae' 'Vratislava' 'Wratislavia'
#  'Wratislaviæ' 'Vratistaviae']
# 859
# ['Wratislav.' 'Wratisl.']
# 860
# ['Vratisl.']
# 861
# ['Vratislaviensis']
# 862
# ['Vratislaviae  Lipsiae']
# 863
# ['Vratislaviae  Lignicii']
# 864
# ['Wratislaviae Silesiorum']
# 865
# ['Wratislaviae in Canonicatu']
# 866
# ['Wien Hotel Imperial']
# 867
# ['Wien Imperialhotel']
# 868
# ['Wien Hotel Bristol']
# 869
# ['Wien Hotel Meißl & Schadn' 'Wien Hotel Meissl & Schadn']
# 870
# ['Wien Hotel Meisel und Schadn']
# 871
# ['Wien Hotel Sacher']
# 872
# ['Wien Hotel de France']
# 873
# ['Wien Hotel Continental']
# 874
# ['Wien Hotel Ambassador']
# 875
# ['Ried Hotel Post']
# 876
# ['Mömpelgard']
# 877
# ['Mömpelgard  Straßburg']
# 878
# ['Mömpelgard  Frankfurt/Main']
# 879
# ['Kloster/Hiddensee Haus Seedorn' 'Kloster (Hiddensee) Haus Seedorn'
#  'Kloster Hiddensee, Haus Seedorf' 'Kloster Hiddensee/ Haus Seedorn'
#  'Kloster Hiddensee Haus Seedorn' 'Kloster, Hiddensee Haus Seedorn'
#  'Kloster Hiddensee, Haus Seedorn']
# 880
# ['Kloster/Hiddensee Haus Seedorn; erschlossen']
# 881
# ['Vitte/Hiddensee' 'Vitte Hiddensee' 'Vitte, Hiddensee']
# 882
# ['Vitte auf Hiddensee']
# 883
# ['Kloster (Hiddensee)' 'Kloster/Hiddensee' 'Kloster Hiddensee'
#  'Kloster auf Hiddensee']
# 884
# ['Kloster (Hiddensee) erschlossen' 'Kloster, Hiddensee erschlossen'
#  'Kloster, Hiddensee erschl.']
# 885
# ['Kloster (Hiddensee) mutmaßlich']
# 886
# ['Kloster/ Hiddensee  Greifswald']
# 887
# ['Vitte/Hiddensee Haus Seedorn']
# 888
# ['Kloster/Hiddensee Pension "Haus am Meer"']
# 889
# ['Kloster Hermon']
# 890
# ['Baden-Baden Brenners Parkhotel "Kurhof"']
# 891
# ['Baden-Baden Brenners Parkhotel']
# 892
# ['Hildesii']
# 893
# ['Hildesiae']
# 894
# ['Hildesheim' 'Hildesheim ']
# 895
# ['Hildenßheim' 'Hildeßheimb']
# 896
# ['Hillesheimii']
# 897
# ['Arlesheim']
# 898
# ['Ilbesheim']
# 899
# ['Hildesheim  Braunschweig']
# 900
# ['Hilperhusae']
# 901
# ['Florenz Helvetia Hotel']
# 902
# ['Florenz Hotel Royal']
# 903
# ['Wetzlar' 'Wezlar']
# 904
# ['Wetzlariæ']
# 905
# ['Wetzlariae']
# 906
# ['Minden an der Weser']
# 907
# ['Rinteln an der Weser']
# 908
# ['Detmold Lippe' 'Detmold-Lippe']
# 909
# ['Detmold']
# 910
# ['Detmold  Lemgo']
# 911
# ['Biberach-Riß']
# 912
# ['Biberach']
# 913
# ['Alethopoli' 'Aetopoli']
# 914
# ['Eleutheropoli']
# 915
# ['Irenopoli']
# 916
# ['Kerenopolis']
# 917
# ['Melitopol']
# 918
# ['Seehöhe']
# 919
# ['Seeheim']
# 920
# ['Mergentheim']
# 921
# ['Manchester ' 'Manchester']
# 922
# ['Travemünde Villa Alma Mater']
# 923
# ['Travemünde Villa Felsenburg']
# 924
# ['Cleveland, Ohio' 'Cleveland Ohio']
# 925
# ['Cleveland']
# 926
# ['Cleve']
# 927
# ['Kleve']
# 928
# ['Olivae' 'Oliva']
# 929
# ['Cliviae']
# 930
# ['Pratteln']
# 931
# ['Prettin']
# 932
# ['Orléans']
# 933
# ['Orleans']
# 934
# ['Marmato']
# 935
# ['Saratov']
# 936
# ['Bützow' 'Bütow']
# 937
# ['Munising']
# 938
# ['Minusio']
# 939
# ['Santafe de Bogota' 'Santafee de Bogota']
# 940
# ['Santafé de Bogotá']
# 941
# ['Santafé']
# 942
# ['Kahla']
# 943
# ['Cahla']
# 944
# ['Grimma']
# 945
# ['Grimmen']
# 946
# ['Simmern']
# 947
# ['Alencon']
# 948
# ['Alençon']
# 949
# ['Sneek']
# 950
# ['Te Sneek']
# 951
# ['Zeitz  Zeitz' 'Zeiz  Zeiz']
# 952
# ['Zeitz']
# 953
# ['Schreiberhau']
# 954
# ['Schreiberhau erschl.']
# 955
# ['Schreiberhau i. Rsgb.']
# 956
# ['Schreiberdorf']
# 957
# ['Wiener-Neustadt' 'Wiener Neustadt ']
# 958
# ['Gross-Strehlitz' 'Groß-Strehlitz']
# 959
# ['Groß-Salze']
# 960
# ['Clavieres']
# 961
# ['Cavite']
# 962
# ['Wien  Nürnberg']
# 963
# ['Lyon  Nürnberg']
# 964
# ['Rio de Janeiro']
# 965
# ['Rio de Janeiro  S. Pãulo']
# 966
# ['Rio de Janeiro  Rio de Janeiro']
# 967
# ['Kleinmachnow']
# 968
# ['Klein Machnow']
# 969
# ['Kleinmachnow Berlin']
# 970
# ['Kleinmachnow vermutlich']
# 971
# ['Sainte-Menehould' 'Sainte-Ménehould']
# 972
# ['Sainte-Menehould Poststempel']
# 973
# ['Santorso']
# 974
# ['Santorin']
# 975
# ['Saint-Trond']
# 976
# ['Canton']
# 977
# ['Kanton']
# 978
# ['Canton, China']
# 979
# ['Saint-Cloud']
# 980
# ['Tegel (Berlin)']
# 981
# ['Tempelhof (Berlin)']
# 982
# ['Tempelhof bei Berlin']
# 983
# ['Tempelhof']
# 984
# ['Dresden - Weißer Hirsch Poststempel'
#  'Dresden Weißer Hirsch - Poststempel']
# 985
# ['Dresden - Weißer Hirsch']
# 986
# ['Dresden Weißer Hirsch']
# 987
# ['Cothenis Anhaltinorum' 'Cothenis, Anhaltinorum']
# 988
# ['Neukirchen' 'Neukirch']
# 989
# ['Neukirch Breslau']
# 990
# ['Neukirchen, Kr. Moers']
# 991
# ['Halae Hermundurorum' 'Halae Hermunduror.']
# 992
# ['Halae Hermund.']
# 993
# ['Halae Venedorum']
# 994
# ['Lemgo  Hannover']
# 995
# ['Celle  Hannover']
# 996
# ['Gotha  Erffordt']
# 997
# ['Gotha  Erfurt']
# 998
# ['Hamm  Münster']
# 999
# ['Hamm  Münster  Leipzig  Frankfurt']
# 1000
# ['Köln  Neuwied']
# 1001
# ['Köln  Neuwied  Koblenz']
# 1002
# ['Sondershusae' 'Sondershausen' 'Sondershausen ']
# 1003
# ['Sangerhausen']
# 1004
# ['Sangerhausen a.H.']
# 1005
# ['Sangerhausen  Zeitz']
# 1006
# ['Berlin Fasanenstr. 13']
# 1007
# ['Berlin Fasanenstraße']
# 1008
# ['Pankow-Berlin']
# 1009
# ['Pankow bei Berlin']
# 1010
# ['Panker']
# 1011
# ['Bethaniae ad Oderam']
# 1012
# ['Bethaniae Ad Viadr.']
# 1013
# ['Bethaniae']
# 1014
# ['Kiliae Holsatorum']
# 1015
# ['Kilonii Holsatorum']
# 1016
# ['Campidonae' 'Campidona']
# 1017
# ['Cremona']
# 1018
# ['Tremoniae']
# 1019
# ['Rouen']
# 1020
# ['Rodaun']
# 1021
# ['Passau']
# 1022
# ['Passay']
# 1023
# ['Passau(?)']
# 1024
# ['Neuchâtel']
# 1025
# ['Neuchatel']
# 1026
# ['Neuchâtel  Lausanne']
# 1027
# ['Dessaviae  Lipsiae  Dessaviae  Lipsiae']
# 1028
# ['Dessaviae  Lipsiae  Dessaviae']
# 1029
# ['Dessaviae  Dessaviae']
# 1030
# ['Dessaviae']
# 1031
# ['Leverkusen bei Köln']
# 1032
# ['Leverkusen']
# 1033
# ['Leuven']
# 1034
# ['Leuwarden' 'Leeuwarden']
# 1035
# ['Lahr']
# 1036
# ['Lahore']
# 1037
# ['Lahr in Baden']
# 1038
# ['Lahr i. B.']
# 1039
# ['Singapore']
# 1040
# ['Singapur']
# 1041
# ['Cotbus' 'Cottbus']
# 1042
# ['Cotbusii']
# 1043
# ['Oppenheim']
# 1044
# ['Pappenheim']
# 1045
# ['Rumpenheim']
# 1046
# ['Gotha' 'Gothae' 'Gotha?']
# 1047
# ['Gotha  Wien']
# 1048
# ['La Capponcina Florenz']
# 1049
# ['La Capponcina']
# 1050
# ['La Capponcina ermittelt']
# 1051
# ['Genua - Nervi Strandhotel Miramare']
# 1052
# ['Genua - Nervi Strandhotel Miramare - Postkarte von']
# 1053
# ['Genua - Nervi Hotel Miramare']
# 1054
# ['Anclam ' 'Anclam']
# 1055
# ['Anklam']
# 1056
# ['Alais']
# 1057
# ['Ala']
# 1058
# ['Alcalá']
# 1059
# ['Albany']
# 1060
# ['Anklam  Berlin']
# 1061
# ['Johannaberg']
# 1062
# ['Johannisberg']
# 1063
# ['Genova Zoagli, Villa Mare']
# 1064
# ['Zoagli Genova Villa Mare']
# 1065
# ['Zoagli Villa Mare']
# 1066
# ['Zoagli Villa Mare - Postkarte von']
# 1067
# ['Genova Villa Mare']
# 1068
# ['Danzig  Königsberg']
# 1069
# ['Danzig  Königsberg  Thorn']
# 1070
# ['San Francisco']
# 1071
# ['San Francisco ermittelt']
# 1072
# ['Niederrhein (Köln?)']
# 1073
# ['Niederrhein']
# 1074
# ['Niedersachsen']
# 1075
# ['Oldendorff' 'Oldendorf']
# 1076
# ['Sindelsdorf']
# 1077
# ['Klagenfurt' 'Clagenfurt']
# 1078
# ['Klagenfurth  Laybach']
# 1079
# ['Ribe']
# 1080
# ['Ried']
# 1081
# ['Rom  Rom' 'Roma  Roma' 'Rome  Rome']
# 1082
# ['Roma  Roma  Roma']
# 1083
# ['Rio  Rio']
# 1084
# ['Roma' 'Romae' 'Rome']
# 1085
# ['Rom']
# 1086
# ['Riom']
# 1087
# ['Romæ']
# 1088
# ['Roye']
# 1089
# ['Zehlendorf Berlin']
# 1090
# ['Zehlendorf']
# 1091
# ['Zehlendorf - Mitte Berlin']
# 1092
# ['St. Johann']
# 1093
# ['St. Johann a. d. Saar']
# 1094
# ['Hildburghausen' 'Hildburghausen?']
# 1095
# ['Burghausen']
# 1096
# ['Constantinopel  Franckfurth  Leipzig'
#  'Constantinopel  Franckfurt  Leipzig']
# 1097
# ['Constantinopel  Leipzig  Franckfurth'
#  'Constantinopel  Leipzig  Franckfurt']
# 1098
# ['Schneidemühl']
# 1099
# ['Schönheide']
# 1100
# ['Gerstungen']
# 1101
# ['Melsungen']
# 1102
# ['Nördlingen']
# 1103
# ['Nordlingae']
# 1104
# ['Mörsingen']
# 1105
# ['Drömlingen']
# 1106
# ['Mödling']
# 1107
# ['Mödling bei Wien']
# 1108
# ['Wohlau']
# 1109
# ['Wehlau']
# 1110
# ['Wolfshau']
# 1111
# ['Wolfshau Karpacz']
# 1112
# ['Carlsbad']
# 1113
# ['Karlsbad']
# 1114
# ['Lesnae Polonorum' 'Lesnae Polonor.']
# 1115
# ['Mulhusii Thuringorum']
# 1116
# ['Mulhusii Tyrigetarum']
# 1117
# ['Yokohama  Tokyo  London  Leipzig']
# 1118
# ['Yokohama  London  Leipzig']
# 1119
# ['Ienae  Halae Magdeburgicae  Halae Magdeburgicae']
# 1120
# ['Ienae  Halae Magdeburgicae']
# 1121
# ['Rapallo Grand Hotel Excelsior' 'Rapallo Grand Hotel Exelsior']
# 1122
# ['Rapallo Gr. Hôtel Excelsior' 'Rapallo Grand Hôtel Excelsior']
# 1123
# ['Rapallo Hotel Excelsior' 'Rapallo Hotel Exelsior']
# 1124
# ['Rapallo Exelsior Hotel']
# 1125
# ['Rapallo Hotel Excelsior; vermutlich']
# 1126
# ['Rapallo Hotel Excelsior & New Casino']
# 1127
# ['Rapallo Grand Hotel Savoia']
# 1128
# ['Rapallo Gr. Hotel Exelsior & New Casino']
# 1129
# ['Schlehdorf']
# 1130
# ['Schmetzdorf']
# 1131
# ['Schondorf']
# 1132
# ['Neustrelitz  Neubrandenburg']
# 1133
# ['Neustrelitz  Leipzig  Neubrandenburg']
# 1134
# ['Neustrelitz']
# 1135
# ['Ziegenhals ']
# 1136
# ['Ziegenhals i. Schles.']
# 1137
# ['Altorfii Nor.' 'Altdorfii Nor.' 'Altdorfii Noric.']
# 1138
# ['Altdorfii Noricorum' 'Altorfi Noricorum' 'Altorfii Noricorum']
# 1139
# ['Altorphii' 'Altdorphii']
# 1140
# ['Altdorf' 'Altdorfii' 'Altdorffii' 'Altorfii' 'Altdorff' 'Altdorfi']
# 1141
# ['Adorf']
# 1142
# ['Altdorf  Nürnberg']
# 1143
# ['Altdorf  Nürnberg  Nürnberg']
# 1144
# ['Altdorfii  Norimbergae']
# 1145
# ['Fürth  Nürnberg']
# 1146
# ['München Pension Stella']
# 1147
# ['München Pension Doering']
# 1148
# ['Langensalza' 'Langensaltza' 'Langensalza ']
# 1149
# ['Langen-Saltz' 'Langen-Saltza']
# 1150
# ['Lantzen-Saltza']
# 1151
# ['Langensalza  Erfurt']
# 1152
# ['Erfurt  Langensalza']
# 1153
# ['Sedini  Lipsiae  Merseburg']
# 1154
# ['Stettin  Leipzig  Merseburg']
# 1155
# ['Bad Liebenstein Hotel Kaiserhof']
# 1156
# ['Bad Liebenstein Hotel "Der Kaiserhof"']
# 1157
# ['Bad Liebenstein Thüringen']
# 1158
# ['Bad Liebenstein']
# 1159
# ['Bad Liebenstein erschlossen']
# 1160
# ['Weißensee in Thüringen']
# 1161
# ['Bad Liebenstein Hotel und Pension Herzogin Charlotte']
# 1162
# ['Semmering Südbahn-Hotel' 'Semmering Südbahnhotel']
# 1163
# ["Batavia  's Gravenhage" "Batavia  's-Gravenhage"]
# 1164
# ['Mülheim am Rhein' 'Mühlheim am Rhein']
# 1165
# ['Mühlheim a. d. Ruhr' 'Mülheim a. d. Ruhr' 'Mühlheim a.d. Ruhr'
#  'Mülheim a.d.Ruhr' 'Mülheim a. d. R' 'Mülheim a.d. Ruhr' 'Mülheim a.d.R.'
#  'Mülheim a. d. R.']
# 1166
# ['Mülheim (Ruhr)']
# 1167
# ['Mülheim an der Ruhr']
# 1168
# ['Mühlheim']
# 1169
# ['Mehlem']
# 1170
# ['Dresden-Blasewitz']
# 1171
# ['Dresden-Loschwitz']
# 1172
# ['Dresden-Loschwitz Sanatorium Dr. Weidner']
# 1173
# ['Florence']
# 1174
# ['Florenz']
# 1175
# ['Firenze']
# 1176
# ['Firenze  Firenze']
# 1177
# ['Filehne']
# 1178
# ['Stein an der Oder' 'Steinaw an der Oder' 'Steinau an der Oder']
# 1179
# ['Jeßnitz an der Milde']
# 1180
# ['Groningen']
# 1181
# ['Groningae']
# 1182
# ['Grüningen']
# 1183
# ['Gent']
# 1184
# ['Genthin']
# 1185
# ['Genf']
# 1186
# ['Großenhain']
# 1187
# ['Saltzwedel' 'Salzwedel']
# 1188
# ['Konstantinopel' 'Constantinopel']
# 1189
# ['Constantine' 'Constantiae']
# 1190
# ['Constantinopolis']
# 1191
# ['Langwaltersdorf']
# 1192
# ['Lgw. Langwaltersdorf']
# 1193
# ['Langwaltersdorf ermittelt']
# 1194
# ['Rückersdorf']
# 1195
# ['Wickersdorf']
# 1196
# ['Woltersdorf']
# 1197
# ['Einsiedeln ' 'Einsiedeln']
# 1198
# ['Einsiedeln usw.']
# 1199
# ['Einsidlia']
# 1200
# ['Niederlande']
# 1201
# ['Niederlande, östliche']
# 1202
# ['Rotterdam']
# 1203
# ['Rotterdam  Amsterdam']
# 1204
# ['Rintelii' 'Rinthelii' 'Rintelli' 'Rintellii']
# 1205
# ['Rinteln' 'Rintheln']
# 1206
# ['Rintelium']
# 1207
# ['Kopenhagen  Leipzig' 'Copenhagen  Leipzig']
# 1208
# ['Kopenhagen' 'Copenhagen' 'Koppenhagen' 'Copenhague']
# 1209
# ['Kopenhagen ermittelt']
# 1210
# ['Bad Tölz']
# 1211
# ['Bad Tölz Kurhotel']
# 1212
# ['Bonn et Cologne' 'Bonn  Cologne' 'Bonn & Cologne']
# 1213
# ['Bonna  Colonia']
# 1214
# ['Islebii']
# 1215
# ['Islebiae']
# 1216
# ['Linz']
# 1217
# ['Binz']
# 1218
# ['Biganzolo']
# 1219
# ['Treuenbrietzen']
# 1220
# ['Treuenbrietzen (Mark)']
# 1221
# ['Trento']
# 1222
# ['Trebnitz']
# 1223
# ['Lugano Park Hotel' 'Lugano Park-Hotel' 'Lugano Parkhotel']
# 1224
# ['Lugano Parkhotel Lugano']
# 1225
# ['Tarnowitz']
# 1226
# ['Jannowitz']
# 1227
# ['Czernowitz']
# 1228
# ['Gernewitz']
# 1229
# ['Wanne']
# 1230
# ['Cannes']
# 1231
# ['Schwäbisch Gmünd' 'Schwäbisch Gemünd']
# 1232
# ['Schwäb. Gmünd']
# 1233
# ['Schwäbisch Hall' 'Schwabisch Hall']
# 1234
# ['Schw. Hall' 'Schwäb. Hall']
# 1235
# ['Schwäbisch Hall  Leipzig']
# 1236
# ['Schwobach']
# 1237
# ['Schwabach']
# 1238
# ['Wien  Schwabach']
# 1239
# ['Schwabach  Berlin']
# 1240
# ['Brodnica']
# 1241
# ['Brodnicy']
# 1242
# ['Bronsvic']
# 1243
# ['Ansbach']
# 1244
# ['Anspach']
# 1245
# ['Aidenbach']
# 1246
# ['Samarang']
# 1247
# ['Semarang']
# 1248
# ['Wandsbek' 'Wandsbeck']
# 1249
# ['Wanßbeck']
# 1250
# ['Siegburg']
# 1251
# ['Aigen/Salzburg']
# 1252
# ['Warendorf in Westf.']
# 1253
# ['Warendorf i. Westf.']
# 1254
# ['Warnsdorf']
# 1255
# ['Warendorf']
# 1256
# ['Wünsdorf']
# 1257
# ['Stahnsdorf']
# 1258
# ['Elberfeld']
# 1259
# ['Elbenfeld']
# 1260
# ['Eberfeld ']
# 1261
# ['Elberfeld-Sonnborn']
# 1262
# ['Elberfeld Wuppertal']
# 1263
# ['Italien' 'Italien?']
# 1264
# ['Rom, Italien']
# 1265
# ['Güstrow']
# 1266
# ['Gustrow']
# 1267
# ['Güstroviae' 'Gustroviae']
# 1268
# ['Gustrovii' 'Gustroviii']
# 1269
# ['Güstrovii']
# 1270
# ['Gustrovi.']
# 1271
# ['Güstroviæ  Lipsiæ']
# 1272
# ['Güstrow  Rostock']
# 1273
# ['St. Margherita Villa Nido']
# 1274
# ['St. Margherita Il Nido']
# 1275
# ['St. Margarethen']
# 1276
# ['St. Margherita']
# 1277
# ['St. Margherita La Roccia']
# 1278
# ['St. Margarethen  Wittersham']
# 1279
# ['St. Margherita Castello Paraggi']
# 1280
# ['Stolp i. Pom.' 'Stolp i.Pom.' 'Stolp i. Pomm.']
# 1281
# ['Stargard an der Ihna' 'Stargardt an der Ihna']
# 1282
# ['Stargardt' 'Stargard' 'Stargardiæ']
# 1283
# ['Stargardiae']
# 1284
# ['Stargardt in Pommern' 'Stargard in Pommern']
# 1285
# ['Stargard i. Pomm.']
# 1286
# ['Stargardae Pomeranorum']
# 1287
# ['Recklinghausen ' 'Recklingshausen ']
# 1288
# ['Westend Berlin' 'Westend-Berlin']
# 1289
# ['Wannsee Berlin' 'Wannsee-Berlin']
# 1290
# ['Wannsee bei Berlin']
# 1291
# ['Westend Burg']
# 1292
# ['Wannsee Berlin (Villa Albrecht)']
# 1293
# ['Neu-Westend Berlin']
# 1294
# ['Berchtesgaden' 'Berchtesgarden']
# 1295
# ['Berchtesgaden-Schönau']
# 1296
# ['Berchtesgaden Poststempel']
# 1297
# ['Berlin - Kleinmachnow' 'Berlin Kleinmachnow']
# 1298
# ['Hall in Sachsen  Hall in Sachsen' 'Hall in Sachen  Hall in Sachsen']
# 1299
# ['Hall in Sachs.  Hall in Sachs.']
# 1300
# ['Hall in Sachsen' 'Halle in Sachsen']
# 1301
# ['Hall in Saxen']
# 1302
# ['Hall in Sachsen  Leipzig']
# 1303
# ['Hall in S.']
# 1304
# ['Hall in Sachsen  Wittenberg']
# 1305
# ['Sundii  Lipsiae']
# 1306
# ['Suinfurti  Lipsiae']
# 1307
# ['München  Ingolstatt' 'München  Ingolstadt']
# 1308
# ['Michelstadt']
# 1309
# ['Ohlstadt']
# 1310
# ['KoÌ\x88ln']
# 1311
# ['CoÌ\x88ln']
# 1312
# ['Koblenz' 'Koblenz ']
# 1313
# ['Coblenz' 'Coblentz']
# 1314
# ['Coeln']
# 1315
# ['Koblenz  Hadamar']
# 1316
# ['Coblenz  Coblenz']
# 1317
# ['Coloniae Agrippinae' 'Colonia Agrippina']
# 1318
# ['Freistadt, Schles' 'Freistadt, Schl']
# 1319
# ['La Haye  New-York  Paris  Londres  Berlin']
# 1320
# ['New-York  La Haye  Berlin  Paris  Londres']
# 1321
# ['La Haye; New-York  Paris  Berlin  Londres']
# 1322
# ['Lipsiae  Halis Saxonum']
# 1323
# ['Lipsiae  Halae Saxonum']
# 1324
# ['Alassio Grand Hotel']
# 1325
# ['Oslo Grand Hotel']
# 1326
# ['Franqfurṭ de-Odra' 'Franḳfurṭ de-Odra']
# 1327
# ['Franqfurṭ de-Odra  Franqfurṭ de-Odra'
#  'Franḳfurṭ de-Odrah  Franḳfurṭ de-Odrah'
#  'Franḳfurṭ de-Odra  Franḳfurṭ de-Odra']
# 1328
# ['Franḳfurṭ de-Oder  Franḳfurṭ de-Oder  Franḳfurṭ de-Oder']
# 1329
# ['Neusalz a. Oder']
# 1330
# ['Neusalz (Oder)']
# 1331
# ['Neusalz' 'Neusalza']
# 1332
# ['Neusalz  Sagan']
# 1333
# ['Neusatz  Belgrad']
# 1334
# ['Zippendorf']
# 1335
# ['Zinndorf']
# 1336
# ['Hain']
# 1337
# ['Haindorf']
# 1338
# ['Haiphong']
# 1339
# ['Laon' 'Laon ']
# 1340
# ['Lyon' 'Lyon?']
# 1341
# ['A Lyon']
# 1342
# ['Berlin-Karlshorst' 'Berlin - Karlshorst']
# 1343
# ['Bad Eilsen Hotel Fürstenhof']
# 1344
# ['Bad Eilsen Der Fürstenhof']
# 1345
# ['St. Blasien']
# 1346
# ['St. Blasien Kurhaus']
# 1347
# ['Sankt Gallen']
# 1348
# ['Sankt Gilgen']
# 1349
# ['Sankt Blasien']
# 1350
# ['St. Blasien Schwarzwald']
# 1351
# ['Gorlicii' 'Gorlici']
# 1352
# ['Bétsben']
# 1353
# ['Betsben']
# 1354
# ['Bingen a. Rhein' 'Bingen / Rhein']
# 1355
# ['Dantzigk  Dantzigk' 'Dantzig  Dantzig' 'Danzig  Danzig']
# 1356
# ['Danzig' 'Dantzig' 'Dantzigk' 'Danzig?']
# 1357
# ['Danzig  Berlin']
# 1358
# ['Mainz  Berlino']
# 1359
# ['Lankwitz b. Berlin']
# 1360
# ['Marienthal']
# 1361
# ['Marienbad']
# 1362
# ['Dauchau' 'Dachau']
# 1363
# ['Warschau']
# 1364
# ['Kaschau']
# 1365
# ['Patschkau']
# 1366
# ['Warschau  Dresden']
# 1367
# ['Warschau i.e. Berlin']
# 1368
# ['Kaschau  Kaschau']
# 1369
# ['Porto']
# 1370
# ['Portofino']
# 1371
# ['Portsmouth']
# 1372
# ['Portsmouth ermittelt']
# 1373
# ['Potosi']
# 1374
# ['Tutzing Kurhaus']
# 1375
# ['Tutzing']
# 1376
# ['Tutzing  München']
# 1377
# ['Kagel erschlossen']
# 1378
# ['Köln erschlossen']
# 1379
# ['Warmbrunn erschlossen']
# 1380
# ['Hamburg erschlossen']
# 1381
# ['Berlin erschlossen']
# 1382
# ['Sarepta']
# 1383
# ['Sparta']
# 1384
# ['Spa']
# 1385
# ['Salta']
# 1386
# ['Soltau']
# 1387
# ['Sorau']
# 1388
# ['Torgau']
# 1389
# ['Toruń']
# 1390
# ['Sprottau']
# 1391
# ['Paris  Trevoux']
# 1392
# ['Paris  Bordeaux']
# 1393
# ['Paris  Bruxelles']
# 1394
# ['Zutphen']
# 1395
# ['Zütphen']
# 1396
# ['Leiden' 'Leide']
# 1397
# ['Leyde' 'Leyden' 'Leyden ']
# 1398
# ['Heiden']
# 1399
# ['Batavia' 'Batavia  ' 'Batavia ' 'Batavia?']
# 1400
# ['Batavia  Leiden']
# 1401
# ['Batavia-Solo']
# 1402
# ['Batavia  Batavia']
# 1403
# ['Batawi']
# 1404
# ['Betawi']
# 1405
# ['Beuthen']
# 1406
# ['Beuthen O.-S.']
# 1407
# ['Penig i. Sa.']
# 1408
# ['Sebnitz i. Sa.']
# 1409
# ['Frankreich' 'Frankreich?']
# 1410
# ['Franckenhausen' 'Frankenhausen']
# 1411
# ['Franken']
# 1412
# ['Frankenthal']
# 1413
# ['Dessau']
# 1414
# ['Deßau']
# 1415
# ['Venedig']
# 1416
# ['Venedig  Wien']
# 1417
# ['Münster i. W.' 'Münster i.W.']
# 1418
# ['Münster' 'Münster ']
# 1419
# ['Munster']
# 1420
# ['Münster  Hamm']
# 1421
# ['Münster in Westphalen' 'Münster in Westfalen']
# 1422
# ['Münster in Westf.']
# 1423
# ['Münster, Westfalen']
# 1424
# ['Monasterii Westphaliae']
# 1425
# ['Münster  Münster']
# 1426
# ['Osnabrugæ']
# 1427
# ['Osnabrugi']
# 1428
# ['Osnabrück']
# 1429
# ['Oßnabrück']
# 1430
# ['Osnabrüg']
# 1431
# ['Osnabrück  Münster']
# 1432
# ['Osnabrück  Dortmund']
# 1433
# ['Osnabrugi  Osnabrugi']
# 1434
# ['Stockholm Hotel Regina']
# 1435
# ['Stockholm Hotel Plaza']
# 1436
# ['Stockholm Grand Hotel']
# 1437
# ['Stockholm' 'Stockolm']
# 1438
# ['Stockholm  Hamburg']
# 1439
# ['Stockholm  Carlskron']
# 1440
# ['Stockholm  Stockholm  Carlskron']
# 1441
# ['Berlin-Niederschönhausen']
# 1442
# ['Berlin-Niederschöneweide']
# 1443
# ['Starnberg-München']
# 1444
# ['Starnberg']
# 1445
# ['Brunswick']
# 1446
# ['Brunswick  Londres']
# 1447
# ['Märk. Friedland']
# 1448
# ['Friedland']
# 1449
# ['Braine (Aisne) Poststempel']
# 1450
# ['Braine (Aisne) ermittelt']
# 1451
# ['Hittfeld']
# 1452
# ['Hittfeld Eddelsen']
# 1453
# ['St. Goar']
# 1454
# ['St. Goarshausen']
# 1455
# ['Schio' 'Scio']
# 1456
# ['Saigon']
# 1457
# ['Saig']
# 1458
# ['Sion']
# 1459
# ['Shillong']
# 1460
# ['Sagani' 'Sagan']
# 1461
# ['Chang-hai']
# 1462
# ['Chang-Hai']
# 1463
# ['Shanghai' 'Shanghai ' 'Schanghai' 'Shang-ʿhai']
# 1464
# ['Shanghae']
# 1465
# ['Shanghai u.a']
# 1466
# ['Shanghai, China']
# 1467
# ['Schwanheim']
# 1468
# ['Reinfeld']
# 1469
# ['Weinfelden']
# 1470
# ['Posen  Berlin  Breslau  Stettin  Leipzig'
#  'Berlin  Posen  Breslau  Stettin  Leipzig']
# 1471
# ['Berlin  Posen  Breslau  Stettin  Leipzig  London  Moskau']
# 1472
# ['Posen  Berlin  Breslau  Stettin  Leipzig  Moscau  St. Petersburg']
# 1473
# ['Nikolassee Berlin']
# 1474
# ['Nikolassee']
# 1475
# ['Stolp']
# 1476
# ['Strobl']
# 1477
# ['Berlin Kaiserin Augusta-Str. 58' 'Berlin Kaiserin Augusta - Str. 57'
#  'Berlin Kaiserin Augusta - Str. 58' 'Berlin Kaiserin Augusta-Str. 57']
# 1478
# ['Pontresina Schlosshotel']
# 1479
# ['Pontresina Schloss Hotel Enderlin']
# 1480
# ['Rapallo Villa Carlevaro']
# 1481
# ['Rapallo Villa Carlevaro erschl.']
# 1482
# ['Rapallo Villa Devoto']
# 1483
# ['Rapallo Via Avenaggi' 'Rapallo Via Avenaggi 6']
# 1484
# ['Rapallo Villa Andreae']
# 1485
# ['Rapallo Villino Chiaro']
# 1486
# ['Schwednitz  Potsdam' 'Schwedt  Potsdam']
# 1487
# ['Giessae Hassorum' 'Gissae Hassorum' 'Gissae-Hassorum']
# 1488
# ['Gissae-Cattorum']
# 1489
# ['Wismar  Schwerin']
# 1490
# ['Wismar  Schwerin  Rostock']
# 1491
# ['Oxford' 'Oxford ']
# 1492
# ['Budissinae' 'Budissin']
# 1493
# ['Budißin']
# 1494
# ['Budißin  Lauban']
# 1495
# ['Herischdorf Riesengebirge' 'Herischdorf Riesengebrige']
# 1496
# ['Petersdorf (Riesengebirge)']
# 1497
# ['Paris  La Haye  Londres  Berlin  New York'
#  'La Haye  Paris  Londres  Berlin  New York']
# 1498
# ['Berlin  Londres  Paris  La Haye  New York']
# 1499
# ['Paris  Berlin  Londres  La Haye  New-York']
# 1500
# ['La Haye  Berlin  Londres  Paris']
# 1501
# ['Itzstein  Wetzlar']
# 1502
# ['Itzstein']
# 1503
# ['Reval']
# 1504
# ['Revaliae']
# 1505
# ['Arendsee']
# 1506
# ['Arenas']
# 1507
# ['Dalmatien']
# 1508
# ['Sarmatien']
# 1509
# ['Samaden']
# 1510
# ['Crossen (Oder)']
# 1511
# ['Crossen a. Oder']
# 1512
# ['Crossen a.O.']
# 1513
# ['Crossen']
# 1514
# ['Comines']
# 1515
# ['Comi']
# 1516
# ['Colmar']
# 1517
# ['Wolmar']
# 1518
# ['Colmariae']
# 1519
# ['Goslar' 'Goslar?']
# 1520
# ['Goßlar']
# 1521
# ['Goslariae']
# 1522
# ['Brüssel' 'Brüssel ']
# 1523
# ['Brussel']
# 1524
# ['Braila']
# 1525
# ['Brăila']
# 1526
# ['Basileae' 'Basilieae']
# 1527
# ['Basiliae']
# 1528
# ['Basel' 'Basle' 'Basel?']
# 1529
# ['A Basle']
# 1530
# ['Basileæ']
# 1531
# ['Kassel' 'Kassel ']
# 1532
# ['Cassellis' 'Casselis']
# 1533
# ['Cassel' 'Cassell']
# 1534
# ['Hasselt']
# 1535
# ['Kusel']
# 1536
# ['Kagel']
# 1537
# ['Cassellis  Cassellis']
# 1538
# ['Paderborn' 'Paderborn ' 'Paderbornae']
# 1539
# ['Herborn']
# 1540
# ['Herbornae']
# 1541
# ['Paderborn  Arnsberg']
# 1542
# ['Paderborn Schöningh']
# 1543
# ['Erkner bei Berlin']
# 1544
# ['Erkner Berlin']
# 1545
# ['Ahrenshoop Postkarte von']
# 1546
# ['Wangeroog Postkarte von']
# 1547
# ['Zerbst  Wittenberg']
# 1548
# ['Zerbst  Wittenberg  Wittenberg']
# 1549
# ['Stetin  Königsberg']
# 1550
# ['Berlin  Königsberg']
# 1551
# ['Tubingae  Tubingae']
# 1552
# ['Tubingae  Tubingae  Francofurti']
# 1553
# ['Elbingae  Elbingae']
# 1554
# ['Locarno-Monti Villa Jorana' 'Locarno-Monti Villa "Jorana"']
# 1555
# ['Locarno ' 'Locarno']
# 1556
# ['Locarno-Monti']
# 1557
# ['Lugano mutmaßlich']
# 1558
# ['Locarno mutmaßlich']
# 1559
# ['Eisenach Harnstein']
# 1560
# ['Eisenach Hohenhainstein']
# 1561
# ['Newstatt' 'Newenstadt' 'Newenstatt']
# 1562
# ['Neustadt']
# 1563
# ['Neustadt, Orla']
# 1564
# ['Neustadt  Breßlau']
# 1565
# ['Neustadt/Haardt']
# 1566
# ['Newstatt an der Hard' 'Neustatt an der Hard']
# 1567
# ['Neustadt a. d. O.' 'Neustadt a. d. D.']
# 1568
# ['Neustadt a. d. Hdt.' 'Neustadt a.d. Haardt' 'Neustadt a. d. Haardt']
# 1569
# ['Neustadt a.d. Orla']
# 1570
# ['Neustadt an der Orla']
# 1571
# ['Neustad. Ad Oril.']
# 1572
# ['Konstanz' 'Konstanza']
# 1573
# ['Lipsiae  Magdeburgi  Wittenberg  Lipsiae']
# 1574
# ['Lipsiae  Magdeburgi']
# 1575
# ['Philadelphia' 'Philadelphie' 'Phiadelphia' 'Phialdelphia']
# 1576
# ['Philadelphia  Berlin']
# 1577
# ['Philadelphia  Königsberg']
# 1578
# ['Braunschweig  Stolberg am Harz']
# 1579
# ['Braunschweig  überkl. Hamburg']
# 1580
# ['Perleberg  Salzwedel']
# 1581
# ['Gardelegen  Salzwedel']
# 1582
# ['Gardelegen']
# 1583
# ['Gardelegen  Helmstädt']
# 1584
# ['Hiddensee']
# 1585
# ['Hiddensee/ Kloster']
# 1586
# ['Züllichau  Freystadt' 'Züllichau  Freistadt']
# 1587
# ['Straßburg  Straßburg' 'Strasburg  Straßburg']
# 1588
# ['Straßburg  Straßburg  Straßburg']
# 1589
# ['Straßburg  Paris  Straßburg']
# 1590
# ['Striegau' 'Striegau ']
# 1591
# ['New York  München  London']
# 1592
# ['New York  London  München']
# 1593
# ['München  New York  London']
# 1594
# ['New York  London']
# 1595
# ['München  London  New-York']
# 1596
# ['New York' 'New York ']
# 1597
# ['New York City']
# 1598
# ['New York: Harper']
# 1599
# ['New York ermittelt']
# 1600
# ['New York vermutlich']
# 1601
# ['Colbergae  Colbergae']
# 1602
# ['Colbergae  Stettin  Colbergae']
# 1603
# ['Rostochii  Rostochii']
# 1604
# ['Rostochi  Rostochi']
# 1605
# ['Rostock  Rostock']
# 1606
# ["Francfort sur l'Oder"]
# 1607
# ['Francfort sur le Mein']
# 1608
# ['A Francfort sur le Mein']
# 1609
# ['Kreuznach' 'Kreuznach ']
# 1610
# ['Creutzenach']
# 1611
# ['Grätz  Grätz' 'Grätz  Graz' 'Grätz  Gratz']
# 1612
# ['Görlitz  Görlitz']
# 1613
# ['Dresden erschlossen']
# 1614
# ['Bozen-Gries erschlossen']
# 1615
# ['Bozen-Gries']
# 1616
# ['St. Moritz Hotel Caspar Badrutt']
# 1617
# ['St.Moritz Hotel Caspar Badrutt']
# 1618
# ['St. Moritz Hotel Chantarella']
# 1619
# ['St. Moritz Hotel Calonder']
# 1620
# ['St. Moritz Chantarella']
# 1621
# ['St. Moritz Kurhaus Chantarella']
# 1622
# ['Angermünde']
# 1623
# ['Tangermünde']
# 1624
# ['Warnemünde']
# 1625
# ['Travemünde']
# 1626
# ['Travemünde Kurhaus']
# 1627
# ['St. Moritz' 'St.Moritz']
# 1628
# ['Ingolstadt']
# 1629
# ['Ingolstadii']
# 1630
# ['Ingolstadt  München']
# 1631
# ['Ingolstadii  Monachii']
# 1632
# ['Ingolstadii  Eystadii']
# 1633
# ['Washington, DC' 'Washinton D.C.' 'Washington D.C.']
# 1634
# ['Washington']
# 1635
# ['Washington-city']
# 1636
# ['Celle' 'Cellae']
# 1637
# ['Zell' 'Zelle']
# 1638
# ['Cölln  Cölln' 'Cöllen  Cöllen']
# 1639
# ['Cöln  Cöln']
# 1640
# ['Köln  Köln']
# 1641
# ['Cöln am Rhein' 'Köln am Rhein' 'Köln am Rheine' 'Cöln ama Rhein'
#  'Cölln am Rhein' 'Kölln am Rhein' 'Cöllen am Rhein']
# 1642
# ['Coln am Rein']
# 1643
# ['Köln (Rhein)']
# 1644
# ['Cölln am Rhein  Wien  Rom']
# 1645
# ['Köln a. Rh.' 'Köln a.Rh.' 'Cöln a. Rh.' 'Cöln a./Rh.' 'Cöln a.Rh.'
#  'Köln a.R.']
# 1646
# ['Köln a/Rh.']
# 1647
# ['Köln' 'Köln ' 'Köln?']
# 1648
# ['Cöln' 'Cölln' 'Cöllen' 'Cöln ']
# 1649
# ['Cöslin']
# 1650
# ['Mölln']
# 1651
# ['Cöln  Jena']
# 1652
# ['Zwolle']
# 1653
# ['Cellis']
# 1654
# ['Cilli']
# 1655
# ['Fichtenwalde']
# 1656
# ['Mittenwald']
# 1657
# ['Fraustadt']
# 1658
# ['Frau-Stadt']
# 1659
# ['Fraustadt  Lissa']
# 1660
# ['Freystadt']
# 1661
# ['Freistadii']
# 1662
# ['Freienwalde']
# 1663
# ['Freiwaldau']
# 1664
# ['Freital']
# 1665
# ['Osterode']
# 1666
# ['Ostende']
# 1667
# ['Besançon']
# 1668
# ['Bressanone']
# 1669
# ['Vindobonae']
# 1670
# ['Vidobonae']
# 1671
# ['Lugano ermittelt']
# 1672
# ['London ermittelt']
# 1673
# ['Bayreuth ermittelt Haus Chamberlain']
# 1674
# ['Bayreuth Poststempel - Haus Chamberlain']
# 1675
# ['Bayreuth ermittelt']
# 1676
# ['Dessau  Dessau']
# 1677
# ['Deßau  Deßau']
# 1678
# ['Siusi']
# 1679
# ['Silusiae']
# 1680
# ['Schotten']
# 1681
# ['Süchteln']
# 1682
# ['Emden' 'Embden']
# 1683
# ['Embdae' 'Emdae']
# 1684
# ['Eldena']
# 1685
# ['Rauschen']
# 1686
# ['Rauschen Kurhaus']
# 1687
# ['Kilonii' 'Kiloni']
# 1688
# ['Kiliae']
# 1689
# ['Kiliæ']
# 1690
# ['Erffurth  Erffurth' 'Erffurti  Erffurti' 'Erffurt  Erffurt'
#  'Erffurdt  Erffurdt']
# 1691
# ['Erfurti  Erfurti']
# 1692
# ['Oberursel  Frankfurt/Main']
# 1693
# ['Erfurt  Frankfurt/Main']
# 1694
# ['Haag']
# 1695
# ["s' Haage"]
# 1696
# ['Oberhofen']
# 1697
# ['Oberhof']
# 1698
# ['Mülhusii']
# 1699
# ['Mulhusii']
# 1700
# ['Mühlhausen i. Thür.' 'Mühlhausen i. Th.' 'Mühlhausen i.Th.'
#  'Mülhausen i. Th.']
# 1701
# ['Mülhausen' 'Müllhausen']
# 1702
# ['Mühlhausen']
# 1703
# ['Mühlhausen  Jena']
# 1704
# ['Mühlhausen  Erfurt']
# 1705
# ['Mühlhausen  Mühlhausen']
# 1706
# ['Mühlh. i. Th.']
# 1707
# ['Mulhusae']
# 1708
# ['Neuhusii']
# 1709
# ['Oberhausen']
# 1710
# ['Merzhausen']
# 1711
# ['Ebenhausen']
# 1712
# ['Nennhausen']
# 1713
# ['Oberhausen (Rhld.)']
# 1714
# ['Ebenhausen München']
# 1715
# ['Merzhausen Hildenhof']
# 1716
# ['Oberursel']
# 1717
# ['Merzhausen vermutlich']
# 1718
# ['Hersfeld']
# 1719
# ['Gersfeld']
# 1720
# ['Herßfeld']
# 1721
# ['Crefeld']
# 1722
# ['Krefeld']
# 1723
# ['Coesfeld']
# 1724
# ['Landshut' 'Landeshut']
# 1725
# ['Waldshut']
# 1726
# ['Landeshut Schlesien']
# 1727
# ['Cothenis' 'Cothenius']
# 1728
# ['Cothenii']
# 1729
# ['Coloniae Brand.' 'Coloniae Brandenb.']
# 1730
# ['Coloniae Brandenburgicae' 'Coloniae Brandeburgicae'
#  'Coloniae Brandenburgicæ']
# 1731
# ['Coloniæ Brandenburgicæ']
# 1732
# ['Colon. Brandenb.']
# 1733
# ['Coloniae' 'Colonia']
# 1734
# ['Cologne']
# 1735
# ['A Cologne']
# 1736
# ['Boulogne']
# 1737
# ['Bologna']
# 1738
# ['Cologne  Bonn']
# 1739
# ['Coloniae Brandenburgicae  Coloniae Brandenburgicae']
# 1740
# ['Coloniae Ad Spream' 'Coloniae. Ad. Spream.']
# 1741
# ['Colonia ad Spream']
# 1742
# ['Coloniae cis Spream']
# 1743
# ['Coloniae ad Spream']
# 1744
# ['Coloniae cis Spream  Coloniae cis Spream']
# 1745
# ['Mannheim' 'Mannheim ']
# 1746
# ['Mannheim  Speyer']
# 1747
# ['Burgo-Steinfurti' 'Burgsteinfurt' 'Burgosteinfurti']
# 1748
# ['Freudenstadt Hotel Waldeck']
# 1749
# ['Freudenstadt Hotel Waldlust']
# 1750
# ['Wertheim']
# ...
# 5460
# ['Tauberbischofsheim']
# 5461
# ['Pleß  Breslau  Ratibor']
# 5462
# ['Stuttgart vermutlich  Straßburg vermutlich']
# 5463
# ['Perez']
# 5464
# ['São Paulo']
# 5465
# ['Puschlaff']
# 5466
# ['Helgoland']
# 5467
# ['Rønne']
# 5468
# ['Wentorf/Hamburg']
# 5469
# ['Drill']
# 5470
# ['En te Parthenopolei']
# 5471
# ['Nassau Kurhaus']
# 5472
# ['Lipsku  Dreznie']
# 5473
# ['München  Güttland  Danzig  Erfurt']
# 5474
# ['Ascona Kurhaus Collinetta']
# 5475
# ['Luzern  Freiburg, Schweiz']
# 5476
# ['Sainte-Adresse']
# 5477
# ['Stralsund  Königliche Regierungs-Buchdruckerei']
# 5478
# ['Turnbridge Wells']
# 5479
# ['Althagen bei Wustrow, Mecklenburg']
# 5480
# ['Oaxaca']
# 5481
# ['Medingen bei Lüneburg']
# 5482
# ['Clifton']
# 5483
# ['Glasgow']
# 5484
# ['Osaka ']
# 5485
# ['Roorkee']
# 5486
# ['Tarlac']
# 5487
# ['Xalapa']
# 5488
# ['Hudson']
# 5489
# ['Leipsic  Chez Breitkopf & Härtel à Leipsic']
# 5490
# ['Ravicii']
# 5491
# ['Be1 Bl.']
# 5492
# ['Torbole']
# 5493
# ['Peresznye bei Csepreg']
# 5494
# ['Orkney']
# 5495
# ['Zagreb']
# 5496
# ['Hain Haus Hockewanzel']
# 5497
# ['Kudowa']
# 5498
# ['Lüttich']
# 5499
# ['Namslau']
# 5500
# ['Wjasma']
# 5501
# ['50 Bl.']
# 5502
# ['Iavorii']
# 5503
# ['V Praze']
# 5504
# ['Capebam']
# 5505
# ['Egypten']
# 5506
# ['Heide  Friedrichstadt']
# 5507
# ['Garmisch Partenkirchen Hotel Gibson']
# 5508
# ['Bad Brambach Haus Bergfrieden']
# 5509
# ['Steinigtwolmsdorf']
# 5510
# ['Ouderkerk bij Amsterdam']
# 5511
# ['Marggrabowa']
# 5512
# ['Ferrara']
# 5513
# ['Wernigerode vermutlich Poststempel schlecht lesbar']
# 5514
# ['Guben in Nieder-Lausitz']
# 5515
# ['St. Bernhard;Genf']
# 5516
# ['Royal Gardens Kew']
# 5517
# ['Genff im Hollandt']
# 5518
# ['Lenzkirch Hirahof']
# 5519
# ['Breslau-Neukirch  Bonn  Heidelberg']
# 5520
# ['Pirk Schloss Pirk']
# 5521
# ['Tugii Helvetiorum']
# 5522
# ['Ammendorf b. Halle a. S']
# 5523
# ['Kilchberg-Zürich']
# 5524
# ['Madonna di Campiglio Poststempel']
# 5525
# ['Göggingen  Mittelschreiberhau']
# 5526
# ['Manila, Philippine Islands']
# 5527
# ['Neapel an Bord der Sachsen']
# 5528
# ['Zerbst  Magdeburg  Zwickau']
# 5529
# ['Wolkenstein Warmbad']
# 5530
# ['Roubaix']
# 5531
# ['Obornik']
# 5532
# ['Danzig fingiert  Druckort- Paris']
# 5533
# ['Flöha i. S.']
# 5534
# ['Rom 22 Via dei Villini']
# 5535
# ['Moyencourt Ergänzung von Margarete Hauptmann']
# 5536
# ['Certaldo/Italien']
# 5537
# ['Haaseloff in Weitland']
# 5538
# ['Culm an der Weichsel']
# 5539
# ['Girgenti Hotel Belvedere']
# 5540
# ['Botanischer Garten bei Berlin']
# 5541
# ['Franckfurt  Leipzig  Naumburg  Leipzig  Franckfurt  Merseburg  Merseburg  Franckfurt  Leipzig']
# 5542
# ['Fürstenberg Sanatorium Schloss Fürstenberg']
# 5543
# ['Obernai (Bas Rhin)']
# 5544
# ['Hain Riesengebirge']
# 5545
# ['Reesewitz bei Oels']
# 5546
# ['Campidonae  Augustae Vindelicorum  Kauffburae']
# 5547
# ['Koblenz  Brüssel  Rotterdam  Koblenz']
# 5548
# ['Mainz Antwerpen und Brüssel']
# 5549
# ['Büderich bei Düsseldorf - Poststempel']
# 5550
# ['Königstein (Taunus)']
# 5551
# ['Wien Hübners Parkhotel Schönbrunn']
# 5552
# ['Ante (Marne)']
# 5553
# ['Casoro Figino']
# 5554
# ['Magonza  Roma']
# 5555
# ['Herenchiemsee']
# 5556
# ['St. Leonhardt (Elsaß)']
# 5557
# ['Berg am Starnberger See']
# 5558
# ['Middelburg  Middelburg  Middelberg  Middelberg']
# 5559
# ['Leamington-Warwickshire']
# 5560
# ['Wien und Süddeutschland']
# 5561
# ['Gouda']
# 5562
# ['Ibagué']
# 5563
# ['Tartu']
# 5564
# ['Amalfi']
# 5565
# ['Korfu']
# 5566
# ['Confluentiae']
# 5567
# ['Bacharach']
# 5568
# ['St. Peter Spindelmühle']
# 5569
# ['Æquinoctio  Zürich?']
# 5570
# ['Itzehoe']
# 5571
# ['Neudamm']
# 5572
# ['Bordesholm']
# 5573
# ['Ostheim']
# 5574
# ['Leitmeritz']
# 5575
# ['Kjustendža']
# 5576
# ['Ustrzyki dolne']
# 5577
# ['Rappoltsweiler']
# 5578
# ['Fauvillers']
# 5579
# ['Neuveville']
# 5580
# ['Bayern oder Niederösterreich']
# 5581
# ['Braunschweig  New York, NY  Paris  Bruxelles  Schutte  London']
# 5582
# ['Paraggi Hotel Pension Cosmopolite']
# 5583
# ['Zweibrücken']
# 5584
# ['Budyschini  Budyschini']
# 5585
# ['Wasserdrüdingen  Zittau']
# 5586
# ['Rauscha O.-L.']
# 5587
# ['Frölichs-Burg']
# 5588
# ['Brüssel  Ort in Vorlageform- Jideeltje']
# 5589
# ['Hamburg Hotel zu den Vier Jahreszeiten']
# 5590
# ['Schönborn bei Züllichau']
# 5591
# ['Oberpöcking vermutlich Starnberger See']
# 5592
# ['La Spezia']
# 5593
# ['Kirchzarten  St. Petersburg']
# 5594
# ['Seugenhof Eschkam']
# 5595
# ['Bad Staffelstein ermittelt']
# 5596
# ['Brückenau <Bad>;']
# 5597
# ['Montana-Vermala']
# 5598
# ['南京  nan jing']
# 5599
# ['Ystad Hotel Saltsjöbaden']
# 5600
# ['Möltenort bei Kiel']
# 5601
# ['Paris  Wisbade  Francfort-sur-le-Mein  Mayence  Paris']
# 5602
# ['Prinz-Heinrich-Baude im Riesengebirge - Poststempel']
# 5603
# ['St. Gilgen bei Ischl']
# 5604
# ['Kampen Haus Kampmann auf Sylt']
# 5605
# ['Mainz  Bei B. Schott in Mainz']
# 5606
# ['Neu Globsow Haus Brandenburg']
# 5607
# ['Bologna auf dem Dampfer Cap Arcona']
# 5608
# ['Bennigsen  München']
# 5609
# ['Ilfeld am Harz']
# 5610
# ['Byzantinisches Reich']
# 5611
# ['Pengkalan Pasir']
# 5612
# ['Donauwörth']
# 5613
# ['Tōkyō']
# 5614
# ['Port-Artur']
# 5615
# ['Sofia']
# 5616
# ['Plock']
# 5617
# ['Billerbeck']
# 5618
# ['Fortemarmi']
# 5619
# ['Locarno-Orselina Villa "Les Hirondelles"']
# 5620
# ['Nizza']
# 5621
# ['Feldberg Feldberghotel und Feldbergerhof']
# 5622
# ['Florenz Villa Fontanella alla Badla']
# 5623
# ['Turku']
# 5624
# ['Guadeloupe']
# 5625
# ['Neudamm-Berlin  Kassel-Wilhelmshöhe']
# 5626
# ['Bodenseegebiet']
# 5627
# ['Ǧidda']
# 5628
# ['Mekka']
# 5629
# ['Vevey']
# 5630
# ['Modegascar']
# 5631
# ['Sternwarte bei Christiania']
# 5632
# ['Weston-super-Mare']
# 5633
# ['Rüben-Rötha i.Sa.']
# 5634
# ['Tarnopol im Schützengraben']
# 5635
# ['Heyligenstadt in Eichsfeld']
# 5636
# ['Berlin Schloss Rehnitz  Rehnitz Schloss Rehnitz']
# 5637
# ['Kaltenleutgeben']
# 5638
# ['Kempen, im Großherzogthum Posen']
# 5639
# ['Heerenveen']
# 5640
# ['Dihernfurṭ']
# 5641
# ['Niederuzwil (St. Gallen)']
# 5642
# ['Malmesburg  Wiesenthal']
# 5643
# ['Freiburg i. Br.  Freiburg i. Br.  Freiburg i. Br.  Freiburg i. Br.  Freiburg i. Br.']
# 5644
# ['Köln  Waldshut  Einsiedeln']
# 5645
# ['Jauer  See  Ober-Schönfeld']
# 5646
# ['Mittweyda  Penig']
# 5647
# ['Liberec Reichenberg']
# 5648
# ['Longo-Salissae']
# 5649
# ['Buenos Aires']
# 5650
# ['Crans s/Sierre']
# 5651
# ['Svaety Antol']
# 5652
# ['Morcote Lugano']
# 5653
# ['Nice Villa La Baraque']
# 5654
# ['U Dubrovniku']
# 5655
# ['Villach']
# 5656
# ['Bockwitz (Kr. Liebenwerda)']
# 5657
# ['Positano Salerno']
# 5658
# ['Oetingae Rhetorum']
# 5659
# ['Schloss Schwarzenau']
# 5660
# ['Roßtrappe']
# 5661
# ['Grenzgebiet Bayern/Österreich']
# 5662
# ['Berlin Fritz Troepfers Hotel Prinz Friedrich Carl']
# 5663
# ['En Biennē tēs Austrias']
# 5664
# ['Mödingen, Kloster Maria Medingen']
# 5665
# ['Milan  Florence  Mendrisio  Bonn']
# 5666
# ['Peking i.e. Thal-Ehrenbreitstein']
# 5667
# ['Stratford on Avon']
# 5668
# ['Singen-Hohentwiel']
# 5669
# ['Aurach Haus Hildegard']
# 5670
# ['Köln (Kartause St. Barbara)']
# 5671
# ['Sansscouci']
# 5672
# ['Grenoble']
# 5673
# ['Pestini Budae  Cassoviae  Pestini']
# 5674
# ['Varenna vermutlich Bildpostkarte von Varenna']
# 5675
# ['Chantarella St. Moritz']
# 5676
# ['Ried b. Benediktbeuern']
# 5677
# ['Bensheim  Offenbach']
# 5678
# ['Woolwich']
# 5679
# ['Blumeshof']
# 5680
# ['Morogoro']
# 5681
# ['Uithuizen']
# 5682
# ['San Borja']
# 5683
# ['Kitzbühel']
# 5684
# ['Cornwall']
# 5685
# ['Flottbeck']
# 5686
# ['Cöpenick']
# 5687
# ['Langenbielau Preussischer Hof']
# 5688
# ['Venezia San Marco, Hotel Splendid Corso']
# 5689
# ['Sattendorf Berghof']
# 5690
# ['Bécs']
# 5691
# ['Orotava']
# 5692
# ['Graptomaniacum']
# 5693
# ['Garrey Fläming']
# 5694
# ['Darmstadt Generaldirektion des Hessischen Landestheaters']
# 5695
# ['Aumühle']
# 5696
# ['Graal-Müritz Kurhaus Neuhaus']
# 5697
# ['Diez an der Lahn Oranien']
# 5698
# ['Beaulieu Hotel Metropole']
# 5699
# ['Leipzig  Göttingen  Altona  Helmstädt  Berlin  Halle']
# 5700
# ['Klais ermittelt Schloss Elmau']
# 5701
# ['Flemming  Glogau']
# 5702
# ['Wirsitz in Posen']
# 5703
# ['Breslau abgebildet das Stadttheater in Breslau']
# 5704
# ['Bremen Marine Genesungsheim St. Magnus']
# 5705
# ['Portofino a Mare Villa Aurelia  Genova Villa Aurelia']
# 5706
# ['Mürzzuschlag']
# 5707
# ['Wenningstedt Sylt']
# 5708
# ['Diözese Utrecht']
# 5709
# ['Lugano Hotel Weisses Kreuz Schiller']
# 5710
# ['Oberloschwitz Sanatorium Königspark']
# 5711
# ['Patras Aufdruck Postkarte']
# 5712
# ['Andernach Gut Nettehammer']
# 5713
# ['Saarbrücken']
# 5714
# ['Napoléon-Vendée']
# 5715
# ['Neu-Ulm  Memmingen']
# 5716
# ['Glücksburg Kurhaus']
# 5717
# ['Zella am Thüringer Walde']
# 5718
# ['Apolda']
# 5719
# ['Damaskus']
# 5720
# ['Makassar']
# 5721
# ['Slough']
# 5722
# ['Dännemark']
# 5723
# ['Zug']
# 5724
# ['Pie\x9atany']
# 5725
# ['Schoffschütz']
# 5726
# ['Niederseeon über Moosach']
# 5727
# ['Seeshaupt']
# 5728
# ["Gowgark'"]
# 5729
# ['Olomucii']
# 5730
# ['Hann. Münden']
# 5731
# ['Edinburgh  Glasgow  Dundee  London  London  Dublin  Edinburgh']
# 5732
# ['Besserwirds']
# 5733
# ['Norditalien und Provence  Norditalien']
# 5734
# ['Schierke/Harz Hotel Fürst zu Stolberg']
# 5735
# ['Zoagli Beschriftung Ansichtspostkarte']
# 5736
# ['Malente-Gremsmühlen in Holstein']
# 5737
# ['Gabicce di Cattolica']
# 5738
# ['Voralberg Waldhaus Brand bei Bludenz']
# 5739
# ['Cölln  München  Franckfurt  Wienn']
# 5740
# ['Tiefenbach Oberstdorf']
# 5741
# ['Warder vermutlich  Werder vermutlich']
# 5742
# ['Kamenez-Podolski']
# 5743
# ['Altstadt-Königsberg']
# 5744
# ['Sunne Marbacka']
# 5745
# ['Ludwigslust  Parchim  Boizenburg']
# 5746
# ['Ienae  Helmstadii  Weissenfelsae']
# 5747
# ['Bad Reichenhall Hotel am Predigtstuhl']
# 5748
# ['Maurbach (Niederösterreich)']
# 5749
# ['Heterodoxiepolis i.e. Braunschweig']
# 5750
# ['Sankt Andreasberg  Göttingen']
# 5751
# ['上海']
# 5752
# ['Rom Albergo Atlantico Roma']
# 5753
# ['隆福寺  北京 : 聚珍堂']
# 5754
# ['Leipzig  Wilna  Wilna  Warschau  Warschau  Hamburg  St. Petersburg']
# 5755
# ['Sorento Sorrento']
# 5756
# ['Licata bei Girgenti in Sizilien ?']
# 5757
# ['En Kōnstantinupolei']
# 5758
# ['Hotel Cumberland Berlin W. 15']
# 5759
# ['Die neueste Edition  Franckfurth  Leipzig']
# 5760
# ['Estoril bei Lissabon']
# 5761
# ['Careggi bei Florenz']
# 5762
# ['La Haye  La Haye  Amsterdam  La Haye  Amsterdam']
# 5763
# ['Timmendorfer Strand']
# 5764
# ['Kunern bei Münsterberg']
# 5765
# ['Nimes Hotel Imperator Nimes']
# 5766
# ['Trier  Mainz  Salzburg  Bonn  Köln']
# 5767
# ['Nunspeet']
# 5768
# ['Wädenswil Neugut']
# 5769
# ['Vallombrosa']
# 5770
# ['w Kwidzynie']
# 5771
# ['Kehrsatz Landgut Lohn']
# 5772
# ['Hochburg bey Weinhausen']
# 5773
# ['Hain  Fellhammer  Berlin - Charlottenburg']
# 5774
# ['Liebfrauenberg près Woerth Bas Rhin']
# 5775
# ['In Civitate Veronidum']
# 5776
# ['Focşani']
# 5777
# ['東京  岩国  広島  大阪']
# 5778
# ['Gstaad Royal Hotel, Winter & Gstaad Palace']
# 5779
# ['Puerto de la Cruz Kanarische Inseln']
# 5780
# ['Lago di Garda Villa Halkyone']
# 5781
# ['St. Ulrich in Groeden']
# 5782
# ['Van-See']
# 5783
# ['ohne Ort']
# 5784
# ['Tur Abdin']
# 5785
# ['Abendroth Heiden']
# 5786
# ['Regiom. Borussonu.  Regiom. Borussonu.']
# 5787
# ['Weißenburg in Franken  Ingolstadt']
# 5788
# ['W Berlinie y Szczecinie  W Wrocławiu y Lesznie  W Wrocławiu']
# 5789
# ['Gottlieben bei Konstanz']
# 5790
# ['Diözese Augsburg oder Regensburg']
# 5791
# ['Müritz Ostseebad Müritz']
# 5792
# ['Aussig']
# 5793
# ['Schloss Roop']
# 5794
# ['Riesengebirge Hotel Schneekoppe']
# 5795
# ['Moeno-Francofurti  Offenbachi Ysenburg']
# 5796
# ['Bühl Kurhaus und Sanatorium Bühlerhöhe']
# 5797
# ['Pansdorf Eschenhof']
# 5798
# ['Tönning']
# 5799
# ['Weimar  Utrecht  Amsterdam  Rotterdam  Leipzig']
# 5800
# ['Huy']
# 5801
# ['Ort nicht entzifferbar']
# 5802
# ['Monti Trinita']
# 5803
# ['Höchenschwand']
# 5804
# ['Mönichkirchen']
# 5805
# ['Sorau . Im Selbstverlage des Verfassers']
# 5806
# ['V Rostove na Donu']
# 5807
# ['Leucopetrae']
# 5808
# ['Ciudad de México']
# 5809
# ['Przemyśl']
# 5810
# ['Koljuschki']
# 5811
# ['Gedruckt an der österreichischen Gränze  Breslau']
# 5812
# ['Wusterhanse (Kreis Neustettin)']
# 5813
# ['Palaion - Phaliron']
# 5814
# ['Thamsbrück bei Langensalza']
# 5815
# ['Seis am Schlern Hotel Dolomitenhof']
# 5816
# ['Vilkerath Rhld.']
# 5817
# ['Isfahan']
# 5818
# ['Rieben Ortsteil der Stadt Beelitz']
# 5819
# ['Le Tréport']
# 5820
# ['Ort in Vorlageform- München  Berlin']
# 5821
# ['Banskabystrica']
# 5822
# ['Côtes Lorraine']
# 5823
# ['San Martino di Castrozza Hotel Dolomiti']
# 5824
# ['Sylt Postkarte vom Nordseebad Sylt']
# 5825
# ['Schweigmatt Kurhaus Schweigmatt']
# 5826
# ['Hessisch-Lichtenau']
# 5827
# ['Ohlau Schloss Jacobine bei Ohlau, Schlesien']
# 5828
# ['Diablerets Grand Hotel des Diablerets']
# 5829
# ['Dorotheenthal bei Arnstadt']
# 5830
# ['Highland Park, Ill.']
# 5831
# ['Raginae Hradecii']
# 5832
# ['Naini Tal']
# 5833
# ['Hofheim im Taunus  Wolfshau']
# 5834
# ['Wuppertal']
# 5835
# ['Schluderbach/Südtirol']
# 5836
# ['Pedeponti']
# 5837
# ['Posen;  Buchdruckerei des "Kuryer Poznnanski"']
# 5838
# ['Wittstock']
# 5839
# ['Dayton / Ohio']
# 5840
# ['1 Brief, 4 S.']
# 5841
# ['Hagae Comitis']
# 5842
# ['Dommelstadl Neuburg']
# 5843
# ['Klein-Flottbek Holstein']
# 5844
# ['Glaucha-Hallensis']
# 5845
# ['Presso Antonio Zatta E Figli. In Venezia  Venezia']
# 5846
# ['Máramarossziget']
# 5847
# ['Dt. Krone']
# 5848
# ['Tavoy']
# 5849
# ['Iloilo']
# 5850
# ['Hijar']
# 5851
# ['洛陽 京都']
# 5852
# ['Vulpera Schweizerhof']
# 5853
# ['Gausdal Aulestad']
# 5854
# ['Fossé']
# 5855
# ["Köln ... Gedruckt in der Langen'schen Buchdruckerei"]
# 5856
# ['Elmau Schloss Elmau, Oberbayern']
# 5857
# ['Anacapri Via Boffe']
# 5858
# ['Amstelodami  Lipsiae  Noribergae  Kilonae  Lubecae  Brunswicae  Halae  Berolina  Francofurti  Francofurti  Hamburgi']
# 5859
# ['Hohenschönhausen KZ Lager Hohenschönhausen']
# 5860
# ['Abinger Common Abinger Manor Cottage']
# 5861
# ['Mortschach a.Vierwaldstättersee']
# 5862
# ['Hasenpoth  Mitau']
# 5863
# ['Misdroy/Ostsee']
# 5864
# ['Berlin Verlag der Königlichen Geheimen Ober-Oberhofbuchdruckerei (R. v. Decker)']
# 5865
# ['Riessersee Kurhotel Riessersee']
# 5866
# ['Sondervig Jütland']
# 5867
# ['Matsuyama']
# 5868
# ['Springfield, Mass.']
# 5869
# ['Wunstorf  Ranstädt']
# 5870
# ['Novi Sad']
# 5871
# ["Ayravank'"]
# 5872
# ['Trinity Colege, Cambridge']
# 5873
# ['Gotha  Dreßden  Franckfurt am Mayn  Leipzig  Franckfurt an der Oder  Franckfurt an der Oder  Gotha']
# 5874
# ['Grundschöttel, Post Volmarstein']
# 5875
# ['Eaux-Bonnes']
# 5876
# ['Noordwyk aan Zee Huis Ter Duin']
# 5877
# ['Lutetiae Parisiorum  Parisiis']
# 5878
# ['G.']
# 5879
# ['Veitsch Proschenhof']
# 5880
# ['Fort Marlborough']
# 5881
# ['Foochow ']
# 5882
# ['Plitvicer Seen']
# 5883
# ['Nothburg im Zwingenthal  Uri']
# 5884
# ['zum Hof']
# 5885
# ['Kufstein Edschlössel']
# 5886
# ['East Grinstead Shovelstrode Manor']
# 5887
# ['Kuala Lumpur  London']
# 5888
# ['Cuba bey Gera']
# 5889
# ['Tham in der Newmarck']
# 5890
# ['Slg. I 大阪  江戸  Slg. II 江戸  京都']
# 5891
# ["Capri Ca'-Del-Sole"]
# 5892
# ['Lengenfeld unterm Stein']
# 5893
# ['Cranley Place, Onslow Square']
# 5894
# ['Istambol  Monte Santo  Coburg']
# 5895
# ['Paramé - Saint Malo']
# 5896
# ['Ostseebad Ahrenshoop Haus Hoffmann']
# 5897
# ['Selo-Boldino, Russland']
# 5898
# ['Bad Salzschlirf Villa Rottstein']
# 5899
# ['Aychstätt']
# 5900
# ['Ṭûr-ʿAbdîn']
# 5901
# ['Kufstein Pension Neuhaus']
# 5902
# ['Neue Auflage. (Unveränderter Abdruick der Auflage von 1821)']
# 5903
# ['Starfield, Liverpool']
# 5904
# ['Mähr.-Ostrau']
# 5905
# ['Altheide Kreis Glatz']
# 5906
# ['Bokenäs Wärnanäs']
# 5907
# ['Ephrata, Pa.']
# 5908
# ['Newark New Jersey']
# 5909
# ['Dord  Haarlem  Delft  Amsterdam  Leiden  Leiden  Rotterdam  Gouda  Hage  Alkmaar  Hoorn  Enkhuizen  Middelburg  Middelburg  Utrecht  Zaandam']
# 5910
# ['Rhein-Maingebiet (Frankfurt a.M.?)']
# 5911
# ['Gatterstädt bei Querfurt']
# 5912
# ['Colle Isarco Palace-Hotel']
# 5913
# ['1 Postkarte, 1 S. und Adresse']
# 5914
# ['Nouveau-Phalére']
# 5915
# ['Woolton Liverpool']
# 5916
# ['Calmar im Königreich Schweden']
# 5917
# ['Norddorf/Amrun']
# 5918
# ["L'vov"]
# 5919
# ['Vulaqhavbaqhadur Ulaanbaatar']
# 5920
# ['Friemersheim (Niederrhein)']
# 5921
# ['Stockton-on-Tees, Durham']
# 5922
# ['Amoy']
# 5923
# ['Pelton Colliery, Chester le Stret']
# 5924
# ['Reykjavik']
# 5925
# ['Elderen  Ottobeyren  Eldern  Ottobeuren']
# 5926
# ['Lány']
# 5927
# ['Capri Morgano & Tiberio Palace']
# 5928
# ['北平']
# 5929
# ['Kyïv']
# 5930
# ['Åbo']
# 5931
# ['學古堂  gu xue tang']
# 5932
# ['Neu-Bojanowa  Neu-Bojanowa']
# 5933
# ['Uffing am Staffelsee']
# 5934
# ['Tullnerbach-Pressbaum bei Wien, Villa Kastner']
# 5935
# ['Feldpoststation A.A. Falkenhausen']
# 5936
# ['Hoppenrade bei Löwenberg (Mark)  Bleicherode bei Löwenberg (Mark)']
# 5937
# ['Ilha de Paqueta']
# 5938
# ['Kiltsi/Schloss Ass, Wierland']
# 5939
# ['江陵, 湖北  jiang ling']
# 5940
# ['Hradec Králowé']
# 5941
# ['Nor Jowġa']
# 5942
# ['Katzhütte Danz´s Bahnhofs-Hotel und Restaurant']
# 5943
# ['Lofthouse Park, Wakefield (Yorkshire), Sued-Lager']
# 5944
# ['順天 (北京)']
# 5945
# ['Nykyrka Övralid']
# 5946
# ['禪山  聖德堂']
# 5947
# ['武英殿']
# 5948
# ['葛塚 クズツカ 新潟県  東京']
# 5949
# ['姑蘇  槐蔭草堂']
# 5950
# ['南都 奈良']
# 5951
# ['裏如棠  碧香齋  檢香齋  振賢堂']
# 5952
# ['華藏']
# 5953
# ['尚義堂 重刊  宣城  宗文書院 刊行']
# 5954
# ['江南省 通行']
# 5955
# ['裏如堂  省城醉經樓']
# 5956
# ['湖南']
# 5957
# ['揚州詩局刻']
# 5958
# ['英華書院刊']
# 5959
# ['鳳城龍山鄉']
# 5960
# ['あいのまち通高田町 京都']
# 5961
# ['竹韻山房 藏']
# 5962
# ['天台山']
# 5963
# ['大津, 白河']
# 5964
# ['古虞朱氏 刊']
# 5965
# ['合肥李氏重刊']
# 5966
# ['中西時務學堂新鐫  中西時務學堂']
# 5967
# ['荊州 : 荊州駐防繙譯總學']
# 5968
# ['一經堂']
# 5969
# ['槐堂書齋 裔孫邦瑞 刊']
# 5970
# ['金陵']
# 5971
# ['香港']
# 5972
# ['内府刻本']
# 5973
# ['覺亭梁氏鐫']
# 5975
# ['閩']
# 5976
# ['闽']
# 5977
# ['嵯峨']
# 5978
# ['湘鄉']
# 5979
# ['晦明軒']
# 5980
# ['奈良']
# 5981
# ['寧波']
# 5982
# ['横浜']
# 5983
# ['見返し']
# 5984
# ['根来']

# %%
if not os.path.exists("./picklez/"):
    os.mkdir("./picklez/")
# backup of the dataframe as we are going to remove data from the spatialClean column
pickleCompress('./picklez/df3_unclean_spatials.picklez',df3)
# if you want to continue from here, uncomment the following line
#df3=pickleDecompress('./picklez/df3_unclean_spatials.picklez')
# Out:
# [2018-09-21 16:24:57.095634]	Pickling to './picklez/df3_unclean_spatials.picklez'
# [2018-09-21 16:25:09.766654]	Pickling done.

# %% [markdown]
# ### Further Cleaning
#
# You might have noticed that preparing your data is a cumbersome task. On some occasions, we even have to deal with spatialClean entries that contain multiple cities.

# %%
# PPN836134109 contains multiple cities
df3[df3.PPN=="PPN836134109"]
# Out:
#                                                object    type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                 creator             subject                           spatial issued  date alternative  \
# 22  http://digital.staatsbibliothek-berlin.de/euro...  Volume  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Ludwig Ernst von Faramond seltsame aber wohlme...  image/jpeg  Faramond, Ludwig Ernst: Ludwig Ernst von Faram...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  Faramond, Ludwig Ernst  Historische Drucke  Leipzig  Franckfurth  [Nürnberg]   1732  1732         NaN
#
#    publisher                                           relation description           PPN                    spatialClean dateClean spatialCluster
# 22    Monath  Faramond, Ludwig Ernst: Ludwig Ernst von Faram...         NaN  PPN836134109  Leipzig  Franckfurth  Nürnberg      1732           3549

# %% [markdown]
# In this notebook, we will face this challenge with a simple approach. To handle compound city names, we will work with a lookup table that is read from disk. The list contains only German cities but the method can be easily extended by using the ressources presented above. In addition, we will also handle typical prefix such as "Saint", "St.", "Den", "New", "Bad" etc.
# To simplify the example, we will only consider the first found city name in case of multiple entries.

# %%
cityNameFile_DE = open('citynames.txt', 'r')
cityNGramsDE=dict()
lastLetter=""
for line in cityNameFile_DE:
    if not line.startswith("//"):
        r=line.replace("\n","").strip()
        if " " in r:
            #print r
            if not lastLetter==r[0].lower():
                lastLetter=r[0].lower()
                cityNGramsDE[lastLetter]=[]
            cityNGramsDE[lastLetter].append(r)
            #py27 cityNGramsDE[lastLetter].append(r.decode("utf-8"))

# Various test cases of city names
#s1="Frankfurt, O"
#s2='Hallae Magdeburgicae  Hallae Magdeburgicae'
#s3="Leipzig  Paris  Petersburg  London"
#s4='Franckfurt  N\xc3\xbcrnberg  Leipzig'
#s5='Freiburg i.Br. ' # not matched correctly but okay
#s6='Frankfurt/Main' 
#s7='Frankfurt, Main'

#s8='Bad Nauheim'
#s9='Rottach-Egern am Tegernsee'
#s10='Egern a. Tegernsee'
#s11="Plancy-L'Abbaye"
#s12='Bad Nauheim Sankt'
#s13="Saint Tropez"
#s14="Sankt Augustin"
#s15="Sankt-Augustin"
#s16="St.-Whatever"
#s17="St. Whatever"

def pickFirstCity(testString):
# checks if the testString contains multiple cities separated by whitespaces and returns the first city respecting city name prefixes such as Saint, St. etc.
    #py27 testString=unicode(testString,"utf-8")
    #print type(testString)
    #testString=testString.decode('unicode-escape')
    
    # matches for whitespaces that are NOT preceded by the following signs: ", ; : \ / " denoted in the regex by (?<!...)
    regex = re.compile("(?<![,;:\\\/])\s*",re.UNICODE)

    # matches various city prefix such as Saint etc.
    spatialPrefixRegExes=[]
    spatialPrefixRegExes.append(re.compile("^[Bb][Aa][Dd]\s*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Ss][Aa][Nn][Kk][Tt][\s-]*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Ss][Aa][Ii][Nn][Tt][\s-]*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[S][t]\.[\s-]*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Dd][Ee][Nn]\s*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Ne][Ee][Ww]\s*",re.UNICODE))

    #print "Tested string: >%s<" % testString
    
    if allowExactStringMatching:
        # checks whether the spatial is known to consist of more than one word
        # for the sake of efficiency we will only check for spatial names with the same leading character (see above)
        lowTestString=testString.lower()
        if len(lowTestString)>=1:
            currentLetter=lowTestString[0]
            if currentLetter in cityNGramsDE:
                for cityName in cityNGramsDE[currentLetter]:
                    foundIndex=lowTestString.find(cityName.lower())
                    #regexCity = re.compile("^\b"+cityName.lower()+"\b",re.UNICODE)
                    r=re.match("\\b"+cityName.lower()+"\\b",lowTestString)
                    #if foundIndex==0:
                    if r is not None:
                        #print "Compound city: "+cityName+" @ "+str(foundIndex)
                        return cityName
    
    # general purpose splitting
    foundSpatialPrefix=False
    for i,r in enumerate(spatialPrefixRegExes):
        m = r.search(testString)
        if m:
            #print "Prefix %i" %i
            foundSpatialPrefix=True
    #print type(testString)
    m = regex.split(testString)
    
    if foundSpatialPrefix:
        if len(m)>1:
            return m[0]+" "+m[1]
    else:
        return m[0]

print(pickFirstCity('Bad Königshofen im Grabfeld'))
# Out:
# Bad Königshofen im Grabfeld

# %% [markdown]
# Next, we will process the complete dataframe.

# %%
counter=0
maxItems=df3.shape[0]

multipleCitiesPPN=dict()

printLog("Processing multiple spatial names entries...")
for row in df3.iterrows():
    ppn=str(row[1]["PPN"])  
    spatialC=str(row[1]["spatialClean"])
    multipleCitiesPPN[ppn]=[]
    
    counter=counter+1
    if counter%10000==0:
        printLog("\tProcessed %i items of %i"%(counter,maxItems))
                
    if spatialC:
        origSpatialClean="<"+spatialC+"> ("+ppn+")"
        f=pickFirstCity(spatialC)
        loopCount=1
        while f:
            #print f
            multipleCitiesPPN[ppn].append(f)
            #py27 spatialC=spatialC.decode("utf-8")
            spatialC=re.sub('\s+',' ',spatialC.replace(f,u"")).strip()
            #py27 spatialC=spatialC.encode("utf-8")
            if spatialC:
                #print "<"+f.encode("utf-8")+"> | <"+spatialC+">"
                #f=spatialC
                f=pickFirstCity(spatialC)
            else:
                #print origSpatialClean
                break
            loopCount=loopCount+1
            if loopCount>15:
                printLog("Max. loop count reached @ "+origSpatialClean+ " with last f of: <"+f+">")
                break
        #if f:
            #spatialC=spatialC.decode("utf-8")
            #spatialC=spatialC.replace(f,u"").strip()
            #spatialC=spatialC.encode("utf-8")
            #if spatialC:
                #print origSpatialClean
                #print "<"+f.encode("utf-8")+"> | <"+spatialC+">"
                #counter=counter+1
                #if counter==10:
                    #break
    #print ppn
    #break
printLog("Done.")
pickleCompress("./picklez/multipleSpatialNamesPerPPN.picklez",multipleCitiesPPN)
# Out:
# [2018-09-21 16:25:09.922536]	Processing multiple spatial names entries...
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:79: FutureWarning: split() requires a non-empty pattern match.
# [2018-09-21 16:25:11.071039]		Processed 10000 items of 120000
# [2018-09-21 16:25:12.302919]		Processed 20000 items of 120000
# [2018-09-21 16:25:13.400695]		Processed 30000 items of 120000
# [2018-09-21 16:25:14.596309]		Processed 40000 items of 120000
# [2018-09-21 16:25:15.605498]		Processed 50000 items of 120000
# [2018-09-21 16:25:16.778174]		Processed 60000 items of 120000
# [2018-09-21 16:25:18.099298]		Processed 70000 items of 120000
# [2018-09-21 16:25:19.139005]		Processed 80000 items of 120000
# [2018-09-21 16:25:20.212773]		Processed 90000 items of 120000
# [2018-09-21 16:25:21.288014]		Processed 100000 items of 120000
# [2018-09-21 16:25:22.341198]		Processed 110000 items of 120000
# [2018-09-21 16:25:23.440016]		Processed 120000 items of 120000
# [2018-09-21 16:25:23.441632]	Done.
# [2018-09-21 16:25:23.442106]	Pickling to './picklez/multipleSpatialNamesPerPPN.picklez'
# [2018-09-21 16:25:24.683460]	Pickling done.

# %% [markdown]
# * display the PPNs with multiple spatial names

# %%
for ppn in multipleCitiesPPN:
    array=multipleCitiesPPN[ppn]
    if len(array)>1:
        #py27 print(ppn+":\t"+"; ".join(array).encode("utf-8"))
        print(ppn+":\t"+"; ".join(array))
        #for e in array:
            #print e.encode("utf-8")
# Out:
# PPN836134109:	Leipzig; Franckfurth; Nürnberg
# PPN836042700:	Leipzig; Franckfurt
# PPN779175883:	Franckfurt; Nürnberg; Leipzig
# PPN782853501:	Birkenfeld; Idar-Oberstein
# PPN833198416:	Altona; Hamburg
# PPN822087154:	Sedini; Lipsiae; Merseburg
# http://resolver.staatsbibliothek-berlin.de/SBB0001997100000000:	Stettin; Leipzig; Merseburg
# PPN828797005:	Leipzig; Hamburg
# PPN743982797:	Birkenfeld; Idar-Oberstein
# PPN842361669:	Berlin; Leipzig
# PPN825602424:	Freiburg; i.Br.
# PPN782853447:	Birkenfeld; Idar-Oberstein
# PPN832381586:	Augsburg; Oberursel
# PPN82554095X:	Freiburg; i.Br.
# PPN840970080:	Kulmbach; Bayreuth
# PPN82559894X:	Freiburg; i.Br.
# PPN825731828:	Freiburg; i.Br.
# PPN844762350:	Leipzig; Paris; Petersburg; London
# PPN844989258:	Leipzig; Paris; Petersburg; London
# PPN825605121:	Freiburg; i.Br.
# PPN840213107:	Leipzig; Frankfurt
# PPN824683188:	Freiburg; i.; Br.
# PPN805478337:	Halle; Leipzig
# PPN825548136:	Freiburg; i.Br.
# PPN825732174:	Freiburg; i.Br.
# PPN81783415X:	Cölln; an; der; Spree
# PPN817835539:	Cölln; an; der; Spree
# PPN817837493:	Cölln; an; der; Spree
# PPN839012888:	Bonn; London
# PPN842177361:	Offenbach; a/M
# PPN839013116:	Bonn; London
# PPN83266605X:	Francofurti; Ad; Oderam
# PPN842182101:	Braunschweig; New York, NY; Paris; Bruxelles; Schutte; London
# PPN839209169:	Berlin; München
# PPN840124376:	Leipzig; Deßau
# PPN841234213:	Leipzig; Franckfurth; Nürnberg
# PPN841234477:	Leipzig; Franckfurth; Nürnberg
# PPN841235074:	Leipzig; Franckfurt; Nürnberg
# PPN82552699X:	Freiburg; i.Br.
# PPN825527376:	Freiburg; i.Br.
# PPN832955213:	Liebfrauenberg; près; Woerth; Bas; Rhin
# PPN825525411:	Freiburg; i.Br.
# PPN82552783X:	Freiburg; i.Br.
# PPN785886249:	Frankreich; (Montpellier?); oder; Nordspanien
# PPN814162150:	Hagenau; Augsburg
# PPN834298414:	Wittenberg; i.e.; Augsburg
# PPN834299313:	Wittenberg; i.e.; Augsburg
# PPN837707692:	Franckfurt; und; Leipzig
# PPN832639451:	Schwarzach; bey; Culmbach
# PPN838005470:	Mülheim; am; Rhein
# PPN83540031X:	Wittenberg; Augsburg
# PPN835400425:	Wittenberg; Augsburg
# PPN820249246:	Hamburg; Nürnberg
# PPN820478091:	Tübingen; Stuttgart
# PPN819250333:	Leipzig; Stuttgart
# PPN840592434:	Halle; a.S.
# PPN820248983:	Stuttgart; Tübingen
# PPN82024824X:	Berlin; Wien
# PPN820249432:	Tübingen; Stuttgart
# PPN819250287:	Stuttgart; Leipzig
# PPN819250457:	Stuttgart; Leipzig
# PPN837754135:	Frankfurt; Leipzig
# PPN836015290:	Leipzig; Franckfurth
# PPN838221688:	Traiecti; Ad; Viadrum
# PPN837938872:	Frankfurt; an; der; O
# PPN837749883:	Franckfurt; Leipzig
# PPN838537790:	Duisburgi; ad; Rhenum
# PPN837897580:	Schleiz; Leipzig
# PPN836323645:	Berlin; Stralsund
# PPN786793287:	Tur; Abdin
# PPN786793651:	Tur; Abdin
# PPN786793856:	Tur; Abdin
# PPN839140681:	Berg; am; Starnberger; See
# PPN839140169:	Berg; am; Starnberger; See
# PPN837838126:	Leipzig; Berlin
# PPN835043363:	Frankfurt; Leipzig
# PPN839749074:	Francofurti; ad; Moenum
# PPN837925983:	London; Leipzig; Brüssel
# PPN837796261:	Berlin; Leipzig
# PPN837796040:	Berlin; Leipzig
# PPN830204180:	Gerae; ad; Elystrum
# PPN837589991:	Londres; Mayence; Paris; Bruxelles; Leipzig
# PPN838351638:	Köln; a.; Rh.
# PPN837926319:	London; Brüssel; Leipzig
# PPN839007884:	Offenbach; a.; Main
# PPN839007388:	Offenbach; a.; Main
# PPN839010966:	Offenbach; a.; Main
# PPN837795362:	Berlin; Riga
# PPN839010257:	Offenbach; a.; Main
# PPN839009070:	Offenbach; A/Main
# PPN839011210:	Offenbach; a.; Main
# PPN839009542:	Offenbach; a/M.
# PPN83900866X:	Offenbach; a.; Main
# PPN837796415:	Leipsic; Moscou
# PPN837795567:	Berlin; Petersbourg
# PPN839010486:	Offenbach; a.; Main
# PPN827663188:	Freiburg; i.; Schl.
# PPN826363636:	Ciudad; de; México
# PPN816926271:	Lipsiae; Regiom.; Francofurti; Ienae
# PPN816926573:	Lipsiae; Regiom.; Francofurti; Ienae
# PPN82858768X:	Wien; Lüttich
# PPN816592926:	Regiomonti; Gedani
# PPN816592845:	Dantisci; Rigae
# PPN823048470:	Stettin; Berlin
# PPN822873982:	Leipzig; Frankfurt
# PPN816505020:	Cölln; an; der; Spree
# PPN82192737X:	Frankfurt; Leipzig
# PPN814784836:	Leipzig; Franckfurt; Hannover
# PPN817961992:	Breslau; Leipzig
# PPN819553573:	Nürnberg; Brünn; Wien
# PPN821927434:	Francofurti; Ad; Moenum
# PPN818450827:	Steinau; an; der; O
# PPN820244090:	Halis; Saxonum
# PPN828042187:	Halle; Leipzig
# PPN820511633:	Halae; Magdeburgicae
# PPN818451386:	Steinau; an; der; O
# PPN79207226X:	Alten; Stettin
# PPN82056415X:	Regiomonti; Borussorum
# PPN827600801:	Francofurti; ad; Virum
# PPN822065878:	Ienae; Halae; Magdeburgicae
# PPN819249149:	Frankfurt; a.M.
# PPN822098024:	Halae; Magdeburgicae
# PPN777698609:	Hagenau; Augsburg
# PPN727381792:	M.; Gladbach
# PPN726101885:	Mühlhausen; i.; Thür.
# PPN726078964:	Frankfurt; a.; O.
# PPN72610129X:	Mühlhausen; i.; Thür.
# PPN767212452:	Berlin; getarnt; Druckort-; Paris
# PPN730922634:	Bonn; a.; Rh.
# PPN730533522:	Mühlhausen; i.; Th.
# PPN767453905:	Nevers; <Nièvre, Kriegsgefangenenlager>; Druckort-; Paris
# PPN723785791:	Werdau; i.; S.
# PPN71813835X:	Rostock; i.; M.
# PPN755918967:	Leipzig; -R.
# PPN769073654:	Grundschöttel, Post; Volmarstein
# PPN731841956:	Knockaloe, Isle; of; Man
# PPN726321923:	Forchheim; (Bayern)
# PPN718477499:	Rottenburg; a.; N.
# PPN73459075X:	Oldenburg; i.; Gr.
# PPN769401813:	Karlsruhe; i.; B.
# PPN688716563:	Köln; a.Rh.
# PPN767876725:	Danzig; fingiert; Druckort-; Paris
# PPN715388630:	Stuttgart; Berlin
# PPN729962830:	Straßburg; i.; Els.
# PPN715725440:	Frankfurt; a.; M.
# PPN718565797:	Bad Nassau; (Lahn)
# PPN717957837:	Bonn; a.; Rh.
# PPN723682348:	Saalfeld; i.; Thür.
# PPN721240739:	Rostock; i.; M.
# PPN725786175:	Einsiedeln; usw.
# PPN670054828:	Lissa; i.P.
# PPN668496037:	Dülmen; i.; W.
# PPN730564053:	Mühlhausen; i.Th.
# PPN730518124:	M.; Gladbach
# PPN768269490:	Berlin; Leipzig
# PPN718543769:	Halle; (Saale)
# PPN720605695:	Meerane; (Sa.)
# PPN715722255:	Freiburg; i.; Br.
# PPN767482247:	Castelluccio; <Korsika, Kriegsgefangenenlager>; Druckort-; Paris
# PPN72394346X:	Eßlingen; a.; N.
# PPN730642194:	Minden; (Westf.)
# PPN767237455:	Oldenburg; i.; Gr.
# PPN730135381:	Worms; a.; Rhein
# PPN721351603:	M.; Gladbach
# PPN717994945:	Friemersheim; (Niederrhein)
# PPN730518957:	Straßburg; i.; Els.
# PPN696793431:	Dinglingen; (Baden)
# PPN74254463X:	Karlsruhe; und; Leipzig
# PPN715357042:	Naumburg; a.S.
# PPN749595035:	Leipzig; Mainz
# PPN71592642X:	Marburg; a.; L.
# PPN718049705:	Marburg; in; Hessen
# PPN715493469:	Freiburg; i.; B.
# PPN688597408:	M.; Gladbach
# PPN715131680:	Berlin; Greiz
# PPN718135997:	Rothenburg; o.Tauber
# PPN679536574:	Straßburg; i.E.
# PPN726745871:	Frankfurt; a.; M.
# PPN755414691:	Neumarkt; i.; O.
# PPN715373536:	Rauscha; O.-L.
# PPN730561186:	Mühlhausen; i.Th.
# PPN723786569:	Bocholt; i.; W.
# PPN722033699:	Halle; a.; S.
# PPN72557092X:	Klitschdorf; i.; Schl.
# PPN679547223:	Hagen; i.W.
# PPN729517322:	Königsberg; i.; Pr.
# PPN722012152:	Hagen; i.; W.
# PPN755400623:	Lissa; i.; P.
# PPN767490347:	New York; Druckort-; Paris
# PPN738380164:	Heidelberg; Leipzig
# PPN767085434:	ohne; Ort
# PPN720720222:	Freiburg; i.; Br.
# PPN667644539:	Godesberg; bei; Bonn
# PPN719294304:	Frankfurt; a.; M.
# PPN719549566:	Diessen; vor; München
# PPN723868697:	Dülmen; i.; W.
# PPN769061257:	Berlin; Photographische; Gesellschaft
# PPN716576805:	Bocholt; i.; W.
# PPN725574909:	Halle; (Saale)
# PPN755314530:	Freiburg; i.; B.
# PPN752293729:	Frankfurt; a.M.
# PPN721141544:	Halle; a.; S.
# PPN718139216:	Rostock; i.; M.
# PPN699903076:	Stolp; i.; Pom.
# PPN69989204X:	Eßlingen; a.N.
# PPN729367657:	Penig; i.; Sa.
# PPN720813093:	Frankfurt; a.; M.
# PPN723758891:	Lorch; (Württemberg)
# PPN749588020:	Chemnitz; Leipzig
# PPN719805201:	M.; Gladbach
# PPN715321579:	Leipzig; Darmstadt
# PPN721268900:	Königsberg; i.; Pr.
# PPN729627632:	Frankfurt; a.; M.
# PPN730507017:	Mühlhausen; i.; Thür.
# PPN718138880:	Rostock; i.; M.
# PPN715358669:	Münster; i.; W.
# PPN730558851:	Mühlhausen; i.Th.
# PPN716120925:	Hemer; i.; Westf.
# PPN730526933:	Mühlhausen; i.; Th.
# PPN730334767:	Münster; i.; W.
# PPN741297493:	Schwarzenberg; (Sachsen)
# PPN688718302:	Bonn; a.Rh.
# PPN742418898:	Freiburg; i.; Br.
# PPN729130169:	Halle; <Saale>
# PPN726099007:	Halle; a.; S.
# PPN71880287X:	Dülmen; i.; W.
# PPN755274741:	Brüssel; Ort; in; Vorlageform-; Jideeltje
# PPN730524418:	Mühlh.; i.; Th.
# PPN738598941:	Warendorf; in; Westf.
# PPN726175277:	M.; Gladbach
# PPN742075125:	Königsberg; i.; Pr.
# PPN715966812:	Halle; (Saale)
# PPN718955528:	Halle; a.; S.
# PPN748877657:	Chemnitz; Leipzig
# PPN688547796:	Oldenburg; i.Gr.
# PPN738503479:	Cöln; am; Rhein
# PPN77015820X:	Saalfeld; a.S.
# PPN717583406:	Schwerin; i.; Mecklb.
# PPN720740738:	Sulzbach; i.; Opf.
# PPN699927927:	Frankfurt; a.; Oder
# PPN717901394:	Halle; (Saale)
# PPN755415558:	Freiburg; i.; B.
# PPN717900215:	Halle; (Saale)
# PPN719910943:	Schwerin; i.; M.
# PPN725776625:	Bad Nassau; (Lahn)
# PPN688550266:	Oldenburg; i.; Gr.
# PPN725952903:	Buer; i.; W.
# PPN718138058:	Rostock; i.; M.
# PPN71598604X:	Halle; (Saale)
# PPN720303990:	Frankfurt; a.; M.
# PPN68954233X:	Frankfurt; a.; Oder
# PPN718618459:	Schwerin; in; Mecklb.
# PPN729128644:	Halle; <Saale>
# PPN738597120:	Warendorf; in; Westf.
# PPN736439447:	Witten; (Ruhr)
# PPN729519422:	Freiburg; i.; Br.
# PPN716185180:	Frankfurt; a.; d.; Oder
# PPN726101540:	Mühlhausen; i.; Thür.
# PPN719449243:	Königsberg; i.; Pr.
# PPN738644501:	Halle; (Saale)
# PPN719290279:	Märk.; Friedland
# PPN670206903:	Siemensstadt; b.; Berlin
# PPN720363446:	Oldenburg; i.Gr.
# PPN721446612:	Ulm; a.Donau
# PPN716094037:	M.; Gladbach
# PPN669422339:	Königsberg; i.Pr.
# PPN715332619:	Culm; a.; W.
# PPN729938115:	Cöln; a.; Rh.
# PPN668500298:	Frankfurt; a.M.
# PPN755406702:	Lissa; i.P.
# PPN730531317:	Mühlhausen; i.; Th.
# PPN71813687X:	Halle; (Saale)
# PPN727506714:	Camburg; (Saale)
# PPN715981560:	Dülmen; i.; W.
# PPN719387930:	Schwerin; i.; Mecklb.
# PPN72704351X:	Bad Nassau; (Lahn)
# PPN723888795:	Oranienburg; bei; Berlin
# PPN729730840:	Bapaume; München
# PPN735221561:	Freiburg; i.; Br.
# PPN718706587:	Neustadt; a.; d.; Hdt.
# PPN71789908X:	Halle; (Saale)
# PPN687877024:	Halle; a.; d.; S.
# PPN766441407:	Berlin; Südende
# PPN689363109:	Halle; (Saale)
# PPN720413389:	Dülmen; i.W.
# PPN688549195:	Freiburg; (Baden)
# PPN715981110:	Dülmen; i.; W.
# PPN730576132:	Mühlhausen; i.Th.
# PPN738647888:	Halle; (Saale)
# PPN718706978:	Frankfurt; a.; M.
# PPN715357476:	Ulm; a.; D.
# PPN688547273:	Leipzig; Dresden
# PPN730508099:	Mühlhausen; i.; Thür.
# PPN726100889:	Mühlhausen; i.; Thür.
# PPN73075703X:	Straßburg; i.; E.
# PPN734811055:	M.; Gladbach
# PPN769053904:	Berlin; Photographische; Gesellschaft
# PPN675803349:	Schwerin; i.; Mecklb.
# PPN71728624X:	Dinglingen; (Baden)
# PPN729513513:	Münster; i.; W.
# PPN717414434:	M.; Gladbach
# PPN736442391:	Schwerin; i.; Mecklb.
# PPN717899950:	Halle; (Saale)
# PPN72610048X:	Schönberg; i.; Mecklb.
# PPN720297680:	Ulm; a.; D.
# PPN717899349:	Halle; (Saale)
# PPN689543905:	Godesberg; a.; Rh.
# PPN721239994:	Rostock; i.; M.
# PPN721558143:	Bockwitz; (Kr.; Liebenwerda)
# PPN720286913:	Dinglingen; (Baden)
# PPN668501626:	Münster; i.W.
# PPN688723160:	Königsberg; i.Pr.
# PPN719548519:	Diessen; vor; München
# PPN736522441:	Frankfurt; a.; M.
# PPN67273897X:	Halle; (Saale)
# PPN71777211X:	Frankfurt; a.; M.
# PPN715678647:	Ulm; a.; D.
# PPN767085426:	Sankt Petersburg; Ort; in; Vorlageform-; Petrograd
# PPN72957699X:	M.; Gladbach
# PPN723885982:	Lissa; i.; P.
# PPN729132382:	Witten; <Ruhr>
# PPN699903688:	Pössneck; i.; Th.
# PPN720844452:	Karlsruhe; i.; B.
# PPN734594372:	Schwerin; i.; Mecklb.
# PPN717898687:	Halle; (Saale)
# PPN767481933:	Montargis; <Kriegsgefangenenlager>; Druckort-; Paris
# PPN726102008:	Mühlhausen; i.; Thür.
# PPN679548025:	Hagen; i.W.
# PPN824472608:	2.; Auflage; Leipzig
# PPN719325358:	Wirsitz; in; Posen
# PPN72610258X:	Mühlhausen; i.; Thür.
# PPN727067826:	Oldenburg; i.; Gr.
# PPN729468585:	Münster; in; Westf.
# PPN734010281:	Friedrichshagen; bei; Berlin
# PPN770699758:	Halle; (Saale)
# PPN727401572:	M.; Gladbach
# PPN726102156:	Mühlhausen; i.; Thür.
# PPN719537649:	Diessen; vor; München
# PPN688546676:	Dülmen; i.; W.
# PPN718563050:	Oppenau; (Baden)
# PPN716151448:	Frankfurt; a.; M.
# PPN766848213:	Schwarzenberg; <Erzgebirge>
# PPN730564673:	Mühlhausen; i.Th.
# PPN736359257:	Minden; in; Westfalen
# PPN700544801:	Schwerin; i.; Mecklb.
# PPN715363514:	Dülmen; i.; W.
# PPN755869060:	Mühlhausen; i.; Thür.
# PPN774640057:	Ort; in; Vorlageform-; München; Berl
# PPN715515519:	Marburg; a.; L.
# PPN668915609:	Schwerin; i.Meckl.
# PPN72993988X:	Cöln; a.; Rh.
# PPN732075017:	M.; Gladbach
# PPN726101087:	Mühlhausen; i.; Thür.
# PPN688593844:	B.; Leipa
# PPN719074215:	Kallmünz; bei; Regensburg
# PPN756829852:	Brandenburg; a.; H.
# PPN726229172:	Frankfurt; a.; M.
# PPN717897710:	Halle; (Saale)
# PPN688594476:	Neustadt; a.d.; Haardt
# PPN729707954:	Kurume; (Japan)
# PPN719043794:	Schwerin; i.; Mecklb.
# PPN738599638:	Warendorf; in; Westf.
# PPN770388957:	Berlin-Schöneberg; Leipzig
# PPN715356666:	Freibg; im; Breisgau
# PPN71600061X:	M.; Gladbach
# PPN722028938:	Wusterhanse; (Kreis; Neustettin)
# PPN72373948X:	Ratibor; O.-S.
# PPN688723810:	Culm; an; der; Weichsel
# PPN726229563:	Frankfurt; a.; M.
# PPN699910412:	Münster; i.; W.
# PPN715376039:	Berlin; München
# PPN720247683:	Ulm; a.D.
# PPN718952715:	Freiburg; i.B.
# PPN733992250:	Frankfurt; a.; Main
# PPN742544842:	Karlsruhe; und; Leipzig
# PPN71853171X:	Königsberg; Nm.
# PPN715790986:	M.; Gladbach
# PPN730527905:	Mühlhausen; i.; Th.
# PPN69727649X:	Freiburg; i.; Br.
# PPN75540209X:	Lippa; i.P.
# PPN748796290:	München; Berlin
# PPN730747484:	Camburg; (Saale)
# PPN668918039:	Lissa; i.P.
# PPN730532674:	Mühlhausen; i.Th.
# PPN722305206:	Diessen; vor; München
# PPN768204410:	Le; Havre
# PPN723867453:	Oberhausen; (Rhld.)
# PPN715464957:	Frankfurt; a.; M.
# PPN767490002:	New York; getarnt; Druckort-; Paris
# PPN715295454:	Dresden; &; Leipzig
# PPN721272738:	Herrnhut; i.Sa.
# PPN718138236:	Rostock; i.; M.
# PPN76708523X:	Blankenburg; a.; H.
# PPN75583920X:	Leipzig; -R.
# PPN732558271:	Frankfurt; a.; M.
# PPN767482921:	St-Aubin-Epinay; <Kriegsgefangenenlager>; Druckort-; Paris
# PPN720097231:	Nienburg; (Weser)
# PPN726368660:	Oldenburg; i.Gr.
# PPN755396758:	Lissa; i.P.
# PPN679548262:	Hagen; i.W.
# PPN755310772:	Siegen; Berlin
# PPN725949686:	Diessen; vor; München
# PPN752387103:	Diessen; vor; München
# PPN729951847:	Berlin; Leipzig
# PPN719293456:	Frankfurt; a.; M.
# PPN688729355:	Speyer; a.Rh.
# PPN742390128:	Diessen; vor; München
# PPN730510433:	Mühlhausen; i.; Thür.
# PPN75711654X:	Brandenburg; a.; Havel
# PPN669420344:	Zwickau; i.; Sa.
# PPN719040051:	Frankfurt; a.; M.
# PPN71881729X:	Oldenburg; i.; Gr.
# PPN733888496:	Halle; (Saale)
# PPN71642665X:	Oldenburg; i.Gr.
# PPN719388430:	Schwerin; i.; Mecklb.
# PPN688550703:	Frankfurt; a.; M.
# PPN738377422:	Berlin; Leipzig
# PPN664386083:	Königsberg; Nm.
# PPN715357999:	Freiburg; im; Br.
# PPN716248611:	Dülmen; i.W.
# PPN718126149:	Rostock; i.; M.
# PPN717899675:	Halle; (Saale)
# PPN667360298:	Stolp; i.Pom.
# PPN715574736:	Karlsruhe; i.; B.
# PPN721235999:	Halle; (Saale)
# PPN718138821:	Rostock; i.; M.
# PPN719387388:	Schwerin; i.; Mecklb.
# PPN670003212:	Innsbruck; .
# PPN715490974:	Werder; a.H.
# PPN668784814:	Frankfurt; a.M.
# PPN816585539:	Franckfurt; Leipzig
# PPN731825659:	Halle; (Saale)
# PPN729167801:	Berlin; Cassel
# PPN718138503:	Rostock; i.; M.
# PPN71790086X:	Halle; (Saale)
# PPN717286541:	Dinglingen; (Baden)
# PPN68936380X:	Halle; (Saale)
# PPN671542710:	Frankfurt; a.M.
# PPN74888484X:	Leipzig; Wien; New York
# PPN715373285:	Rauscha; O.-L.
# PPN72123335X:	Neustadt; a.; d.; Haardt
# PPN688591752:	Oldenburg; i.; Gr.
# PPN730577201:	Mühlhausen; i.Th.
# PPN724126856:	Plau; i.; Meckl.
# PPN688721508:	Rostock; i.; M.
# PPN742419460:	Freiburg; i.; Br.
# PPN769006027:	Oldenburg; i.; Gr.
# PPN755315367:	Lissa; i.P.
# PPN71549354X:	Freiburg; i.; B.
# PPN718049462:	Marburg; in; Hessen
# PPN732086787:	Knockaloe; Camp
# PPN738596582:	Warendorf; in; Westf.
# PPN730159930:	Halle; a.S.
# PPN738078611:	Berlin; Leipzig
# PPN728233150:	Ulm; a.; Donau
# PPN734016727:	Herborn; (Dillkreis)
# PPN730535274:	Mühlhausen; i.; Th.
# PPN715293966:	Leipzig; &; Hamburg
# PPN718139003:	Rostock; i.; M.
# PPN718941055:	M.; Gladbach
# PPN719538114:	Oldenburg; i.Gr.
# PPN718138546:	Rostock; i.; M.
# PPN718138619:	Rostock; i.; M.
# PPN718564413:	Halle; a.; S.
# PPN727630083:	Eßlingen; a.; N.
# PPN688546684:	Bad Nassau; (Lahn)
# PPN730522784:	Mülhausen; i.; Th.
# PPN731847873:	Dachau; bei; München
# PPN717285936:	Rothenburg; o.T.
# PPN770377459:	Leipzig; Berlin-Schöneberg
# PPN747343551:	Berlin; Leipzig
# PPN670599824:	Witten; (Ruhr)
# PPN715295136:	Warendorf; in; Westf.
# PPN719293820:	Frankfurt; a.; M.
# PPN726101710:	Mühlhausen; i.; Thür.
# PPN770388205:	Berlin-Schöneberg; Leipzig
# PPN729462625:	Angerburg; Ostpr.
# PPN720719755:	Wismar; i.; M.
# PPN688733263:	Diessen; vor; München
# PPN717897095:	Halle; (Saale)
# PPN71868706X:	Halle; a.S.
# PPN726098272:	Bielefeld; &; Leipzig
# PPN72124047X:	Rostock; i.; M.
# PPN689362056:	Halle; (Saale)
# PPN667378235:	Freiburg; i.B.
# PPN679536094:	Straßburg; i.E.
# PPN688720919:	Freiburg; i.B.
# ...
# PPN643820302:	Stargardt; in; Pommern
# PPN726447935:	Halae; Magdeburg.
# PPN717289249:	Leipzig; Celle
# PPN640354092:	Nürnberg; Hamburg
# PPN635692392:	Erfordi; Ienae; Erfurt
# PPN738048585:	Leipzig; Frankfurt
# PPN68426515X:	Franckfurt; Offenbach
# PPN756674964:	Leipzig; Frankfurt
# PPN688336035:	Cölln; an; der; Spree
# PPN688336078:	Cölln; an; der; Spree
# PPN729568512:	Hamburg; Bremen
# PPN684098164:	Hamm; i.; W.
# PPN717288307:	Franckfurt; am; Mayn
# PPN717288994:	Franckfurt; am; Mayn
# PPN673097277:	Cölln; an; der; Spree
# PPN673097501:	Cölln; an; der; Spree
# PPN716587505:	Hambourg; Hamburg
# PPN667355464:	Hamburg; Kiel
# PPN630519323:	Francofurti; ad; Virum
# PPN732479991:	Königsberg; i.; Pr.
# PPN644260203:	Franckfurt; an; Mäyn
# PPN668844256:	Cölln; an; der; Spree
# PPN749898720:	Berlin-Friedenau; Osterwieck-Hartz
# PPN750545216:	Berlin-Friedenau; Osterwieck-Hartz
# PPN700638962:	Franckfurt; an; der; O
# PPN660177420:	Leipzig; und; Gera
# PPN755888219:	Wiener; Neustadt
# PPN718306481:	Franckfurt; Leipzig
# PPN63542407X:	Halae; Magdeburgicae
# PPN776569953:	Berlin; Paris; Wien
# PPN656669624:	Hall; in; Sachsen
# PPN715322508:	Cölln; an; der; Spree
# PPN685093034:	Cammin; in; Pommern
# PPN688524400:	Frankfurt; a.M.
# PPN722551649:	Lips.; Weissenf.
# PPN726389587:	Hala; Magd.
# PPN730462218:	Güstrow; Rostock
# PPN717197042:	Lissa; i.; P.
# PPN644522062:	Franckfurt; an; der; O
# PPN722368569:	Hall; in; Sachsen
# PPN631312412:	Halae; Magdeb.
# PPN745839932:	Leipzig; Breßlau
# PPN745842933:	Leipzig; Breßlau
# PPN630550166:	Leipzig; London
# PPN663563569:	St. Petersburg; Leipzig
# PPN727084933:	Helmstadii; Lipsiae; Wolffenbutteli
# PPN669265950:	Köln; am; Rhein
# PPN645051330:	Braunschweig; Celle
# PPN679705082:	Amsterdam; Leipzig
# PPN67246912X:	Hamburg; Altona
# PPN755887506:	Wiener; Neustadt
# PPN728510650:	Francofurti; Ad; Viadrum
# PPN750212268:	Leipzig; Magdeburg
# PPN638082803:	Lipsiae; Francofurti; Halberstadt; Helmestadii
# PPN728594595:	Francofurti; Ad; Viadrum
# PPN734636687:	Bern; Amsterdam
# PPN715981528:	Berlin; Leipzig
# PPN722395418:	Helmstädt; Magdeburg; Franckfurt; Leipzig
# PPN66232594X:	Prag; Leipzig
# PPN662042859:	A; Jene
# PPN715358537:	Offenbach; a/M.
# PPN728610477:	Francofurti; Ad; Viadrum
# PPN682742473:	Berlin; Paris; Vienne
# PPN655188746:	Berlin; Kortkampf
# PPN756019605:	Leipzig; Frankfurt
# PPN755922522:	Brüssel; New York, NY; London; Leipzig
# PPN768664470:	Leipzig; Franckfurt
# PPN770472850:	Francofurti; Ad; Viadrum
# PPN72024563X:	Lipsiae; Leipzig
# PPN721548830:	Köln; Neuwied; Koblenz
# PPN715590596:	Magdeburgk; Braunschweig
# PPN755699548:	Wien; Riga; Trieste; Leipzig
# PPN599588241:	Cölln; an; der; Spree
# PPN654092648:	Neuwied; &; Leipzig
# PPN660769816:	Leipzig; Riga
# PPN715687069:	Dessau; Leipzig
# PPN656995025:	En; Biennē; tēs; Austrias
# PPN657407356:	Amsterdam; Hamburg
# PPN665645627:	Oberndorf; a.N.
# PPN734951027:	Leipzig; Amsterdam
# PPN665760213:	Arnstadt; Sondershausen
# PPN664986404:	Bern; St. Gallen
# PPN680156844:	Amsterdam; Mainz
# PPN767019466:	Liegnitz; Leipzig
# PPN63779947X:	Berlin; Paris
# PPN678785767:	Leipzig; Berlin
# PPN728603020:	Francofurti; Ad; Viadrum
# PPN751122068:	Paris; Rheims
# PPN655712283:	Ellwangen; und; Gmünd
# PPN774784059:	Meißen; Kaschau; Pesth
# PPN776583417:	Berlin; Paris
# PPN756337585:	Leipzig; Wien
# PPN723681600:	Aachen; Leipzig; Brüssel
# PPN723759650:	Leipzig; Erlangen
# PPN740898639:	Annaberg; Freyberg
# PPN767068858:	Leipzig; Londres
# PPN665804032:	Frankfurt; Leipzig
# PPN717897044:	Gnesen; Lissa
# PPN656088281:	Fribourg; Freyburg
# PPN636340996:	Halae; Saxonum
# PPN63824417X:	Minden; i.; Westf.
# PPN684532298:	Leipzig; Augsburg
# PPN728155435:	Suinfurti; Lipsiae
# PPN72690371X:	Franckfurth; Leipzig
# PPN668536934:	Triest; Wien
# PPN665640552:	Züllichau; Freystadt
# PPN776566687:	Berlin; Paris; Wien
# PPN739239066:	Wismar; Bützow
# PPN732598540:	Braunschweig; Helmstädt
# PPN756002281:	Offenbach; a/M; London; Philadelphia
# PPN680208798:	Leipzig; , Bey; Breitkopf; &; Härtel
# PPN721928544:	Höchst; Frankfurt
# PPN653790422:	Mainz; Antwerpen; und; Brüssel
# PPN719711282:	Hamburg; Bremen
# PPN75635045X:	Leipzig; Frankfurt
# PPN651734770:	Mayence; et; Anvers; Paris; Vienne; Moscow
# PPN656012196:	Erfurti; Gotae
# PPN756006309:	Frankfurt; Leipzig
# PPN681065176:	Mayence; &; Anvers
# PPN656149884:	Wien; Prag
# PPN719387809:	Wesel; Leipzig
# PPN729595463:	St. Gallen; Leipzig
# PPN657112070:	Prag; Leipzig
# PPN727083716:	Helmstadii; Lipsiae; Wolffenbutteli
# PPN627509053:	Mayence; et; Anvers; Paris; Londres
# PPN65501599X:	Frankfurt; Leipzig
# PPN659449552:	Leipzig; Frankfurt
# PPN729870685:	V; Praze
# PPN638760666:	Lipsiae; Servestae
# PPN644792329:	Marburg; an; der; Lahn
# PPN65693588X:	Prag; Wien
# PPN746616538:	Prag; Leipzig
# PPN738188328:	Prag; Leipzig
# PPN65740280X:	Rostock; Schwerin
# PPN635272024:	Wittebergae; Wittenbergae
# PPN658937324:	Berlin; Dresden
# PPN665249586:	Berlin; Danzig
# PPN71599199X:	Berlin; Stettin; Leipzig
# PPN637043693:	Naumb.; Ienae
# PPN673005186:	Büdingen; Altona
# PPN727572628:	Frankfurt; am; Mayn
# PPN716157101:	Leipzig; Breßlau
# PPN63851892X:	Bingen; a.; Rhein
# PPN662354613:	Quedlinburg; Leipzig
# PPN655751785:	Amtliche; Ausgabe; Berlin
# PPN656923768:	Schloss; Lindenberg
# PPN651732166:	Berlin; &; Posen
# PPN661066789:	Leipzig; Berlin
# PPN685662004:	Arnsberg; Paderborn
# PPN742270742:	Frankfurt; Leipzig
# PPN67230905X:	Provins; Paris; Lagny
# PPN671640437:	Hamburg; Altona
# PPN672557126:	Frankfurt; am; Mayn
# PPN751557234:	Offenbach; a.M.
# PPN640764584:	Magdeburg; Magdegurg
# PPN648873382:	Magdeburg; Magdegurg
# PPN738613061:	Magdeburg; Helmstädt
# PPN767048598:	Leipzig; Varsovie; St. Petersbourg; Wilna; Amsterdam; Hamburg
# PPN678800871:	St. Gallen; Glarus
# PPN666054959:	Amsterdam; Cölln
# PPN689255713:	Leipzig; Berlin
# PPN647209616:	Halle; a.; S.
# PPN64016627X:	Francofurti; Cis; Viadrum
# PPN610714341:	Erfurti; Arnstadiae
# PPN635701839:	Francofurti; Ad; Viadrum
# PPN728999196:	Cölln; an; der; Spree
# PPN732720265:	Hamburg; u.; Leipzig
# PPN700637710:	Friedenau; bei; Berlin
# PPN715585371:	Altona; Halle
# PPN757661688:	Leipzig; Franckfurth; Nürnberg
# PPN68925055X:	Leipsic; Paris; Londres
# PPN746601441:	Leipzig; Erfurth
# PPN729883973:	Amsterdam; Leipzig
# PPN659411202:	Halae; Magdeburgicae
# PPN715322699:	Cölln; an; der; Spree
# PPN590414984:	Berolin.; Francofurti; ad; Oderam
# PPN667862609:	Francofurti; ad; Virum
# PPN632810114:	Offenbaci; ad; Mœnum
# PPN629823820:	Paris; Leipzig
# PPN625697138:	Francofurti; ad; Virum
# PPN715709003:	Breslau; Leipzig
# PPN688366236:	Frankfurt; Leipzig
# PPN622964356:	Franckfurt; Leipzig
# PPN617461147:	Dreßden; Leipzig; Wittenberg
# PPN75154132X:	Offenbach; s/M.
# PPN66771524X:	Cölln; an; der; Spree
# PPN667715355:	Cölln; an; der; Spree
# PPN655974970:	Hall; in; Sachsen
# PPN751187011:	Cölln; an; der; Spree
# PPN667715452:	Cölln; an; der; Spree
# PPN654579571:	Francofurti; Ad; Viadrum
# PPN672558432:	Frankfurt; am; Mayn
# PPN683150693:	Liegnitz; Halle
# PPN672057379:	Hall; in; Sachsen
# PPN641218338:	Amsterdam; Dansig
# PPN735478686:	Schwäb.; Hall; Schwäbisch
# PPN737992530:	Leipzig; Dessau
# PPN647549573:	Francofurti; Lipsiae
# PPN667356606:	Hamburg; Kiel
# PPN638665760:	Altdorf; Nürnberg
# PPN637324498:	Leipsic; Paris
# PPN729006344:	Cölln; an; der; Spree
# PPN722936923:	Coloniae; Brandenburgicae
# PPN627764940:	Ratisbonae; Wetzlar
# PPN720858526:	Marburgi; Cattorum
# PPN677760639:	Leipzig; Franckfurt
# PPN766144984:	Leipzig; Frankfurt; Nürnberg
# PPN732555086:	Frankfurt; Magdeburg; Leipzig
# PPN688378536:	Breßlaw; Leipzig
# PPN767219066:	Berlin; Leipzig
# PPN639006140:	Francofurti; Ad; Viadrum
# PPN750073233:	Reval; Leipzig
# PPN689996659:	Paderborn; Schöningh
# PPN670033901:	Leipzig; Franckfurt; am; Mayn
# PPN655226117:	Rostock; Königsberg; in; Preussen
# PPN750210591:	Cologne; Bonn
# PPN663597218:	Hall; in; Saxony; e, Saale
# PPN635288575:	Dreßden; Leipzig
# PPN668304405:	Hall; in; Sachsen
# PPN685797376:	Cölln; an; der; Spree
# PPN685797589:	Cölln; an; der; Spree
# PPN630468680:	Magdeburg.; Kilonii
# PPN730727521:	Francofurti; ad; Virum
# PPN668866748:	Cölln; an; der; Spree
# PPN72859997X:	Francofurti; Ad; Viadrum
# PPN720908345:	Duisburgi; ad; Rhenum
# PPN722406436:	Cölln; an; der; Spree
# PPN641928955:	Alten; Stettin
# PPN664280625:	Züllichau; Freystadt
# PPN728821060:	Cölln; an; der; Spree
# PPN722402791:	Cölln; an; der; Spree
# PPN729003353:	Cölln; an; der; Spree
# PPN685199479:	Königsberg; in; Pr.
# PPN68454914X:	Breßlau; Leipzig
# PPN684551071:	Leipzig; Breßlau
# PPN64413948X:	Francofurti; cis; Viadrum
# PPN732556422:	Berlin; Königsberg
# PPN659437074:	Halae; Magdeburgicae
# PPN655973311:	Rostock; Leipzig
# PPN689063016:	Frankfurt; a.M.
# PPN735734941:	Neusalz; (Oder)
# PPN71757329X:	Hambourg; Hamburg
# PPN742066509:	Breslau; Oels
# PPN722391382:	Hamburg; Bremen
# PPN688377629:	Leipzig; Breßlaw
# PPN721576842:	Magdeburg; k
# PPN720773504:	Halae; Magdeburgicae
# PPN756558786:	Leipzig; Copenhagen
# PPN660941929:	Franckfurth; Leipzig
# PPN715592416:	Magdeburgk; Braunschweig
# PPN688339808:	Augustae; Vindelicorum
# PPN770473423:	Francofvrti; Ad; Viadrvm
# PPN721553613:	À; Erlang
# PPN685238601:	Alten; Stettin
# PPN746232667:	Franckfurt; Leipzig
# PPN731518403:	Halle, im; Magdeburgischen
# PPN659432781:	Halae; Magdeburgicae

# %% [markdown]
# * finally, we can extract the first cities
#
# * next cell might take ca. 3 min. with list-based exact matching

# %%
printLog("Detecting and picking first cities...")
uniqueSpatials=df3["spatialClean"].unique()
beforeClusterClean=len(uniqueSpatials)
df3["spatialClean"]=df3["spatialClean"].apply(pickFirstCity)
printLog("Done.")

if allowExactStringMatching:
    pickleCompress("./picklez/df3_exactmatch_cities.picklez",df3)
else:
    df3=pickleDecompress("./picklez/df3_exactmatch_cities.picklez")
printLog("Done.")
# Out:
# [2018-09-21 16:25:25.779132]	Detecting and picking first cities...
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:79: FutureWarning: split() requires a non-empty pattern match.
# [2018-09-21 16:25:30.200492]	Done.
# [2018-09-21 16:25:30.201262]	Pickling to './picklez/df3_exactmatch_cities.picklez'
# [2018-09-21 16:25:42.204670]	Pickling done.
# [2018-09-21 16:25:42.205722]	Done.

# %%
df3[df3.spatial.notnull()].head(20)
# Out:
#                                                object        type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                                            creator             subject  \
# 1                                                 NaN  Periodical  http://www.bibliothek.uni-regensburg.de/ezeit/...  Open Access            Allgemeines Polizei-Archiv für Preussen  image/jpeg  Allgemeines Polizei-Archiv für Preussen. Berli...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://www.bibliothek.uni-regensburg.de/ezeit/...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                                NaN  Rechtswissenschaft
# 2   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                             Der XLII. Psalm Davids  image/jpeg  Jordano, Alberto  Läger, Joachimus: Der XLII. ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                 Jordano, Alberto  Läger, Joachimus      Einblattdrucke
# 3   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Der erlauchte Bauer oder Lebensgeschichte und ...  image/jpeg  Maubert de Gouvest, Jean Henri: Der erlauchte ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                     Maubert de Gouvest, Jean Henri  Historische Drucke
# 4                                                 NaN  Periodical  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                                        Der Wächter  image/jpeg  Der Wächter  Polizeiblatt für Mecklenburg. Sch...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                                NaN  Rechtswissenschaft
# 5   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Scheid-Gedicht/ über Den Bitter-Süssen Abzuge ...  image/jpeg  Wolcken, Johann  Meier, Johannes: Scheid-Gedic...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                   Wolcken, Johann  Meier, Johannes  Historische Drucke
# 6   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Hochzeitliches Ehren-Gedicht Auff das Ehliche ...  image/jpeg  Lithoecaeus, Georgius  Röver, Johann  Overbeck...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  
    #py27 if not type(words[i])==unicode:
        #print "bumm "+ str(words[i])+" :"+str(i)
    if not words[i]:
        return 1.0
    #py27 if not type(words[j])==unicode:
        #print "bamm " + str(words[j])+" :"+str(j)
    if not words[j]:
        return 1.0
    dist=1 - jaro_distance(words[i],words[j]) # because jaro_distance is actually returning a similarity
    #print "%s vs. %s -> %f" %(words[i],words[j],dist)
    #return 1 - jaro_distance(unicode(str(words[i]), 'utf-8'), unicode(str(words[j]), 'utf-8'))
    return dist

def d3(coord):
    #print "Altered d()"
    #print coord
    i, j = coord
    #print str(type(words[i]))+" : "+str(type(words[j]))
    #py27 if not type(words[i])==unicode:
        #print "bumm "+ str(words[i])+" :"+str(i)
    if not words[i]:
        return 1.0
    #py27 if not type(words[j])==unicode:
        #print "bamm " + str(words[j])+" :"+str(j)
    if not words[j]:
        return 1.0
    dist=1 - jaro_winkler(words[i],words[j]) # because jaro_distance is actually returning a similarity
    #print "%s vs. %s -> %f" %(words[i],words[j],dist)
    return dist

# %%
if not demoClustering:
    printLog("Calculating Jaro distances...")
    r=np.triu_indices(afterClusterClean, 1)
    r2=np.apply_along_axis(d2, 0, r)
    Z=scipycluster.linkage(r2)
    pickle.dump( Z, open( "cluster_hierarchy_linkage_result.pickle", "wb" ) )
    
    # Jaro-Winkler
    printLog("Calculating Jaro-Winkler distances...")
    r=np.triu_indices(afterClusterClean, 1)
    r3=np.apply_along_axis(d3, 0, r)
    Z3=scipycluster.linkage(r3)
    pickle.dump( Z3, open( "cluster_hierarchy_linkage_jw_result.pickle", "wb" ) )
    #pickle.dump( r2, open( "r2.pickle", "wb" ) )
    printLog("Distance matrices created.")
    # (END_HERE_FOR_LINKAGE)
# Out:
# [2018-09-21 16:25:42.371018]	Calculating Jaro distances...
# [2018-09-21 16:26:14.119933]	Calculating Jaro-Winkler distances...
# [2018-09-21 16:26:45.323887]	Distance matrices created.

# %% [markdown]
# ### Working with the "Final" Data

# %%
## load stuff
printLog("Loading final data...")
# Jaro
#Z_huge=pickle.load( open( "cluster_hierarchy_linkage_result.pickle_bak", "rb" ) )
# Jaro-Winkler
Z_huge=pickle.load( open( "cluster_hierarchy_linkage_jw_result.pickle", "rb" ) )

#r2=pickle.load( open( "r2.pickle", "rb" ) )
printLog("Loading final data completed.")
# Out:
# [2018-09-21 16:26:45.328871]	Loading final data...
# [2018-09-21 16:26:45.330718]	Loading final data completed.

# %% [markdown]
# * group records by their cluster and display results

# %%
uniqueSpatials=df3["spatialClean"].unique()
words=uniqueSpatials
print(len(words))
# Jaro
#clusters=scipycluster.fcluster(Z_huge, t=0.115,criterion="distance") # je höher d, desto mehr kommt in 1 cluster
# Jaro-Winkler
clusters=scipycluster.fcluster(Z_huge, t=0.095,criterion="distance") # je höher d, desto mehr kommt in 1 cluster

print(clusters)
df3['spatialCluster'] = df3["spatialClean"].apply(getClusterID)
grp=df3.groupby("spatialCluster")

print("Number of clusters: %i" % len(grp.groups.keys()))

# save the clusters' names (for simplicity, we just take the name of the cluster's first element)
clusterNames=dict()
maxKey=-1
for key in grp.groups.keys():
    if key:
        if key>maxKey:
            maxKey=key
        if not key in clusterNames:
            clusterNames[key]=grp.get_group(key)["spatialClean"].unique()[0]
            
        print(str(key)+" <"+clusterNames[key]+"> contains:\n\t"+str(grp.get_group(key)["spatialClean"].unique()))
print("Max key value: %i"%maxKey)
# Out:
# 3873
# [2486 1551 1255 ... 1211 1503 1871]
# Number of clusters: 2508
# 1 <羊城> contains:
# 	['羊城']
# 2 <鳳城龍山鄉> contains:
# 	['鳳城龍山鄉']
# 3 <和歌山> contains:
# 	['和歌山']
# 4 <天台山> contains:
# 	['天台山']
# 5 <高崎> contains:
# 	['高崎']
# 6 <長崎> contains:
# 	['長崎']
# 7 <長岡> contains:
# 	['長岡']
# 8 <竹韻山房> contains:
# 	['竹韻山房']
# 9 <禪山> contains:
# 	['禪山']
# 10 <高田山専修寺> contains:
# 	['高田山専修寺']
# 11 <成田> contains:
# 	['成田']
# 12 <武昌> contains:
# 	['武昌']
# 13 <武英殿> contains:
# 	['武英殿']
# 14 <??> contains:
# 	['??']
# 15 <B???> contains:
# 	['B???']
# 16 <2.> contains:
# 	['2.']
# 17 <2> contains:
# 	['2']
# 18 <o.0.> contains:
# 	['o.0.']
# 19 <o.D.> contains:
# 	['o.D.']
# 20 <oO.> contains:
# 	['oO.']
# 21 <Būlāg> contains:
# 	['Būlāg' 'Būlāq']
# 22 <Šīrāz> contains:
# 	['Šīrāz']
# 23 <Širāz> contains:
# 	['Širāz']
# 24 <Djakarta> contains:
# 	['Djakarta']
# 25 <Jogjakarta> contains:
# 	['Jogjakarta']
# 26 <Quito> contains:
# 	['Quito']
# 27 <Juist> contains:
# 	['Juist']
# 28 <Gröwohld/Trittau> contains:
# 	['Gröwohld/Trittau' 'Grönwohld/Trittau']
# 29 <Mähr.-Ostrau> contains:
# 	['Mähr.-Ostrau']
# 30 <Märk.> contains:
# 	['Märk.']
# 31 <Knockaloe, Isle> contains:
# 	['Knockaloe, Isle' 'Knockaloe']
# 32 <sʹGravenhage> contains:
# 	['sʹGravenhage' "s'-Gravenhage" "s'Gravenhage"]
# 33 <Philadelphia> contains:
# 	['Philadelphia' 'Philadelphie' 'Phiadelphia' 'Phialdelphia']
# 34 <New Philadelphia> contains:
# 	['New Philadelphia']
# 35 <Upsaliæ> contains:
# 	['Upsaliæ' 'Upsala']
# 36 <M.> contains:
# 	['M.']
# 37 <M> contains:
# 	['M']
# 38 <Husum> contains:
# 	['Husum']
# 39 <Hudson> contains:
# 	['Hudson']
# 40 <S.I.> contains:
# 	['S.I.']
# 41 <S.> contains:
# 	['S.']
# 42 <den Haag> contains:
# 	['den Haag' 'Den Haag']
# 43 <Slough> contains:
# 	['Slough']
# 44 <Slg.> contains:
# 	['Slg.']
# 45 <Pössneck> contains:
# 	['Pössneck']
# 46 <Pößneck> contains:
# 	['Pößneck']
# 47 <Dinckelsbühl> contains:
# 	['Dinckelsbühl' 'Dinkelsbühl']
# 48 <Ruurlo> contains:
# 	['Ruurlo']
# 49 <Ruhrort> contains:
# 	['Ruhrort']
# 50 <Donauwörth> contains:
# 	['Donauwörth']
# 51 <Donauöschingen> contains:
# 	['Donauöschingen']
# 52 <Alḳôsh> contains:
# 	['Alḳôsh']
# 53 <Alkosh> contains:
# 	['Alkosh']
# 54 <Temesvár> contains:
# 	['Temesvár']
# 55 <Temeswar> contains:
# 	['Temeswar']
# 56 <Ort> contains:
# 	['Ort']
# 57 <Orotava> contains:
# 	['Orotava']
# 58 <Wroclaw> contains:
# 	['Wroclaw']
# 59 <Wloclawek> contains:
# 	['Wloclawek']
# 60 <Tarlac> contains:
# 	['Tarlac']
# 61 <Tartu> contains:
# 	['Tartu']
# 62 <Rønne> contains:
# 	['Rønne']
# 63 <Rø> contains:
# 	['Rø']
# 64 <Neon-Phaliron> contains:
# 	['Neon-Phaliron' 'Neon-Phalirou']
# 65 <Saint-Germain-en-Laye Poststempel> contains:
# 	['Saint-Germain-en-Laye Poststempel' 'Saint-Germain-en-Laye vermutlich']
# 66 <Sainte-Menehould Poststempel> contains:
# 	['Sainte-Menehould Poststempel']
# 67 <Guayana> contains:
# 	['Guayana' 'Guacana' 'Guayra']
# 68 <Guajan> contains:
# 	['Guajan']
# 69 <Guayaquil> contains:
# 	['Guayaquil']
# 70 <Krakau> contains:
# 	['Krakau']
# 71 <Kraków> contains:
# 	['Kraków']
# 72 <Worms> contains:
# 	['Worms' 'Worbis' 'Wormbs']
# 73 <Rötgen> contains:
# 	['Rötgen']
# 74 <Rötz> contains:
# 	['Rötz']
# 75 <Amalfi> contains:
# 	['Amalfi']
# 76 <Amtliche> contains:
# 	['Amtliche']
# 77 <Zoagli> contains:
# 	['Zoagli']
# 78 <Zollikon> contains:
# 	['Zollikon']
# 79 <V> contains:
# 	['V']
# 80 <Vo> contains:
# 	['Vo']
# 81 <Kattowitz> contains:
# 	['Kattowitz']
# 82 <Katzhütte> contains:
# 	['Katzhütte']
# 83 <Kyllith> contains:
# 	['Kyllith']
# 84 <Ḳyllith> contains:
# 	['Ḳyllith']
# 85 <Kyritz> contains:
# 	['Kyritz']
# 86 <Decker> contains:
# 	['Decker']
# 87 <Deventer> contains:
# 	['Deventer']
# 88 <A> contains:
# 	['A']
# 89 <Am> contains:
# 	['Am']
# 90 <Amoy> contains:
# 	['Amoy']
# 91 <A.> contains:
# 	['A.']
# 92 <zur> contains:
# 	['zur']
# 93 <zu> contains:
# 	['zu']
# 94 <zum> contains:
# 	['zum']
# 95 <Cincinnati, Ohio> contains:
# 	['Cincinnati, Ohio' 'Cincinnati']
# 96 <Mexico> contains:
# 	['Mexico' 'Mexici']
# 97 <México> contains:
# 	['México']
# 98 <Mexiko-Stadt> contains:
# 	['Mexiko-Stadt']
# 99 <Vandoeuvre> contains:
# 	['Vandoeuvre']
# 100 <Van-See> contains:
# 	['Van-See']
# 101 <Detmold> contains:
# 	['Detmold' 'Detmold-Lippe']
# 102 <Rapallo> contains:
# 	['Rapallo']
# 103 <Rappoltsweiler> contains:
# 	['Rappoltsweiler']
# 104 <Kjöbenhavn> contains:
# 	['Kjöbenhavn' 'Kjøbenhavn' 'Kiøbenhavn' 'København']
# 105 <Zwickau> contains:
# 	['Zwickau' 'Zwickaw' 'Zwickau(?)']
# 106 <Zwickau-Sachsen> contains:
# 	['Zwickau-Sachsen']
# 107 <Zwickledt> contains:
# 	['Zwickledt']
# 108 <Radebeul-Oberlößnitz> contains:
# 	['Radebeul-Oberlößnitz']
# 109 <Radebeul> contains:
# 	['Radebeul']
# 110 <Espergæde> contains:
# 	['Espergæde' 'Espergaede']
# 111 <Rovio> contains:
# 	['Rovio' 'Rovigo']
# 112 <Aberdovey> contains:
# 	['Aberdovey']
# 113 <Abendroth> contains:
# 	['Abendroth']
# 114 <Białymstoku> contains:
# 	['Białymstoku' 'Bialystok']
# 115 <Querfurti> contains:
# 	['Querfurti' 'Querfurth' 'Querfurt']
# 116 <Utrecht> contains:
# 	['Utrecht']
# 117 <Utrecht: Honig> contains:
# 	['Utrecht: Honig']
# 118 <Ultrajecti> contains:
# 	['Ultrajecti']
# 119 <Kopenhagen> contains:
# 	['Kopenhagen' 'Copenhagen' 'Koppenhagen' 'Copenhague']
# 120 <Cadiz> contains:
# 	['Cadiz']
# 121 <Cádiz> contains:
# 	['Cádiz']
# 122 <Geislingen-St.> contains:
# 	['Geislingen-St.' 'Geislingen-Stg.']
# 123 <Pforzheim> contains:
# 	['Pforzheim']
# 124 <Walporzheim> contains:
# 	['Walporzheim']
# 125 <Ulmae> contains:
# 	['Ulmae']
# 126 <Vlmae> contains:
# 	['Vlmae']
# 127 <Ulm> contains:
# 	['Ulm']
# 128 <Clausthal> contains:
# 	['Clausthal']
# 129 <Caputh> contains:
# 	['Caputh']
# 130 <Elsaß> contains:
# 	['Elsaß' 'Elsaß?']
# 131 <Elsass> contains:
# 	['Elsass']
# 132 <El> contains:
# 	['El']
# 133 <Elmau> contains:
# 	['Elmau']
# 134 <Bützow> contains:
# 	['Bützow' 'Bütow']
# 135 <Follebu> contains:
# 	['Follebu' 'Follebü']
# 136 <Jauer> contains:
# 	['Jauer']
# 137 <Jade> contains:
# 	['Jade']
# 138 <Telkef> contains:
# 	['Telkef' 'Telkêf']
# 139 <Bln> contains:
# 	['Bln' 'Bln.']
# 140 <Newark New> contains:
# 	['Newark New']
# 141 <Newark London> contains:
# 	['Newark London']
# 142 <New York> contains:
# 	['New York' 'New York, NY']
# 143 <New York: Harper> contains:
# 	['New York: Harper']
# 144 <New-York La> contains:
# 	['New-York La']
# 145 <New Haven> contains:
# 	['New Haven']
# 146 <Guelferbyti> contains:
# 	['Guelferbyti' 'Guelpherbyti' 'Gvelpherbyti']
# 147 <Florence> contains:
# 	['Florence' 'Florenz']
# 148 <Firenze> contains:
# 	['Firenze']
# 149 <Filehne> contains:
# 	['Filehne']
# 150 <Flottbeck> contains:
# 	['Flottbeck']
# 151 <Meadville, Pa.> contains:
# 	['Meadville, Pa.']
# 152 <Reading, Pa.> contains:
# 	['Reading, Pa.']
# 153 <Innsbruck> contains:
# 	['Innsbruck' 'Inspruck']
# 154 <Uri> contains:
# 	['Uri' 'Uri?']
# 155 <Urmia, Iran> contains:
# 	['Urmia, Iran']
# 156 <Urmia> contains:
# 	['Urmia']
# 157 <Umbria> contains:
# 	['Umbria']
# 158 <Urbino> contains:
# 	['Urbino']
# 159 <Urbs> contains:
# 	['Urbs']
# 160 <Ursell> contains:
# 	['Ursell']
# 161 <Louvain> contains:
# 	['Louvain']
# 162 <Lovanii> contains:
# 	['Lovanii']
# 163 <Nagpur> contains:
# 	['Nagpur' 'Nagpore']
# 164 <Nágpu'r> contains:
# 	["Nágpu'r"]
# 165 <Naugard> contains:
# 	['Naugard']
# 166 <Hoorn> contains:
# 	['Hoorn' 'Horn']
# 167 <Hobart> contains:
# 	['Hobart']
# 168 <Bogotá> contains:
# 	['Bogotá' 'Bogotà']
# 169 <Hohenlychen> contains:
# 	['Hohenlychen']
# 170 <Hohenzollern> contains:
# 	['Hohenzollern']
# 171 <Hohenelbe> contains:
# 	['Hohenelbe']
# 172 <Hohenschönhausen> contains:
# 	['Hohenschönhausen']
# 173 <Hohensalza> contains:
# 	['Hohensalza']
# 174 <Soerabaia> contains:
# 	['Soerabaia' 'Soerabaya' 'Soerabaja']
# 175 <Desoy> contains:
# 	['Desoy' 'Desoye']
# 176 <Dessau> contains:
# 	['Dessau']
# 177 <Dessaviae> contains:
# 	['Dessaviae']
# 178 <Deßau> contains:
# 	['Deßau']
# 179 <Zu> contains:
# 	['Zu']
# 180 <Zug> contains:
# 	['Zug']
# 181 <Longo-Salissae> contains:
# 	['Longo-Salissae']
# 182 <Longwi> contains:
# 	['Longwi']
# 183 <Ystad> contains:
# 	['Ystad']
# 184 <Gstaad> contains:
# 	['Gstaad']
# 185 <Augustae> contains:
# 	['Augustae' 'August.' 'Augusta' 'Augustæ']
# 186 <Avgvstae> contains:
# 	['Avgvstae']
# 187 <Aulestad> contains:
# 	['Aulestad']
# 188 <Aug.> contains:
# 	['Aug.']
# 189 <Naini> contains:
# 	['Naini']
# 190 <Ninive> contains:
# 	['Ninive']
# 191 <Emmishofen> contains:
# 	['Emmishofen']
# 192 <Elmshorn> contains:
# 	['Elmshorn']
# 193 <Militsch> contains:
# 	['Militsch']
# 194 <Quirlequitsch> contains:
# 	['Quirlequitsch']
# 195 <Lemgo> contains:
# 	['Lemgo' 'Lemgou' 'Lemgoviae']
# 196 <Lugduni> contains:
# 	['Lugduni' 'Lvgduni']
# 197 <Lahr> contains:
# 	['Lahr' 'Lahore']
# 198 <Lyon> contains:
# 	['Lyon' 'Lyon?']
# 199 <Laon> contains:
# 	['Laon']
# 200 <Lago> contains:
# 	['Lago']
# 201 <Lynton> contains:
# 	['Lynton']
# 202 <La> contains:
# 	['La']
# 203 <Lugano> contains:
# 	['Lugano']
# 204 <Wallmow> contains:
# 	['Wallmow']
# 205 <Wallmerod> contains:
# 	['Wallmerod']
# 206 <Wallingford> contains:
# 	['Wallingford']
# 207 <Danzig> contains:
# 	['Danzig' 'Dantzig' 'Dantzigk' 'Danzig?']
# 208 <Dantisci> contains:
# 	['Dantisci']
# 209 <Osnabrück> contains:
# 	['Osnabrück' 'Oßnabrück' 'Osnabrüg' 'Osnabrugi' 'Osnabrugæ']
# 210 <Seehöhe> contains:
# 	['Seehöhe']
# 211 <Seeheim> contains:
# 	['Seeheim']
# 212 <Rostock> contains:
# 	['Rostock' 'Rostochii' 'Rostoghii' 'Rostochi' 'Rost.' 'Rostoch.' 'Rostok'
#  'Rostoch']
# 213 <Rochstochii> contains:
# 	['Rochstochii']
# 214 <Onoldsbachii> contains:
# 	['Onoldsbachii' 'Onoltzbach' 'Onolzbach']
# 215 <Onoldi> contains:
# 	['Onoldi']
# 216 <Sulzbach> contains:
# 	['Sulzbach' 'Sultzbach']
# 217 <Butzbach> contains:
# 	['Butzbach']
# 218 <Kulmbach> contains:
# 	['Kulmbach' 'Culmbaci' 'Culmbach']
# 219 <Culm> contains:
# 	['Culm']
# 220 <Cuba> contains:
# 	['Cuba']
# 221 <Suobaci> contains:
# 	['Suobaci']
# 222 <Gouda> contains:
# 	['Gouda']
# 223 <Gausdal> contains:
# 	['Gausdal']
# 224 <Dortmund> contains:
# 	['Dortmund' 'Dormundt' 'Dortmundt']
# 225 <Dord> contains:
# 	['Dord']
# 226 <Dordraci> contains:
# 	['Dordraci']
# 227 <Dordrecht> contains:
# 	['Dordrecht']
# 228 <Dorf> contains:
# 	['Dorf']
# 229 <Dörpt> contains:
# 	['Dörpt']
# 230 <Dorpat> contains:
# 	['Dorpat']
# 231 <Saint-Marcellin <Isère>> contains:
# 	['Saint-Marcellin <Isère>']
# 232 <Saint-Martin (Eure)> contains:
# 	['Saint-Martin (Eure)']
# 233 <Botiguery> contains:
# 	['Botiguery']
# 234 <Boti?> contains:
# 	['Boti?']
# 235 <Botanischer> contains:
# 	['Botanischer']
# 236 <Byzantinisches> contains:
# 	['Byzantinisches']
# 237 <Alexandrie> contains:
# 	['Alexandrie']
# 238 <Alexandersbad> contains:
# 	['Alexandersbad']
# 239 <Falmouth> contains:
# 	['Falmouth']
# 240 <Falun> contains:
# 	['Falun']
# 241 <Plymouth> contains:
# 	['Plymouth']
# 242 <Grenzgebiet> contains:
# 	['Grenzgebiet']
# 243 <Grenoble> contains:
# 	['Grenoble']
# 244 <Lwów> contains:
# 	['Lwów']
# 245 <Lwow> contains:
# 	['Lwow']
# 246 <Zeitz> contains:
# 	['Zeitz' 'Zeiz']
# 247 <Novum> contains:
# 	['Novum']
# 248 <Novi> contains:
# 	['Novi']
# 249 <Tegel> contains:
# 	['Tegel']
# 250 <Tegernsee> contains:
# 	['Tegernsee']
# 251 <Anklam> contains:
# 	['Anklam' 'Anclam']
# 252 <Alais> contains:
# 	['Alais']
# 253 <Alassio> contains:
# 	['Alassio']
# 254 <Klais> contains:
# 	['Klais']
# 255 <Ala> contains:
# 	['Ala']
# 256 <Alcalá> contains:
# 	['Alcalá']
# 257 <Albany> contains:
# 	['Albany']
# 258 <Alingsås> contains:
# 	['Alingsås']
# 259 <Brühl-Köln> contains:
# 	['Brühl-Köln']
# 260 <Bühl> contains:
# 	['Bühl']
# 261 <Lorch> contains:
# 	['Lorch']
# 262 <Lochham> contains:
# 	['Lochham']
# 263 <Lörrach> contains:
# 	['Lörrach']
# 264 <Gandersheim> contains:
# 	['Gandersheim']
# 265 <Gundelsheim> contains:
# 	['Gundelsheim']
# 266 <Bogliascco> contains:
# 	['Bogliascco' 'Bogliasco']
# 267 <Oppeln> contains:
# 	['Oppeln' 'Oppenau']
# 268 <Oppenheim> contains:
# 	['Oppenheim']
# 269 <Pappenheim> contains:
# 	['Pappenheim']
# 270 <Rumpenheim> contains:
# 	['Rumpenheim']
# 271 <Karalauczuje> contains:
# 	['Karalauczuje' 'Karaliaucziuie' 'Karalauczuie']
# 272 <Emmendingen> contains:
# 	['Emmendingen']
# 273 <Emmerik> contains:
# 	['Emmerik']
# 274 <Amerika> contains:
# 	['Amerika']
# 275 <Kolozsvártt> contains:
# 	['Kolozsvártt' 'Kolozsvár']
# 276 <Eschwege> contains:
# 	['Eschwege' 'Eschweiler']
# 277 <Enschede> contains:
# 	['Enschede']
# 278 <Ensisheim> contains:
# 	['Ensisheim']
# 279 <Wertheim> contains:
# 	['Wertheim' 'Werthemiae']
# 280 <Flemming> contains:
# 	['Flemming']
# 281 <Demmin> contains:
# 	['Demmin']
# 282 <Simferopol> contains:
# 	['Simferopol']
# 283 <Simmern> contains:
# 	['Simmern']
# 284 <Gustrovii> contains:
# 	['Gustrovii' 'Gustroviii' 'Güstrovii' 'Gustrovi.' 'Güstroviæ' 'Güstroviae'
#  'Gustroviae']
# 285 <Güstrow> contains:
# 	['Güstrow' 'Gustrow']
# 286 <Günther> contains:
# 	['Günther']
# 287 <Günterstal> contains:
# 	['Günterstal']
# 288 <Gütersloh> contains:
# 	['Gütersloh']
# 289 <Tempelhof> contains:
# 	['Tempelhof']
# 290 <Templin> contains:
# 	['Templin']
# 291 <Teplitz> contains:
# 	['Teplitz']
# 292 <Zutphen> contains:
# 	['Zutphen' 'Zütphen']
# 293 <Hof> contains:
# 	['Hof' 'Hoff']
# 294 <Noordwijk-Batavia> contains:
# 	['Noordwijk-Batavia' 'Noordwyk' 'Noordwijk']
# 295 <Biberach-Riß> contains:
# 	['Biberach-Riß' 'Biberach']
# 296 <Pörtschach> contains:
# 	['Pörtschach']
# 297 <Mortschach> contains:
# 	['Mortschach']
# 298 <Meriden/Connecticut> contains:
# 	['Meriden/Connecticut']
# 299 <Meriden, Conn.> contains:
# 	['Meriden, Conn.']
# 300 <Orléans> contains:
# 	['Orléans' 'Orleans']
# 301 <Eger> contains:
# 	['Eger' 'Egern']
# 302 <Eggerssen> contains:
# 	['Eggerssen']
# 303 <Locarno> contains:
# 	['Locarno' 'Locarno-Monti']
# 304 <Locarno-Orselina> contains:
# 	['Locarno-Orselina']
# 305 <Liverpool> contains:
# 	['Liverpool']
# 306 <Liverpool: Webb, Hunt> contains:
# 	['Liverpool: Webb, Hunt']
# 307 <Livorno> contains:
# 	['Livorno']
# 308 <Rudolstadt> contains:
# 	['Rudolstadt' 'Rudolfstadt' 'Rudolstadii' 'Roudolstadt']
# 309 <Rudolphipoli> contains:
# 	['Rudolphipoli']
# 310 <Ingolstadt> contains:
# 	['Ingolstadt' 'Ingolstadii']
# 311 <Iglau> contains:
# 	['Iglau']
# 312 <Igls> contains:
# 	['Igls']
# 313 <Delitzsch> contains:
# 	['Delitzsch' 'Delitsch']
# 314 <Veitsch> contains:
# 	['Veitsch']
# 315 <Delitii> contains:
# 	['Delitii']
# 316 <Delft> contains:
# 	['Delft']
# 317 <Delphi> contains:
# 	['Delphi']
# 318 <Primislaviae> contains:
# 	['Primislaviae' 'Primislaviæ']
# 319 <Varsovie> contains:
# 	['Varsovie' 'Varsaviae']
# 320 <Vrastislaviae> contains:
# 	['Vrastislaviae' 'Vratislaviae' 'Wratislaviae' 'Wratislav.' 'Vratislava'
#  'Vratislaviensis' 'Vratisl.' 'Wratislavia' 'Wratislaviæ' 'Wratisl.'
#  'Vratistaviae']
# 321 <Conimbricæ> contains:
# 	['Conimbricæ' 'Conimbricae']
# 322 <Nice> contains:
# 	['Nice']
# 323 <Nimes> contains:
# 	['Nimes']
# 324 <Bennigsen> contains:
# 	['Bennigsen']
# 325 <Bensheim> contains:
# 	['Bensheim']
# 326 <Arosa> contains:
# 	['Arosa']
# 327 <Arolsen> contains:
# 	['Arolsen']
# 328 <Arco> contains:
# 	['Arco']
# 329 <Singapore> contains:
# 	['Singapore' 'Singapur']
# 330 <Zaltbommel> contains:
# 	['Zaltbommel' 'Zalt-Bommel' 'Zel-Bommel']
# 331 <Reval> contains:
# 	['Reval' 'Revaliae']
# 332 <Christianstat> contains:
# 	['Christianstat' 'Kristiania' 'Christiania' 'Christian-Erlang'
#  'Christiansstadt' 'Christ-Erlang' 'Christian-Erlangæ']
# 333 <Christianopel> contains:
# 	['Christianopel']
# 334 <Ansbach> contains:
# 	['Ansbach' 'Anspach']
# 335 <Aidenbach> contains:
# 	['Aidenbach']
# 336 <Tiefenbach> contains:
# 	['Tiefenbach']
# 337 <Andernach> contains:
# 	['Andernach']
# 338 <Apenrade> contains:
# 	['Apenrade']
# 339 <Hoppenrade> contains:
# 	['Hoppenrade']
# 340 <Kochem> contains:
# 	['Kochem' 'Kochel']
# 341 <Cochem> contains:
# 	['Cochem']
# 342 <Kuchelna> contains:
# 	['Kuchelna']
# 343 <Corbie?> contains:
# 	['Corbie?']
# 344 <Corbach> contains:
# 	['Corbach']
# 345 <Wilhelmshaven> contains:
# 	['Wilhelmshaven' 'Wilhelmshagen']
# 346 <Die> contains:
# 	['Die' 'Diez']
# 347 <De> contains:
# 	['De']
# 348 <Cüstrin> contains:
# 	['Cüstrin' 'Cüstrini' 'Custrini']
# 349 <Küstrin> contains:
# 	['Küstrin']
# 350 <Fischbach> contains:
# 	['Fischbach']
# 351 <Fischeln> contains:
# 	['Fischeln']
# 352 <Erfurt> contains:
# 	['Erfurt' 'Erfurti' 'Erffurt' 'Erfordiae' 'Erffurdt' 'Erffurtensis'
#  'Erfurdt' 'Erffurd' 'Erphordiae' 'Erfurth' 'Erfurdiae' 'Erffurti'
#  'Erffordiae' 'Erfurt.' 'Erffurthi' 'Erffurth' 'Erfurt?' 'Erfordiæ'
#  'Erffordt' 'Erffuhrt' 'Erffut' 'Erffurdiae' 'Erfurdi' 'Erfurts' 'Erfordi'
#  'Erffurdi']
# 353 <Erphurti> contains:
# 	['Erphurti']
# 354 <Klagenfurt> contains:
# 	['Klagenfurt' 'Klagenfurth' 'Clagenfurt']
# 355 <Aquila> contains:
# 	['Aquila']
# 356 <Aquisgrani> contains:
# 	['Aquisgrani']
# 357 <Bodenfelde> contains:
# 	['Bodenfelde']
# 358 <Bodenseegebiet> contains:
# 	['Bodenseegebiet']
# 359 <Agnetendorf> contains:
# 	['Agnetendorf' 'Agnentendorf' 'Agenetendorf']
# 360 <Lauderstedt> contains:
# 	['Lauderstedt']
# 361 <Lauchstedt> contains:
# 	['Lauchstedt']
# 362 <Kaufbeuren> contains:
# 	['Kaufbeuren']
# 363 <Bauerhufen> contains:
# 	['Bauerhufen']
# 364 <Munic> contains:
# 	['Munic' 'Munich']
# 365 <Munising> contains:
# 	['Munising']
# 366 <Minusio> contains:
# 	['Minusio']
# 367 <Zittau> contains:
# 	['Zittau']
# 368 <Zittaviae> contains:
# 	['Zittaviae']
# 369 <Mitau> contains:
# 	['Mitau' 'Mietau']
# 370 <Mistra> contains:
# 	['Mistra']
# 371 <Wetzlar> contains:
# 	['Wetzlar' 'Wezlar' 'Wetzlariae' 'Wetzlariæ']
# 372 <Leodii> contains:
# 	['Leodii']
# 373 <Lodi> contains:
# 	['Lodi']
# 374 <Lodz> contains:
# 	['Lodz']
# 375 <Laodicea> contains:
# 	['Laodicea']
# 376 <Nowogrodek> contains:
# 	['Nowogrodek']
# 377 <Novgorod> contains:
# 	['Novgorod']
# 378 <Boston> contains:
# 	['Boston' 'Boyton']
# 379 <Boston, Mass.> contains:
# 	['Boston, Mass.']
# 380 <Noyon> contains:
# 	['Noyon']
# 381 <Carvin> contains:
# 	['Carvin']
# 382 <Capri> contains:
# 	['Capri']
# 383 <Careggi> contains:
# 	['Careggi']
# 384 <Cap-dAil> contains:
# 	['Cap-d\x92Ail']
# 385 <Bocholt> contains:
# 	['Bocholt']
# 386 <Bocholt/Westfalen> contains:
# 	['Bocholt/Westfalen']
# 387 <Bochum> contains:
# 	['Bochum']
# 388 <Klobenstein> contains:
# 	['Klobenstein' 'Lobenstein']
# 389 <Wohlau> contains:
# 	['Wohlau']
# 390 <Wehlau> contains:
# 	['Wehlau']
# 391 <Wolfshau> contains:
# 	['Wolfshau']
# 392 <Wolfenbüttel> contains:
# 	['Wolfenbüttel' 'Wolffenbüttel' 'Wolffenbuttel' 'Wolfenbutteli'
#  'Wulffenbüttel' 'Wolffenbuttelae' 'Wolfenbuttelae' 'Wolfenbuttel']
# 393 <Wolfurt> contains:
# 	['Wolfurt']
# 394 <Wolkenstein> contains:
# 	['Wolkenstein']
# 395 <Allenstein> contains:
# 	['Allenstein']
# 396 <Michelstadt> contains:
# 	['Michelstadt']
# 397 <Ohlstadt> contains:
# 	['Ohlstadt']
# 398 <Ohlau> contains:
# 	['Ohlau']
# 399 <Havanna> contains:
# 	['Havanna']
# 400 <Habana> contains:
# 	['Habana']
# 401 <Cleveland, Ohio> contains:
# 	['Cleveland, Ohio' 'Cleveland' 'Cleve']
# 402 <Kleve> contains:
# 	['Kleve']
# 403 <Olivae> contains:
# 	['Olivae' 'Oliva']
# 404 <Cliviae> contains:
# 	['Cliviae']
# 405 <Clavieres> contains:
# 	['Clavieres']
# 406 <Züllichau> contains:
# 	['Züllichau' 'Züllichow']
# 407 <Cizae> contains:
# 	['Cizae']
# 408 <Zizae> contains:
# 	['Zizae']
# 409 <Zyrich> contains:
# 	['Zyrich' 'Zyrch']
# 410 <Zürich> contains:
# 	['Zürich' 'Zürych']
# 411 <Zürich-Zollikon> contains:
# 	['Zürich-Zollikon']
# 412 <Zürich-Hottingen> contains:
# 	['Zürich-Hottingen']
# 413 <Durlaci> contains:
# 	['Durlaci' 'Durlach']
# 414 <Curiae> contains:
# 	['Curiae']
# 415 <Curiae-Variscorum> contains:
# 	['Curiae-Variscorum']
# 416 <Aurich> contains:
# 	['Aurich' 'Aurach' 'Auricae']
# 417 <Zurzach> contains:
# 	['Zurzach']
# 418 <Zuric> contains:
# 	['Zuric']
# 419 <Autograph> contains:
# 	['Autograph']
# 420 <Agra> contains:
# 	['Agra']
# 421 <Johannaberg> contains:
# 	['Johannaberg' 'Johannisberg']
# 422 <Johanngeorgenstadt> contains:
# 	['Johanngeorgenstadt']
# 423 <Fulda> contains:
# 	['Fulda' 'Fuld' 'Fuldae']
# 424 <Fiurda> contains:
# 	['Fiurda']
# 425 <Airolo> contains:
# 	['Airolo']
# 426 <Air> contains:
# 	['Air']
# 427 <Emden> contains:
# 	['Emden' 'Embdae' 'Embden' 'Emdae']
# 428 <Eldena> contains:
# 	['Eldena' 'Elderen']
# 429 <Dahlem> contains:
# 	['Dahlem' 'Dahme']
# 430 <Jena> contains:
# 	['Jena' 'Jehna' 'Jenae' 'Jhenae' 'Jena?' 'Jene']
# 431 <Ienae> contains:
# 	['Ienae' 'Iena']
# 432 <Ienæ> contains:
# 	['Ienæ']
# 433 <Ien.> contains:
# 	['Ien.']
# 434 <Ilmenau> contains:
# 	['Ilmenau']
# 435 <Isenaci> contains:
# 	['Isenaci']
# 436 <Jena, Erfurt> contains:
# 	['Jena, Erfurt']
# 437 <Ienensi> contains:
# 	['Ienensi']
# 438 <In> contains:
# 	['In']
# 439 <Jemen> contains:
# 	['Jemen']
# 440 <Jever> contains:
# 	['Jever']
# 441 <Alethopoli> contains:
# 	['Alethopoli' 'Aetopoli']
# 442 <Eleutheropoli> contains:
# 	['Eleutheropoli']
# 443 <Salamanticae> contains:
# 	['Salamanticae' 'Salamanca']
# 444 <Saamaaranch> contains:
# 	['Saamaaranch']
# 445 <Makassar> contains:
# 	['Makassar']
# 446 <Marklissa> contains:
# 	['Marklissa']
# 447 <Perez> contains:
# 	['Perez' 'Peresznye']
# 448 <Essen> contains:
# 	['Essen']
# 449 <Essen-Ruhr> contains:
# 	['Essen-Ruhr']
# 450 <Assen> contains:
# 	['Assen']
# 451 <Assaunen> contains:
# 	['Assaunen']
# 452 <Erbsen> contains:
# 	['Erbsen']
# 453 <Valetta> contains:
# 	['Valetta']
# 454 <Valencia> contains:
# 	['Valencia']
# 455 <Valdivia> contains:
# 	['Valdivia']
# 456 <Rawicz> contains:
# 	['Rawicz']
# 457 <Rawitsch> contains:
# 	['Rawitsch']
# 458 <Niederlande> contains:
# 	['Niederlande']
# 459 <Niederlande, östliche> contains:
# 	['Niederlande, östliche']
# 460 <Niederrhein> contains:
# 	['Niederrhein']
# 461 <Niedersachsen> contains:
# 	['Niedersachsen']
# 462 <Niederseeon> contains:
# 	['Niederseeon']
# 463 <Niederösterreich> contains:
# 	['Niederösterreich']
# 464 <Nieder-Schönhausen> contains:
# 	['Nieder-Schönhausen']
# 465 <Niederuzwil> contains:
# 	['Niederuzwil']
# 466 <Nieuwediep> contains:
# 	['Nieuwediep']
# 467 <Rinteln> contains:
# 	['Rinteln' 'Rintelii' 'Rintheln' 'Rinthelii' 'Rintelli' 'Rintellii'
#  'Rintelium']
# 468 <Arendsee> contains:
# 	['Arendsee']
# 469 <Arenas> contains:
# 	['Arenas']
# 470 <Kemnitz> contains:
# 	['Kemnitz']
# 471 <Kemnath> contains:
# 	['Kemnath']
# 472 <Chemnitz> contains:
# 	['Chemnitz']
# 473 <Chemnicii> contains:
# 	['Chemnicii']
# 474 <Islebii> contains:
# 	['Islebii' 'Islebiae' 'Isle']
# 475 <Hiddensee> contains:
# 	['Hiddensee']
# 476 <Hiddensee/ Kloster> contains:
# 	['Hiddensee/ Kloster']
# 477 <Pankow-Berlin> contains:
# 	['Pankow-Berlin']
# 478 <Pankow> contains:
# 	['Pankow']
# 479 <Panker> contains:
# 	['Panker']
# 480 <Parow> contains:
# 	['Parow']
# 481 <Pesaro> contains:
# 	['Pesaro']
# 482 <Janowitz> contains:
# 	['Janowitz' 'Jannowitz']
# 483 <Tarnopol> contains:
# 	['Tarnopol' 'Tarnowo']
# 484 <Tarnowitz> contains:
# 	['Tarnowitz']
# 485 <Lankwitz> contains:
# 	['Lankwitz']
# 486 <Jagotin> contains:
# 	['Jagotin']
# 487 <Czernowitz> contains:
# 	['Czernowitz']
# 488 <Gernewitz> contains:
# 	['Gernewitz']
# 489 <Prag> contains:
# 	['Prag' 'Pragae' 'Prague' 'Praha' 'Praga']
# 490 <Arnhem> contains:
# 	['Arnhem' 'Arnheim']
# 491 <Arlesheim> contains:
# 	['Arlesheim']
# 492 <Ilbesheim> contains:
# 	['Ilbesheim']
# 493 <Glückstadt> contains:
# 	['Glückstadt' 'Glückstadii']
# 494 <Glücksburg> contains:
# 	['Glücksburg']
# 495 <Kosmopolis> contains:
# 	['Kosmopolis' 'Cosmopolis']
# 496 <Duisburgi> contains:
# 	['Duisburgi' 'Duisburg']
# 497 <Duisburg-Ruhrort> contains:
# 	['Duisburg-Ruhrort']
# 498 <Duisburg-Hamborn> contains:
# 	['Duisburg-Hamborn']
# 499 <Augsburg> contains:
# 	['Augsburg' 'Augspurg' 'Augsburg?' 'Augszpurg' 'Augsbourg']
# 500 <Ludwigsburg> contains:
# 	['Ludwigsburg']
# 501 <Lustigburg> contains:
# 	['Lustigburg']
# 502 <Ludwigslust> contains:
# 	['Ludwigslust']
# 503 <Ludwigshafen> contains:
# 	['Ludwigshafen']
# 504 <Lenzkirch> contains:
# 	['Lenzkirch']
# 505 <Lengerich> contains:
# 	['Lengerich']
# 506 <Lerici> contains:
# 	['Lerici']
# 507 <Thamsbrück> contains:
# 	['Thamsbrück']
# 508 <Tham> contains:
# 	['Tham']
# 509 <Kilonii> contains:
# 	['Kilonii' 'Kiloni']
# 510 <Kiliae> contains:
# 	['Kiliae']
# 511 <Kiliæ> contains:
# 	['Kiliæ']
# 512 <Mossul> contains:
# 	['Mossul' 'Mosul']
# 513 <Moskau> contains:
# 	['Moskau' 'Moskva' 'Moscou' 'Moskou']
# 514 <Muskau> contains:
# 	['Muskau']
# 515 <Tiflis> contains:
# 	['Tiflis']
# 516 <Tilsit> contains:
# 	['Tilsit']
# 517 <Tripolis> contains:
# 	['Tripolis']
# 518 <Tbilissi> contains:
# 	['Tbilissi']
# 519 <Tirol> contains:
# 	['Tirol']
# 520 <Fort> contains:
# 	['Fort']
# 521 <Fortemarmi> contains:
# 	['Fortemarmi']
# 522 <Front> contains:
# 	['Front']
# 523 <Polkritz> contains:
# 	['Polkritz' 'Polkwitz']
# 524 <Pont> contains:
# 	['Pont']
# 525 <Pontresina> contains:
# 	['Pontresina']
# 526 <Porto> contains:
# 	['Porto' 'Portofino' 'Port']
# 527 <Portsmouth> contains:
# 	['Portsmouth']
# 528 <Port-Artur> contains:
# 	['Port-Artur']
# 529 <Potosi> contains:
# 	['Potosi']
# 530 <Poistorf> contains:
# 	['Poistorf']
# 531 <Puerto> contains:
# 	['Puerto']
# 532 <Bockwitz> contains:
# 	['Bockwitz']
# 533 <Poissy> contains:
# 	['Poissy']
# 534 <Calw> contains:
# 	['Calw']
# 535 <Calbe> contains:
# 	['Calbe']
# 536 <Einsiedeln> contains:
# 	['Einsiedeln']
# 537 <Einsidlia> contains:
# 	['Einsidlia']
# 538 <Ascona> contains:
# 	['Ascona']
# 539 <Acoma> contains:
# 	['Acoma']
# 540 <Hildesheim> contains:
# 	['Hildesheim' 'Hillesheimii' 'Hildenßheim' 'Hildesii' 'Hildesiae'
#  'Hildeßheimb']
# 541 <Hilperhusae> contains:
# 	['Hilperhusae']
# 542 <Calcutta> contains:
# 	['Calcutta']
# 543 <Kalkutta> contains:
# 	['Kalkutta']
# 544 <Denver Poststempel> contains:
# 	['Denver Poststempel']
# 545 <Densberg Poststempel> contains:
# 	['Densberg Poststempel']
# 546 <Batavia> contains:
# 	['Batavia' 'Batavia-Solo' 'Batawi' 'Batavia?']
# 547 <Bethaniae> contains:
# 	['Bethaniae']
# 548 <Betawi> contains:
# 	['Betawi']
# 549 <Chaltg.> contains:
# 	['Chaltg.']
# 550 <Chlttbg.> contains:
# 	['Chlttbg.']
# 551 <Pratteln> contains:
# 	['Pratteln']
# 552 <Prettin> contains:
# 	['Prettin']
# 553 <Mannheim> contains:
# 	['Mannheim' 'Manheim' 'Mannhemii']
# 554 <Bétsben> contains:
# 	['Bétsben' 'Betsben']
# 555 <Beuthen> contains:
# 	['Beuthen']
# 556 <Deutschland> contains:
# 	['Deutschland' 'Deutschlandsberg']
# 557 <Norditalien> contains:
# 	['Norditalien' 'Nordindien']
# 558 <Nordlingae> contains:
# 	['Nordlingae']
# 559 <Northausen> contains:
# 	['Northausen' 'Nordthausen' 'Nordhausen' 'Nordhusae' 'Northusae' 'Norden'
#  'Norderney' 'Nordausen' 'Nordbayern']
# 560 <Süddeutschland> contains:
# 	['Süddeutschland' 'Südwestdeutschland' 'Norddeutschland'
#  'Nordwestdeutschland' 'Süddeutschland/Österreich'
#  'Norddeutschland; Wienhausen']
# 561 <Nördlingen> contains:
# 	['Nördlingen']
# 562 <Nordelsass> contains:
# 	['Nordelsass']
# 563 <Nordfrankreich> contains:
# 	['Nordfrankreich']
# 564 <Süditalien> contains:
# 	['Süditalien']
# 565 <Nor> contains:
# 	['Nor']
# 566 <Osterwieck/Harz> contains:
# 	['Osterwieck/Harz' 'Osterwieck-Harz' 'Osterwieck']
# 567 <Osterode> contains:
# 	['Osterode' 'Ostende']
# 568 <Ost-Indien> contains:
# 	['Ost-Indien']
# 569 <Osterhagen> contains:
# 	['Osterhagen']
# 570 <Indien> contains:
# 	['Indien']
# 571 <Ostseebad> contains:
# 	['Ostseebad']
# 572 <Ostrau> contains:
# 	['Ostrau']
# 573 <Morogoro> contains:
# 	['Morogoro']
# 574 <Moropolis> contains:
# 	['Moropolis']
# 575 <Wiżnitz> contains:
# 	['Wiżnitz']
# 576 <Wirsitz> contains:
# 	['Wirsitz']
# 577 <Arel> contains:
# 	['Arel']
# 578 <Argelan> contains:
# 	['Argelan']
# 579 <Argentorati> contains:
# 	['Argentorati' 'Argentoratii']
# 580 <Argentinae> contains:
# 	['Argentinae']
# 581 <Abel> contains:
# 	['Abel']
# 582 <Siusi> contains:
# 	['Siusi']
# 583 <Silusiae> contains:
# 	['Silusiae']
# 584 <Sils> contains:
# 	['Sils']
# 585 <Seis> contains:
# 	['Seis']
# 586 <Kersel> contains:
# 	['Kersel']
# 587 <Kerenopolis> contains:
# 	['Kerenopolis']
# 588 <Rückersdorf> contains:
# 	['Rückersdorf' 'Rüdersdorf']
# 589 <Wilmersdorf> contains:
# 	['Wilmersdorf' 'Wilmersdorf-Berlin']
# 590 <Wickersdorf> contains:
# 	['Wickersdorf']
# 591 <Woltersdorf> contains:
# 	['Woltersdorf']
# 592 <Wiesbaden> contains:
# 	['Wiesbaden' 'Wießbaden' 'Wiedbaden' 'Wißbaden' 'Wisladen']
# 593 <Wilda> contains:
# 	['Wilda' 'Wilna' 'Wildbad' 'Wilno']
# 594 <Wisbadii> contains:
# 	['Wisbadii']
# 595 <Haidelbergae> contains:
# 	['Haidelbergae']
# 596 <Havelberg> contains:
# 	['Havelberg']
# 597 <Hadersleben> contains:
# 	['Hadersleben']
# 598 <Kaiserswerth> contains:
# 	['Kaiserswerth' 'Kaiserwerth']
# 599 <Kaiserslautern> contains:
# 	['Kaiserslautern']
# 600 <Rouen> contains:
# 	['Rouen']
# 601 <Rodaun> contains:
# 	['Rodaun']
# 602 <Passau(?)> contains:
# 	['Passau(?)' 'Passau' 'Passay']
# 603 <Nassau> contains:
# 	['Nassau']
# 604 <Namslau> contains:
# 	['Namslau']
# 605 <Dauchau> contains:
# 	['Dauchau' 'Dachau']
# 606 <Warschau> contains:
# 	['Warschau']
# 607 <Kaschau> contains:
# 	['Kaschau']
# 608 <Kasan> contains:
# 	['Kasan']
# 609 <Warszawa> contains:
# 	['Warszawa']
# 610 <Patschkau> contains:
# 	['Patschkau']
# 611 <Paris: Dupont> contains:
# 	['Paris: Dupont']
# 612 <Paris: Plon> contains:
# 	['Paris: Plon']
# 613 <Paris> contains:
# 	['Paris' 'Parisiis' 'Paris?']
# 614 <Paraggi> contains:
# 	['Paraggi']
# 615 <Parigi> contains:
# 	['Parigi']
# 616 <Paramé> contains:
# 	['Paramé' 'Parma']
# 617 <Patras> contains:
# 	['Patras']
# 618 <Parchim> contains:
# 	['Parchim']
# 619 <Castelfranco> contains:
# 	['Castelfranco']
# 620 <Caslano> contains:
# 	['Caslano']
# 621 <Castelraimondo> contains:
# 	['Castelraimondo']
# 622 <Castelluccio> contains:
# 	['Castelluccio']
# 623 <Cassel> contains:
# 	['Cassel' 'Cassellis' 'Cassis' 'Cassell' 'Casselis']
# 624 <Kassel> contains:
# 	['Kassel']
# 625 <Cassel-Wilhelmshöhe> contains:
# 	['Cassel-Wilhelmshöhe']
# 626 <Kagel> contains:
# 	['Kagel']
# 627 <Hasselt> contains:
# 	['Hasselt']
# 628 <Kusel> contains:
# 	['Kusel']
# 629 <Sassnitz> contains:
# 	['Sassnitz']
# 630 <Saßnitz> contains:
# 	['Saßnitz']
# 631 <Holte> contains:
# 	['Holte']
# 632 <Hotel> contains:
# 	['Hotel']
# 633 <Semarang> contains:
# 	['Semarang']
# 634 <Semmering> contains:
# 	['Semmering']
# 635 <Sarmatien> contains:
# 	['Sarmatien']
# 636 <Samaden> contains:
# 	['Samaden']
# 637 <Samarang> contains:
# 	['Samarang']
# 638 <Dalmatien> contains:
# 	['Dalmatien']
# 639 <Lucknow> contains:
# 	['Lucknow' 'Lukow']
# 640 <Luckau> contains:
# 	['Luckau']
# 641 <Lucca> contains:
# 	['Lucca']
# 642 <Moers> contains:
# 	['Moers']
# 643 <Meurs> contains:
# 	['Meurs']
# 644 <Monrepos> contains:
# 	['Monrepos']
# 645 <Alencon> contains:
# 	['Alencon' 'Alençon']
# 646 <Sestri> contains:
# 	['Sestri']
# 647 <Sestri-Levante> contains:
# 	['Sestri-Levante']
# 648 <Servestae> contains:
# 	['Servestae']
# 649 <Soest> contains:
# 	['Soest']
# 650 <Recklinghausen> contains:
# 	['Recklinghausen' 'Recklingshausen']
# 651 <Schreiberhau> contains:
# 	['Schreiberhau']
# 652 <Schreiberdorf> contains:
# 	['Schreiberdorf']
# 653 <Elberfeld> contains:
# 	['Elberfeld' 'Elbenfeld' 'Eberfeld']
# 654 <Elberfeld-Sonnborn> contains:
# 	['Elberfeld-Sonnborn']
# 655 <Eberswalde> contains:
# 	['Eberswalde']
# 656 <Ebersweir> contains:
# 	['Ebersweir']
# 657 <Ehrwald> contains:
# 	['Ehrwald']
# 658 <Zippendorf> contains:
# 	['Zippendorf']
# 659 <Zinndorf> contains:
# 	['Zinndorf']
# 660 <Binz> contains:
# 	['Binz']
# 661 <Biganzolo> contains:
# 	['Biganzolo']
# 662 <Höchst> contains:
# 	['Höchst']
# 663 <Höchenschwand> contains:
# 	['Höchenschwand']
# 664 <Solingen> contains:
# 	['Solingen']
# 665 <Solln> contains:
# 	['Solln']
# 666 <Wittlich> contains:
# 	['Wittlich']
# 667 <Wittstock> contains:
# 	['Wittstock']
# 668 <Aschersleb.> contains:
# 	['Aschersleb.' 'Aschersleben' 'Oschersleben']
# 669 <Kiel> contains:
# 	['Kiel' 'Kielce']
# 670 <Kiev> contains:
# 	['Kiev']
# 671 <Kehl> contains:
# 	['Kehl']
# 672 <Kīev> contains:
# 	['Kīev']
# 673 <Westminster> contains:
# 	['Westminster']
# 674 <Weston-super-Mare> contains:
# 	['Weston-super-Mare']
# 675 <Werningerodae> contains:
# 	['Werningerodae' 'Wernigerode' 'Wernigeroda' 'Wernigerodae']
# 676 <Neukirchen> contains:
# 	['Neukirchen' 'Neukirchen, Kr.' 'Neukirch']
# 677 <Loschwitz> contains:
# 	['Loschwitz']
# 678 <Leobschütz> contains:
# 	['Leobschütz']
# 679 <Sondershusae> contains:
# 	['Sondershusae' 'Sondershausen']
# 680 <Rottweil> contains:
# 	['Rottweil' 'Rotweil']
# 681 <Bürgel> contains:
# 	['Bürgel']
# 682 <Bürgenstock> contains:
# 	['Bürgenstock']
# 683 <Bangalore> contains:
# 	['Bangalore' 'Mangalore']
# 684 <Bando> contains:
# 	['Bando']
# 685 <Bandar> contains:
# 	['Bandar']
# 686 <Bando, Japan> contains:
# 	['Bando, Japan']
# 687 <Bangkok> contains:
# 	['Bangkok']
# 688 <Moosach> contains:
# 	['Moosach' 'Moosbach']
# 689 <Miesbach> contains:
# 	['Miesbach']
# 690 <Dittersbach> contains:
# 	['Dittersbach']
# 691 <Kreuznach> contains:
# 	['Kreuznach']
# 692 <Kreuth> contains:
# 	['Kreuth']
# 693 <Creutzenach> contains:
# 	['Creutzenach']
# 694 <Otta> contains:
# 	['Otta' 'Ottan']
# 695 <Potsdam> contains:
# 	['Potsdam' 'Postdam' 'Potsdamm']
# 696 <Positano> contains:
# 	['Positano']
# 697 <Steglitz-Berlin> contains:
# 	['Steglitz-Berlin' 'Steglitz' 'Steglitz-' 'Stegliz-']
# 698 <Tiguri> contains:
# 	['Tiguri']
# 699 <Tugii> contains:
# 	['Tugii']
# 700 <Turici> contains:
# 	['Turici']
# 701 <Turin> contains:
# 	['Turin']
# 702 <Thun> contains:
# 	['Thun' 'Thurn']
# 703 <Thorn> contains:
# 	['Thorn' 'Thorunii' 'Thorm']
# 704 <Toruniu> contains:
# 	['Toruniu']
# 705 <Toruń> contains:
# 	['Toruń']
# 706 <Torgau> contains:
# 	['Torgau']
# 707 <Tur> contains:
# 	['Tur']
# 708 <Tours> contains:
# 	['Tours']
# 709 <Turku> contains:
# 	['Turku']
# 710 <Tokyo> contains:
# 	['Tokyo' 'Tokio']
# 711 <Torino> contains:
# 	['Torino']
# 712 <Toronto> contains:
# 	['Toronto']
# 713 <Traiecti> contains:
# 	['Traiecti' 'Trajecti']
# 714 <Trier> contains:
# 	['Trier']
# 715 <Triest> contains:
# 	['Triest']
# 716 <Tierra> contains:
# 	['Tierra']
# 717 <Treisa> contains:
# 	['Treisa']
# 718 <Tremoniae> contains:
# 	['Tremoniae']
# 719 <Tiberias> contains:
# 	['Tiberias']
# 720 <Crembs> contains:
# 	['Crembs']
# 721 <Cremona> contains:
# 	['Cremona']
# 722 <Stockholm> contains:
# 	['Stockholm' 'Stockolm']
# 723 <Macao> contains:
# 	['Macao']
# 724 <Macolin> contains:
# 	['Macolin']
# 725 <Konstanz> contains:
# 	['Konstanz' 'Konstanza']
# 726 <Constantinopolis> contains:
# 	['Constantinopolis' 'Konstantinopel' 'Constantinopel' 'Constantine'
#  'Constantiae']
# 727 <Crefeld> contains:
# 	['Crefeld']
# 728 <Krefeld> contains:
# 	['Krefeld']
# 729 <Coesfeld> contains:
# 	['Coesfeld']
# 730 <Hain> contains:
# 	['Hain']
# 731 <Haindorf> contains:
# 	['Haindorf']
# 732 <Haiphong> contains:
# 	['Haiphong']
# 733 <Hannover> contains:
# 	['Hannover' 'Hannoverae' 'Hanoviae' 'Hannoveræ' 'Hanoverae' 'Hanoi'
#  'Hannover-List' 'Havniæ' 'Hannover?' 'Hanoviæ' 'Hanover']
# 734 <Hafniae> contains:
# 	['Hafniae']
# 735 <Hannover-Herrenhausen> contains:
# 	['Hannover-Herrenhausen']
# 736 <Neuchâtel> contains:
# 	['Neuchâtel' 'Neuchatel']
# 737 <Aigen> contains:
# 	['Aigen']
# 738 <Aigen/Salzburg> contains:
# 	['Aigen/Salzburg']
# 739 <Angers> contains:
# 	['Angers' 'Anvers']
# 740 <Angerburg> contains:
# 	['Angerburg']
# 741 <Angermünde> contains:
# 	['Angermünde' 'Tangermünde']
# 742 <Travemünde> contains:
# 	['Travemünde']
# 743 <Warnemünde> contains:
# 	['Warnemünde']
# 744 <Abinger> contains:
# 	['Abinger']
# 745 <Leuwarden> contains:
# 	['Leuwarden' 'Leeuwarden']
# 746 <Leuven> contains:
# 	['Leuven']
# 747 <Leverkusen> contains:
# 	['Leverkusen']
# 748 <Liebfrauenberg> contains:
# 	['Liebfrauenberg']
# 749 <Liebenburg> contains:
# 	['Liebenburg']
# 750 <Liebenwerda> contains:
# 	['Liebenwerda']
# 751 <Liebenthal> contains:
# 	['Liebenthal']
# 752 <Graudenz> contains:
# 	['Graudenz' 'Graudanz']
# 753 <Graubünden> contains:
# 	['Graubünden']
# 754 <Sorento> contains:
# 	['Sorento' 'Sorrent' 'Sorrento']
# 755 <Sorenbohm> contains:
# 	['Sorenbohm']
# 756 <Trento> contains:
# 	['Trento']
# 757 <Trebnitz> contains:
# 	['Trebnitz']
# 758 <Treuenbrietzen> contains:
# 	['Treuenbrietzen']
# 759 <Sebnitz> contains:
# 	['Sebnitz']
# 760 <Münster> contains:
# 	['Münster' 'Munster']
# 761 <Münster, Westfalen> contains:
# 	['Münster, Westfalen']
# 762 <Bordeaux> contains:
# 	['Bordeaux']
# 763 <Bordighera> contains:
# 	['Bordighera']
# 764 <Lunden> contains:
# 	['Lunden' 'Lund']
# 765 <London> contains:
# 	['London' 'Londres' 'Londres;Paris' 'Londen' 'Londre']
# 766 <Gmunden> contains:
# 	['Gmunden']
# 767 <Tondern> contains:
# 	['Tondern']
# 768 <Basel> contains:
# 	['Basel' 'Basileae' 'Basle' 'Basel?' 'Basileæ' 'Basiliae' 'Basilieae']
# 769 <Cöthen> contains:
# 	['Cöthen' 'Cöthen/ Im' 'Cöhten']
# 770 <Cöthen-Anhalt> contains:
# 	['Cöthen-Anhalt']
# 771 <Köthen> contains:
# 	['Köthen']
# 772 <Hofstetten> contains:
# 	['Hofstetten']
# 773 <Hofgastein> contains:
# 	['Hofgastein']
# 774 <Hopsten> contains:
# 	['Hopsten']
# 775 <Genova> contains:
# 	['Genova' 'Geneve' 'Geneva']
# 776 <Ženeva> contains:
# 	['Ženeva']
# 777 <Genua> contains:
# 	['Genua']
# 778 <Genève> contains:
# 	['Genève']
# 779 <Gubenae> contains:
# 	['Gubenae' 'Guben']
# 780 <Lübeck> contains:
# 	['Lübeck' 'Lübek' 'Lübeck?']
# 781 <Lubeck> contains:
# 	['Lubeck' 'Lubecae' 'Lubecæ' 'Lubbenae']
# 782 <Lübben> contains:
# 	['Lübben']
# 783 <Luebek> contains:
# 	['Luebek']
# 784 <Genf> contains:
# 	['Genf' 'Genff']
# 785 <Gent> contains:
# 	['Gent' 'Genthin']
# 786 <Girgenti> contains:
# 	['Girgenti']
# 787 <Walchensee> contains:
# 	['Walchensee']
# 788 <Halensee> contains:
# 	['Halensee']
# 789 <Odessa> contains:
# 	['Odessa']
# 790 <Odense> contains:
# 	['Odense']
# 791 <Cranley> contains:
# 	['Cranley']
# 792 <Crans> contains:
# 	['Crans']
# 793 <Sparsamstadt> contains:
# 	['Sparsamstadt']
# 794 <Sparta> contains:
# 	['Sparta']
# 795 <Sarepta> contains:
# 	['Sarepta']
# 796 <Sprottau> contains:
# 	['Sprottau']
# 797 <Nauen> contains:
# 	['Nauen']
# 798 <Sauen> contains:
# 	['Sauen']
# 799 <Grimma> contains:
# 	['Grimma' 'Grimmen' 'Grimsta']
# 800 <Gries> contains:
# 	['Gries']
# 801 <Pillkallen> contains:
# 	['Pillkallen']
# 802 <Pilsen> contains:
# 	['Pilsen']
# 803 <Pirna> contains:
# 	['Pirna']
# 804 <Piona> contains:
# 	['Piona']
# 805 <Pirk> contains:
# 	['Pirk']
# 806 <Düren> contains:
# 	['Düren' 'Düren.']
# 807 <Dülmen> contains:
# 	['Dülmen']
# 808 <Kleinmachnow> contains:
# 	['Kleinmachnow']
# 809 <Klein> contains:
# 	['Klein']
# 810 <Klein-Flottbek> contains:
# 	['Klein-Flottbek']
# 811 <Kleinlaufenburg> contains:
# 	['Kleinlaufenburg']
# 812 <Loebau> contains:
# 	['Loebau']
# 813 <Loebau, Westpr.> contains:
# 	['Loebau, Westpr.']
# 814 <Soltquellæ> contains:
# 	['Soltquellæ' 'Solquellæ']
# 815 <Soltau> contains:
# 	['Soltau']
# 816 <Sorau> contains:
# 	['Sorau']
# 817 <Solothurn> contains:
# 	['Solothurn']
# 818 <Speyer> contains:
# 	['Speyer' 'Speier']
# 819 <Darmstadt> contains:
# 	['Darmstadt' 'Darmbstadt' 'Darmbstatt' 'Darmstatt']
# 820 <Darmstadt-Eberstadt> contains:
# 	['Darmstadt-Eberstadt']
# 821 <Idstein> contains:
# 	['Idstein' 'Idsteinae']
# 822 <Seidorf> contains:
# 	['Seidorf']
# 823 <Sindelsdorf> contains:
# 	['Sindelsdorf']
# 824 <Palaion> contains:
# 	['Palaion' 'Palaeopoli' 'Palaeo']
# 825 <Palermo> contains:
# 	['Palermo']
# 826 <Palaeo-Sedini> contains:
# 	['Palaeo-Sedini']
# 827 <Pallanza> contains:
# 	['Pallanza']
# 828 <Parthenopolis> contains:
# 	['Parthenopolis']
# 829 <Palestrina> contains:
# 	['Palestrina']
# 830 <Canton> contains:
# 	['Canton' 'Canyon']
# 831 <Canton, China> contains:
# 	['Canton, China']
# 832 <Kanton> contains:
# 	['Kanton']
# 833 <Cannstatt> contains:
# 	['Cannstatt']
# 834 <Cannes> contains:
# 	['Cannes']
# 835 <Campidonae> contains:
# 	['Campidonae' 'Campidona']
# 836 <Caen> contains:
# 	['Caen' 'Campen' 'Camen' 'Camenz']
# 837 <Kempten> contains:
# 	['Kempten' 'Kempen' 'Kempen, im']
# 838 <Kampen> contains:
# 	['Kampen']
# 839 <Kempten-München> contains:
# 	['Kempten-München']
# 840 <Cammin> contains:
# 	['Cammin']
# 841 <Klampenborg> contains:
# 	['Klampenborg']
# 842 <Karersee> contains:
# 	['Karersee']
# 843 <Karen> contains:
# 	['Karen']
# 844 <Kardong> contains:
# 	['Kardong']
# 845 <Düsseldorf> contains:
# 	['Düsseldorf' 'Düsseldorff' 'Dusseldorff' 'Düsseddorf' 'Düßeldorf'
#  'Dusseldorp' 'Dusseldorpii' 'Dusseldorf']
# 846 <Düsseldorf-Kaiserswerth> contains:
# 	['Düsseldorf-Kaiserswerth']
# 847 <Rastatt> contains:
# 	['Rastatt']
# 848 <Rastbach> contains:
# 	['Rastbach']
# 849 <Rauscha> contains:
# 	['Rauscha' 'Rauschen']
# 850 <Ragusa> contains:
# 	['Ragusa']
# 851 <Ragaz> contains:
# 	['Ragaz']
# 852 <Riga> contains:
# 	['Riga' 'Rigae' 'Riga?']
# 853 <Rigi> contains:
# 	['Rigi']
# 854 <Rigæ> contains:
# 	['Rigæ']
# 855 <Rigi-Kaltbad> contains:
# 	['Rigi-Kaltbad']
# 856 <Rigae-Livonorum> contains:
# 	['Rigae-Livonorum']
# 857 <Ratisbonae> contains:
# 	['Ratisbonae' 'Ratisponae' 'Ratisbonne' 'Ratisbonnæ']
# 858 <Ratibor> contains:
# 	['Ratibor']
# 859 <Raginae> contains:
# 	['Raginae']
# 860 <RIga> contains:
# 	['RIga']
# 861 <Plaviae> contains:
# 	['Plaviae' 'Pavia']
# 862 <Patavii> contains:
# 	['Patavii']
# 863 <Padova> contains:
# 	['Padova']
# 864 <Königsberg> contains:
# 	['Königsberg' 'Königsberg, Pr' 'Königsberg, i.' 'Königstein'
#  'Königsberg, Pr.' 'Königsbergi' 'Königserg' 'Königstadt' 'Koenigsberg'
#  'Königsbergk' 'Konigsberg' 'Königßberg' 'Königsberg?' 'Königberg'
#  'Königshütte' 'Königsbrück' 'Königsberg, Nm.']
# 865 <Arnstadiae> contains:
# 	['Arnstadiae' 'Arnstadt' 'Arnstadii' 'Arnstadius']
# 866 <Arnswalde> contains:
# 	['Arnswalde']
# 867 <Kronstadt> contains:
# 	['Kronstadt']
# 868 <Grunewald> contains:
# 	['Grunewald' 'Grunewald-Berlin']
# 869 <Gryphiswaldiae> contains:
# 	['Gryphiswaldiae' 'Greiffswald' 'Gryphißwalt' 'Gryphiswaldi'
#  'Gryphiswaldii' 'Greifswald' 'Greyphswaldt' 'Gryphisw.' 'Greyffswald'
#  'Gryphiae' 'Greifsvald' 'Gryphyswaldiae' 'Greiffswalde' 'Gryphiswaldiæ'
#  'Greiffswaldt']
# 870 <Geringswalde> contains:
# 	['Geringswalde']
# 871 <Neapel> contains:
# 	['Neapel' 'Napoli' 'Neapolis' 'Neapoli']
# 872 <Germanien> contains:
# 	['Germanien' 'Germania']
# 873 <Gerae> contains:
# 	['Gerae' 'Gera']
# 874 <Gerapoli> contains:
# 	['Gerapoli']
# 875 <Germantown> contains:
# 	['Germantown']
# 876 <Gedani> contains:
# 	['Gedani']
# 877 <Glasten> contains:
# 	['Glasten' 'Gastein']
# 878 <Glogoviae> contains:
# 	['Glogoviae' 'Glogaviae']
# 879 <Glogau> contains:
# 	['Glogau']
# 880 <Gloganii> contains:
# 	['Gloganii']
# 881 <Grätz> contains:
# 	['Grätz' 'Gräitz' 'Gräz']
# 882 <Graz> contains:
# 	['Graz' 'Gratz']
# 883 <Graizae> contains:
# 	['Graizae']
# 884 <Gracia> contains:
# 	['Gracia']
# 885 <Graecii> contains:
# 	['Graecii']
# 886 <Glatz> contains:
# 	['Glatz']
# 887 <Gorlicii> contains:
# 	['Gorlicii' 'Gorlici']
# 888 <Görlitz> contains:
# 	['Görlitz' 'Görliz' 'Goerlitz' 'Gorlitz']
# 889 <Merlitz> contains:
# 	['Merlitz']
# 890 <Glacii> contains:
# 	['Glacii']
# 891 <Müritz> contains:
# 	['Müritz']
# 892 <Greiz> contains:
# 	['Greiz']
# 893 <Galveston> contains:
# 	['Galveston']
# 894 <Naples> contains:
# 	['Naples']
# 895 <Limbach> contains:
# 	['Limbach' 'Laibach' 'Laybach']
# 896 <Lima> contains:
# 	['Lima']
# 897 <Neudamm> contains:
# 	['Neudamm']
# 898 <Neudamm-Berlin> contains:
# 	['Neudamm-Berlin']
# 899 <Neu-Barnim> contains:
# 	['Neu-Barnim']
# 900 <Neu-Bojanowa> contains:
# 	['Neu-Bojanowa']
# 901 <Neu-Ulm> contains:
# 	['Neu-Ulm']
# 902 <Neu-Cladow> contains:
# 	['Neu-Cladow']
# 903 <Cunnersdorf> contains:
# 	['Cunnersdorf' 'Cunersdorf' 'Kunersdorf']
# 904 <Kunern> contains:
# 	['Kunern']
# 905 <Bad Tölz> contains:
# 	['Bad Tölz']
# 906 <Bad Boll> contains:
# 	['Bad Boll']
# 907 <Mulhusae> contains:
# 	['Mulhusae']
# 908 <Mulhusii> contains:
# 	['Mulhusii']
# 909 <Mühlhausen> contains:
# 	['Mühlhausen' 'Mülhausen' 'Müllhausen']
# 910 <Mülhusii> contains:
# 	['Mülhusii']
# 911 <Mülheim> contains:
# 	['Mülheim' 'Mühlheim']
# 912 <Mühlh.> contains:
# 	['Mühlh.']
# 913 <Mülheim an der Ruhr> contains:
# 	['Mülheim an der Ruhr']
# 914 <Mühlacker> contains:
# 	['Mühlacker']
# 915 <Franckfurt> contains:
# 	['Franckfurt' 'Frankfurt/Main' 'Francofurti' 'Frankfurt/Oder'
#  'Frankfurt, Main' 'Frankfurt, O' 'Frankfurt, Oder' 'Francfort'
#  'Franckfurth' 'Franckf.' 'Francof.' 'Francofordiae' 'Franckfurdt'
#  'Francfurti' 'Frankfurt am Main' 'Frankfurt' 'Frankfurt/ Main'
#  'Francofort' 'Francourti' 'Frankfurt, Oder?' 'Frankfurth' 'Frankfurt, M'
#  'Frankfurt, M.' 'Frankofurti' 'Frankfurt/ M.' 'Francofurte'
#  'Frankfurt-O.' 'Franqfurṭ' 'Frankf.' 'Franḳfurṭ' 'Francofurdiae'
#  'Franckfurt, Oder' 'Fraancofurti' 'Francofurri' 'Francofurti.'
#  'Francofurtana' 'Francoforti' 'Franckfurt, Main' 'Frankfurta'
#  'Francofvrti' 'Franckufurt' 'Frankfurt/Main, 1562' 'Franckfurt, Leipzig'
#  'Franfurt']
# 916 <Francohusae> contains:
# 	['Francohusae']
# 917 <Frankreich> contains:
# 	['Frankreich' 'Frankreich?']
# 918 <Franken> contains:
# 	['Franken' 'Frankenthal' 'Frankenstein' 'Franckenhausen' 'Frankenhausen']
# 919 <Franequerae> contains:
# 	['Franequerae']
# 920 <Franzensbad> contains:
# 	['Franzensbad']
# 921 <Fano> contains:
# 	['Fano']
# 922 <Löwenberg> contains:
# 	['Löwenberg' 'Löwen']
# 923 <Lötzen> contains:
# 	['Lötzen']
# 924 <Lüneburg> contains:
# 	['Lüneburg' 'Lüneburgi' 'Lunaeburgi' 'Luxemburg' 'Luneburg' 'Luneburgi'
#  'Lüneburg?' 'Lauenburg' 'Laxenburg']
# 925 <Luzern> contains:
# 	['Luzern' 'Lucern' 'Lucerne']
# 926 <Laufen> contains:
# 	['Laufen']
# 927 <Lautern> contains:
# 	['Lautern']
# 928 <Lemberg> contains:
# 	['Lemberg']
# 929 <Papenburg> contains:
# 	['Papenburg']
# 930 <Lauban> contains:
# 	['Lauban' 'Laubae' 'Laubani']
# 931 <Lausanne> contains:
# 	['Lausanne']
# 932 <Liegnitz> contains:
# 	['Liegnitz' 'Lignicii' 'Lignitz' 'Liegniz' 'Linz' 'Lignitii' 'Linicii'
#  'Lincii' 'Lintz' 'Lign.' 'Lignic.' 'Lignici']
# 933 <Balingen> contains:
# 	['Balingen' 'Büdingen' 'Bingen']
# 934 <Lauingen> contains:
# 	['Lauingen' 'Lingae' 'Lingæ' 'Lingen' 'Laugingen' 'Linge']
# 935 <Liege> contains:
# 	['Liege']
# 936 <Liége> contains:
# 	['Liége']
# 937 <Lindich> contains:
# 	['Lindich']
# 938 <Bingii> contains:
# 	['Bingii']
# 939 <Landeck> contains:
# 	['Landeck']
# 940 <Randeck> contains:
# 	['Randeck']
# 941 <Leipzig, Döbeln> contains:
# 	['Leipzig, Döbeln' 'Leipzig, Berlin' 'Leipzig, Dresde' 'Leipzig, Dresden']
# 942 <Leipzig> contains:
# 	['Leipzig' 'Leipzigk' 'Leipsic' 'Leipsig' 'Lepzig' 'Leipzig-R.' 'Leizig'
#  'Leipsik' 'Leiptzich' 'Leiptzig' 'Lepizig' 'Leipzig?' 'Leipz.' 'Leipzic']
# 943 <Leipzigermesse> contains:
# 	['Leipzigermesse']
# 944 <Leipzig-Gohlis> contains:
# 	['Leipzig-Gohlis']
# 945 <Leißnig> contains:
# 	['Leißnig']
# 946 <Leipzig-Reudnitz> contains:
# 	['Leipzig-Reudnitz']
# 947 <Leipzig, Braunschweig> contains:
# 	['Leipzig, Braunschweig']
# 948 <Leipzig-Plagwitz> contains:
# 	['Leipzig-Plagwitz']
# 949 <Leipzig, Hamburg> contains:
# 	['Leipzig, Hamburg']
# 950 <Lissa> contains:
# 	['Lissa' 'Lisboa' 'Lissabon' 'Lissboa' 'Lissaw']
# 951 <Lippa> contains:
# 	['Lippa' 'Lippstadt']
# 952 <Lipsiae> contains:
# 	['Lipsiae' 'Lipsia' 'Lipsens.' 'Lipsensiae' 'Lipsae' 'Lipsiæ' 'Lips.']
# 953 <Lipsku> contains:
# 	['Lipsku']
# 954 <Libau> contains:
# 	['Libau']
# 955 <Löbau> contains:
# 	['Löbau']
# 956 <Langen-Saltz> contains:
# 	['Langen-Saltz' 'Langensalza' 'Langensaltza' 'Langen-Saltza'
#  'Lantzen-Saltza']
# 957 <Langenberg> contains:
# 	['Langenberg' 'Spangenberg']
# 958 <Langenbielau> contains:
# 	['Langenbielau']
# 959 <Langenzell> contains:
# 	['Langenzell']
# 960 <Spanien> contains:
# 	['Spanien']
# 961 <Landshut> contains:
# 	['Landshut' 'Landeshut']
# 962 <Landau> contains:
# 	['Landau' 'Landerneau']
# 963 <Lindau> contains:
# 	['Lindau']
# 964 <Linum> contains:
# 	['Linum']
# 965 <Landsberg> contains:
# 	['Landsberg']
# 966 <Linden-Stadt> contains:
# 	['Linden-Stadt']
# 967 <Spandau> contains:
# 	['Spandau']
# 968 <Liesborn?> contains:
# 	['Liesborn?']
# 969 <Italien> contains:
# 	['Italien' 'Italien?']
# 970 <Italien/Deutschland?> contains:
# 	['Italien/Deutschland?']
# 971 <Rom, Italien> contains:
# 	['Rom, Italien']
# 972 <Herrenalb, Württemberg> contains:
# 	['Herrenalb, Württemberg']
# 973 <Herrenalb> contains:
# 	['Herrenalb']
# 974 <Rees> contains:
# 	['Rees']
# 975 <Reesewitz> contains:
# 	['Reesewitz']
# 976 <Redwitz> contains:
# 	['Redwitz']
# 977 <Rehnitz> contains:
# 	['Rehnitz']
# 978 <Schlictinkoviae> contains:
# 	['Schlictinkoviae']
# 979 <Schlichtingsheim> contains:
# 	['Schlichtingsheim']
# 980 <Amsterdam> contains:
# 	['Amsterdam' 'Amsteldam' 'Amsterdam: den' 'Amsterdam: Sybrandi'
#  'Amstelodami' 'Amstelaedami' 'Ambsterdam']
# 981 <Amsterdam: Elsevier> contains:
# 	['Amsterdam: Elsevier']
# 982 <t'Amsterdam> contains:
# 	["t'Amsterdam"]
# 983 <Weimar> contains:
# 	['Weimar' 'Weymar']
# 984 <Wismar> contains:
# 	['Wismar' 'Wiszmar' 'Wismariae' 'Vinariae' 'Wißmar' 'Vimariae' 'Wimariae']
# 985 <Wisembach> contains:
# 	['Wisembach']
# 986 <Versailles> contains:
# 	['Versailles']
# 987 <Marseille> contains:
# 	['Marseille']
# 988 <Kloster/Hiddensee> contains:
# 	['Kloster/Hiddensee' 'Kloster/ Hiddensee' 'Kloster, Hiddensee']
# 989 <Kloster> contains:
# 	['Kloster']
# 990 <Châlons> contains:
# 	['Châlons' 'Chalons']
# 991 <Châlons-en-Champagne> contains:
# 	['Châlons-en-Champagne']
# 992 <Chablis> contains:
# 	['Chablis']
# 993 <Bruchsal> contains:
# 	['Bruchsal' 'Bruchsall']
# 994 <Bruck> contains:
# 	['Bruck']
# 995 <Budißin> contains:
# 	['Budißin' 'Budissinae' 'Budissin']
# 996 <Wandsbek> contains:
# 	['Wandsbek' 'Wandsbeck' 'Wanßbeck']
# 997 <Forchheim> contains:
# 	['Forchheim' 'Horchheim']
# 998 <Hofheim> contains:
# 	['Hofheim']
# 999 <Hersfeld> contains:
# 	['Hersfeld' 'Gersfeld' 'Herzfelde' 'Herßfeld']
# 1000 <Kirchzarten> contains:
# 	['Kirchzarten']
# 1001 <Kirchbaun> contains:
# 	['Kirchbaun']
# 1002 <Hirschberg> contains:
# 	['Hirschberg' 'Hirschbergae']
# 1003 <Kirchberg> contains:
# 	['Kirchberg']
# 1004 <Hirschberg-Cunnersdorf> contains:
# 	['Hirschberg-Cunnersdorf']
# 1005 <Hirschfelde> contains:
# 	['Hirschfelde']
# 1006 <Kirchheim> contains:
# 	['Kirchheim']
# 1007 <Berchtesgaden> contains:
# 	['Berchtesgaden' 'Berchtesgarden' 'Berchtesgaden-Schönau']
# 1008 <Carlsbad> contains:
# 	['Carlsbad' 'Karlsbad']
# 1009 <Karlsruhe> contains:
# 	['Karlsruhe' 'Carsruhe' 'Carlsruhe' 'Carlsruh' 'Karlsruh']
# 1010 <Carols-Ruh> contains:
# 	['Carols-Ruh']
# 1011 <Carlshagen> contains:
# 	['Carlshagen']
# 1012 <Karlshaven> contains:
# 	['Karlshaven']
# 1013 <Karlshorst> contains:
# 	['Karlshorst']
# 1014 <Cartagena> contains:
# 	['Cartagena']
# 1015 <Ḳarlsru> contains:
# 	['Ḳarlsru']
# 1016 <Altdorf> contains:
# 	['Altdorf' 'Altdorfii' 'Altorphii' 'Altdorphii' 'Altdorffii' 'Altorfii'
#  'Altdorff' 'Adorf' 'Altorfi' 'Altdorfi']
# 1017 <Allendorff> contains:
# 	['Allendorff' 'Allendorf']
# 1018 <Nollendorf> contains:
# 	['Nollendorf']
# 1019 <Ammendorf> contains:
# 	['Ammendorf']
# 1020 <Timmendorfer> contains:
# 	['Timmendorfer']
# 1021 <Hildburghausen> contains:
# 	['Hildburghausen' 'Hildburghausen?']
# 1022 <Bayreuth> contains:
# 	['Bayreuth' 'Bayreut' 'Baruthi' 'Bayreüth' 'Barth' 'Bareut' 'Bath' 'Barlt'
#  'Bari' 'Baireuth' 'Bairūt' 'Bayrūt' 'Baruti' 'Baireut']
# 1023 <Beirut> contains:
# 	['Beirut']
# 1024 <Barlt-Holstein> contains:
# 	['Barlt-Holstein']
# 1025 <Berreuth> contains:
# 	['Berreuth']
# 1026 <Barby> contains:
# 	['Barby']
# 1027 <Reinfeld> contains:
# 	['Reinfeld' 'Weinfelden' 'Rheinfelden']
# 1028 <Rheinland> contains:
# 	['Rheinland']
# 1029 <Rehfeld> contains:
# 	['Rehfeld']
# 1030 <Hemer> contains:
# 	['Hemer' 'Hemme']
# 1031 <Hellerau> contains:
# 	['Hellerau']
# 1032 <Helder> contains:
# 	['Helder']
# 1033 <Leyde> contains:
# ...
# 	['Sampaloc']
# 2093 <Adelaide> contains:
# 	['Adelaide']
# 2094 <Chur> contains:
# 	['Chur']
# 2095 <Chofré> contains:
# 	['Chofré']
# 2096 <Golnow> contains:
# 	['Golnow']
# 2097 <Costantz> contains:
# 	['Costantz']
# 2098 <Bevilacqua> contains:
# 	['Bevilacqua']
# 2099 <Pohldorf> contains:
# 	['Pohldorf']
# 2100 <Ahrenshoop> contains:
# 	['Ahrenshoop']
# 2101 <Woël> contains:
# 	['Woël']
# 2102 <Lyngby> contains:
# 	['Lyngby']
# 2103 <Ziegenhals> contains:
# 	['Ziegenhals']
# 2104 <Le> contains:
# 	['Le']
# 2105 <Smyrna> contains:
# 	['Smyrna']
# 2106 <Mohrungen> contains:
# 	['Mohrungen']
# 2107 <Gülzow> contains:
# 	['Gülzow']
# 2108 <Swinemünde> contains:
# 	['Swinemünde']
# 2109 <Lchsaw> contains:
# 	['Lchsaw']
# 2110 <Thionville> contains:
# 	['Thionville']
# 2111 <Sadska> contains:
# 	['Sadska']
# 2112 <Völklingen> contains:
# 	['Völklingen']
# 2113 <Cypern> contains:
# 	['Cypern']
# 2114 <Jerusalem> contains:
# 	['Jerusalem']
# 2115 <Pritzwalk> contains:
# 	['Pritzwalk']
# 2116 <Lengenfeld> contains:
# 	['Lengenfeld']
# 2117 <Lannion> contains:
# 	['Lannion']
# 2118 <Bapaume> contains:
# 	['Bapaume']
# 2119 <Roorkee> contains:
# 	['Roorkee']
# 2120 <Ravicii> contains:
# 	['Ravicii']
# 2121 <Orkney> contains:
# 	['Orkney']
# 2122 <Vertus> contains:
# 	['Vertus']
# 2123 <Capebam> contains:
# 	['Capebam']
# 2124 <Dorotheenthal> contains:
# 	['Dorotheenthal']
# 2125 <Zerbst> contains:
# 	['Zerbst']
# 2126 <Ningpo> contains:
# 	['Ningpo']
# 2127 <Hottingen-Zürich> contains:
# 	['Hottingen-Zürich']
# 2128 <Kurrachee> contains:
# 	['Kurrachee']
# 2129 <Sansscouci> contains:
# 	['Sansscouci']
# 2130 <Birmingham> contains:
# 	['Birmingham']
# 2131 <Kehrsatz> contains:
# 	['Kehrsatz']
# 2132 <Sigmaringen> contains:
# 	['Sigmaringen']
# 2133 <Gelsenkirchen> contains:
# 	['Gelsenkirchen']
# 2134 <Kilchberg-Zürich> contains:
# 	['Kilchberg-Zürich']
# 2135 <Hessen-Rotenburg> contains:
# 	['Hessen-Rotenburg']
# 2136 <Kurume> contains:
# 	['Kurume']
# 2137 <Alt-Gaarz> contains:
# 	['Alt-Gaarz']
# 2138 <Seeshaupt> contains:
# 	['Seeshaupt']
# 2139 <Schluderbach/Südtirol> contains:
# 	['Schluderbach/Südtirol']
# 2140 <Wedderstedt> contains:
# 	['Wedderstedt']
# 2141 <Ems> contains:
# 	['Ems']
# 2142 <The> contains:
# 	['The']
# 2143 <Mesopotamien> contains:
# 	['Mesopotamien']
# 2144 <Bacharach> contains:
# 	['Bacharach']
# 2145 <Leamington-Warwickshire> contains:
# 	['Leamington-Warwickshire']
# 2146 <Kaunas> contains:
# 	['Kaunas']
# 2147 <Korfu> contains:
# 	['Korfu']
# 2148 <Ziesar> contains:
# 	['Ziesar']
# 2149 <Kensington> contains:
# 	['Kensington']
# 2150 <Eutin> contains:
# 	['Eutin']
# 2151 <Épernay> contains:
# 	['Épernay']
# 2152 <Pulkowa> contains:
# 	['Pulkowa']
# 2153 <Ebsdorf> contains:
# 	['Ebsdorf']
# 2154 <Nancy> contains:
# 	['Nancy']
# 2155 <Kallmünz> contains:
# 	['Kallmünz']
# 2156 <Garmisch> contains:
# 	['Garmisch']
# 2157 <Blida> contains:
# 	['Blida']
# 2158 <Côtes> contains:
# 	['Côtes']
# 2159 <Güttland> contains:
# 	['Güttland']
# 2160 <Interlaken> contains:
# 	['Interlaken']
# 2161 <Frölichs-Burg> contains:
# 	['Frölichs-Burg']
# 2162 <Hoyerswerda> contains:
# 	['Hoyerswerda']
# 2163 <Hörnerburg> contains:
# 	['Hörnerburg']
# 2164 <Kniebis> contains:
# 	['Kniebis']
# 2165 <Overstrand> contains:
# 	['Overstrand']
# 2166 <Lille> contains:
# 	['Lille']
# 2167 <Ruhla> contains:
# 	['Ruhla']
# 2168 <Heerenveen> contains:
# 	['Heerenveen']
# 2169 <Sofia> contains:
# 	['Sofia']
# 2170 <Silvaplana> contains:
# 	['Silvaplana']
# 2171 <Mekka> contains:
# 	['Mekka']
# 2172 <Vevey> contains:
# 	['Vevey']
# 2173 <Modegascar> contains:
# 	['Modegascar']
# 2174 <Dubrovnik> contains:
# 	['Dubrovnik']
# 2175 <Saint Quentin> contains:
# 	['Saint Quentin']
# 2176 <Kevelaer> contains:
# 	['Kevelaer']
# 2177 <Sewastopol> contains:
# 	['Sewastopol']
# 2178 <Flöha> contains:
# 	['Flöha']
# 2179 <Zahna> contains:
# 	['Zahna']
# 2180 <East> contains:
# 	['East']
# 2181 <Ösel> contains:
# 	['Ösel']
# 2182 <Viry> contains:
# 	['Viry']
# 2183 <Unterschondorf> contains:
# 	['Unterschondorf']
# 2184 <Singen-Hohentwiel> contains:
# 	['Singen-Hohentwiel']
# 2185 <Anacapri> contains:
# 	['Anacapri']
# 2186 <England> contains:
# 	['England']
# 2187 <Kephissia> contains:
# 	['Kephissia']
# 2188 <Boldevitz> contains:
# 	['Boldevitz']
# 2189 <Bahrenfeld-Altona> contains:
# 	['Bahrenfeld-Altona']
# 2190 <Bécs> contains:
# 	['Bécs']
# 2191 <Roubaix> contains:
# 	['Roubaix']
# 2192 <Woolton> contains:
# 	['Woolton']
# 2193 <Vulpera> contains:
# 	['Vulpera']
# 2194 <Römhild> contains:
# 	['Römhild']
# 2195 <Taškent> contains:
# 	['Taškent']
# 2196 <Unterach/Attersee> contains:
# 	['Unterach/Attersee']
# 2197 <Highland> contains:
# 	['Highland']
# 2198 <Einbeck> contains:
# 	['Einbeck']
# 2199 <Cracoviæ> contains:
# 	['Cracoviæ']
# 2200 <roemhild> contains:
# 	['roemhild']
# 2201 <Ueckermünde> contains:
# 	['Ueckermünde']
# 2202 <Pfaffendorf> contains:
# 	['Pfaffendorf']
# 2203 <Saarbrücken> contains:
# 	['Saarbrücken']
# 2204 <Weltevreden> contains:
# 	['Weltevreden']
# 2205 <Ospedaletti> contains:
# 	['Ospedaletti']
# 2206 <Zweibrücken> contains:
# 	['Zweibrücken']
# 2207 <Bischofzell> contains:
# 	['Bischofzell']
# 2208 <Diablerets> contains:
# 	['Diablerets']
# 2209 <Dorlisheim> contains:
# 	['Dorlisheim']
# 2210 <Lohne/Wasenberg> contains:
# 	['Lohne/Wasenberg']
# 2211 <Erscheinungsort> contains:
# 	['Erscheinungsort']
# 2212 <Damaskus> contains:
# 	['Damaskus']
# 2213 <Appeldoorn> contains:
# 	['Appeldoorn']
# 2214 <Bagazivg> contains:
# 	['Bagazivg']
# 2215 <Sizilien> contains:
# 	['Sizilien']
# 2216 <Zeesen> contains:
# 	['Zeesen']
# 2217 <Pietany> contains:
# 	['Pie\x9atany']
# 2218 <Erkner> contains:
# 	['Erkner']
# 2219 <Gladbach-Rheydt> contains:
# 	['Gladbach-Rheydt']
# 2220 <Göteborg> contains:
# 	['Göteborg']
# 2221 <Jüterbog> contains:
# 	['Jüterbog']
# 2222 <Coppet> contains:
# 	['Coppet']
# 2223 <Soissons> contains:
# 	['Soissons']
# 2224 <Gowgark'> contains:
# 	["Gowgark'"]
# 2225 <Cöpenick> contains:
# 	['Cöpenick']
# 2226 <Kew> contains:
# 	['Kew']
# 2227 <Uelzen> contains:
# 	['Uelzen']
# 2228 <Aix> contains:
# 	['Aix']
# 2229 <Ciudad> contains:
# 	['Ciudad']
# 2230 <Döbeln> contains:
# 	['Döbeln']
# 2231 <Dyrotz> contains:
# 	['Dyrotz']
# 2232 <Lofthouse> contains:
# 	['Lofthouse']
# 2233 <Allahabad> contains:
# 	['Allahabad']
# 2234 <Epe> contains:
# 	['Epe']
# 2235 <Kaltenleutgeben> contains:
# 	['Kaltenleutgeben']
# 2236 <Quebec> contains:
# 	['Quebec']
# 2237 <Putbus> contains:
# 	['Putbus']
# 2238 <Zobten> contains:
# 	['Zobten']
# 2239 <Göhren> contains:
# 	['Göhren']
# 2240 <Hünern> contains:
# 	['Hünern']
# 2241 <En> contains:
# 	['En']
# 2242 <U> contains:
# 	['U']
# 2243 <Elb175> contains:
# 	['Elb175']
# 2244 <Territet> contains:
# 	['Territet']
# 2245 <Herenchiemsee> contains:
# 	['Herenchiemsee']
# 2246 <Besserwirds> contains:
# 	['Besserwirds']
# 2247 <Woolwich> contains:
# 	['Woolwich']
# 2248 <Rheydt> contains:
# 	['Rheydt']
# 2249 <Tsingtau> contains:
# 	['Tsingtau']
# 2250 <Lyck> contains:
# 	['Lyck']
# 2251 <Shiraz> contains:
# 	['Shiraz']
# 2252 <Figino> contains:
# 	['Figino']
# 2253 <Ithaca> contains:
# 	['Ithaca']
# 2254 <Pepowo> contains:
# 	['Pepowo']
# 2255 <Skalmierzyce> contains:
# 	['Skalmierzyce']
# 2256 <Guingamp> contains:
# 	['Guingamp']
# 2257 <Tauberbischofsheim> contains:
# 	['Tauberbischofsheim']
# 2258 <Drill> contains:
# 	['Drill']
# 2259 <Gatterstädt> contains:
# 	['Gatterstädt']
# 2260 <Guadeloupe> contains:
# 	['Guadeloupe']
# 2261 <Clifton> contains:
# 	['Clifton']
# 2262 <Rangoon> contains:
# 	['Rangoon']
# 2263 <Aussig> contains:
# 	['Aussig']
# 2264 <Kaibitz> contains:
# 	['Kaibitz']
# 2265 <Flüelen> contains:
# 	['Flüelen']
# 2266 <Svaety> contains:
# 	['Svaety']
# 2267 <Tullnerbach-Pressbaum> contains:
# 	['Tullnerbach-Pressbaum']
# 2268 <Wjasma> contains:
# 	['Wjasma']
# 2269 <Dommelstadl> contains:
# 	['Dommelstadl']
# 2270 <Vallombrosa> contains:
# 	['Vallombrosa']
# 2271 <Kyelang> contains:
# 	['Kyelang']
# 2272 <Ferrara> contains:
# 	['Ferrara']
# 2273 <Apolda> contains:
# 	['Apolda']
# 2274 <Koljuschki> contains:
# 	['Koljuschki']
# 2275 <Görbersdorf> contains:
# 	['Görbersdorf']
# 2276 <Hongkong> contains:
# 	['Hongkong']
# 2277 <Przemyśl> contains:
# 	['Przemyśl']
# 2278 <Dihernfurṭ> contains:
# 	['Dihernfurṭ']
# 2279 <Gedruckt> contains:
# 	['Gedruckt']
# 2280 <Udine> contains:
# 	['Udine']
# 2281 <Ülzen> contains:
# 	['Ülzen']
# 2282 <Ischl> contains:
# 	['Ischl']
# 2283 <shang> contains:
# 	['shang']
# 2284 <Wichulec> contains:
# 	['Wichulec']
# 2285 <Mönichkirchen> contains:
# 	['Mönichkirchen']
# 2286 <Graptomaniacum> contains:
# 	['Graptomaniacum']
# 2287 <Dyherrnfurth> contains:
# 	['Dyherrnfurth']
# 2288 <Ibagué> contains:
# 	['Ibagué']
# 2289 <Sydney> contains:
# 	['Sydney']
# 2290 <Garrey> contains:
# 	['Garrey']
# 2291 <Itzehoe> contains:
# 	['Itzehoe']
# 2292 <Louisville> contains:
# 	['Louisville']
# 2293 <Fauvillers> contains:
# 	['Fauvillers']
# 2294 <Zeebrügge> contains:
# 	['Zeebrügge']
# 2295 <Rottach-Egern> contains:
# 	['Rottach-Egern']
# 2296 <Roßtrappe> contains:
# 	['Roßtrappe']
# 2297 <Wentorf/Hamburg> contains:
# 	['Wentorf/Hamburg']
# 2298 <Aumühle> contains:
# 	['Aumühle']
# 2299 <Tōkyō> contains:
# 	['Tōkyō']
# 2300 <Bombay> contains:
# 	['Bombay']
# 2301 <Osaka> contains:
# 	['Osaka']
# 2302 <Olmütz> contains:
# 	['Olmütz']
# 2303 <Nizza> contains:
# 	['Nizza']
# 2304 <Kudowa> contains:
# 	['Kudowa']
# 2305 <Cevio> contains:
# 	['Cevio']
# 2306 <Davos> contains:
# 	['Davos']
# 2307 <Bleicherode> contains:
# 	['Bleicherode']
# 2308 <Kaliningrad> contains:
# 	['Kaliningrad']
# 2309 <Untertürkheim> contains:
# 	['Untertürkheim']
# 2310 <Blumeshof> contains:
# 	['Blumeshof']
# 2311 <Puschlaff> contains:
# 	['Puschlaff']
# 2312 <Plitvicer> contains:
# 	['Plitvicer']
# 2313 <Wuppertal> contains:
# 	['Wuppertal']
# 2314 <ohne> contains:
# 	['ohne']
# 2315 <Krummhübel> contains:
# 	['Krummhübel']
# 2316 <Estoril> contains:
# 	['Estoril']
# 2317 <Österreich> contains:
# 	['Österreich']
# 2318 <Kiltsi/Schloss> contains:
# 	['Kiltsi/Schloss']
# 2319 <Chêne-Bougeries> contains:
# 	['Chêne-Bougeries']
# 2320 <St-Aubin-Epinay> contains:
# 	['St-Aubin-Epinay']
# 2321 <w> contains:
# 	['w']
# 2322 <t'> contains:
# 	["t'"]
# 2323 <Oxford> contains:
# 	['Oxford']
# 2324 <Hradec> contains:
# 	['Hradec']
# 2325 <Xalapa> contains:
# 	['Xalapa']
# 2326 <W> contains:
# 	['W']
# 2327 <Kitzbühel> contains:
# 	['Kitzbühel']
# 2328 <Yvorne> contains:
# 	['Yvorne']
# 2329 <Claudiopoli> contains:
# 	['Claudiopoli']
# 2330 <Typis> contains:
# 	['Typis']
# 2331 <Certaldo/Italien> contains:
# 	['Certaldo/Italien']
# 2332 <Oaxaca> contains:
# 	['Oaxaca']
# 2333 <Zagreb> contains:
# 	['Zagreb']
# 2334 <Lüttich> contains:
# 	['Lüttich']
# 2335 <Iavorii> contains:
# 	['Iavorii']
# 2336 <Egypten> contains:
# 	['Egypten']
# 2337 <Nunspeet> contains:
# 	['Nunspeet']
# 2338 <Gabicce> contains:
# 	['Gabicce']
# 2339 <Dännemark> contains:
# 	['Dännemark']
# 2340 <Ouray> contains:
# 	['Ouray']
# 2341 <Ǧidda> contains:
# 	['Ǧidda']
# 2342 <Vulaqhavbaqhadur> contains:
# 	['Vulaqhavbaqhadur']
# 2343 <Norddorf/Amrun> contains:
# 	['Norddorf/Amrun']
# 2344 <Olomucii> contains:
# 	['Olomucii']
# 2345 <Focşani> contains:
# 	['Focşani']
# 2346 <Uithuizen> contains:
# 	['Uithuizen']
# 2347 <Tavoy> contains:
# 	['Tavoy']
# 2348 <Ouderkerk> contains:
# 	['Ouderkerk']
# 2349 <Müggelsee> contains:
# 	['Müggelsee']
# 2350 <Eppan> contains:
# 	['Eppan']
# 2351 <Fossé> contains:
# 	['Fossé']
# 2352 <Máramarossziget> contains:
# 	['Máramarossziget']
# 2353 <Mürzzuschlag> contains:
# 	['Mürzzuschlag']
# 2354 <Hijar> contains:
# 	['Hijar']
# 2355 <Uffing> contains:
# 	['Uffing']
# 2356 <Wädenswil> contains:
# 	['Wädenswil']
# 2357 <Leucopetrae> contains:
# 	['Leucopetrae']
# 2358 <s'> contains:
# 	["s'"]
# 2359 <Dt.> contains:
# 	['Dt.']
# 2360 <Pa1> contains:
# 	['Pa1']
# 2361 <Spb.> contains:
# 	['Spb.']
# 2362 <São> contains:
# 	['São']
# 2363 <Pr.> contains:
# 	['Pr.']
# 2364 <Ge8> contains:
# 	['Ge8']
# 2365 <Be1> contains:
# 	['Be1']
# 2366 <Ustrzyki> contains:
# 	['Ustrzyki']
# 2367 <Hann. Münden> contains:
# 	['Hann. Münden']
# 2368 <Altstadt-Königsberg> contains:
# 	['Altstadt-Königsberg']
# 2369 <Foochow> contains:
# 	['Foochow']
# 2370 <VI, 107> contains:
# 	['VI, 107']
# 2371 <Tönning> contains:
# 	['Tönning']
# 2372 <Plancy-L'Abbaye> contains:
# 	["Plancy-L'Abbaye"]
# 2373 <Yokohama> contains:
# 	['Yokohama']
# 2374 <VIII, 35> contains:
# 	['VIII, 35']
# 2375 <Isfahan> contains:
# 	['Isfahan']
# 2376 <Glaucha-Hallensis> contains:
# 	['Glaucha-Hallensis']
# 2377 <Hessisch-Lichtenau> contains:
# 	['Hessisch-Lichtenau']
# 2378 <Aychstätt> contains:
# 	['Aychstätt']
# 2379 <Matsuyama> contains:
# 	['Matsuyama']
# 2380 <HXIV, 303> contains:
# 	['HXIV, 303']
# 2381 <BeVI, 261> contains:
# 	['BeVI, 261']
# 2382 <Ayravank'> contains:
# 	["Ayravank'"]
# 2383 <Malente-Gremsmühlen> contains:
# 	['Malente-Gremsmühlen']
# 2384 <Mömpelgard> contains:
# 	['Mömpelgard']
# 2385 <Iloilo> contains:
# 	['Iloilo']
# 2386 <Méry-sur-Seine> contains:
# 	['Méry-sur-Seine']
# 2387 <Misdroy/Ostsee> contains:
# 	['Misdroy/Ostsee']
# 2388 <Feldpoststation> contains:
# 	['Feldpoststation']
# 2389 <Springfield, Mass.> contains:
# 	['Springfield, Mass.']
# 2390 <Riquewihr> contains:
# 	['Riquewihr']
# 2391 <Eaux-Bonnes> contains:
# 	['Eaux-Bonnes']
# 2392 <Starfield, Liverpool> contains:
# 	['Starfield, Liverpool']
# 2393 <Istambol> contains:
# 	['Istambol']
# 2394 <Prinz-Heinrich-Baude> contains:
# 	['Prinz-Heinrich-Baude']
# 2395 <Huy> contains:
# 	['Huy']
# 2396 <Br117> contains:
# 	['Br117']
# 2397 <Æquinoctio> contains:
# 	['Æquinoctio']
# 2398 <Selo-Boldino, Russland> contains:
# 	['Selo-Boldino, Russland']
# 2399 <Snowdonia-Nationalpark> contains:
# 	['Snowdonia-Nationalpark']
# 2400 <Vanduvre-lès-Nancy> contains:
# 	['Vand\x9cuvre-lès-Nancy']
# 2401 <Ephrata, Pa.> contains:
# 	['Ephrata, Pa.']
# 2402 <Nouveau-Phalére> contains:
# 	['Nouveau-Phalére']
# 2403 <Rüben-Rötha> contains:
# 	['Rüben-Rötha']
# 2404 <Nykyrka> contains:
# 	['Nykyrka']
# 2405 <L'vov> contains:
# 	["L'vov"]
# 2406 <Stockton-on-Tees, Durham> contains:
# 	['Stockton-on-Tees, Durham']
# 2407 <Reykjavik> contains:
# 	['Reykjavik']
# 2408 <Grundschöttel, Post> contains:
# 	['Grundschöttel, Post']
# 2409 <N.> contains:
# 	['N.']
# 2410 <B.> contains:
# 	['B.']
# 2411 <Lány> contains:
# 	['Lány']
# 2412 <G.> contains:
# 	['G.']
# 2413 <Bar-Sur-Aube> contains:
# 	['Bar-Sur-Aube']
# 2414 <S?> contains:
# 	['S?']
# 2415 <s.n.> contains:
# 	['s.n.']
# 2416 <Ha68> contains:
# 	['Ha68']
# 2417 <Kyïv> contains:
# 	['Kyïv']
# 2418 <Åbo> contains:
# 	['Åbo']
# 2419 <Ṭûr-ʿAbdîn> contains:
# 	['Ṭûr-ʿAbdîn']
# 2420 <50> contains:
# 	['50']
# 2421 <大阪> contains:
# 	['大阪']
# 2422 <大坂> contains:
# 	['大坂']
# 2423 <江戸> contains:
# 	['江戸']
# 2424 <水戸> contains:
# 	['水戸']
# 2425 <江南省> contains:
# 	['江南省']
# 2426 <湖南> contains:
# 	['湖南']
# 2427 <江陵, 湖北> contains:
# 	['江陵, 湖北']
# 2428 <金陵> contains:
# 	['金陵']
# 2429 <大津, 白河> contains:
# 	['大津, 白河']
# 2430 <名古屋> contains:
# 	['名古屋']
# 2431 <名古屋, 江戸> contains:
# 	['名古屋, 江戸']
# 2432 <本堂藏板> contains:
# 	['本堂藏板']
# 2433 <本衙藏板> contains:
# 	['本衙藏板']
# 2434 <文畬堂藏板> contains:
# 	['文畬堂藏板']
# 2435 <元新堂藏板> contains:
# 	['元新堂藏板']
# 2436 <文畲堂> contains:
# 	['文畲堂']
# 2437 <貴文堂> contains:
# 	['貴文堂']
# 2438 <石渠閣藏板> contains:
# 	['石渠閣藏板']
# 2439 <玉堂> contains:
# 	['玉堂']
# 2440 <華藏> contains:
# 	['華藏']
# 2441 <槐堂書齋> contains:
# 	['槐堂書齋']
# 2442 <玉勾草堂> contains:
# 	['玉勾草堂']
# 2443 <松本> contains:
# 	['松本']
# 2444 <振賢堂梓行> contains:
# 	['振賢堂梓行']
# 2445 <振賢堂> contains:
# 	['振賢堂']
# 2446 <吳門種書堂梓> contains:
# 	['吳門種書堂梓']
# 2447 <敬書堂> contains:
# 	['敬書堂']
# 2448 <英華書院刊> contains:
# 	['英華書院刊']
# 2449 <浪華> contains:
# 	['浪華']
# 2450 <尚義堂> contains:
# 	['尚義堂']
# 2451 <紹義堂> contains:
# 	['紹義堂']
# 2452 <裏如堂> contains:
# 	['裏如堂']
# 2453 <裏如棠> contains:
# 	['裏如棠']
# 2454 <南海伍氏粵雅堂> contains:
# 	['南海伍氏粵雅堂']
# 2455 <南海> contains:
# 	['南海']
# 2456 <上海> contains:
# 	['上海']
# 2457 <南京> contains:
# 	['南京']
# 2458 <北京> contains:
# 	['北京']
# 2459 <東京> contains:
# 	['東京']
# 2460 <東都> contains:
# 	['東都']
# 2461 <京都> contains:
# 	['京都']
# 2462 <南都> contains:
# 	['南都']
# 2463 <北平> contains:
# 	['北平']
# 2464 <伊勢> contains:
# 	['伊勢']
# 2465 <伊勢国津> contains:
# 	['伊勢国津']
# 2466 <廣東> contains:
# 	['廣東']
# 2467 <廣東嘉應州> contains:
# 	['廣東嘉應州']
# 2468 <廣州> contains:
# 	['廣州']
# 2469 <杭州> contains:
# 	['杭州']
# 2470 <荊州> contains:
# 	['荊州']
# 2471 <伊州> contains:
# 	['伊州']
# 2472 <廣慶堂> contains:
# 	['廣慶堂']
# 2473 <揚州詩局刻> contains:
# 	['揚州詩局刻']
# 2474 <培德堂> contains:
# 	['培德堂']
# 2475 <春暉堂> contains:
# 	['春暉堂']
# 2476 <一經堂> contains:
# 	['一經堂']
# 2477 <近譬堂> contains:
# 	['近譬堂']
# 2478 <來鹿堂> contains:
# 	['來鹿堂']
# 2479 <學古堂> contains:
# 	['學古堂']
# 2480 <積秀堂> contains:
# 	['積秀堂']
# 2481 <古虞朱氏> contains:
# 	['古虞朱氏']
# 2482 <灌文書社> contains:
# 	['灌文書社']
# 2483 <中西時務學堂新鐫> contains:
# 	['中西時務學堂新鐫']
# 2484 <覺亭梁氏鐫> contains:
# 	['覺亭梁氏鐫']
# 2485 <合肥李氏重刊> contains:
# 	['合肥李氏重刊']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-0a65dcf21042> in <module>()
#      23             clusterNames[key]=grp.get_group(key)["spatialClean"].unique()[0]
#      24
# ---> 25         print(str(key)+" <"+clusterNames[key]+"> contains:\n\t"+str(grp.get_group(key)["spatialClean"].unique()))
#      26 print("Max key value: %i"%maxKey)
#
# TypeError: must be str, not NoneType

# %%
grp.get_group(clusters[getWordIndex("Moskau")][0])["spatialClean"].unique()
# Out:
# array(['Moskau', 'Moskva', 'Moscou', 'Moskou'], dtype=object)

# %%
grp.get_group(clusters[getWordIndex("Bamberg")][0])["spatialClean"].unique()
# Out:
# array(['Bamberg'], dtype=object)

# %%
grp.get_group(clusters[getWordIndex("Berlin")][0])["spatialClean"].unique()
# Out:
# array(['Berlin', 'Berlin?', 'Berolini', 'Berolinae', 'Berlini',
#        'Beroloni', 'Bern', 'Berg', 'Bergamo', 'Berlin(?)', 'Berlino',
#        'Berlin-Pankow', 'Berlin-Tegel', 'Berln', 'Berlin-Dahlem',
#        'Berlin-Lankwitz', 'Benares', 'Berlinie', 'Bernae', 'Berol.',
#        'Berna', 'Berin', 'Berlin-', 'Berlin-Britz', 'Bergün', 'Berne',
#        'Berolino', 'Bernau', 'Berlien', 'Berolin.'], dtype=object)

# %%
grp.get_group(clusters[getWordIndex("Frankfurt")][0])["spatialClean"].unique()
# Out:
# array(['Franckfurt', 'Frankfurt/Main', 'Francofurti', 'Frankfurt/Oder',
#        'Frankfurt, Main', 'Frankfurt, O', 'Frankfurt, Oder', 'Francfort',
#        'Franckfurth', 'Franckf.', 'Francof.', 'Francofordiae',
#        'Franckfurdt', 'Francfurti', 'Frankfurt am Main', 'Frankfurt',
#        'Frankfurt/ Main', 'Francofort', 'Francourti', 'Frankfurt, Oder?',
#        'Frankfurth', 'Frankfurt, M', 'Frankfurt, M.', 'Frankofurti',
#        'Frankfurt/ M.', 'Francofurte', 'Frankfurt-O.', 'Franqfurṭ',
#        'Frankf.', 'Franḳfurṭ', 'Francofurdiae', 'Franckfurt, Oder',
#        'Fraancofurti', 'Francofurri', 'Francofurti.', 'Francofurtana',
#        'Francoforti', 'Franckfurt, Main', 'Frankfurta', 'Francofvrti',
#        'Franckufurt', 'Frankfurt/Main, 1562', 'Franckfurt, Leipzig',
#        'Franfurt'], dtype=object)

# %%
grp.get_group(clusters[getWordIndex("Hamburg")][0])["spatialClean"].unique()
# Out:
# array(['Hamburg', 'Hamburgi', 'Hambourg', 'Homberg', 'Homburg',
#        'Hamburg, Leipzig', 'Harburg', 'Hambvrgi', 'Harzburg', 'Hamburgii',
#        'Hamburgo', 'Hamburg?'], dtype=object)

# %%
grp.get_group(clusters[getWordIndex("Uri")][0])["spatialClean"].unique()
# Out:
# array(['Uri', 'Uri?'], dtype=object)

# %%
# write out the spatial cluster names...
def getClusterName(clusterID):
    if clusterID and clusterID in clusterNames:
        if clusterNames[clusterID]:
            return clusterNames[clusterID].title()
        else:
            return np.nan
    else:
        return np.nan

df3['spatialClusterName'] = df3["spatialCluster"].apply(getClusterName)

# %% [markdown]
# Our data is still not completely clean. For instance, historical names need additional corrections. The same holds true for names in different languages or other special cases such as:
#
# * Carlsruhe
# * Crefeld
# * Weymar
# * Kjøbenhavn
# * Leipzig, Dresden
# * St. Peterburg
# * Coblentz
# * Halæ
#
# However, it would be cumbersome to correct everything manually without further assistance as shown below.

# %%
df3.ix[df3["spatialClusterName"]=="Carlsruhe", "spatialClusterName"] = "Karlsruhe"
df3.ix[df3["spatialClusterName"]=="Crefeld", "spatialClusterName"] = "Krefeld"
df3.ix[df3["spatialClusterName"]=="Weymar", "spatialClusterName"] = "Weimar"
df3.ix[df3["spatialClusterName"]==u"Kjøbenhavn", "spatialClusterName"] = u"København"
df3.ix[df3["spatialClusterName"]=="Leipzig, Dresden", "spatialClusterName"] = "Leipzig"
df3.ix[df3["spatialClusterName"]=="St. Peterburg", "spatialClusterName"] = "Sankt Petersburg"
df3.ix[df3["spatialClusterName"]=="Coblentz", "spatialClusterName"] = "Koblenz"
df3.ix[df3["spatialClusterName"]==u"Halæ", "spatialClusterName"] = u"Halle"
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
# if there was no cluster name, just take the cleaned spatial name
df3.spatialClusterName.fillna(df3.spatialClean, inplace=True)
uniqueValues(df3)
# Out:
# object;		 unique values:	102053	 total count: 102054
# type;		 unique values:	6	 total count: 120000
# identifier;		 unique values:	119938	 total count: 120000
# rights;		 unique values:	1	 total count: 120000
# title;		 unique values:	85471	 total count: 120000
# format;		 unique values:	1	 total count: 120000
# source;		 unique values:	101804	 total count: 120000
# provider;		 unique values:	1	 total count: 120000
# isShownAt;		 unique values:	119933	 total count: 119994
# dataProvider;		 unique values:	1	 total count: 120000
# creator;		 unique values:	44469	 total count: 92532
# subject;		 unique values:	44	 total count: 120000
# spatial;		 unique values:	8054	 total count: 98511
# issued;		 unique values:	571	 total count: 64751
# date;		 unique values:	571	 total count: 64751
# alternative;		 unique values:	29238	 total count: 32089
# publisher;		 unique values:	14755	 total count: 60862
# relation;		 unique values:	16791	 total count: 27570
# description;		 unique values:	9500	 total count: 9794
# PPN;		 unique values:	119956	 total count: 120000
# spatialClean;		 unique values:	3873	 total count: 119895
# dateClean;		 unique values:	535	 total count: 119375
# spatialCluster;		 unique values:	2508	 total count: 120000
# spatialClusterName;		 unique values:	2502	 total count: 119895

# %% [markdown]
# ### Exporting an Excel Document for Manual Corrections
# * in the next step, we will extract all unique spatial cluster names for manual correction
# * an Excel sheet is created which also contains statistical data about the name in order to reveal outliers
# * the statistics will help you to reveal different error classes, e.g., very short or long names or other atypical values in the corpus
#
# The resulting Excel file can be modified and will be read in again below.

# %%
dfValues={'SpatialClusterName':[],'Length':[],'NoOfElements':[],'Entries':[]}

sortedUniqueDF3=df3.sort_values(by="spatialClusterName")["spatialClusterName"].unique()

for uniqueName in sortedUniqueDF3:
    if uniqueName:
        length=str(len(uniqueName))
        entries=df3[df3["spatialClusterName"]==uniqueName]["spatialClean"].unique()
        noOfElements=str(len(entries))
        entriesString=",".join(entries)
        dfValues['SpatialClusterName'].append(uniqueName)
        dfValues['Length'].append(length)
        dfValues['NoOfElements'].append(noOfElements)
        dfValues['Entries'].append(entriesString)

spDF=pd.DataFrame(dfValues)
spDF = spDF[['SpatialClusterName', 'Length','NoOfElements','Entries']]
spDF['NoOfElements'] = pd.to_numeric(spDF['NoOfElements'])
spDF['Length'] = pd.to_numeric(spDF['Length'])
spDF['NewName']=""

stdLength=spDF.std()["Length"]
avgLength=spDF.mean()["Length"]
lowerLength=avgLength-stdLength
upperLength=avgLength+stdLength

stdNoOfElements=spDF.std()['NoOfElements']
avgNoOfElements=spDF.mean()['NoOfElements']
lowerNoOfElements=avgNoOfElements-stdNoOfElements
upperNoOfElements=avgNoOfElements+stdNoOfElements

def atypicalLength(x):
    if x < lowerLength or x > upperLength:
        return True
    else:
        return False

def atypicalNoOfElements(x):
    if x < lowerNoOfElements or x > upperNoOfElements:
        return True
    else:
        return False
    

spDF['AtypicalLength']=spDF['Length'].apply(atypicalLength)
spDF['AtypicalNoOfElements']=spDF['NoOfElements'].apply(atypicalNoOfElements)

spDF.to_excel("./spatialnames.xlsx",index=False)
spDF.shape
# Out:
# (2500, 7)

# %% [markdown]
# ### Visualization of the Results

# %%
grpNoOfElements=spDF.groupby("NoOfElements")
grpNoOfElements.count().plot()
if saveFiguresAsPDF:
    plt.savefig('./figures/noelements_cluster.pdf')

# %%
grpLength=spDF.groupby("Length")
grpLength.count().plot()
if saveFiguresAsPDF:
    plt.legend("")
    plt.ylabel("Amount")
    plt.xlabel("Length of Cluster Name")
    plt.savefig('./figures/length_spatialnames.pdf')

# %% [markdown]
# Before running the following cell, you should have inspected the Excel file from above and saved your corrections to "spatialnamesCorrections.xlsx".

# %%
spDF_manuallyCleaned=pd.read_excel("spatialnamesCorrections.xlsx")
spDF_manuallyCleaned.head(20)
# Out:
#       SpatialClusterName  Length  NoOfElements                    Entries            NewName  AtypicalLength  AtypicalNoOfElements
# 0                      1       1             1                          1                  .            True                 False
# 1                      2       1             1                          2                  .            True                 False
# 2                     2.       2             1                         2.                  .            True                 False
# 3                     50       2             1                         50                  .            True                 False
# 4                     ??       2             1                         ??                  .            True                 False
# 5                      A       1             1                          A                  .            True                 False
# 6                     A.       2             1                         A.                  .            True                 False
# 7                   Abel       4             1                       Abel                NaN            True                 False
# 8                   Agra       4             1                       Agra                NaN            True                 False
# 9         Aigen/Salzburg      14             1             Aigen/Salzburg              Aigen            True                 False
# 10                   Air       3             1                        Air                NaN            True                 False
# 11                   Aix       3             1                        Aix                NaN            True                 False
# 12                  Aken       4             1                       Aken                NaN            True                 False
# 13                   Ala       3             1                        Ala                NaN            True                 False
# 14         Alexandersbad      13             1              Alexandersbad                NaN            True                 False
# 15         Alten-Stettin      13             2  Alten-Stettin,Alt-Stettin            Stettin            True                 False
# 16  Altenburg, Thüringen      20             1       Altenburg, Thüringen          Altenburg            True                 False
# 17     Altona-Bahrenfeld      17             1          Altona-Bahrenfeld  Bahrenfeld-Altona            True                 False
# 18   Altstadt-Königsberg      19             1        Altstadt-Königsberg         Königsberg            True                 False
# 19                    Am       2             1                         Am                  .            True                 False

# %%
df3[df3.spatialClusterName=="Aigen/Salzburg"].head() # returns PPN771101503 and PPN771101589
# Out:
#                                                   object  type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                                       creator                   subject         spatial issued date  \
# 57390  http://digital.staatsbibliothek-berlin.de/euro...  Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Brief von Friederike von Kap-herr an Gerhart H...  image/jpeg  Kap-herr, Friederike von  Hauptmann, Gerhart: ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  Kap-herr, Friederike von  Hauptmann, Gerhart  Nachlässe und Autographe  Aigen/Salzburg    NaN  NaN
# 67962  http://digital.staatsbibliothek-berlin.de/euro...  Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Brief von Friederike von Kap-herr an Gerhart H...  image/jpeg  Kap-herr, Friederike von  Hauptmann, Gerhart: ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  Kap-herr, Friederike von  Hauptmann, Gerhart  Nachlässe und Autographe  Aigen/Salzburg    NaN  NaN
#
#       alternative publisher relation description           PPN    spatialClean dateClean spatialCluster spatialClusterName
# 57390         NaN       NaN      NaN         NaN  PPN771101503  Aigen/Salzburg      1738            738     Aigen/Salzburg
# 67962         NaN       NaN      NaN         NaN  PPN771101589  Aigen/Salzburg      1738            738     Aigen/Salzburg

# %%
df3[df3.spatialClusterName=="1"].head() # returns PPN662043146 and PPN688520944
# Out:
#                                                   object  type                                         identifier       rights                           title      format                                             source                                           provider                                          isShownAt                                       dataProvider                              creator subject                        spatial issued date alternative publisher relation  \
# 87521  http://digital.staatsbibliothek-berlin.de/euro...  Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access        Brief an Marie von Bülow  image/jpeg  Draeseke, Felix  Bülow, Marie: Brief an Marie ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...        Draeseke, Felix  Bülow, Marie   Musik                  1 Brief, 4 S.    NaN  NaN  22.06.1900       NaN      NaN
# 88624  http://digital.staatsbibliothek-berlin.de/euro...  Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Postkarte an Wilhelm Engelmann  image/jpeg  Schumann, Clara  Engelmann, Wilhelm: Postkarte...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  Schumann, Clara  Engelmann, Wilhelm   Musik  1 Postkarte, 1 S. und Adresse    NaN  NaN  17.12.1885       NaN      NaN
#
#       description           PPN spatialClean dateClean spatialCluster spatialClusterName
# 87521         NaN  PPN662043146            1      1738           2504                  1
# 88624         NaN  PPN688520944            1      1738           2504                  1

# %%
uniqueValues(df3)
# Out:
# object;		 unique values:	102053	 total count: 102054
# type;		 unique values:	6	 total count: 120000
# identifier;		 unique values:	119938	 total count: 120000
# rights;		 unique values:	1	 total count: 120000
# title;		 unique values:	85471	 total count: 120000
# format;		 unique values:	1	 total count: 120000
# source;		 unique values:	101804	 total count: 120000
# provider;		 unique values:	1	 total count: 120000
# isShownAt;		 unique values:	119933	 total count: 119994
# dataProvider;		 unique values:	1	 total count: 120000
# creator;		 unique values:	44469	 total count: 92532
# subject;		 unique values:	44	 total count: 120000
# spatial;		 unique values:	8054	 total count: 98511
# issued;		 unique values:	571	 total count: 64751
# date;		 unique values:	571	 total count: 64751
# alternative;		 unique values:	29238	 total count: 32089
# publisher;		 unique values:	14755	 total count: 60862
# relation;		 unique values:	16791	 total count: 27570
# description;		 unique values:	9500	 total count: 9794
# PPN;		 unique values:	119956	 total count: 120000
# spatialClean;		 unique values:	3873	 total count: 119895
# dateClean;		 unique values:	535	 total count: 119375
# spatialCluster;		 unique values:	2508	 total count: 120000
# spatialClusterName;		 unique values:	2502	 total count: 119895

# %%
#df3temp=df3

# %%
# df3.ix[df3["spatialClusterName"]=="Carlsruhe", "spatialClusterName"] = "Karlsruhe"
printLog("Fixing spatial cluster names on the basis of manual corrections...")
counterRemoved=0
counterAltered=0
ignoredSpatialNamesLowerCase=[]

for row in spDF_manuallyCleaned.iterrows():
    #py27 newName=readDate=unicode(row[1]["NewName"])
    #py27 oldName=unicode(row[1]["SpatialClusterName"])
    newName=str(row[1]["NewName"])
    oldName=row[1]["SpatialClusterName"]
    
    if newName==".":
        #print("Removed: "+row[1]["SpatialClusterName"])
        df3.ix[df3["spatialClusterName"]==oldName, "spatialClusterName"] = ""
        ignoredSpatialNamesLowerCase.append(oldName.lower())
        counterRemoved=counterRemoved+1
    elif newName=="nan":
        pass
    else:
        #print("Changed: "+row[1]["SpatialClusterName"])
        df3.ix[df3["spatialClusterName"]==oldName, "spatialClusterName"] = newName
        counterAltered=counterAltered+1
        
printLog("Done.")
printLog("Removed clusters: %i"%counterRemoved)
printLog("Altered clusters: %i"%counterAltered)
# Out:
# [2018-09-21 16:37:22.694942]	Fixing spatial cluster names on the basis of manual corrections...
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# [2018-09-21 16:37:58.193609]	Done.
# [2018-09-21 16:37:58.194086]	Removed clusters: 62
# [2018-09-21 16:37:58.194568]	Altered clusters: 186

# %%
uniqueValues(df3)
# Out:
# object;		 unique values:	102053	 total count: 102054
# type;		 unique values:	6	 total count: 120000
# identifier;		 unique values:	119938	 total count: 120000
# rights;		 unique values:	1	 total count: 120000
# title;		 unique values:	85471	 total count: 120000
# format;		 unique values:	1	 total count: 120000
# source;		 unique values:	101804	 total count: 120000
# provider;		 unique values:	1	 total count: 120000
# isShownAt;		 unique values:	119933	 total count: 119994
# dataProvider;		 unique values:	1	 total count: 120000
# creator;		 unique values:	44469	 total count: 92532
# subject;		 unique values:	44	 total count: 120000
# spatial;		 unique values:	8054	 total count: 98511
# issued;		 unique values:	571	 total count: 64751
# date;		 unique values:	571	 total count: 64751
# alternative;		 unique values:	29238	 total count: 32089
# publisher;		 unique values:	14755	 total count: 60862
# relation;		 unique values:	16791	 total count: 27570
# description;		 unique values:	9500	 total count: 9794
# PPN;		 unique values:	119956	 total count: 120000
# spatialClean;		 unique values:	3873	 total count: 119895
# dateClean;		 unique values:	535	 total count: 119375
# spatialCluster;		 unique values:	2508	 total count: 120000
# spatialClusterName;		 unique values:	2316	 total count: 119895

# %% [markdown]
# Some debugging...

# %%
df3[df3.spatialClusterName=="Upsaliæ"].head()
# Out:
# Empty DataFrame
# Columns: [object, type, identifier, rights, title, format, source, provider, isShownAt, dataProvider, creator, subject, spatial, issued, date, alternative, publisher, relation, description, PPN, spatialClean, dateClean, spatialCluster, spatialClusterName]
# Index: []

# %%
df3[df3.PPN=="PPN771101503"].head() # returns PPN771101503
# Out:
#                                                   object  type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                                       creator                   subject         spatial issued date  \
# 57390  http://digital.staatsbibliothek-berlin.de/euro...  Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Brief von Friederike von Kap-herr an Gerhart H...  image/jpeg  Kap-herr, Friederike von  Hauptmann, Gerhart: ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  Kap-herr, Friederike von  Hauptmann, Gerhart  Nachlässe und Autographe  Aigen/Salzburg    NaN  NaN
#
#       alternative publisher relation description           PPN    spatialClean dateClean spatialCluster spatialClusterName
# 57390         NaN       NaN      NaN         NaN  PPN771101503  Aigen/Salzburg      1738            738              Aigen

# %%
pickleCompress('./picklez/clean_dataframe.picklez',df3)
pickleCompress('./picklez/ignoredSpatialNames.picklez',ignoredSpatialNamesLowerCase)
# Out:
# [2018-09-21 16:39:02.667634]	Pickling to './picklez/clean_dataframe.picklez'
# [2018-09-21 16:39:16.058896]	Pickling done.
# [2018-09-21 16:39:16.059713]	Pickling to './picklez/ignoredSpatialNames.picklez'
# [2018-09-21 16:39:16.061543]	Pickling done.

# %% [markdown]
# ## Generating Geographical Data
#
# After running all cells above, we still end up with verbal spatial names which are not language-independent. Hence, we have to link the cities or locations to coordinates. This example will directly interact with Google Maps or OpenStreet Maps but using [GeoPy](https://geopy.readthedocs.io/en/stable/) could also be an interesting alternative.
#
# __ATTENTION__ To use Google Maps you need an API key! See https://developers.google.com/maps/documentation/javascript/get-api-key

# %%
# uncomment only needed if you resume the notebook
#df4=pickleDecompress('./picklez/clean_dataframe.picklez')
#ignoredSpatialNamesLowerCase=pickleDecompress('./picklez/ignoredSpatialNames.picklez')

# otherwise just run this line:
df4=df3

# %%
if useGoogleMapsAPI:
    # idee ist, die Algorithmen von Google zu nutzen, um mit mitunter fehlerhaften, mehrsprachigen Ortsbezeichner umzugehen
    gmaps = googlemaps.Client(key='XXX')
    # if you re-run this cell you might want to uncomment the following line
    latLng=dict()
    printLog("Fetching geolocations from Google Maps...")
    for row in df4.iterrows():
        if not row[1]["spatialClusterName"]:
            # in some cases, i.e., when the cluster was corrected manually above, 
            # we will ignore the spatialClean replacement
            loc=row[1]["spatialClean"]
            if loc:
                if not loc.lower() in ignoredSpatialNamesLowerCase:
                    printLog("Taking %s instead."%loc)
                else:
                    loc=None
        else:
            loc=row[1]["spatialClusterName"]
        if loc:
            if loc not in latLng:
                #printLog(loc)
                try:
                    retLL=gmaps.geocode(loc)
                    if len(retLL)>0:
                        latLng[loc]=retLL[0][u'geometry'][u'location']
                    else:
                        latLng[loc]=None
                except googlemaps.exceptions.ApiError:
                    printLog("Problem fetching: "+loc)
                    latLng[loc]=None
    printLog("Done.")

    triedAgain=[]
    printLog("Fetching geolocations from Google Maps a second time (aka the brute force failover solution)...")
    for row in df4.iterrows():
        if not row[1]["spatialClusterName"]:
            loc=row[1]["spatialClean"]
        else:
            loc=row[1]["spatialClusterName"]
        if loc:
            if latLng[loc]==None:
                if loc not in triedAgain:
                    #printLog(loc)
                    triedAgain.append(loc)
                    try:
                        retLL=gmaps.geocode(loc)
                        if len(retLL)>0:
                            latLng[loc]=retLL[0][u'geometry'][u'location']
                        else:
                            latLng[loc]=None
                    except googlemaps.exceptions.ApiError:
                        printLog("Problem fetching: "+loc)
                        latLng[loc]=None
    printLog("Done.")
    pickleCompress('./picklez/geo_coordinates.picklez',latLng)
else:
    printLog("Skipping Google Map API calls.")
# Out:
# [2018-09-21 16:49:33.185472]	Skipping Google Map API calls.

# %%
# see http://wiki.openstreetmap.org/wiki/Nominatim#Reverse_Geocoding
if not useGoogleMapsAPI:
    if getSpatialNamesFromOSM:
        osmNominatimURL="http://nominatim.openstreetmap.org/search?format=json&namedetails=1&q="
        # if you re-run this cell you might want to uncomment the following line
        latLng=dict()
        names=dict()
    
        maxItems=df4.shape[0]
        counter=0
    
        printLog("Fetching geolocations from OpenStreetMaps...")
        for row in df4.iterrows():
            counter=counter+1
            if counter%5000==0:
                printLog("\tProcessed %i items of %i"%(counter,maxItems))
            if not row[1]["spatialClusterName"]:
                # in some cases, i.e., when the cluster was corrected manually above, 
                # we will ignore the spatialClean replacement
                loc=str(row[1]["spatialClean"])
                if loc:
                    if not loc.lower() in ignoredSpatialNamesLowerCase:
                        printLog("No spatial cluster name for %s. Taking %s instead."%(row[1]["PPN"],loc))
                    else:
                        loc=None
            else:
                loc=str(row[1]["spatialClusterName"])
            if loc:
                if loc not in latLng:
                #printLog(loc)
                    locURL=osmNominatimURL+urllib.parse.quote(loc).replace(" ","+")
                    try:
                        data = json.load(urllib.request.urlopen(locURL))
                        latLng[loc]=dict()
                        if len(data)>0:
                            #print data[0]
                            latLng[loc][u'lat']=data[0]["lat"]
                            latLng[loc][u'lng']=data[0]["lon"]
                            #print loc
                            names[loc]=dict()
                            if len(data[0]['namedetails'])>0:
                                for k,v in data[0]['namedetails'].items():
                                    names[loc][k]=v
                            else:
                                names[loc][u'name']=loc
                                #print "No namedetails for "+loc
                            #print names[loc]
                        else:
                            latLng[loc]=None
                    except IOError:
                        printLog("\tCould not open: "+locURL)
                        pickleCompress('./picklez/save_names.picklez',names)
                        pickleCompress('./picklez/save_latLng.picklez',latLng)
                    time.sleep(1) # see http://wiki.openstreetmap.org/wiki/Nominatim_usage_policy
        printLog("Done.")
    else:
        printLog("Skipping OpenStreetMap API calls.")
else:
    printLog("Skipping OpenStreetMap API calls.")
# Out:
# [2018-09-21 16:50:26.551421]	Fetching geolocations from OpenStreetMaps...
# [2018-09-21 16:53:04.559304]	No spatial cluster name for PPN601268105. Taking None instead.
# [2018-09-21 16:53:36.088891]	No spatial cluster name for PPN601266560. Taking None instead.
# [2018-09-21 16:53:48.626315]	No spatial cluster name for PPN601267419. Taking None instead.
# [2018-09-21 16:53:58.868689]	No spatial cluster name for PPN60126777X. Taking None instead.
# [2018-09-21 16:54:00.103198]	No spatial cluster name for PPN601267583. Taking None instead.
# [2018-09-21 16:54:01.379184]	No spatial cluster name for PPN601265505. Taking None instead.
# [2018-09-21 16:55:19.210433]		Processed 5000 items of 120000
# [2018-09-21 16:57:34.940151]	No spatial cluster name for PPN790388022. Taking None instead.
# [2018-09-21 17:38:21.482928]	No spatial cluster name for PPN688802060. Taking None instead.
# [2018-09-21 17:38:30.338528]		Processed 110000 items of 120000
# [2018-09-21 17:38:38.056253]	No spatial cluster name for PPN746968884. Taking None instead.
# [2018-09-21 17:39:10.519487]	No spatial cluster name for PPN688710352. Taking None instead.
# [2018-09-21 17:39:10.534973]	No spatial cluster name for PPN688812546. Taking None instead.
# [2018-09-21 17:39:15.580666]		Processed 115000 items of 120000
# [2018-09-21 17:39:21.964297]	No spatial cluster name for PPN688713157. Taking None instead.
# [2018-09-21 17:39:33.574857]	No spatial cluster name for PPN668008717. Taking None instead.
# [2018-09-21 17:39:33.587881]	No spatial cluster name for PPN735478686. Taking Schwäb. instead.
# [2018-09-21 17:39:34.894844]	No spatial cluster name for PPN633580872. Taking None instead.
# [2018-09-21 17:39:38.717042]	No spatial cluster name for PPN688813917. Taking None instead.
# [2018-09-21 17:39:42.570207]	No spatial cluster name for PPN68880439X. Taking None instead.
# [2018-09-21 17:39:51.511879]	No spatial cluster name for PPN667682600. Taking None instead.
# [2018-09-21 17:39:52.806955]		Processed 120000 items of 120000
# [2018-09-21 17:39:52.808918]	Done.

# %%
printLog("Number of coordinates: %i"%len(latLng))
# Out:
# [2018-09-21 17:39:52.813908]	Number of coordinates: 2316

# %%
# for manual additions, you can directly pass an URL as the example below shows
#manualLocation="Kehl"
#data = json.load(urllib.urlopen("http://nominatim.openstreetmap.org/search?format=json&namedetails=1&q="+manualLocation))
#loc=manualLocation
#if len(data)>0:
#    latLng[loc][u'lat']=data[0]["lat"]
#    latLng[loc][u'lng']=data[0]["lon"]
#    names[loc]=dict()
#    if len(data[0]['namedetails'])>0:
#        for k,v in data[0]['namedetails'].items():
#            names[loc][k]=v
#    else:
#        names[loc][u'name']=loc
#else:
#    latLng[loc]=None

# %%
# save everything
if not useGoogleMapsAPI:
    if getSpatialNamesFromOSM:
        pickleCompress('./picklez/osm_names.picklez',names)
        pickleCompress('./picklez/osm_latLng.picklez',latLng)
# Out:
# [2018-09-21 17:45:27.220152]	Pickling to './picklez/osm_names.picklez'
# [2018-09-21 17:45:27.614735]	Pickling done.
# [2018-09-21 17:45:27.618180]	Pickling to './picklez/osm_latLng.picklez'
# [2018-09-21 17:45:27.662933]	Pickling done.

# %%
if useGoogleMapsAPI:
    latLng=pickleDecompress('./picklez/geo_coordinates.picklez')
else:
    latLng=pickleDecompress('./picklez/osm_latLng.picklez')
    osmNames=pickleDecompress('./picklez/osm_names.picklez')
# Out:
# [2018-09-21 17:45:37.538363]	Depickling from './picklez/osm_latLng.picklez'
# [2018-09-21 17:45:37.546014]	Depickling done.
# [2018-09-21 17:45:37.548084]	Depickling from './picklez/osm_names.picklez'
# [2018-09-21 17:45:37.571403]	Depickling done.

# %% [markdown]
# * save latitude and longitude to separate columns

# %%
def getLat(spatialName):
    if spatialName:
        if spatialName in latLng:
            if latLng[spatialName]:
                return latLng[spatialName][u'lat']
            else:
                return np.nan
    else:
        return np.nan

def getLng(spatialName):
    if spatialName:
        if spatialName in latLng:
            if latLng[spatialName]:
                return latLng[spatialName][u'lng']
            else:
                return np.nan
    else:
        return np.nan

df4['latitude']=df4['spatialClusterName'].apply(getLat)
df4['longitude']=df4['spatialClusterName'].apply(getLng)

# %%
# overwrite every "nulled" column (i.e. NULL or NaN) with -1
df4.ix[df4["dateClean"].isnull(), "dateClean"] = -1

df4["century"]=df4["dateClean"].apply(lambda x: int(int(x)/100)) # uns interessiert nur das jahrhundert
df4.head(20)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#                                                object        type                                         identifier       rights                                              title      format                                             source                                           provider                                          isShownAt                                       dataProvider                                            creator                   subject   spatial issued  date  \
# 0   http://digital.staatsbibliothek-berlin.de/euro...        Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Großer Kommentar über die Metaphysik des Arist...  image/jpeg  Averroes,: Großer Kommentar über die Metaphysi...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                          Averroes,  Hebräische Handschriften       NaN    NaN   NaN
# 1                                                 NaN  Periodical  http://www.bibliothek.uni-regensburg.de/ezeit/...  Open Access            Allgemeines Polizei-Archiv für Preussen  image/jpeg  Allgemeines Polizei-Archiv für Preussen. Berli...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://www.bibliothek.uni-regensburg.de/ezeit/...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                                NaN        Rechtswissenschaft    Berlin    NaN   NaN
# 2   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                             Der XLII. Psalm Davids  image/jpeg  Jordano, Alberto  Läger, Joachimus: Der XLII. ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                 Jordano, Alberto  Läger, Joachimus            Einblattdrucke    [S.l.]   1650  1650
# 3   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Der erlauchte Bauer oder Lebensgeschichte und ...  image/jpeg  Maubert de Gouvest, Jean Henri: Der erlauchte ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                     Maubert de Gouvest, Jean Henri        Historische Drucke    Berlin   1755  1755
# 4                                                 NaN  Periodical  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access                                        Der Wächter  image/jpeg  Der Wächter  Polizeiblatt für Mecklenburg. Sch...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                                                NaN        Rechtswissenschaft  Schwerin    NaN   NaN
# 5   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Scheid-Gedicht/ über Den Bitter-Süssen Abzuge ...  image/jpeg  Wolcken, Johann  Meier, Johannes: Scheid-Gedic...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                   Wolcken, Johann  Meier, Johannes        Historische Drucke   Hamburg   1650  1650
# 6   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Hochzeitliches Ehren-Gedicht Auff das Ehliche ...  image/jpeg  Lithoecaeus, Georgius  Röver, Johann  Overbeck...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...  Lithoecaeus, Georgius  Röver, Johann  Overbeck...        Historische Drucke   Hamburg   1645  1645
# 7   http://digital.staatsbibliothek-berlin.de/euro...      Volume  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Aufsätze aus Wochenschriften und freundschaftl...  image/jpeg  Chesterfield, Philipp Dormer Stanhope: Aufsätz...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...              Chesterfield, Philipp Dormer Stanhope        Historische Drucke   Leipzig   1780  1780
# 8   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Ehren-Gedicht/ Auff den Hochzeitlichen Ehrenta...  image/jpeg  Hardkopf, Georgius  Schönfeld, Gertrud: Ehren-...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...             Hardkopf, Georgius  Schönfeld, Gertrud        Historische Drucke   Hamburg   1650  1650
# 9   http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Lucidor und Chloris. Das ist Glück-Wünschung/ ...  image/jpeg  Tiesen, Joachimus  Schröder, Margarita: Lucido...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...             Tiesen, Joachimus  Schröder, Margarita        Historische Drucke   Hamburg   1641  1641
# 10  http://digital.staatsbibliothek-berlin.de/euro...        Text  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access          Schriftprobe František Václav Míča (1729)  image/jpeg  Míča, František Václav: Schriftprobe František...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu...                             Míča, František Václav           Schlüsselseiten       NaN    NaN   NaN
# 11  http://digital.staatsbibliothek-berlin.de/euro...   Monograph  http://resolver.staatsbibliothek-berlin.de/SBB...  Open Access  Nuptiis Auspicatissimis Clarissimi Consultissi...  image/jpeg  Palladius, Jacobus  Penshorn, David  Wichman, ...  Staatsbibliothek zu Berlin - Preußischer Kultu...  http://resolver.staatsbibliothek-berlin.de/SBB...  Staatsbibliothek zu Berlin - Preußischer Kultu
# 19       Mozart, Wolfgang Amadeus  Marteau, Henri: Sona...    5    1808    345    Berlin   490         2058    245    Berlin    695           2058    215  1551    700               2058    198      Berlin    751    2058     19           Historische Drucke    836   2058   1880                                     Am Reissbrette    19   2058      4  Monograph   1491
# 20       Spanier, Arthur: [Bildnis Arthur Spanier]. Ber...    1       2      1    Berlin     2            2      1    Berlin      2              2      1  1551      2                  2      1      Berlin      2       2      1               Einblattdrucke      2      2      2  [Fotografie der Gipsbüste 'Karl August Varnhag...     1      2      1  Monograph      2
#
# [13 rows x 104 columns]

# %%
grpCentury.count().plot()

# %% [markdown]
# ## Text-based Clustering
#
# Another scenario in which we can use another clustering algorithm is the search for similar titles in the corpus. We will use a [k-means](https://en.wikipedia.org/wiki/K-means_clustering) algorithm. For this algorithm, we have to know the number of clusters (_k_) a priori.

# %%
# prepare the data for clustering
printLog("Number of unique title fields %i"%len(df4.title.unique()))
#title soll geclustert werden -> textCluster
corpus=df4.title.astype(str)

true_k=5000

if sys.version_info.major>=3 or allowComputationallyExtensiveCalculations:
    printLog("Clustering text with cluster target size k=%i"%true_k)
    printLog("\t Preparing tf*idf model")
    # from an analysis we know that there are 167,715 different words in the corpus
    # to speed up processing, we limit the vocabulary size to the ca. top-75% of the words
    tfidfvectorizer = TfidfVectorizer(min_df=1,max_features=125000) #max_features is used to limit the vocabulary size 
    Xtfidf=tfidfvectorizer.fit_transform(corpus)
    featNames=tfidfvectorizer.get_feature_names()
    printLog("\t Number of feature names: %i"%len(featNames))

    printLog("\t K-Means clustering")
    # the mini batch k-means is a very efficient implementation of the k-means algorithm
    km=MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
    # fit the k-means algorithm on the data created above
    km.fit(Xtfidf)
    printLog("Done.")
    if sys.version_info.major<3:
        pickleCompress('./picklez/textClustersK_'+str(true_k)+'.picklez',km)
else:
    km=pickleDecompress('./picklez/textClustersK_'+str(true_k)+'.picklez')
    printLog("\t Updating Dataframe")
# add the detected clusters as a new column to the original data frame
df4['textCluster']=km.labels_
printLog("Done.")
# Out:
# [2018-09-21 18:03:01.444639]	Clustering text with cluster target size 5000
# [2018-09-21 18:03:01.445354]		 Preparing tf*idf model
# [2018-09-21 18:03:03.573603]		 Number of feature names: 125000
# [2018-09-21 18:03:03.574109]		 K-Means clustering
# /anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:1418: RuntimeWarning: init_size=300 should be larger than k=5000. Setting it to 3*k
#   init_size=init_size)
# [2018-09-21 18:10:10.694767]	Done.
# [2018-09-21 18:10:10.697334]	Done.

# %%
if allowComputationallyExtensiveCalculations:
    # group the data by the cluster and describe it
    df4.groupby('textCluster').describe()

# %%
df4=df4.sort_values(by="textCluster")
df4[['PPN','title','textCluster']].tail()
# Out:
#                  PPN                                              title  textCluster
# 28987   PPN770569285  Lehr-Buch, darin ein Kurzgefasster Unterricht ...         4997
# 92984   PPN635707225  De Summo Hominis Bono Practico, in essentia & ...         4998
# 82393   PPN749751134  Ein hübsch new Liede || von dem Raumensattel/ ...         4999
# 80693   PPN749751665  Ein huebsch new Liedt/|| von dem Raumensattel/...         4999
# 108155  PPN749752041  Ein huebsch new Liedt/|| von dem Raumensattel/...         4999

# %% [markdown]
# We can try the same approach for the creator column.

# %%
true_k=10000

#creator soll geclustert werden -> creatorCluster
corpus=df4.creator.astype(str)
printLog("Number of unique creator fields %i"%len(df4.creator.unique()))

if sys.version_info.major>=3 or allowComputationallyExtensiveCalculations:
    printLog("Clustering text with cluster target size %i"%true_k)
    printLog("\t Preparing tf*idf model")
    tfidfvectorizer = TfidfVectorizer(min_df=1) #max_features setzen?
    Xtfidf=tfidfvectorizer.fit_transform(corpus)
    featNames=tfidfvectorizer.get_feature_names()
    printLog("\t Number of feature names: %i"%len(featNames))

    printLog("\t K-Means clustering")
    km=MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
    # fit the k-means algorithm on the data created above
    km.fit(Xtfidf)
    printLog("Done.")
    pickleCompress('./picklez/creatorClustersK_'+str(true_k)+'.picklez',km)
else:
    km=pickleDecompress('./picklez/creatorClustersK_'+str(true_k)+'.picklez')
    printLog("\t Updating Dataframe")
# add the detected clusters as a new column to the original data frame
df4['creatorCluster']=km.labels_
printLog("Done.")
# Out:
# [2018-09-21 18:16:30.599181]	Clustering text with cluster target size 10000
# [2018-09-21 18:16:30.599929]		 Preparing tf*idf model
# [2018-09-21 18:16:31.335755]		 Number of feature names: 38481
# [2018-09-21 18:16:31.336277]		 K-Means clustering
# /anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:1418: RuntimeWarning: init_size=300 should be larger than k=10000. Setting it to 3*k
#   init_size=init_size)
# [2018-09-21 18:24:15.120513]	Done.
# [2018-09-21 18:24:15.121100]	Pickling to './picklez/creatorClustersK_10000.picklez'
# [2018-09-21 18:24:34.191727]	Pickling done.
# [2018-09-21 18:24:34.193690]	Done.

# %%
df4=df4.sort_values(by="creatorCluster")
df4[['PPN','creator','creatorCluster']].tail()
# Out:
#                 PPN                          creator  creatorCluster
# 57198  PPN771086873  Jonas, Paul  Hauptmann, Gerhart            9999
# 58008  PPN771087527  Jonas, Paul  Hauptmann, Gerhart            9999
# 62581  PPN771086628  Jonas, Paul  Hauptmann, Gerhart            9999
# 64088  PPN771087462  Jonas, Paul  Hauptmann, Gerhart            9999
# 66480  PPN771087438  Jonas, Paul  Hauptmann, Gerhart            9999

# %%
pickleCompress('./picklez/clean_dataframe_with_century.picklez',df4)
# Out:
# [2018-09-21 18:26:56.472130]	Pickling to './picklez/clean_dataframe_with_century.picklez'
# [2018-09-21 18:27:11.596913]	Pickling done.

# %%
df4.to_csv("cleanedData.csv",sep=';',header=True, index=False, encoding='utf-8')

# %% [markdown]
# ## The Graph-based Analyses Shall Begin!
#
# It is safe to continue the notebook from here because the needed data will be loaded from disk.

# %%
# if you have run this notebook from top to bottom, you don't have to reload the data
df4=pickleDecompress('./picklez/clean_dataframe_with_century.picklez')
grpCentury=df4.groupby("century")
#df4.shape
# Out:
# [2018-09-21 18:27:17.183599]	Depickling from './picklez/clean_dataframe_with_century.picklez'
# [2018-09-21 18:27:18.652285]	Depickling done.

# %% [markdown]
# ### A Note on Efficiency
#
# As the following code relies heavily on PPNs and associated fields, we create a look-up table to prevent inefficient loops over the dataframe. This will speed up the following cells by a magnitude.

# %%
printLog("Creating PPN look-up table...")
ppnLookup=dict()
for row in df4.iterrows():
    ppn=readDate=str(row[1]["PPN"])
    if ppn not in ppnLookup:
        ppnLookup[ppn]=dict()
    # it is redundant but handy for later JSON exports to save the PPN as a value as well
    ppnLookup[ppn]["ppn"]=ppn
    ppnLookup[ppn]["dateClean"]=str(row[1]["dateClean"])
    ppnLookup[ppn]["title"]=str(row[1]["title"])
    ppnLookup[ppn]["creator"]=str(row[1]["creator"])
    
    if not row[1]["spatialClusterName"]:
        if row[1]["spatialClean"]:
            ppnLookup[ppn]["spatialClusterName"]=row[1]["spatialClean"]
        else:
            ppnLookup[ppn]["spatialClusterName"]="None"
    else:
        ppnLookup[ppn]["spatialClusterName"]=row[1]["spatialClusterName"] 
    ppnLookup[ppn]['spatialClean']=row[1]["spatialClean"]
    ppnLookup[ppn]['spatialRaw']=str(row[1]["spatial"])
    ppnLookup[ppn]['mediatype']=str(row[1]["type"])
    ppnLookup[ppn]['subject']=str(row[1]["subject"])
    ppnLookup[ppn]['source']=str(row[1]["source"])
    ppnLookup[ppn]['publisher']=str(row[1]["publisher"])
    ppnLookup[ppn]['alternative']=str(row[1]["alternative"])
    ppnLookup[ppn]['lat']=str(row[1]["latitude"])
    ppnLookup[ppn]['lng']=str(row[1]["longitude"])
    ppnLookup[ppn]['textCluster']=str(row[1]["textCluster"])
    ppnLookup[ppn]['creatorCluster']=str(row[1]["creatorCluster"])
    
printLog("Done.")
pickleCompress("./picklez/ppnLookup.picklez",ppnLookup)
# Out:
# [2018-09-21 18:27:42.091236]	Creating PPN look-up table...
# [2018-09-21 18:27:59.860468]	Done.
# [2018-09-21 18:27:59.861033]	Pickling to './picklez/ppnLookup.picklez'
# [2018-09-21 18:28:06.331590]	Pickling done.

# %%
#serialize data per PPN; one large file would be more than 80 MB and thus too much for a transmission to a browser
if serializePPNLookup2JSON:
    printLog("Serializing PPN lookup table to JSON in directory:\n\t"+jsonWebDir)
    for k in ppnLookup:
        dump=json.dumps(ppnLookup[k])

        jsonFile = open(jsonWebDir+k+".json", "w")
        jsonFile.write(dump)
        jsonFile.close()
    printLog("Done.")

# %% [markdown]
# ### A Creation and Its Place of Origin - Graphing the Library World
# We will create a complex graph that links publishers/creators with spatialClusterName (locations). In addition, we add the associated dateClean, century, and title to each node of the graph for later visualization purposes.
# We will also create separate graphs for each century to limit the complexity.

# %%
def createGraph(consideredDataFrame):
    # for testing purposes it is handy to limit the number of records
    #consideredDataFrame=consideredDataFrame[(consideredDataFrame.Year>=1961) & (consideredDataFrame.Year<1975)]

    # create an empty graph from the nx (networkx) package imported above
    G=nx.Graph()

    rowCount=0
    seenCreators=[]
    seenLocations=[]
    for row in consideredDataFrame.iterrows():
        rowCount=rowCount+1
        #if rowCount%1000==0:
        #    printLog("Processed %i rows..."%rowCount)
        ppn=row[1]["PPN"]
        creator=str(row[1]["publisher"]).upper()
        if creator=="NAN":
            creator=str(row[1]["creator"]).upper()
        if creator=="NAN":
            creator="Unknown creator"
        
        location=row[1]["spatialClusterName"]
        if location=="NAN":
            location="s. l."
        elif not location:
            location="s. l."
        year=row[1]["dateClean"]
        subject=row[1]["subject"]
        
        #if not creator in G.nodes():
        #if not creator in seenCreators:
        
        G.add_node(creator)
        if not creator=="Unknown creator":
            # the name attribute will be helpful for D3.js visualizations
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "creator"
            G.node[creator]['subject']=subject
            G.node[creator]['century']=row[1]["century"]
            seenCreators.append(creator)
        else:
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "no_creator"
        
        #if not location in G.nodes():
        #if not location in seenLocations:
       
        # the name attribute will be helpful for D3.js visualizations
        if not location=="s. l.":
            G.add_node(location)
            G.node[location]['name'] = location
            G.node[location]['year'] = year
            G.node[location]['type'] = "location"
            seenLocations.append(location)
            G.add_edge(creator,location)
        else:
            pass
        # if we would like to add the unknown location, uncomment the following lines and the comment the last line
            #G.add_node(location)
            #G.node[location]['name'] = location
            #G.node[location]['year'] = year
            #G.node[location]['type'] = "no_location"
    
        #print location
        #print creator
        #print "* * *"
    return G

# %%
printLog("Creating graphs and additional data...")

graphsPerCentury=dict()
ppnPerCentury=OrderedDict()
for century in range(7,21): # we know that there are only media from the 7th century on
    if century in grpCentury.groups:
        centDF=grpCentury.get_group(century)
        returnedGraph=createGraph(centDF)
        graphsPerCentury[century]=returnedGraph
        printLog("Graph for century %i built with %i nodes and %i edges."%(century, len(returnedGraph.nodes()),len(returnedGraph.edges())))
        # export as GraphML, which can be read by Gephi
        nx.write_gml(returnedGraph,"graphs/century_"+str(century)+".gml")
        
        # now save the PPNs
        ppnPerCentury[century]=[]
        for row in centDF.iterrows():
            ppn=row[1]["PPN"]
            ppnPerCentury[century].append(ppn)

# create the full graph
returnedGraph=createGraph(df4)
printLog("Graph for all centuries built with %i nodes and %i edges."%(len(returnedGraph.nodes()),len(returnedGraph.edges())))
nx.write_gml(returnedGraph,"graphs/all_centuries.gml")
printLog("Done.")
# Out:
# [2018-09-21 19:15:52.996013]	Creating graphs and additional data...
# [2018-09-21 19:15:52.999347]	Graph for century 7 built with 2 nodes and 1 edges.
# [2018-09-21 19:15:53.026223]	Graph for century 10 built with 1 nodes and 0 edges.
# [2018-09-21 19:15:53.029072]	Graph for century 11 built with 1 nodes and 0 edges.
# [2018-09-21 19:15:53.033084]	Graph for century 12 built with 14 nodes and 3 edges.
# [2018-09-21 19:15:53.038823]	Graph for century 13 built with 11 nodes and 0 edges.
# [2018-09-21 19:15:53.077398]	Graph for century 14 built with 214 nodes and 160 edges.
# [2018-09-21 19:15:54.145069]	Graph for century 15 built with 2062 nodes and 1886 edges.
# [2018-09-21 19:15:56.205177]	Graph for century 16 built with 3762 nodes and 3429 edges.
# [2018-09-21 19:16:04.678227]	Graph for century 17 built with 22099 nodes and 18882 edges.
# [2018-09-21 19:16:11.011602]	Graph for century 18 built with 4733 nodes and 4305 edges.
# [2018-09-21 19:16:12.221472]	Graph for century 19 built with 1185 nodes and 854 edges.
# [2018-09-21 19:16:12.365048]	Graph for century 20 built with 3 nodes and 2 edges.
# [2018-09-21 19:16:26.129252]	Graph for all centuries built with 31647 nodes and 28208 edges.
# [2018-09-21 19:16:26.983957]	Done.

# %%
def createFullGraph(consideredDataFrame):
    # for testing purposes it is handy to limit the number of records
    #consideredDataFrame=consideredDataFrame[(consideredDataFrame.Year>=1961) & (consideredDataFrame.Year<1975)]

    # create an empty graph from the nx (networkx) package imported above
    G=nx.Graph()

    rowCount=0
    seenCreators=[]
    seenLocations=[]
    for row in consideredDataFrame.iterrows():
        rowCount=rowCount+1
        #if rowCount%1000==0:
        #    printLog("Processed %i rows..."%rowCount)
        ppn=row[1]["PPN"]
        creator=str(row[1]["publisher"]).upper()
        if creator=="NAN":
            creator=str(row[1]["creator"]).upper()
        if creator=="NAN":
            creator="Unknown creator"
        
        location=row[1]["spatialClusterName"]
        if location=="NAN":
            location="s. l."
        elif not location:
            location="s. l."
        year=row[1]["dateClean"]
        subject=row[1]["subject"]
        
        #if not creator in G.nodes():
        #if not creator in seenCreators:
        
        G.add_node(creator)
        if not creator=="Unknown creator":
            # the name attribute will be helpful for D3.js visualizations
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "creator"
            G.node[creator]['subject']=subject
            G.node[creator]['century']=row[1]["century"]
            seenCreators.append(creator)
        else:
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "no_creator"
        
        #if not location in G.nodes():
        #if not location in seenLocations:
       
        # the name attribute will be helpful for D3.js visualizations
        if not location=="s. l.":
            G.add_node(location)
            G.node[location]['name'] = location
            G.node[location]['year'] = year
            G.node[location]['type'] = "location"
            seenLocations.append(location)
            G.add_edge(creator,location)
        else:
            pass
        # if we would like to add the unknown location, uncomment the following lines and the comment the last line
            #G.add_node(location)
            #G.node[location]['name'] = location
            #G.node[location]['year'] = year
            #G.node[location]['type'] = "no_location"
    
        #print location
        #print creator
        #print "* * *"
        
        G.add_node(ppn)
        G.node[ppn]['name'] = str(ppn)
        G.node[ppn]['year'] = year
        G.node[ppn]['type'] = "PPN"
        G.node[ppn]['century']=row[1]["century"]
        G.add_edge(ppn,creator)

    return G

# %%
printLog("Creating graphs incl. PPNs...")

graphsPerCentury=dict()
for century in range(7,21): # we know that there are only media from the 7th century on
    if century in grpCentury.groups:
        centDF=grpCentury.get_group(century)
        returnedGraph=createFullGraph(centDF)
        graphsPerCentury[century]=returnedGraph
        gmlPath="graphs/century_ppn_"+str(century)+".gml"
        # export as GraphML, which can be read by Gephi
        nx.write_gml(returnedGraph,gmlPath)
        printLog("Graph for century %i built with %i nodes and %i edges (see %s)."%(century, len(returnedGraph.nodes()),len(returnedGraph.edges()),gmlPath))
        

# create the full graph
returnedGraph=createFullGraph(df4)
gmlPath="graphs/all_centuries_ppn.gml"
nx.write_gml(returnedGraph,gmlPath)
printLog("Graph for all centuries built with %i nodes and %i edges (see %s)."%(len(returnedGraph.nodes()),len(returnedGraph.edges()),gmlPath))
printLog("Done.")
# Out:
# [2018-09-21 18:30:49.675415]	Creating graphs incl. PPNs...
# [2018-09-21 18:30:49.679180]	Graph for century 7 built with 3 nodes and 2 edges (see graphs/century_ppn_7.gml).
# [2018-09-21 18:30:49.681433]	Graph for century 10 built with 2 nodes and 1 edges (see graphs/century_ppn_10.gml).
# [2018-09-21 18:30:49.683736]	Graph for century 11 built with 2 nodes and 1 edges (see graphs/century_ppn_11.gml).
# [2018-09-21 18:30:49.688728]	Graph for century 12 built with 28 nodes and 17 edges (see graphs/century_ppn_12.gml).
# [2018-09-21 18:30:49.693848]	Graph for century 13 built with 28 nodes and 17 edges (see graphs/century_ppn_13.gml).
# [2018-09-21 18:30:49.743940]	Graph for century 14 built with 504 nodes and 450 edges (see graphs/century_ppn_14.gml).
# [2018-09-21 18:30:51.244033]	Graph for century 15 built with 12711 nodes and 12535 edges (see graphs/century_ppn_15.gml).
# [2018-09-21 18:30:53.295538]	Graph for century 16 built with 17967 nodes and 17634 edges (see graphs/century_ppn_16.gml).
# [2018-09-21 18:31:03.467353]	Graph for century 17 built with 97761 nodes and 94544 edges (see graphs/century_ppn_17.gml).
# [2018-09-21 18:31:05.702062]	Graph for century 18 built with 21165 nodes and 20738 edges (see graphs/century_ppn_18.gml).
# [2018-09-21 18:31:05.995785]	Graph for century 19 built with 3242 nodes and 2911 edges (see graphs/century_ppn_19.gml).
# [2018-09-21 18:31:05.998867]	Graph for century 20 built with 5 nodes and 4 edges (see graphs/century_ppn_20.gml).
# [2018-09-21 18:31:21.726902]	Graph for all centuries built with 151603 nodes and 148165 edges (see graphs/all_centuries_ppn.gml).
# [2018-09-21 18:31:21.727706]	Done.

# %%
# takes ca. 45 min for a graph built with 16368 nodes and 18539 edges on my MacBook Pro, i.e., with the full data set
# with http://networkx.github.io/documentation/latest/reference/generated/networkx.drawing.layout.spring_layout.html#networkx.drawing.layout.spring_layout
# theory behind it: https://en.wikipedia.org/wiki/Force-directed_graph_drawing
#printLog("Preparing to draw...")

#nx.draw(G)
#plt.savefig("graph.pdf")
#printLog("Done.")

# %% [markdown]
# * generic graph building with all sorts of attributes

# %%
def createGenericGraph(consideredDataFrame):
    # for testing purposes it is handy to limit the number of records
    #consideredDataFrame=consideredDataFrame[(consideredDataFrame.Year>=1961) & (consideredDataFrame.Year<1975)]

    # create an empty graph from the nx (networkx) package imported above
    G=nx.Graph()

    rowCount=0
    seenCreators=[]
    seenLocations=[]
    # [u'PPN', u'alternative', u'creator', u'dataProvider', u'date', 
    # u'description', u'format', u'identifier', u'isShownAt', u'issued', 
    # u'object', u'provider', u'publisher', u'relation', u'rights', u'source', 
    # u'spatial', u'subject', u'title', u'type', u'spatialClean', u'dateClean', 
    # u'spatialCluster', u'spatialClusterName', u'latitude', u'longitude', u'century']
    ignoreList=[u'rights', u'issued',u'source',u'spatial',u'dataProvider', u'date',u'format',u'spatialCluster',u'century', u'provider']
    for row in consideredDataFrame.iterrows():#itertuples(): 
        ppn=val=row[1]["PPN"]
        G.add_node(ppn)
        G.node[ppn]['name'] = ppn
        G.node[ppn]['type'] = "PPN"
            
        keys=row[1].keys()
        for k in keys:
            elementEmpty=False
            if k not in ignoreList:
                #print k
                val=row[1][k]
                if val: 
                    if type(val) is float:
                        if not math.isnan(val):
                            #print row[1][k]
                            pass
                        else:
                            #print "I DON'T KNOW!"
                            elementEmpty=True
                    else:
                        #print row[1][k]
                        pass
                else:
                    #print "I DON'T KNOW!"
                    elementEmpty=True
                
                # only process non-empty elements
                if not elementEmpty:
                    if not val in G.nodes():
                        G.add_node(val)
                        G.node[val]['name'] = val
                        G.node[val]['type'] = k
                    
                    G.add_edge(ppn,val)
            
        # spatialClean auf spatialClusterName binden, den rest dann mit spatialClusterName
        # spatialClusterName erhält als Attribut latitude/longitude

       

    return G

printLog("Building general graph...")
generalG=createGenericGraph(df4)
printLog("Done.")
# Out:
# [2018-09-21 19:21:07.685507]	Building general graph...
# [2018-09-21 19:21:37.204767]	Done.

# %%
if allowComputationallyExtensiveCalculations:
    printLog("Creating graphs incl. PPNs...")

    graphsPerCentury=dict()
    for century in range(7,21):#(7,21): # we know that there are only media from the 7th century on
        if century in grpCentury.groups:
            centDF=grpCentury.get_group(century)
            returnedGraph=createGenericGraph(centDF)
            graphsPerCentury[century]=returnedGraph
            gmlPath="graphs/generics/full_"+str(century)+".gml"
            # export as GraphML, which can be read by Gephi
            nx.write_gml(returnedGraph,gmlPath)
            printLog("Graph for century %i built with %i nodes and %i edges (see %s)."%(century, len(returnedGraph.nodes()),len(returnedGraph.edges()),gmlPath))
    printLog("Done.")
# Out:
# [2018-09-21 19:17:11.073664]	Creating graphs incl. PPNs...
# [2018-09-21 19:17:11.077834]	Graph for century 7 built with 12 nodes and 12 edges (see graphs/generics/full_7.gml).
# [2018-09-21 19:17:11.080331]	Graph for century 10 built with 10 nodes and 10 edges (see graphs/generics/full_10.gml).
# [2018-09-21 19:17:11.082608]	Graph for century 11 built with 10 nodes and 10 edges (see graphs/generics/full_11.gml).
# [2018-09-21 19:17:11.090563]	Graph for century 12 built with 101 nodes and 143 edges (see graphs/generics/full_12.gml).
# [2018-09-21 19:17:11.098722]	Graph for century 13 built with 102 nodes and 158 edges (see graphs/generics/full_13.gml).
# [2018-09-21 19:17:11.220610]	Graph for century 14 built with 1741 nodes and 3793 edges (see graphs/generics/full_14.gml).
# [2018-09-21 19:17:15.234558]	Graph for century 15 built with 49224 nodes and 137451 edges (see graphs/generics/full_15.gml).
# [2018-09-21 19:17:21.059076]	Graph for century 16 built with 77100 nodes and 199143 edges (see graphs/generics/full_16.gml).
# [2018-09-21 19:17:47.463524]	Graph for century 17 built with 344718 nodes and 939795 edges (see graphs/generics/full_17.gml).
# [2018-09-21 19:17:53.434532]	Graph for century 18 built with 83951 nodes and 217053 edges (see graphs/generics/full_18.gml).
# [2018-09-21 19:17:54.222466]	Graph for century 19 built with 12493 nodes and 27146 edges (see graphs/generics/full_19.gml).
# [2018-09-21 19:17:54.227014]	Graph for century 20 built with 22 nodes and 29 edges (see graphs/generics/full_20.gml).
# [2018-09-21 19:17:54.227441]	Done.

# %%
grpCentury.get_group(17).count()
# Out:
# object                66257
# type                  75665
# identifier            75665
# rights                75665
# title                 75665
# format                75665
# source                75665
# provider              75665
# isShownAt             75660
# dataProvider          75665
# creator               61394
# subject               75665
# spatial               56105
# issued                20416
# date                  20416
# alternative           18449
# publisher             30420
# relation              14030
# description            5149
# PPN                   75665
# spatialClean          75581
# dateClean             75665
# spatialCluster        75665
# spatialClusterName    75581
# latitude              46614
# longitude             46614
# century               75665
# textCluster           75665
# creatorCluster        75665
# dtype: int64

# %% [markdown]
# ## Exploring the Collection by Visual Content
#
# __ATTENTION__  __The following cells are no longer working as they rely on external Java programs. Currently, this part of the notebook is ported to a Python-only solution.__
#
#
# * reading the feature files takes approx. 12 min
# * https://en.wikipedia.org/wiki/Bag-of-words_model_in_computer_vision
#
# ![Visual Words](img/visword.jpg)
# By Masterwaw - Own work, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=19645418
#
# Scale-invariant feature transform, reference for local feature detection
#
# ![Visual Word Generation](img/visword_generation2.png)
#
# int sampleDocumentsToCreateCodebook = 5000;
# int numberOfClusters = 1000;
#
# next step takes ca. 40 minutes if the raw features are loaded from disk and converted

# %%
featureBaseDir="/Users/david/Documents/src/python/CulturalAnalytics/featureFiles.5k1k/"
missingPPNs=[]
readPPNs=[]
featuresPPN=[]
featsPerCentury=dict()
readPpnPerCentury=dict()

printLog("Loading features...")
if reinterpretVisualWordRawFeatures:
    for century in range(7,21):
        if century in grpCentury.groups:
            featsPerCentury[century]=[]
    for century in range(7,21):
        if century in grpCentury.groups:
            readPpnPerCentury[century]=[]

    index=0
    for row in df4.iterrows():
        index=index+1
        if index%10000==0:
            printLog("Processed %i documents."%index)
        ppn=str(row[1]["PPN"])
        if os.path.isfile(featureBaseDir+ppn+".csv"):
            #print ppn+" okay."
            featFile=open(featureBaseDir+ppn+".csv")
            for line in featFile:
                feature=line
            tokens=feature.split()
            harray=[]
            for t in tokens:
                harray.append(int(t,16))
            featFile.close()

            readPPNs.append(ppn)
            featuresPPN.append(np.array(harray,dtype=np.uint8))
            # check to which century the feature belongs
            for century in range(7,21):
                if century in grpCentury.groups:
                    if ppn in ppnPerCentury[century]:
                        readPpnPerCentury[century].append(ppn)
                        featsPerCentury[century].append(np.array(harray,dtype=np.uint8))
        else:
            missingPPNs.append(ppn)
    printLog("Done.")
    printLog("Number of missing PPNs: %i"%len(missingPPNs))
    
    # pickling takes about 15 minutes
    pickleCompress('./picklez/missingPPNs.picklez',missingPPNs)
    pickleCompress('./picklez/readPPNs.picklez',readPPNs)
    pickleCompress('./picklez/featuresPPN.picklez',featuresPPN)
    pickleCompress('./picklez/featsPerCentury.picklez',featsPerCentury)
    pickleCompress('./picklez/readPpnPerCentury.picklez',readPpnPerCentury)
    printLog("Pickling completed.")
else:
    # takes about 1 minute
    missingPPNs=pickleDecompress('./picklez/missingPPNs.picklez')
    readPPNs=pickleDecompress('./picklez/readPPNs.picklez')
    featuresPPN=pickleDecompress('./picklez/featuresPPN.picklez')
    featsPerCentury=pickleDecompress('./picklez/featsPerCentury.picklez')
    readPpnPerCentury=pickleDecompress('./picklez/readPpnPerCentury.picklez')
    printLog("Loading from disk completed.")
# Out:
# [2018-09-21 18:33:37.644692]	Loading features...
# [2018-09-21 18:33:38.576238]	Processed 10000 documents.
# [2018-09-21 18:33:39.265102]	Processed 20000 documents.
# [2018-09-21 18:33:39.957706]	Processed 30000 documents.
# [2018-09-21 18:33:40.629747]	Processed 40000 documents.
# [2018-09-21 18:33:41.280013]	Processed 50000 documents.
# [2018-09-21 18:33:41.947751]	Processed 60000 documents.
# [2018-09-21 18:33:42.609890]	Processed 70000 documents.
# [2018-09-21 18:33:43.274009]	Processed 80000 documents.
# [2018-09-21 18:33:43.963435]	Processed 90000 documents.
# [2018-09-21 18:33:44.655070]	Processed 100000 documents.
# [2018-09-21 18:33:45.335903]	Processed 110000 documents.
# [2018-09-21 18:33:46.026409]	Processed 120000 documents.
# [2018-09-21 18:33:46.032097]	Done.
# [2018-09-21 18:33:46.032923]	Number of missing PPNs: 120000
# [2018-09-21 18:33:46.033349]	Pickling to './picklez/missingPPNs.picklez'
# [2018-09-21 18:33:46.796293]	Pickling done.
# [2018-09-21 18:33:46.796836]	Pickling to './picklez/readPPNs.picklez'
# [2018-09-21 18:33:46.798114]	Pickling done.
# [2018-09-21 18:33:46.798653]	Pickling to './picklez/featuresPPN.picklez'
# [2018-09-21 18:33:46.800756]	Pickling done.
# [2018-09-21 18:33:46.801479]	Pickling to './picklez/featsPerCentury.picklez'
# [2018-09-21 18:33:46.803081]	Pickling done.
# [2018-09-21 18:33:46.803735]	Pickling to './picklez/readPpnPerCentury.picklez'
# [2018-09-21 18:33:46.804551]	Pickling done.
# [2018-09-21 18:33:46.804989]	Pickling completed.

# %% [markdown]
# * Clustering of 101031 elements started with 1000 as cluster target size: 3 min
# * note that the cluster labels vary for each run

# %%
# working with all features will most likely halt your computer because of the memory consumption if you use KMeans!
feats=featuresPPN#[:20000] 

# define the number of clusters to be found
true_k=1000
printLog("Clustering of %i elements started with %i as cluster target size."%(len(feats),true_k))
# initialize the k-means algorithm
#km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
# we will rely on the mini batch k-means algorithm due to performance consideration otherwise your computer might crash...
km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)

# apply the algorithm on the data
km.fit(feats)
printLog("Clustering finished.")
km.labels_
# Out:
# [2018-09-21 18:33:52.606315]	Clustering of 0 elements started with 1000 as cluster target size.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-254-36e47381e0b8> in <module>()
#      11
#      12 # apply the algorithm on the data
# ---> 13 km.fit(feats)
#      14 printLog("Clustering finished.")
#      15 km.labels_
#
# /anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y)
#    1352         random_state = check_random_state(self.random_state)
#    1353         X = check_array(X, accept_sparse="csr", order='C',
# -> 1354                         dtype=[np.float64, np.float32])
#    1355         n_samples, n_features = X.shape
#    1356         if n_samples < self.n_clusters:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
saveDir="/Users/david/Documents/src/python/CulturalAnalytics/html/_clusteroverview_allcents/"
if not os.path.exists(saveDir):
        os.makedirs(saveDir)
        
imgDir="file:///Users/david/Documents/src/python/CulturalAnalytics/web/thumbnails/"
#imgDir="file:///Volumes/2TB_WD/sbb_images/tmp/"
htmlHead="<html><head></head><body bgcolor='#000000'>"
htmlTail="</body></html>"
clusters=dict()
for i,val in enumerate(km.labels_):
    if val not in clusters:
        clusters[val]=[]
    clusters[val].append(readPPNs[i])
#print clusters
for i in clusters:
    htmlOut=open(saveDir+str(i)+".html","w")
    htmlOut.write(htmlHead+"\n")
    htmlOut.write("<a href='"+str(i-1)+".html'>last</a> &nbsp;"+"<a href='"+str(i+1)+".html'>next</a>\n"+"<br />")
    for ppn in clusters[i]:
        htmlOut.write("<img width='170' src='"+imgDir+ppn+".jpg' />\n")
    htmlOut.write(htmlTail)
    htmlOut.close()

# %% [markdown]
# repeat the same step for each century...

# %%
clustersPerCentury=dict()
maxClusterAmount=100
printLog("Starting clustering per century...")
for century in featsPerCentury:
    maxClusters=len(featsPerCentury[century])
    # define the number of clusters to be found
    true_k=int(maxClusters*0.1+1)
    # restrict the number of clusters to prevent extremely large clusters
    if true_k>(maxClusterAmount*2):
        true_k=maxClusterAmount+int(maxClusters*0.005)
    elif true_k>maxClusterAmount:
        true_k=maxClusterAmount+int(maxClusters*0.01)
    printLog("Clustering of %i element(s) started with %i as cluster target size for century %i."%(maxClusters,true_k,century))
    # initialize the k-means algorithm
    #km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
    # we will rely on the mini batch k-means algorithm due to performance consideration otherwise your computer might crash...
    km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)

    # apply the algorithm on the data
    km.fit(featsPerCentury[century])
    clustersPerCentury[century]=km.labels_
printLog("Clustering finished.")
# Out:
# [2017-02-23 09:23:12.374375]	Starting clustering per century...
# [2017-02-23 09:23:12.377891]	Clustering of 1 element(s) started with 1 as cluster target size for century 7.
# [2017-02-23 09:23:12.497396]	Clustering of 1 element(s) started with 1 as cluster target size for century 10.
# [2017-02-23 09:23:12.624215]	Clustering of 1 element(s) started with 1 as cluster target size for century 11.
# [2017-02-23 09:23:12.764276]	Clustering of 14 element(s) started with 2 as cluster target size for century 12.
# [2017-02-23 09:23:12.932725]	Clustering of 14 element(s) started with 2 as cluster target size for century 13.
# [2017-02-23 09:23:13.235309]	Clustering of 282 element(s) started with 29 as cluster target size for century 14.
# [2017-02-23 09:23:13.807443]	Clustering of 7394 element(s) started with 136 as cluster target size for century 15.
# [2017-02-23 09:23:19.136269]	Clustering of 10653 element(s) started with 153 as cluster target size for century 16.
# [2017-02-23 09:23:21.678045]	Clustering of 66099 element(s) started with 430 as cluster target size for century 17.
# /Users/david/anaconda/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:1381: RuntimeWarning: init_size=300 should be larger than k=430. Setting it to 3*k
#   init_size=init_size)
# [2017-02-23 09:24:09.769616]	Clustering of 14107 element(s) started with 170 as cluster target size for century 18.
# [2017-02-23 09:24:14.378635]	Clustering of 1937 element(s) started with 119 as cluster target size for century 19.
# [2017-02-23 09:24:15.470580]	Clustering of 2 element(s) started with 1 as cluster target size for century 20.
# [2017-02-23 09:24:15.628998]	Clustering finished.

# %% [markdown]
# Computing 'centroids' takes up to 6 minutes;

# %%
clusterCentroidsPerCentury=dict()
numberCentroids=0

printLog("Computing 'centroids' for...")

for century in clustersPerCentury:
    printLog("\tcentury %i"%century)
    clusters=dict()
    centFeats=dict()

    for i,val in enumerate(clustersPerCentury[century]):
        if val not in centFeats:
            centFeats[val]=[]
        if val not in clusters:
            clusters[val]=[]
        index=readPPNs.index(readPpnPerCentury[century][i])
        clusters[val].append(readPpnPerCentury[century][i])
        centFeats[val].append(featuresPPN[index])

    clusterCentroidsPerCentury[century]=dict()
    for cluster in centFeats:
        r=centFeats[cluster]
        meanDistances=[]
        D=pairwise_distances(r,r)
        #A distance matrix D such that D_{i, j} is the distance between the ith and jth vectors of the given matrix X, if Y is None.
        #If Y is not None, then D_{i, j} is the distance between the ith array from X and the jth array from Y.
        # distance between element 0 and 13 (=0.0 if X and Y are anti-correlated)
        #D[0][13]
        for row in D:
            # each row in D stands for one document and its distances to all other documents
            # by calculating its mean, we compute how dissimilar this document is to all others
            meanDistances.append(np.mean(row))
        #print meanDistances
        minVal=np.min(meanDistances)
        index=meanDistances.index(minVal)
        clusterCentroidsPerCentury[century][cluster]=clusters[cluster][index]
        numberCentroids=numberCentroids+1
        #print str(cluster)+": "+str(clusters[cluster][index])+" (of %i elements)"%len(meanDistances)

printLog("Done computing %i 'centroids'."%numberCentroids)
# Out:
# [2017-02-23 09:27:37.380166]	Computing 'centroids' for...
# [2017-02-23 09:27:37.382053]		century 7
# [2017-02-23 09:27:38.907449]		century 10
# [2017-02-23 09:27:38.913100]		century 11
# [2017-02-23 09:27:38.918848]		century 12
# [2017-02-23 09:27:38.950573]		century 13
# [2017-02-23 09:27:38.984115]		century 14
# [2017-02-23 09:27:39.705281]		century 15
# [2017-02-23 09:28:01.171028]		century 16
# [2017-02-23 09:28:38.395726]		century 17
# [2017-02-23 09:33:52.215362]		century 18
# [2017-02-23 09:34:38.614388]		century 19
# [2017-02-23 09:34:43.097367]		century 20
# [2017-02-23 09:34:43.108393]	Done computing 1041 'centroids'.

# %% [markdown]
# * iterate over all centuries and save output per centroids
# * CSV output is for the visualization with the web-based QA tools

# %%
printLog("Creating HTML and CSV output...")

# limits the shown PPNs per century-separated cluster
limitClusterCentroidsPerCentury=10
# for the cluster detail views limitClusterCentroidsPerCentury*centuryLimitFactor elements will be displayed per centroid
centuryLimitFactor=3

csvOut=open("/Users/david/Documents/src/python/CulturalAnalytics/web/qa/data/clusters.csv","w")
csvOut.write("id,value\n")
rootNode="all."
csvOut.write("all,"+"\n")

for century in clustersPerCentury:
    largestClusterSize=0
    largestCluster=None
    
    csvCenturyOut=open("/Users/david/Documents/src/python/CulturalAnalytics/web/qa/data/"+str(century)+".csv","w")
    csvCenturyOut.write("id,value\n")
    rootCenturyNode="all"
    csvCenturyOut.write(rootCenturyNode+","+"\n")
    
    csvOut.write("all."+str(century)+","+"\n")
    
    saveDir="/Users/david/Documents/src/python/CulturalAnalytics/html/_clusteroverview_per_century/"+str(century)+"/"
    if not os.path.exists(saveDir):
        os.makedirs(saveDir)
    imgDir="file:///Users/david/Documents/src/python/CulturalAnalytics/web/thumbnails/"
    #imgDir="file:///Volumes/2TB_WD/sbb_images/tmp/"
    htmlHead="<html><head></head><body bgcolor='#000000'>"
    htmlTail="</body></html>"
    
    clusters=dict()
    for i,val in enumerate(clustersPerCentury[century]):
        if val not in clusters:
            clusters[val]=[]
        clusters[val].append(readPpnPerCentury[century][i])
        

    clusterSizes=[]
    shownCentroidCount=0
    shownMoreCentroidsAvailable=False
    
    noClustersInCentury=len(clusters)
    for i in clusters:
        clusterSizes.append(len(clusters[i]))
        
        if largestClusterSize<len(clusters[i]):
            largestClusterSize=len(clusters[i])
            largestCluster=i
        
        # the cluster's centroid
        # 14/14: PPN789774356
        #<br/>
        #<img src='file:///Users/david/Documents/src/python/CulturalAnalytics/tmp/PPN789774356.jpg' />
        #print "\tCentroid for cluster "+str(i)+": "+str(clusterCentroidsPerCentury[century][i])
        centroid="<img src='"+imgDir+str(clusterCentroidsPerCentury[century][i])+".jpg' />\n"+"<br/>\n"
    
        if shownCentroidCount<limitClusterCentroidsPerCentury:
            shownCentroidCount=shownCentroidCount+1
            csvOut.write(rootNode+str(century)+"."+str(clusterCentroidsPerCentury[century][i])+",\n")
        else:
            if not shownMoreCentroidsAvailable:
                csvOut.write(rootNode+str(century)+".more,\n")
                shownMoreCentroidsAvailable=True
                
        csvCenturyOut.write(rootCenturyNode+"."+str(clusterCentroidsPerCentury[century][i])+",\n")
        
        
        
        htmlOut=open(saveDir+str(i)+".html","w")
        htmlOut.write(htmlHead+"\n")
        #htmlOut.write("<a href='"+str(century)+str(i-1)+".html'>last</a> &nbsp;"+"<a href='"+str(century)+str(i+1)+".html'>next</a>\n"+"<br />")
        htmlOut.write("<a href='"+str(i-1)+".html'>last</a> &nbsp;"+"<a href='"+str(i+1)+".html'>next</a>\n"+"<br />")
        
        htmlOut.write(centroid)
        
        centroidPPN=str(clusterCentroidsPerCentury[century][i])#str(clusters[i][0])
        csvPPNOut=open("/Users/david/Documents/src/python/CulturalAnalytics/web/qa/data/"+centroidPPN+".csv","w")
        csvPPNOut.write("id,value\n")
        rootPPNNode="all"
        csvPPNOut.write(rootPPNNode+","+"\n")
        csvPPNOut.write(rootPPNNode+"."+centroidPPN+",\n")
        ppnCount=0
    
        for ppn in clusters[i]:
            htmlOut.write("<img width='170' src='"+imgDir+ppn+".jpg' alt='"+ppn+"'/>\n")
            #csvOut.write(rootNode+str(century)+"."+str(clusterCentroidsPerCentury[century][i])+"."+ppn+",\n")
            if ppnCount<limitClusterCentroidsPerCentury*centuryLimitFactor:
                ppnCount=ppnCount+1
                csvCenturyOut.write(rootCenturyNode+"."+str(clusterCentroidsPerCentury[century][i])+"."+ppn+",\n")
            else:
                csvCenturyOut.write(rootCenturyNode+"."+str(clusterCentroidsPerCentury[century][i])+".more,\n")
                break
            
            csvPPNOut.write(rootPPNNode+"."+centroidPPN+"."+ppn+",\n")
        csvPPNOut.close()
        htmlOut.write(htmlTail)
        htmlOut.close()
    
    csvCenturyOut.close()
    print("\tLargest cluster for century %i is %i with %i elements."%(century,largestCluster,largestClusterSize))
    print("\t\tNumber of clusters: %i"%noClustersInCentury)
    print("\t\tMean cluster size: %s"%str(np.mean(clusterSizes)))
    print("\t\tCluster size standard deviation: %s"%str(np.std(clusterSizes)))
    print("\t\tMin. cluster size: %s"%str(np.amin(clusterSizes)))
    print("\t\tMax. cluster size: %s"%str(np.amax(clusterSizes)))
csvOut.close()
printLog("Done.")
# Out:
# [2017-02-23 09:35:02.373993]	Creating HTML and CSV output...
# 	Largest cluster for century 7 is 0 with 1 elements.
# 		Number of clusters: 1
# 		Mean cluster size: 1.0
# 		Cluster size standard deviation: 0.0
# 		Min. cluster size: 1
# 		Max. cluster size: 1
# 	Largest cluster for century 10 is 0 with 1 elements.
# 		Number of clusters: 1
# 		Mean cluster size: 1.0
# 		Cluster size standard deviation: 0.0
# 		Min. cluster size: 1
# 		Max. cluster size: 1
# 	Largest cluster for century 11 is 0 with 1 elements.
# 		Number of clusters: 1
# 		Mean cluster size: 1.0
# 		Cluster size standard deviation: 0.0
# 		Min. cluster size: 1
# 		Max. cluster size: 1
# 	Largest cluster for century 12 is 1 with 13 elements.
# 		Number of clusters: 2
# 		Mean cluster size: 7.0
# 		Cluster size standard deviation: 6.0
# 		Min. cluster size: 1
# 		Max. cluster size: 13
# 	Largest cluster for century 13 is 0 with 13 elements.
# 		Number of clusters: 2
# 		Mean cluster size: 7.0
# 		Cluster size standard deviation: 6.0
# 		Min. cluster size: 1
# 		Max. cluster size: 13
# 	Largest cluster for century 14 is 3 with 221 elements.
# 		Number of clusters: 29
# 		Mean cluster size: 9.72413793103
# 		Cluster size standard deviation: 40.016286815
# 		Min. cluster size: 1
# 		Max. cluster size: 221
# 	Largest cluster for century 15 is 12 with 1592 elements.
# 		Number of clusters: 136
# 		Mean cluster size: 54.3676470588
# 		Cluster size standard deviation: 245.914434211
# 		Min. cluster size: 1
# 		Max. cluster size: 1592
# 	Largest cluster for century 16 is 25 with 4711 elements.
# 		Number of clusters: 153
# 		Mean cluster size: 69.6274509804
# 		Cluster size standard deviation: 483.522125162
# 		Min. cluster size: 1
# 		Max. cluster size: 4711
# 	Largest cluster for century 17 is 164 with 9894 elements.
# 		Number of clusters: 430
# 		Mean cluster size: 153.718604651
# 		Cluster size standard deviation: 1003.38815202
# 		Min. cluster size: 1
# 		Max. cluster size: 9894
# 	Largest cluster for century 18 is 12 with 6164 elements.
# 		Number of clusters: 169
# 		Mean cluster size: 83.4733727811
# 		Cluster size standard deviation: 586.583903058
# 		Min. cluster size: 1
# 		Max. cluster size: 6164
# 	Largest cluster for century 19 is 113 with 1171 elements.
# 		Number of clusters: 116
# 		Mean cluster size: 16.6982758621
# 		Cluster size standard deviation: 117.181940752
# 		Min. cluster size: 1
# 		Max. cluster size: 1171
# 	Largest cluster for century 20 is 0 with 2 elements.
# 		Number of clusters: 1
# 		Mean cluster size: 2.0
# 		Cluster size standard deviation: 0.0
# 		Min. cluster size: 2
# 		Max. cluster size: 2
# [2017-02-23 09:35:08.583488]	Done.

# %% [markdown]
# ### A Visual Timeline of Publications
# plotting of the "centroids"

# %%
imgDir="file:///Users/david/Documents/src/python/CulturalAnalytics/web/thumbnails/"
htmlHead="<html><head></head><body bgcolor='#000000'>"
htmlTail="</body></html>"
centroidPath="html/_centroids.html"

printLog("Saving centroid overview HTML page at: "+centroidPath)
htmlOut=open(centroidPath,"w")
htmlOut.write(htmlHead)
for century in clustersPerCentury:
    htmlOut.write("<h1 style='color:white;'>"+str(century)+"</h1>\n")
    for centroid in clusterCentroidsPerCentury[century]:
        htmlOut.write("<img width='170' src='"+imgDir+clusterCentroidsPerCentury[century][centroid]+".jpg' />\n")
htmlOut.write(htmlTail)
htmlOut.close()
printLog("Done.")
# Out:
# [2017-02-23 09:35:14.962704]	Saving centroid overview HTML page at: html/_centroids.html
# [2017-02-23 09:35:14.973050]	Done.

# %% [markdown]
# we can also extend the idea and create a graph of the data
# to base a nice visualization of the clusters...

# %%
printLog("Creating overview graph...")
G=nx.Graph()

lastCentury="7"
for century in clustersPerCentury: 
#for century in [7,10,11,12,13,14,15,16]:#range(12,15):
    strCentury=str(century)
    G.add_node(strCentury)
    G.node[strCentury]['name'] = strCentury
    G.node[strCentury]['type'] = "century"
    
    for centroid in clusterCentroidsPerCentury[century]:
        ppn=str(clusterCentroidsPerCentury[century][centroid])
        imagePath=imgDir.replace("file://","")+ppn+".jpg"
        G.add_node(ppn)
        G.node[ppn]['name'] = ppn
        if os.path.isfile(imagePath):
            G.node[ppn]['name'] = ppn
            G.node[ppn]['imagePath'] = ppn
        else:
            G.node[ppn]['name'] = ppn
            G.node[ppn]['imagePath'] = "none"
        G.node[ppn]['title'] = ppnLookup[ppn]['title']
        G.node[ppn]['creator'] = ppnLookup[ppn]['creator']
        if ppnLookup[ppn]['spatialClusterName']:
            G.node[ppn]['location'] = ppnLookup[ppn]['spatialClusterName']
        G.node[ppn]['locationRaw'] =ppnLookup[ppn]['spatialRaw']
        
        G.node[ppn]['mediatype'] =ppnLookup[ppn]['mediatype']
        G.node[ppn]['subject'] =ppnLookup[ppn]['subject']
        G.node[ppn]['source'] =ppnLookup[ppn]['source']
        G.node[ppn]['publisher'] =ppnLookup[ppn]['publisher']
        G.node[ppn]['alternative'] =ppnLookup[ppn]['alternative']
            
        G.node[ppn]["century"]=century
        G.node[ppn]['dateClean'] =ppnLookup[ppn]['dateClean']
        G.node[ppn]["cluster"]=str(centroid)
        G.node[ppn]['lat']=ppnLookup[ppn]['lat']
        G.node[ppn]['lng']=ppnLookup[ppn]['lng']
        G.node[ppn]['type'] = "image"
        G.node[ppn]['textCluster'] =ppnLookup[ppn]['textCluster']
        G.node[ppn]['creatorCluster'] =ppnLookup[ppn]['creatorCluster']
        
        G.add_edge(strCentury,ppn)
    G.add_edge(strCentury,lastCentury)
    lastCentury=strCentury
    
nx.write_gml(G,"graphs/century.gml")
d = json_graph.node_link_data(G)
jsonPath='./web/force/century.json'
#jsonPath='./force/century_test.json'
json.dump(d, open(jsonPath,'w'))
printLog("Done (see %s)."%jsonPath)
# Out:
# [2017-02-23 09:35:20.356380]	Creating overview graph...
# [2017-02-23 09:35:22.667366]	Done (see ./web/force/century.json).

# %%
printLog("Creating cluster graph output...")
for century in clustersPerCentury:
    printLog("Processing century "+str(century))
    saveDir="/Users/david/Documents/src/python/CulturalAnalytics/force/clusters/"+str(century)+"/"
    if not os.path.exists(saveDir):
        os.makedirs(saveDir)
    imgDir="file:///Users/david/Documents/src/python/CulturalAnalytics/tmp/"

    clusters=dict()
    for i,val in enumerate(clustersPerCentury[century]):
        if val not in clusters:
            clusters[val]=[]
        clusters[val].append(readPpnPerCentury[century][i])

    for i in clusters:
        G=nx.Graph()
        # the cluster's centroid
        centroid=str(clusterCentroidsPerCentury[century][i])
        G.add_node(centroid)
        G.node[centroid]['type'] = "centroid"
        
        for ppn in clusters[i]:
            imagePath=imgDir.replace("file://","")+ppn+".jpg"
            #dateClean=str(df4[df4.PPN==ppn].iloc[-1]['dateClean'])
            dateClean=ppnLookup[ppn]["dateClean"]
            G.add_node(dateClean)
            G.node[dateClean]['name'] = dateClean
            G.node[dateClean]['type'] = "dateClean"
            G.add_edge(centroid,dateClean)
            
            G.add_node(ppn)
            G.node[ppn]['name'] = ppn
            if os.path.isfile(imagePath):
                G.node[ppn]['name'] = ppn
                G.node[ppn]['imagePath'] = ppn
            else:
                G.node[ppn]['name'] = ppn
                G.node[ppn]['imagePath'] = "none"
            #G.node[ppn]['title'] = df4[df4.PPN==ppn].iloc[-1]['title']
            #G.node[ppn]['creator'] = str(df4[df4.PPN==ppn].iloc[-1]['creator'])
            #G.node[ppn]['location'] = df4[df4.PPN==ppn].iloc[-1]['spatialClusterName']
            G.node[ppn]['title'] = ppnLookup[ppn]["title"]
            G.node[ppn]['creator'] = ppnLookup[ppn]["creator"]
            if ppnLookup[ppn]["spatialClusterName"]:
                G.node[ppn]['location'] = ppnLookup[ppn]["spatialClusterName"]
            else:
                G.node[ppn]['location']="none"
            G.node[ppn]['locationRaw'] =ppnLookup[ppn]['spatialRaw']
            
            G.node[ppn]['mediatype'] =ppnLookup[ppn]['mediatype']
            G.node[ppn]['subject'] =ppnLookup[ppn]['subject']
            G.node[ppn]['source'] =ppnLookup[ppn]['source']
            G.node[ppn]['publisher'] =ppnLookup[ppn]['publisher']
            G.node[ppn]['alternative'] =ppnLookup[ppn]['alternative']
            G.node[ppn]['dateClean'] =ppnLookup[ppn]['dateClean']
            G.node[ppn]['lat']=ppnLookup[ppn]['lat']
            G.node[ppn]['lng']=ppnLookup[ppn]['lng']
            
            if ppn==centroid:
                G.node[centroid]['type'] = "centroid"
            else:
                G.node[ppn]['type'] = "image"
            
            G.add_edge(dateClean,ppn)
            
        nx.write_gml(G,saveDir+str(i)+".gml")
        d = json_graph.node_link_data(G)
        jsonPath='./web/force/clusters/'+str(century)+'/'+str(i)+'.json'
        json.dump(d, open(jsonPath,'w'))
printLog("Done.")
# Out:
# [2017-02-23 09:35:30.870204]	Creating cluster graph output...
# [2017-02-23 09:35:30.872317]	Processing century 7
# [2017-02-23 09:35:30.890249]	Processing century 10
# [2017-02-23 09:35:30.902293]	Processing century 11
# [2017-02-23 09:35:30.910687]	Processing century 12
# [2017-02-23 09:35:30.935608]	Processing century 13
# [2017-02-23 09:35:30.966658]	Processing century 14
# [2017-02-23 09:35:31.813593]	Processing century 15
# [2017-02-23 09:35:39.801221]	Processing century 16
# [2017-02-23 09:35:45.973394]	Processing century 17
# [2017-02-23 09:36:13.171219]	Processing century 18
# [2017-02-23 09:36:19.670819]	Processing century 19
# [2017-02-23 09:36:21.142212]	Processing century 20
# [2017-02-23 09:36:21.159243]	Done.

# %% [markdown]
# ## Geospatial Extravaganza

# %%
# points are latitude, longitude
# Latitudes range from -90 to 90.
# Longitudes range from -180 to 180
newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
test=(-95,-161)
x=vincenty(newport_ri, test)
print(x.kilometers)
# Out:
# 5425.501973149517

# %%
index=0
ppnPosition=[]
ppnPositionLabels=[]
ppnPositionSpatialClean=[]

printLog("Extracting latitude and longitude...")

for row in df4.iterrows():
    index=index+1
    if index%10000==0:
        printLog("Processed %i documents."%index)
    ppn=str(row[1]["PPN"])
    try:
        lat=float(row[1]["latitude"])
        lng=float(row[1]["longitude"])
        spatialClean=row[1]["spatialClean"]
        if math.isnan(lat) and math.isnan(lng):
            pass
        else:
            ppnPositionLabels.append(ppn)
            ppnPositionSpatialClean.append(spatialClean)
            ppnPosition.append((lat,lng))
    except TypeError:
        #print(row[1]["latitude"])
        pass
    
printLog("Found %i PPNs with coordinates." %len(ppnPositionLabels))
# Out:
# [2017-02-23 09:36:33.757551]	Extracting latitude and longitude...
# [2017-02-23 09:36:35.926724]	Processed 10000 documents.
# [2017-02-23 09:36:37.724667]	Processed 20000 documents.
# [2017-02-23 09:36:39.338387]	Processed 30000 documents.
# [2017-02-23 09:36:40.430643]	Processed 40000 documents.
# [2017-02-23 09:36:41.660233]	Processed 50000 documents.
# [2017-02-23 09:36:43.565882]	Processed 60000 documents.
# [2017-02-23 09:36:45.458732]	Processed 70000 documents.
# [2017-02-23 09:36:46.683881]	Processed 80000 documents.
# [2017-02-23 09:36:47.874280]	Processed 90000 documents.
# [2017-02-23 09:36:49.137197]	Processed 100000 documents.
# [2017-02-23 09:36:50.593702]	Processed 110000 documents.
# [2017-02-23 09:36:51.968182]	Processed 120000 documents.
# [2017-02-23 09:36:51.969022]	Found 83418 PPNs with coordinates.

# %%
plt.title('Distribution of Geo-Spatial Coordinates')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.scatter(*zip(*ppnPosition),alpha=0.1)
if saveFiguresAsPDF:
    plt.savefig('./figures/sample.pdf')

# %% [markdown]
# * Latitudes range from -90 to 90. -> x-Achse sollte 180 breit sein, Mitte ist 90
# * Longitudes range from -180 to 180 -> y-Achse sollte 360 breit sein, Mitte ist 180

# %%
feats=ppnPosition

# define the number of clusters to be found
true_k=30
printLog("Clustering of %i elements started with %i as cluster target size."%(len(feats),true_k))
# initialize the k-means algorithm
#km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
# we will rely on the mini batch k-means algorithm due to performance consideration otherwise your computer might crash...
km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)

# apply the algorithm on the data
km.fit(feats)
printLog("Clustering finished.")
km.labels_
# Out:
# [2017-02-23 09:37:31.506481]	Clustering of 83418 elements started with 30 as cluster target size.
# [2017-02-23 09:37:31.694850]	Clustering finished.
# array([ 8, 23, 23, ..., 13, 24,  0], dtype=int32)

# %% [markdown]
# bounding boxes from http://boundingbox.klokantech.com/

# %% [markdown]
# Visualization with GeoJSON (http://geojson.org/) https://pypi.python.org/pypi/geojson and OpenLayers  http://openlayers.org/en/latest/doc/ http://openlayers.org/en/latest/apidoc/

# %%
regions=["Europe","Africa","Asia","Australia","SouthAmerica","NorthAmerica"]
regionBoundingBox=dict()
#westlimit=-22.5; southlimit=33.6; eastlimit=58.4; northlimit=82.9
regionBoundingBox["Europe"]=[33.6,82.9,-22.5,58.4]
#africa westlimit=-22.9; southlimit=-63.7; eastlimit=58.0; northlimit=37.2
regionBoundingBox["Africa"]=[-63.7,37.2,-22.9,58.0]
#asia westlimit=29.5; southlimit=-11.4; eastlimit=-168.4; northlimit=81.2
regionBoundingBox["Asia"]=[-11.4,81.2,-168.4,29.5]
#australia westlimit=112.5; southlimit=-50.4; eastlimit=-162.9; northlimit=-10.0
regionBoundingBox["Australia"]=[-50.4,-10.0,-162.9,112.5]
#south america westlimit=-119.5; southlimit=-57.0; eastlimit=-29.9; northlimit=28.1
regionBoundingBox["SouthAmerica"]=[-57.0,28.1,-119.5,-29.9]
#north america westlimit=-169.1; southlimit=23.7; eastlimit=-20.0; northlimit=71.4
regionBoundingBox["NorthAmerica"]=[23.7,71.4,-169.1,-20.0]


# man muss checken in welchen intervallen die kontinente liegen, insb. bei 2 und 3
def getRegion(lat,lng):
    for region in regions:
        if region in regionBoundingBox:
            if regionBoundingBox[region][0] <= lat <= regionBoundingBox[region][1]:
                if regionBoundingBox[region][2] <= lng <= regionBoundingBox[region][3]:
                    return region

    return "other"

#print getRegion(51,10)

# %%
# combine all arrays and check if there is more than one location associated with a PPN
# ppnPosition is (lat,lng)
printLog("Creating GeoJSON data...")
multipleCitiesPPN=pickleDecompress("./picklez/multipleSpatialNamesPerPPN.picklez")

baseDir="/Users/david/Documents/src/python/CulturalAnalytics/web/qa/data/layers/"
fileName=baseDir+"test.json"
locationFeatures=dict()
locationFeaturesGlobal=[]

spots=zip(ppnPositionLabels, ppnPositionSpatialClean,ppnPosition)

for spot in spots:
    ppn=spot[0]
    leadingLoc=spot[1]
    latLng=spot[2]
    # GeoJSON points are in longitude , latitude but our storage is lat/lng
    my_point = gj.Point((latLng[1], latLng[0]))

    region=getRegion(latLng[0],latLng[1])
    if region not in locationFeatures:
        locationFeatures[region]=[]
        print("Adding "+region)
    else:
        locationFeatures[region].append(gj.Feature(geometry=my_point, properties={"title": leadingLoc+" "+ppn, "ppn":ppn}))
    
    locationFeaturesGlobal.append(gj.Feature(geometry=my_point, properties={"title": leadingLoc+" "+ppn, "ppn":ppn}))
    #print ppn
    if ppn in multipleCitiesPPN:
        array=multipleCitiesPPN[ppn]
        #if there are alternative locations for this PPN
        if len(array)>1:
            #print leadingLoc+" "+ppn
            #print "\t"+"; ".join(array).encode("utf-8")
            pass

for region in locationFeatures:
    geoJSON_collection=gj.FeatureCollection(locationFeatures[region])
    dump = gj.dumps(geoJSON_collection, sort_keys=True)

    jsonFile = open(baseDir+region.lower()+".json", "w")
    jsonFile.write(dump)
    jsonFile.close()
    

geoJSON_collection=gj.FeatureCollection(locationFeaturesGlobal)
dump = gj.dumps(geoJSON_collection, sort_keys=True)

globalJSONPath=baseDir+"global.json"
jsonFile = open(globalJSONPath, "w")
jsonFile.write(dump)
jsonFile.close()
printLog("Serialized %i metadata records.\n\tSaved global JSON document at %s." %(len(locationFeaturesGlobal),globalJSONPath))

printLog("Done.")
# Out:
# [2017-02-23 09:37:51.578663]	Creating GeoJSON data...
# [2017-02-23 09:37:51.580057]	Depickling from './picklez/multipleSpatialNamesPerPPN.picklez'
# [2017-02-23 09:37:51.788285]	Depickling done.
# Adding Europe
# Adding Africa
# Adding other
# Adding Asia
# Adding Australia
# [2017-02-23 09:37:55.285860]	Serialized 83418 metadata records.
# 	Saved global JSON document at /Users/david/Documents/src/python/CulturalAnalytics/web/qa/data/layers/global.json.
# [2017-02-23 09:37:55.286687]	Done.

# %%
#print spots.index("PPN766441857")
#print(spots[10])
#print(getRegion(spots[10][2][0],spots[10][2][1]))

# %%
# we will create an inverted mapping from alternative location names to "leading" location names
# the resulting dicts "main" key will be the leading character of the alternative location name 
# within this map will be a mapping to the "leading" location name, e.g., 'Corfu' would be mapped to 'Korfu'
# lastLetter=r[0].lower()
osmNames=pickleDecompress('./picklez/osm_names.picklez')
osmAlternativesSorted=dict()
for leadLoc in osmNames:
    #print leadLoc
    for v in osmNames[leadLoc].values():
        leadingLetter=v[0].lower()
        if not leadingLetter in osmAlternativesSorted:
            osmAlternativesSorted[leadingLetter]=dict()
        else:
            osmAlternativesSorted[leadingLetter][v]=leadLoc
# Out:
# [2017-02-23 09:38:05.227255]	Depickling from './picklez/osm_names.picklez'
# [2017-02-23 09:38:05.281364]	Depickling done.

# %%
# osmNames(key): alle alternativen titel in der Form names[loc][u'name']:
# u'Ems': {u'name:nl': u'Eems', u'name': u'Ems', u'name:de': u'Ems', u'name:la': u'Amisia'...
# latLng(key)[lat|lng]: latitude/longitude pro key

# %% [markdown]
# # Service Functions
# to avoid problems with JSON access you should load the web pages from your own HTTP server

# %%
if launchHTTPServer:
    # the resulting HTTP service will listen on port 8000 and open the main page in the browser
    import http_server
    http_server.load_url('web/index.html')
# Out:
# Webserver working directory: /Users/david/Documents/src/python/CulturalAnalytics
# 127.0.0.1 - - [23/Feb/2017 09:38:18] "GET /web/index.html HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2017 09:38:30] "GET /web/qa/geoviz.html HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Feb/2017 09:38:31] "GET /web/qa/data/layers/global.json HTTP/1.1" 200 -
# Press <RETURN> to stop server
#
# To restart server run:
# python -m http.server 8000
